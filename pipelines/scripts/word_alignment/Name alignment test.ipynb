# %%
from pathlib import Path
from combined import run_fa, run_match_words, combine_df
import os
from match import normalize_word
import pandas as pd
from tqdm import tqdm
from machine.tokenization import LatinWordTokenizer
from typing import Iterable, Tuple, List
import re
tqdm.pandas()
from collections import Counter

pd.set_option('display.max_rows', 500)

# %%
model_df = pd.read_csv('pfs/out/en-NIV84_hbo-MaculaHebTok_combined/en-NIV84_hbo-MaculaHebTok_combined.csv')
# reverse_model_df = pd.read_csv('pfs/out/hbo-MaculaHebTok_en-NIV84_combined/hbo-MaculaHebTok_en-NIV84_combined.csv')
bible_df = pd.read_parquet('../../../../new2old/data/bible_words.parquet')
all_df = pd.read_csv('pfs/out/en-NIV84_hbo-MaculaHebTok_align/in_context.csv')

# %%
vref_file = 'pfs/ref_data/vref.txt'
with open(vref_file) as f:
    vref_data = f.readlines()

# %%
def text_to_words(text: str) -> List[str]:
    """
    Inputs:
        text:   Normally a sentence, or Bible verse
    Outputs:
        A list of words, where the sentence has had its punctuation removed, and words splits into a list of words
    """
    # word_list = re.sub("[^\w\s]", "", text.lower()).split()
    # word_list = text.lower().replace('.', '').replace(',', '').replace('?', '').replace('!', '').split()
    word_tokenizer = LatinWordTokenizer()
    word_list = [normalize_word(word) for word in word_tokenizer.tokenize(text)]
    return word_list


def vref_to_df(file):
    with open(file, 'r') as f:
        bible_data = f.readlines()
    words = [text_to_words(line) for line in bible_data]
    normalized_words = [[normalize_word(word) if word else '' for word in word_list] if word_list else [] for word_list in words]
    df = pd.DataFrame({'text': bible_data, 'words': words, 'normalized_words': normalized_words})
    df = df[df['text'].apply(lambda x: len(x) > 2)]
    df = df[df['text'] != "b'\n'"]
    return df

# %%
NIV84_df = vref_to_df('pfs/text_data/en-NIV84.txt')

# %%
gold_data = pd.read_parquet('../../../../new2old/data/gold_translation_data.parquet')

# %%
model_df.loc[:, 'total_score'] = model_df.apply(lambda row: row['word score'] + 5 * row['jac_sim'], axis=1)

# %%
domains = ['003001001', '003001002','003001004','003001006', '003001007','003001008','003001009','003001010', '003001012' ,'003001013' , '003001014', '003001015' , '003001017']
names_df = bible_df[bible_df['domain_codes'].apply(lambda x: len(set(domains).intersection(set(x))) > 0)]
names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)
# print(names)
english_names = names_df['english'].unique()
english_names = [name.lower() for name in english_names if name is not None]
hebrew_names = names_df['text'].unique()
hebrew_names = [name.lower() for name in hebrew_names if name is not None]
# Out:
# /tmp/ipykernel_259064/892064452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)

# %%
hebrew_matched_names = list(set(hebrew_names).intersection(df[df['jac_sim'] > 0]['target'].unique()))
english_matched_names = list(set(english_names).intersection(df[df['jac_sim'] > 0]['source'].unique()))

# %%
print(len(hebrew_names))
print(len(hebrew_matched_names))
print(len(english_names))
print(len(english_matched_names))
# Out:
# 9744
# 7797
# 2649
# 2155

# %%
names = names_df[names_df['text'].apply(lambda x: x in hebrew_names)]
# print(names_df.iloc[:, :14][names_df['english'].apply(lambda x: x in english_matched_names)])

# %%
names = names[gold_data['NIV84'].apply(lambda x: x is not None)]
# Out:
# /tmp/ipykernel_259064/1840373318.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   names = names[gold_data['NIV84'].apply(lambda x: x is not None)]

# %%
def get_best_match_id(word, candidate_df):
    if candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].shape[0] > 0:
        return candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)]['total_score'].idxmax()
    else:
        return None

# %%
max_rows = -1
counter = Counter()
for index, row in names.iloc[:max_rows, :].iterrows():
    hebrew_source = row['text']
    hebrew_source_normalized = normalize_word(hebrew_source)    
    book = row['book']
    chapter = row['chapter']
    verse = row['verse']
#     word = row['word']
#     subword = row['subword']
    ref = f'{book} {chapter}:{verse}\n'
    vref_index = vref_data.index(ref)
#     print(ref)
#     print(vref_index)
#     candidate_words = set(gold_data[(gold_data['book'] == book) & (gold_data['chapter'] == chapter) & (gold_data['verse'] == verse)]['NIV84'])
#     candidate_words = [word.lower() for word in candidate_words if word is not None]
    candidate_words = set(NIV84_df.loc[vref_index, 'words'])  if vref_index in NIV84_df.index else set([])
    candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]

    candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
#     reverse_candidate_df = reverse_model_df[reverse_model_df['normalized_source'] == hebrew_source_normalized]
    
    pred_index = get_best_match_id(hebrew_source_normalized, candidate_df)
#     reverse_pred_index = get_best_match_id(hebrew_source_normalized, reverse_candidate_df)
#     score = -100
#     reverse_score = -100
#     pred = None
#     reverse_pred = None
    
    if pred_index:
        score = candidate_df.loc[pred_index, 'total_score']
        pred = candidate_df.loc[pred_index, 'source']
        
#     if reverse_pred_index:
#         reverse_score = reverse_candidate_df.loc[reverse_pred_index, 'total_score']
#         reverse_pred = reverse_candidate_df.loc[reverse_pred_index, 'target']
    
#     if score >= reverse_score:
#         overall_pred = pred
#     else:
#         overall_pred = reverse_pred
    

    #     actual = row['english']
    actual = gold_data.loc[index, ['NIV84']].values[0] if index in gold_data.index else None
    actual = actual.lower() if actual else ''
    if len(actual.split()) > 1:
        counter['multiple words'] += 1
    elif pred == None:
        counter['no prediction'] += 1
    else:
        correct = pred == actual or pred == actual.split("ʼ")[0] or actual == pred.split("ʼ")[0] 
        counter.update([correct]) 

    if not correct:
        print(index)
        print(f"actual: {actual}   pred: {pred}")
#         print(candidate_df)
        print(counter)
# Out:
# 1591
# actual: adam   pred: of
# Counter({True: 30, False: 1})
# 1682
# actual: adam   pred: of
# Counter({True: 32, False: 2})
# 2231
# actual: adam   pred: in
# Counter({True: 91, False: 3})
# 2281
# actual: adam   pred: man
# Counter({True: 97, False: 4})
# 2314
# actual: adam   pred: in
# Counter({True: 97, False: 5})
# 2777
# actual: shem   pred: the
# Counter({True: 144, False: 6})
# 3519
# actual: shem   pred: the
# Counter({True: 171, False: 7})
# 4687
# actual: shem   pred: the
# Counter({True: 190, False: 8})
# 4750
# actual: shem   pred: in
# Counter({True: 198, False: 9})
# 4813
# actual: shem   pred: the
# Counter({True: 202, False: 10})
# 4828
# actual: shem   pred: in
# Counter({True: 204, False: 11})
# 4865
# actual: shem   pred: the
# Counter({True: 208, False: 12})
# 4883
# actual: madai   pred: gomer
# Counter({True: 213, False: 13})
# 4935
# actual: put   pred: mizraim
# Counter({True: 229, False: 14})
# 4995
# actual: akkad   pred: erech
# Counter({True: 244, False: 15})
# 5036
# actual: ludites   pred: mizraim
# Counter({True: 253, False: 16})
# 5039
# actual: anamites   pred: ludites
# Counter({True: 253, False: 17})
# 5042
# actual: lehabites   pred: anamites
# Counter({True: 253, False: 18})
# 5048
# actual: pathrusites   pred: casluhites
# Counter({True: 254, False: 19})
# 5101
# actual: zemarites   pred: hamathites
# Counter({True: 267, False: 20})
# 5116
# actual: canaan   pred: the
# Counter({True: 269, False: 21})
# 5132
# actual: admah   pred: zeboiim
# Counter({True: 274, False: 22})
# 5134
# actual: zeboiim   pred: lasha
# Counter({True: 274, False: 23})
# 5154
# actual: shem   pred: the
# Counter({True: 276, False: 24})
# 5167
# actual: shem   pred: the
# Counter({True: 277, False: 25})
# 5223
# actual: almodad   pred: joktan
# Counter({True: 293, False: 26})
# 5226
# actual: sheleph   pred: almodad
# Counter({True: 293, False: 27})
# 5229
# actual: hazarmaveth   pred: sheleph
# Counter({True: 293, False: 28})
# 5253
# actual: ophir   pred: havilah
# Counter({True: 300, False: 29})
# 5272
# actual: sephar   pred: the
# Counter({True: 304, False: 30})
# 5279
# actual: shem   pred: in
# Counter({True: 304, False: 31})
# 5483
# actual: babel   pred: of
# Counter({True: 309, False: 32})
# 5505
# actual: shem   pred: the
# Counter({True: 311, False: 33})
# 5506
# actual: shem   pred: the
# Counter({True: 311, False: 34})
# 5520
# actual: shem   pred: the
# Counter({True: 312, False: 35})
# 6177
# actual: egyptians   pred: egypt
# Counter({True: 404, False: 36, 'multiple words': 1})
# 6717
# actual: shinab   pred: gomorrah
# Counter({True: 468, False: 37, 'multiple words': 2})
# 6719
# actual: admah   pred: zeboiim
# Counter({True: 468, False: 38, 'multiple words': 2})
# 6721
# actual: shemeber   pred: zeboiim
# Counter({True: 468, False: 39, 'multiple words': 2})
# 6776
# actual: ham   pred: out
# Counter({True: 476, False: 40, 'multiple words': 2})
# 6834
# actual: admah   pred: zeboiim
# Counter({True: 486, False: 41, 'multiple words': 2})
# 6943
# actual: trees   pred: mamre
# Counter({True: 508, False: 42, 'multiple words': 2})
# 7131
# actual: god   pred: to
# Counter({True: 530, False: 43, 'multiple words': 2})
# 7211
# actual: lord   pred: sovereign
# Counter({True: 538, False: 44, 'multiple words': 2})
# 7213
# actual: sovereign   pred: lord
# Counter({True: 538, False: 45, 'multiple words': 2})
# 7337
# actual: lord   pred: sovereign
# Counter({True: 546, False: 46, 'multiple words': 2})
# 7339
# actual: sovereign   pred: lord
# Counter({True: 546, False: 47, 'multiple words': 2})
# 7552
# actual: kenizzites   pred: kenites
# Counter({True: 556, False: 48, 'multiple words': 2})
# 7597
# actual: egyptian   pred: hagar
# Counter({True: 565, False: 49, 'multiple words': 2})
# 7637
# actual: egyptian   pred: hagar
# Counter({True: 573, False: 50, 'multiple words': 2})
# 7863
# actual: god   pred: to
# Counter({True: 590, False: 51, 'multiple words': 2})
# 7939
# actual: god   pred: to
# Counter({True: 601, False: 52, 'multiple words': 2})
# 9182
# actual: them   pred: sodom
# Counter({True: 672, False: 53, 'multiple words': 3})
# 9318
# actual: friends   pred: my
# Counter({True: 675, False: 54, 'multiple words': 3})
# 10066
# actual: moabites   pred: moab
# Counter({True: 703, False: 55, 'multiple words': 3})
# 10652
# actual: egyptian   pred: hagar
# Counter({True: 754, False: 56, 'multiple words': 3})
# 11698
# actual: pildash   pred: jidlaph
# Counter({True: 827, False: 57, 'multiple words': 3})
# 11937
# actual: hittite   pred: hittites
# Counter({True: 854, False: 58, 'multiple words': 3})
# 13732
# actual: hanoch   pred: abida
# Counter({True: 962, False: 59, 'multiple words': 3})
# 13734
# actual: abida   pred: eldaah
# Counter({True: 962, False: 60, 'multiple words': 3})
# 13881
# actual: egyptian   pred: hagar
# Counter({True: 985, False: 61, 'multiple words': 3})
# 13974
# actual: asshur   pred: to
# Counter({True: 1005, False: 62, 'multiple words': 3})
# 14837
# actual: ahuzzath   pred: the
# Counter({True: 1091, False: 63, 'multiple words': 4})
# 14980
# actual: shibah   pred: the
# Counter({True: 1097, False: 64, 'multiple words': 4})
# 15003
# actual: judith   pred: beeri
# Counter({True: 1099, False: 65, 'multiple words': 4})
# 16092
# actual: canaanite   pred: do
# Counter({True: 1167, False: 66, 'multiple words': 4})
# 16095
# actual: paddan aram   pred: paddan
# Counter({True: 1167, False: 66, 'multiple words': 5})
# 16221
# actual: canaanite   pred: do
# Counter({True: 1184, False: 67, 'multiple words': 7})
# 16257
# actual: mahalath   pred: nebaioth
# Counter({True: 1189, False: 68, 'multiple words': 8})
# 17520
# actual: asher   pred: the
# Counter({True: 1293, False: 69, 'multiple words': 9})
# 21516
# actual: god   pred: to
# Counter({True: 1522, False: 70, 'multiple words': 13})
# 21776
# actual: asher   pred: the
# Counter({True: 1558, False: 71, 'multiple words': 13})
# 22179
# actual: ezer   pred: dishan
# Counter({True: 1672, False: 72, 'multiple words': 14})
# 22195
# actual: hori   pred: lotan
# Counter({True: 1677, False: 73, 'multiple words': 14})
# 22255
# actual: hemdan   pred: dishon
# Counter({True: 1696, False: 74, 'multiple words': 14})
# 22257
# actual: eshban   pred: hemdan
# Counter({True: 1696, False: 75, 'multiple words': 14})
# 22291
# actual: ezer   pred: dishan
# Counter({True: 1711, False: 76, 'multiple words': 14})
# 22319
# actual: israelite   pred: the
# Counter({True: 1715, False: 77, 'multiple words': 14})
# 22351
# actual: husham   pred: temanites
# Counter({True: 1724, False: 78, 'multiple words': 14})
# 22365
# actual: bedad   pred: midian
# Counter({True: 1727, False: 79, 'multiple words': 14})
# 22421
# actual: hadad   pred: of
# Counter({True: 1740, False: 80, 'multiple words': 14})
# 22431
# actual: mehetabel   pred: matred
# Counter({True: 1741, False: 81, 'multiple words': 14})
# 22470
# actual: magdiel   pred: iram
# Counter({True: 1752, False: 82, 'multiple words': 14})
# 22486
# actual: edomites   pred: edom
# Counter({True: 1755, False: 83, 'multiple words': 14})
# 23305
# actual: adullam   pred: hirah
# Counter({True: 1793, False: 84, 'multiple words': 14})
# 23517
# actual: adullamite   pred: hirah
# Counter({True: 1820, False: 85, 'multiple words': 14})
# 23555
# actual: enaim   pred: a
# Counter({True: 1823, False: 86, 'multiple words': 14})
# 25074
# actual: riverbank   pred: nile
# Counter({True: 1892, False: 87, 'multiple words': 14})
# 25911
# actual: on   pred: potiphera
# Counter({True: 1944, False: 88, 'multiple words': 14})
# 26119
# actual: egyptians   pred: egypt
# Counter({True: 1966, False: 89, 'multiple words': 14})
# 26148
# actual: egyptians   pred: egypt
# Counter({True: 1968, False: 90, 'multiple words': 14})
# 29478
# actual: shuni   pred: haggi
# Counter({True: 2149, False: 91, 'multiple words': 15})
# 29480
# actual: ezbon   pred: shuni
# Counter({True: 2149, False: 92, 'multiple words': 15})
# 29488
# actual: asher   pred: the
# Counter({True: 2152, False: 93, 'multiple words': 15})
# 29548
# actual: on   pred: potiphera
# Counter({True: 2171, False: 94, 'multiple words': 15})
# 29567
# actual: rosh   pred: the
# Counter({True: 2180, False: 95, 'multiple words': 15})
# 30363
# actual: egyptians   pred: egypt
# Counter({True: 2260, False: 96, 'multiple words': 15})
# 30717
# actual: god   pred: to
# Counter({True: 2290, False: 97, 'multiple words': 15})
# 31396
# actual: it   pred: obedience
# Counter({True: 2348, False: 98, 'multiple words': 15})
# 31439
# actual: seashore   pred: the
# Counter({True: 2349, False: 99, 'multiple words': 15})
# 32387
# actual: asher   pred: and
# Counter({True: 2440, False: 100, 'multiple words': 18})
# 32506
# actual: pithom   pred: store
# Counter({True: 2449, False: 101, 'multiple words': 18})
# 32583
# actual: puah   pred: shiphrah
# Counter({True: 2454, False: 102, 'multiple words': 18})
# 32591
# actual: hebrew   pred: childbirth
# Counter({True: 2454, False: 103, 'multiple words': 18})
# 32743
# actual: levite   pred: levi
# Counter({True: 2462, False: 104, 'multiple words': 18})
# 32829
# actual: river   pred: nile
# Counter({True: 2465, False: 105, 'multiple words': 18})
# 32868
# actual: hebrew   pred: the
# Counter({True: 2465, False: 106, 'multiple words': 18})
# 33788
# actual: hebrews   pred: lord
# Counter({True: 2554, False: 107, 'multiple words': 18})
# 34121
# actual: river   pred: nile
# Counter({True: 2570, False: 108, 'multiple words': 18})
# 34323
# actual: jethro   pred: of
# Counter({True: 2581, False: 109, 'multiple words': 18})
# 34917
# actual: israelite   pred: the
# Counter({True: 2630, False: 110, 'multiple words': 18})
# 34945
# actual: israelite   pred: the
# Counter({True: 2631, False: 111, 'multiple words': 18})
# 35011
# actual: israelite   pred: the
# Counter({True: 2633, False: 112, 'multiple words': 18})
# 35170
# actual: god   pred: to
# Counter({True: 2650, False: 113, 'multiple words': 18})
# 35618
# actual: levite   pred: were
# Counter({True: 2746, False: 114, 'multiple words': 18})
# 35796
# actual: egyptians   pred: egypt
# Counter({True: 2777, False: 115, 'multiple words': 18})
# 36080
# actual: river   pred: nile
# Counter({True: 2812, False: 116, 'multiple words': 18})
# 36196
# actual: river   pred: nile
# Counter({True: 2822, False: 117, 'multiple words': 18})
# 36200
# actual: egyptians   pred: egypt
# Counter({True: 2822, False: 118, 'multiple words': 18})
# 36270
# actual: river   pred: nile
# Counter({True: 2828, False: 119, 'multiple words': 18})
# 37147
# actual: israelites   pred: israel
# Counter({True: 2909, False: 120, 'multiple words': 18})
# 38420
# actual: sea   pred: west
# Counter({True: 3008, False: 121, 'multiple words': 18})
# 38694
# actual: egyptians   pred: egypt
# Counter({True: 3034, False: 122, 'multiple words': 18})
# 38777
# actual: israelites   pred: israel
# Counter({True: 3043, False: 123, 'multiple words': 18})
# 39564
# actual: egyptians   pred: egypt
# Counter({True: 3080, False: 124, 'multiple words': 18})
# 39638
# actual: egyptians   pred: egypt
# Counter({True: 3088, False: 125, 'multiple words': 18})
# 39836
# actual: israelite   pred: the
# Counter({True: 3105, False: 126, 'multiple words': 18})
# 40821
# actual: egyptians   pred: egypt
# Counter({True: 3195, False: 127, 'multiple words': 18})
# 40828
# actual: egyptians   pred: egypt
# Counter({True: 3195, False: 128, 'multiple words': 18})
# 41138
# actual: egyptians   pred: egypt
# Counter({True: 3218, False: 129, 'multiple words': 18})
# 41349
# actual: lord   pred: the
# Counter({True: 3243, False: 130, 'multiple words': 18})
# 41819
# actual: israelite   pred: the
# Counter({True: 3279, False: 131, 'multiple words': 18})
# 42057
# actual: israelite   pred: the
# Counter({True: 3299, False: 132, 'multiple words': 18})
# 42076
# actual: israelite   pred: the
# Counter({True: 3301, False: 133, 'multiple words': 18})
# 42655
# actual: israelite   pred: the
# Counter({True: 3335, False: 134, 'multiple words': 18})
# 42658
# actual: sin   pred: traveling
# Counter({True: 3335, False: 135, 'multiple words': 18})
# 42979
# actual: amalekite   pred: overcame
# Counter({True: 3374, False: 136, 'multiple words': 18})
# 43030
# actual: lord   pred: the
# Counter({True: 3380, False: 137, 'multiple words': 18})
# 46670
# actual: israelite   pred: the
# Counter({True: 3526, False: 138, 'multiple words': 18})
# 52359
# actual: sound   pred: moses
# Counter({True: 3705, False: 139, 'multiple words': 18})
# 54164
# actual: israelite   pred: the
# Counter({True: 3808, False: 140, 'multiple words': 18})
# 54222
# actual: israelite   pred: the
# Counter({True: 3811, False: 141, 'multiple words': 18})
# 54509
# actual: israelite   pred: the
# Counter({True: 3816, False: 142, 'multiple words': 18})
# 54736
# actual: israelite   pred: the
# Counter({True: 3822, False: 143, 'multiple words': 18})
# 59864
# actual: israelite   pred: the
# Counter({True: 3976, False: 144, 'multiple words': 18})
# 69062
# actual: israelite   pred: the
# Counter({True: 4224, False: 145, 'multiple words': 18})
# 69886
# actual: israelite   pred: the
# Counter({True: 4252, False: 146, 'multiple words': 18})
# 70030
# actual: israelite   pred: to
# Counter({True: 4259, False: 147, 'multiple words': 18})
# 70073
# actual: israelite   pred: from
# Counter({True: 4260, False: 148, 'multiple words': 18})
# 70166
# actual: israelite   pred: the
# Counter({True: 4261, False: 149, 'multiple words': 18})
# 71444
# actual: israelites   pred: israel
# Counter({True: 4301, False: 150, 'multiple words': 18})
# 71450
# actual: israelite   pred: israel
# Counter({True: 4301, False: 151, 'multiple words': 18})
# 71575
# actual: molech   pred: in
# Counter({True: 4302, False: 152, 'multiple words': 18})
# 72905
# actual: israelites   pred: israel
# Counter({True: 4339, False: 153, 'multiple words': 18})
# 72914
# actual: israelite   pred: israel
# Counter({True: 4339, False: 154, 'multiple words': 18})
# 74266
# actual: israelite   pred: lord
# Counter({True: 4414, False: 155, 'multiple words': 18})
# 74294
# actual: israelite   pred: blasphemed
# Counter({True: 4417, False: 156, 'multiple words': 18})
# 74312
# actual: dibri   pred: the
# Counter({True: 4419, False: 157, 'multiple words': 18})
# 75183
# actual: levitical   pred: levites
# Counter({True: 4438, False: 158, 'multiple words': 18})
# 76520
# actual: jacob   pred: egypt
# Counter({True: 4453, False: 159, 'multiple words': 18})
# 77407
# actual: israelite   pred: the
# Counter({True: 4489, False: 160, 'multiple words': 18})
# 77518
# actual: asher   pred: of
# Counter({True: 4519, False: 161, 'multiple words': 18})
# 77994
# actual: asher   pred: the
# Counter({True: 4555, False: 162, 'multiple words': 18})
# 78021
# actual: asher   pred: the
# Counter({True: 4555, False: 163, 'multiple words': 18})
# 78091
# actual: israelites   pred: israel
# Counter({True: 4560, False: 164, 'multiple words': 18})
# 78126
# actual: levi   pred: were
# Counter({True: 4561, False: 165, 'multiple words': 18})
# 78258
# actual: israelite   pred: the
# Counter({True: 4570, False: 166, 'multiple words': 18})
# 78679
# actual: asher   pred: the
# Counter({True: 4622, False: 167, 'multiple words': 18})
# 78684
# actual: asher   pred: the
# Counter({True: 4622, False: 168, 'multiple words': 18})
# 79020
# actual: israelite   pred: israelites
# Counter({True: 4668, False: 169, 'multiple words': 18})
# 79157
# actual: libnites   pred: gershon
# Counter({True: 4695, False: 170, 'multiple words': 18})
# 79362
# actual: mahlites   pred: merari
# Counter({True: 4715, False: 171, 'multiple words': 18})
# 79370
# actual: merarite   pred: merari
# Counter({True: 4716, False: 172, 'multiple words': 18})
# 79517
# actual: israelite   pred: the
# Counter({True: 4730, False: 173, 'multiple words': 18})
# 83184
# actual: asher   pred: the
# Counter({True: 4913, False: 174, 'multiple words': 18})
# 83358
# actual: israelite   pred: the
# Counter({True: 4922, False: 175, 'multiple words': 18})
# 83664
# actual: israelite   pred: the
# Counter({True: 4936, False: 176, 'multiple words': 18})
# 83806
# actual: israelite   pred: israelites
# Counter({True: 4955, False: 177, 'multiple words': 18})
# 83907
# actual: israelite   pred: the
# Counter({True: 4966, False: 178, 'multiple words': 18})
# 84871
# actual: helon   pred: zebulun
# Counter({True: 5029, False: 179, 'multiple words': 18})
# 84923
# actual: kohathites   pred: set
# Counter({True: 5039, False: 180, 'multiple words': 18})
# 84969
# actual: gideoni   pred: benjamin
# Counter({True: 5046, False: 181, 'multiple words': 18})
# 84996
# actual: asher   pred: the
# Counter({True: 5049, False: 182, 'multiple words': 18})
# 85012
# actual: israelite   pred: the
# Counter({True: 5054, False: 183, 'multiple words': 18})
# 85026
# actual: midianite   pred: reuel
# Counter({True: 5057, False: 184, 'multiple words': 18})
# 85838
# actual: medad   pred: eldad
# Counter({True: 5097, False: 185, 'multiple words': 18})
# 85873
# actual: medad   pred: prophesying
# Counter({True: 5099, False: 186, 'multiple words': 18})
# 86467
# actual: asher   pred: the
# Counter({True: 5179, False: 187, 'multiple words': 18})
# 86689
# actual: eshcol   pred: cluster
# Counter({True: 5205, False: 188, 'multiple words': 19})
# 86724
# actual: israelite   pred: the
# Counter({True: 5208, False: 189, 'multiple words': 19})
# 87038
# actual: israelite   pred: the
# Counter({True: 5234, False: 190, 'multiple words': 19})
# 87062
# actual: israelite   pred: the
# Counter({True: 5238, False: 191, 'multiple words': 19})
# 88365
# actual: israelite   pred: the
# Counter({True: 5313, False: 192, 'multiple words': 19})
# 88397
# actual: israelite   pred: the
# Counter({True: 5314, False: 193, 'multiple words': 19})
# 88457
# actual: israelite   pred: the
# Counter({True: 5315, False: 194, 'multiple words': 19})
# 88747
# actual: on   pred: eliab
# Counter({True: 5338, False: 195, 'multiple words': 19})
# 88761
# actual: israelite   pred: the
# Counter({True: 5341, False: 196, 'multiple words': 19})
# 88908
# actual: israelite   pred: israel
# Counter({True: 5356, False: 197, 'multiple words': 19})
# 89616
# actual: israelite   pred: the
# Counter({True: 5412, False: 198, 'multiple words': 19})
# 91087
# actual: israelite   pred: the
# Counter({True: 5503, False: 199, 'multiple words': 19})
# 91453
# actual: israelite   pred: the
# Counter({True: 5507, False: 200, 'multiple words': 19})
# 91792
# actual: egyptians   pred: egypt
# Counter({True: 5538, False: 201, 'multiple words': 19})
# 91942
# actual: israelite   pred: the
# Counter({True: 5547, False: 202, 'multiple words': 19})
# 91946
# actual: hor   pred: mount
# Counter({True: 5547, False: 203, 'multiple words': 19})
# 91958
# actual: hor   pred: mount
# Counter({True: 5550, False: 204, 'multiple words': 19})
# 92004
# actual: hor   pred: mount
# Counter({True: 5555, False: 205, 'multiple words': 19})
# 92037
# actual: hor   pred: mount
# Counter({True: 5560, False: 206, 'multiple words': 19})
# 92112
# actual: israelites   pred: israel
# Counter({True: 5573, False: 207, 'multiple words': 19})
# 92170
# actual: hor   pred: mount
# Counter({True: 5579, False: 208, 'multiple words': 19})
# 92174
# actual: red sea   pred: sea
# Counter({True: 5579, False: 208, 'multiple words': 20})
# 92385
# actual: amorite   pred: amorites
# Counter({True: 5597, False: 209, 'multiple words': 20})
# 92429
# actual: beer   pred: well
# Counter({True: 5608, False: 210, 'multiple words': 20})
# 92873
# actual: moabites   pred: moab
# Counter({True: 5677, False: 211, 'multiple words': 20})
# 92912
# actual: pethor   pred: beor
# Counter({True: 5683, False: 212, 'multiple words': 20})
# 93029
# actual: moabite   pred: the
# Counter({True: 5690, False: 213, 'multiple words': 20})
# 93136
# actual: moabite   pred: the
# Counter({True: 5701, False: 214, 'multiple words': 20})
# 93686
# actual: moabite   pred: the
# Counter({True: 5739, False: 215, 'multiple words': 20})
# 94822
# actual: asshur   pred: to
# Counter({True: 5840, False: 216, 'multiple words': 20})
# 94862
# actual: moabite   pred: the
# Counter({True: 5843, False: 217, 'multiple words': 20})
# 94940
# actual: israelite   pred: israel
# Counter({True: 5852, False: 218, 'multiple words': 20})
# 94991
# actual: israelite   pred: israelites
# Counter({True: 5858, False: 219, 'multiple words': 20})
# 95002
# actual: israelite   pred: israelites
# Counter({True: 5858, False: 220, 'multiple words': 20})
# 95108
# actual: israelite   pred: the
# Counter({True: 5866, False: 221, 'multiple words': 20})
# 95216
# actual: israelite   pred: israel
# Counter({True: 5884, False: 222, 'multiple words': 20})
# 95294
# actual: carmite   pred: carmi
# Counter({True: 5903, False: 223, 'multiple words': 20})
# 95298
# actual: reuben   pred: the
# Counter({True: 5903, False: 224, 'multiple words': 20})
# 95415
# actual: simeon   pred: clans
# Counter({True: 5928, False: 225, 'multiple words': 20})
# 95436
# actual: haggite   pred: haggi
# Counter({True: 5932, False: 226, 'multiple words': 20})
# 95438
# actual: shuni   pred: haggi
# Counter({True: 5932, False: 227, 'multiple words': 20})
# 95441
# actual: shunite   pred: haggi
# Counter({True: 5932, False: 228, 'multiple words': 20})
# 95443
# actual: ozni   pred: oznite
# Counter({True: 5932, False: 229, 'multiple words': 20})
# 95451
# actual: erite   pred: eri
# Counter({True: 5934, False: 230, 'multiple words': 20})
# 95456
# actual: arodite   pred: arodi
# Counter({True: 5935, False: 231, 'multiple words': 20})
# 95461
# actual: arelite   pred: areli
# Counter({True: 5936, False: 232, 'multiple words': 20})
# 95596
# actual: zebulun   pred: jahleelite
# Counter({True: 5971, False: 233, 'multiple words': 20})
# 95680
# actual: noah   pred: mahlah
# Counter({True: 5997, False: 234, 'multiple words': 20})
# 95841
# actual: asher   pred: the
# Counter({True: 6036, False: 235, 'multiple words': 20})
# 95849
# actual: imnite   pred: imnah
# Counter({True: 6037, False: 236, 'multiple words': 20})
# 95854
# actual: ishvite   pred: ishvi
# Counter({True: 6038, False: 237, 'multiple words': 20})
# 95881
# actual: asher   pred: the
# Counter({True: 6047, False: 238, 'multiple words': 20})
# 95906
# actual: gunite   pred: guni
# Counter({True: 6051, False: 239, 'multiple words': 20})
# 96027
# actual: merarite   pred: merari
# Counter({True: 6063, False: 240, 'multiple words': 20})
# 96039
# actual: hebronite   pred: clan
# Counter({True: 6066, False: 241, 'multiple words': 20})
# 96060
# actual: levites   pred: levi
# Counter({True: 6073, False: 242, 'multiple words': 20})
# 96230
# actual: noah   pred: mahlah
# Counter({True: 6111, False: 243, 'multiple words': 20})
# 96513
# actual: kadesh   pred: holy
# Counter({True: 6132, False: 244, 'multiple words': 20})
# 96625
# actual: israelite   pred: the
# Counter({True: 6142, False: 245, 'multiple words': 20})
# 98541
# actual: evi   pred: rekem
# Counter({True: 6201, False: 246, 'multiple words': 20})
# 98553
# actual: reba   pred: hur
# Counter({True: 6204, False: 247, 'multiple words': 20})
# 98641
# actual: israelite   pred: the
# Counter({True: 6211, False: 248, 'multiple words': 20})
# 99825
# actual: israelite   pred: to
# Counter({True: 6301, False: 249, 'multiple words': 20})
# 100038
# actual: israelite   pred: the
# Counter({True: 6320, False: 250, 'multiple words': 20})
# 100270
# actual: makirites   pred: gilead
# Counter({True: 6356, False: 251, 'multiple words': 20})
# 100742
# actual: hor   pred: mount
# Counter({True: 6426, False: 252, 'multiple words': 21})
# 100755
# actual: hor   pred: mount
# Counter({True: 6428, False: 253, 'multiple words': 21})
# 100798
# actual: hor   pred: mount
# Counter({True: 6432, False: 254, 'multiple words': 21})
# 100823
# actual: hor   pred: mount
# Counter({True: 6436, False: 255, 'multiple words': 21})
# 101228
# actual: northern   pred: the
# Counter({True: 6479, False: 256, 'multiple words': 21})
# 101237
# actual: hor   pred: mount
# Counter({True: 6480, False: 257, 'multiple words': 21})
# 101241
# actual: hor   pred: mount
# Counter({True: 6480, False: 258, 'multiple words': 21})
# 101368
# actual: reuben   pred: the
# Counter({True: 6495, False: 259, 'multiple words': 21})
# 101377
# actual: gad   pred: manasseh
# Counter({True: 6495, False: 260, 'multiple words': 21})
# 101462
# actual: shemuel   pred: simeon
# Counter({True: 6507, False: 261, 'multiple words': 21})
# 101468
# actual: elidad   pred: kislon
# Counter({True: 6509, False: 262, 'multiple words': 21})
# 101470
# actual: kislon   pred: benjamin
# Counter({True: 6509, False: 263, 'multiple words': 21})
# 101479
# actual: jogli   pred: dan
# Counter({True: 6511, False: 264, 'multiple words': 21})
# 101499
# actual: shiphtan   pred: joseph
# Counter({True: 6517, False: 265, 'multiple words': 21})
# 101508
# actual: parnach   pred: zebulun
# Counter({True: 6519, False: 266, 'multiple words': 21})
# 101517
# actual: azzan   pred: issachar
# Counter({True: 6521, False: 267, 'multiple words': 21})
# 101522
# actual: asher   pred: the
# Counter({True: 6521, False: 268, 'multiple words': 21})
# 101524
# actual: ahihud   pred: tribe
# Counter({True: 6521, False: 269, 'multiple words': 21})
# 101526
# actual: shelomi   pred: asher
# Counter({True: 6521, False: 270, 'multiple words': 21})
# 101533
# actual: pedahel   pred: tribe
# Counter({True: 6522, False: 271, 'multiple words': 21})
# 102345
# actual: israelite   pred: the
# Counter({True: 6549, False: 272, 'multiple words': 21})
# 102389
# actual: israelite   pred: the
# Counter({True: 6552, False: 273, 'multiple words': 21})
# 102510
# actual: israelite   pred: israel
# Counter({True: 6560, False: 274, 'multiple words': 21})
# 102519
# actual: israelite   pred: the
# Counter({True: 6560, False: 275, 'multiple words': 21})
# 102533
# actual: israelite   pred: the
# Counter({True: 6560, False: 276, 'multiple words': 21})
# 102555
# actual: israelite   pred: the
# Counter({True: 6560, False: 277, 'multiple words': 21})
# 102575
# actual: noah   pred: mahlah
# Counter({True: 6567, False: 278, 'multiple words': 21})
# 102643
# actual: suph   pred: the
# Counter({True: 6579, False: 279, 'multiple words': 21})
# 102648
# actual: tophel   pred: paran
# Counter({True: 6580, False: 280, 'multiple words': 21})
# 102716
# actual: ashtaroth   pred: reigned
# Counter({True: 6592, False: 281, 'multiple words': 21})
# 103950
# actual: moabites   pred: rephaites
# Counter({True: 6665, False: 282, 'multiple words': 21})
# 104336
# actual: moabites   pred: seir
# Counter({True: 6699, False: 283, 'multiple words': 21})
# 104893
# actual: maacathites   pred: geshurites
# Counter({True: 6764, False: 284, 'multiple words': 21})
# 105069
# actual: joshua   pred: jordan
# Counter({True: 6782, False: 285, 'multiple words': 21})
# 105130
# actual: lord   pred: sovereign
# Counter({True: 6786, False: 286, 'multiple words': 21})
# 105132
# actual: sovereign   pred: lord
# Counter({True: 6786, False: 287, 'multiple words': 21})
# 109789
# actual: lord   pred: sovereign
# Counter({True: 7009, False: 288, 'multiple words': 21})
# 109791
# actual: sovereign   pred: lord
# Counter({True: 7009, False: 289, 'multiple words': 21})
# 110516
# actual: egyptian   pred: brought
# Counter({True: 7049, False: 290, 'multiple words': 21})
# 110574
# actual: reubenite   pred: the
# Counter({True: 7054, False: 291, 'multiple words': 21})
# 111212
# actual: moreh   pred: vicinity
# Counter({True: 7080, False: 292, 'multiple words': 22})
# 117426
# actual: israelite   pred: the
# Counter({True: 7257, False: 293, 'multiple words': 22})
# 117809
# actual: pethor   pred: naharaim
# Counter({True: 7266, False: 294, 'multiple words': 22})
# 118067
# actual: israelite   pred: to
# Counter({True: 7273, False: 295, 'multiple words': 22})
# 120047
# actual: asher   pred: to
# Counter({True: 7356, False: 296, 'multiple words': 22})
# 122073
# actual: manasseh   pred: bashan
# Counter({True: 7419, False: 297, 'multiple words': 22})
# 122480
# actual: admah   pred: zeboiim
# Counter({True: 7436, False: 298, 'multiple words': 22})
# 124804
# actual: joshua   pred: of
# Counter({True: 7524, False: 299, 'multiple words': 22})
# 124954
# actual: hor   pred: mountain
# Counter({True: 7537, False: 300, 'multiple words': 22})
# 125418
# actual: lake   pred: the
# Counter({True: 7581, False: 301, 'multiple words': 22})
# 125425
# actual: asher   pred: of
# Counter({True: 7581, False: 302, 'multiple words': 22})
# 125430
# actual: asher   pred: of
# Counter({True: 7581, False: 303, 'multiple words': 22})
# 125883
# actual: hittite   pred: euphrates
# Counter({True: 7643, False: 304, 'multiple words': 23})
# 127369
# actual: completely   pred: salt
# Counter({True: 7719, False: 305, 'multiple words': 23})
# 127838
# actual: set   pred: jordan
# Counter({True: 7764, False: 306, 'multiple words': 23})
# 128022
# actual: coast   pred: west
# Counter({True: 7780, False: 307, 'multiple words': 23})
# 129214
# actual: israelites   pred: israel
# Counter({True: 7847, False: 308, 'multiple words': 23})
# 129405
# actual: lord   pred: sovereign
# Counter({True: 7865, False: 309, 'multiple words': 24})
# 129407
# actual: sovereign   pred: lord
# Counter({True: 7865, False: 310, 'multiple words': 24})
# 129790
# actual: a   pred: from
# Counter({True: 7903, False: 311, 'multiple words': 24})
# 130636
# actual: israelites   pred: israel
# Counter({True: 7952, False: 312, 'multiple words': 25})
# 130708
# actual: israelites   pred: israel
# Counter({True: 7956, False: 313, 'multiple words': 25})
# 131173
# actual: perhaps   pred: hivites
# Counter({True: 8006, False: 314, 'multiple words': 25})
# 131437
# actual: israelites   pred: israel
# Counter({True: 8023, False: 315, 'multiple words': 25})
# 132017
# actual: israelites   pred: israel
# Counter({True: 8078, False: 316, 'multiple words': 25})
# 132798
# actual: debir   pred: the
# Counter({True: 8150, False: 317, 'multiple words': 25})
# 132933
# actual: northern   pred: the
# Counter({True: 8172, False: 318, 'multiple words': 27})
# 133465
# actual: debir   pred: the
# Counter({True: 8233, False: 319, 'multiple words': 28})
# 133490
# actual: israelite   pred: and
# Counter({True: 8238, False: 320, 'multiple words': 28})
# 133664
# actual: maacah   pred: geshur
# Counter({True: 8270, False: 321, 'multiple words': 29})
# 133711
# actual: israelites   pred: israel
# Counter({True: 8280, False: 322, 'multiple words': 29})
# 133814
# actual: debir   pred: the
# Counter({True: 8299, False: 323, 'multiple words': 29})
# 133887
# actual: goyim   pred: the
# Counter({True: 8318, False: 324, 'multiple words': 29})
# 133960
# actual: gaza   pred: philistine
# Counter({True: 8328, False: 325, 'multiple words': 30})
# 133963
# actual: ashdod   pred: philistine
# Counter({True: 8328, False: 326, 'multiple words': 30})
# 133965
# actual: ashkelon   pred: philistine
# Counter({True: 8328, False: 327, 'multiple words': 30})
# 133967
# actual: gath   pred: philistine
# Counter({True: 8328, False: 328, 'multiple words': 30})
# 133970
# actual: ekron   pred: philistine
# Counter({True: 8328, False: 329, 'multiple words': 30})
# 134032
# actual: israelites   pred: israel
# Counter({True: 8338, False: 330, 'multiple words': 30})
# 134139
# actual: maacah   pred: geshur
# Counter({True: 8355, False: 331, 'multiple words': 31})
# 134187
# actual: maacah   pred: geshur
# Counter({True: 8363, False: 332, 'multiple words': 32})
# 134329
# actual: evi   pred: rekem
# Counter({True: 8387, False: 333, 'multiple words': 32})
# 134341
# actual: reba   pred: hur
# Counter({True: 8390, False: 334, 'multiple words': 32})
# 134412
# actual: ammonite   pred: rabbah
# Counter({True: 8401, False: 335, 'multiple words': 32})
# 134446
# actual: zaphon   pred: the
# Counter({True: 8409, False: 336, 'multiple words': 32})
# 134584
# actual: israelites   pred: israel
# Counter({True: 8438, False: 337, 'multiple words': 32})
# 135077
# actual: azmon   pred: passed
# Counter({True: 8495, False: 338, 'multiple words': 32})
# 135146
# actual: debir   pred: the
# Counter({True: 8505, False: 339, 'multiple words': 32})
# 135219
# actual: northern   pred: the
# Counter({True: 8513, False: 340, 'multiple words': 33})
# 135357
# actual: anakites   pred: anak
# Counter({True: 8537, False: 341, 'multiple words': 33})
# 135375
# actual: debir   pred: the
# Counter({True: 8541, False: 342, 'multiple words': 33})
# 135682
# actual: mareshah   pred: aczib
# Counter({True: 8618, False: 343, 'multiple words': 33})
# 135736
# actual: jattir   pred: shamir
# Counter({True: 8627, False: 344, 'multiple words': 33})
# 135757
# actual: giloh   pred: their
# Counter({True: 8635, False: 345, 'multiple words': 33})
# 135784
# actual: zior   pred: hebron
# Counter({True: 8640, False: 346, 'multiple words': 33})
# 135823
# actual: eltekon   pred: maarath
# Counter({True: 8652, False: 347, 'multiple words': 33})
# 135847
# actual: middin   pred: arabah
# Counter({True: 8653, False: 348, 'multiple words': 33})
# 135933
# actual: westward   pred: sea
# Counter({True: 8667, False: 349, 'multiple words': 33})
# 136039
# actual: sea   pred: west
# Counter({True: 8684, False: 350, 'multiple words': 33})
# 136045
# actual: ephraimites   pred: the
# Counter({True: 8684, False: 351, 'multiple words': 33})
# 136056
# actual: ephraimites   pred: the
# Counter({True: 8684, False: 352, 'multiple words': 33})
# 136061
# actual: manassites   pred: of
# Counter({True: 8684, False: 353, 'multiple words': 33})
# 136112
# actual: gileadites   pred: gilead
# Counter({True: 8691, False: 354, 'multiple words': 34})
# 136143
# actual: helek   pred: allotment
# Counter({True: 8695, False: 355, 'multiple words': 34})
# 136196
# actual: noah   pred: mahlah
# Counter({True: 8707, False: 356, 'multiple words': 34})
# 136291
# actual: asher   pred: the
# Counter({True: 8723, False: 357, 'multiple words': 34})
# 136321
# actual: ephraimites   pred: the
# Counter({True: 8729, False: 358, 'multiple words': 34})
# 136374
# actual: asher   pred: the
# Counter({True: 8740, False: 359, 'multiple words': 35})
# 136392
# actual: asher   pred: the
# Counter({True: 8744, False: 360, 'multiple words': 35})
# 136406
# actual: dor   pred: endor
# Counter({True: 8745, False: 361, 'multiple words': 35})
# 136436
# actual: manassites   pred: were
# Counter({True: 8747, False: 362, 'multiple words': 35})
# 136653
# actual: israelite   pred: had
# Counter({True: 8766, False: 363, 'multiple words': 35})
# 136942
# actual: northern   pred: north
# Counter({True: 8793, False: 364, 'multiple words': 35})
# 137137
# actual: northern   pred: salt
# Counter({True: 8809, False: 365, 'multiple words': 36})
# 137143
# actual: south   pred: jordan
# Counter({True: 8809, False: 366, 'multiple words': 36})
# 137211
# actual: towns   pred: geba
# Counter({True: 8817, False: 367, 'multiple words': 36})
# 137296
# actual: sheba   pred: beersheba
# Counter({True: 8831, False: 368, 'multiple words': 37})
# 137324
# actual: sharuhen   pred: ziklag
# Counter({True: 8838, False: 369, 'multiple words': 37})
# 137584
# actual: towns   pred: jordan
# Counter({True: 8875, False: 370, 'multiple words': 38})
# 137613
# actual: asher   pred: the
# Counter({True: 8876, False: 371, 'multiple words': 38})
# 137728
# actual: asher   pred: the
# Counter({True: 8897, False: 372, 'multiple words': 38})
# 137798
# actual: asher   pred: the
# Counter({True: 8906, False: 373, 'multiple words': 38})
# 137815
# actual: zer   pred: ziddim
# Counter({True: 8908, False: 374, 'multiple words': 38})
# 137836
# actual: iron   pred: migdal
# Counter({True: 8916, False: 375, 'multiple words': 38})
# 137931
# actual: danites   pred: dan
# Counter({True: 8933, False: 376, 'multiple words': 38})
# 138454
# actual: simeon   pred: thirteen
# Counter({True: 8981, False: 377, 'multiple words': 38})
# 138500
# actual: asher   pred: the
# Counter({True: 8988, False: 378, 'multiple words': 38})
# 138615
# actual: anak   pred: pastureland
# Counter({True: 9001, False: 379, 'multiple words': 38})
# 138706
# actual: juttah   pred: shemesh
# Counter({True: 9013, False: 380, 'multiple words': 38})
# 138837
# actual: eltekeh   pred: tribe
# Counter({True: 9027, False: 381, 'multiple words': 38})
# 138903
# actual: levite   pred: were
# Counter({True: 9033, False: 382, 'multiple words': 38})
# 138965
# actual: asher   pred: the
# Counter({True: 9039, False: 383, 'multiple words': 39})
# 139061
# actual: kartah   pred: jokneam
# Counter({True: 9051, False: 384, 'multiple words': 39})
# 139476
# actual: west   pred: jordan
# Counter({True: 9089, False: 385, 'multiple words': 39})
# 139639
# actual: israelite   pred: israelites
# Counter({True: 9108, False: 386, 'multiple words': 39})
# 139709
# actual: israelite   pred: israel
# Counter({True: 9118, False: 387, 'multiple words': 39})
# 141000
# actual: egyptians   pred: egypt
# Counter({True: 9233, False: 388, 'multiple words': 39})
# 142331
# actual: hittites   pred: luz
# Counter({True: 9373, False: 389, 'multiple words': 40})
# 142459
# actual: asher   pred: in
# Counter({True: 9390, False: 390, 'multiple words': 40})
# 142464
# actual: acco   pred: in
# Counter({True: 9390, False: 391, 'multiple words': 40})
# 142471
# actual: ahlab   pred: or
# Counter({True: 9391, False: 392, 'multiple words': 40})
# 142480
# actual: aphek   pred: helbah
# Counter({True: 9393, False: 393, 'multiple words': 40})
# 143327
# actual: israelites   pred: israel
# Counter({True: 9473, False: 394, 'multiple words': 41})
# 143406
# actual: israelites   pred: israel
# Counter({True: 9483, False: 395, 'multiple words': 41})
# 144137
# actual: kenite   pred: kenites
# Counter({True: 9564, False: 396, 'multiple words': 41})
# 144315
# actual: jael   pred: went
# Counter({True: 9594, False: 397, 'multiple words': 41})
# 144396
# actual: jael   pred: went
# Counter({True: 9595, False: 398, 'multiple words': 41})
# 144446
# actual: jael   pred: went
# Counter({True: 9598, False: 399, 'multiple words': 41})
# 144778
# actual: asher   pred: the
# Counter({True: 9650, False: 400, 'multiple words': 41})
# 145571
# actual: lord   pred: sovereign
# Counter({True: 9717, False: 401, 'multiple words': 41})
# 145573
# actual: sovereign   pred: lord
# Counter({True: 9717, False: 402, 'multiple words': 41})
# 145868
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9734, False: 403, 'multiple words': 41})
# 145930
# actual: asher   pred: to
# Counter({True: 9742, False: 404, 'multiple words': 41})
# 146087
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9748, False: 405, 'multiple words': 41})
# 146530
# actual: israelite   pred: the
# Counter({True: 9776, False: 406, 'multiple words': 41})
# 146792
# actual: asher   pred: the
# Counter({True: 9791, False: 407, 'multiple words': 41})
# 146850
# actual: midianite   pred: midianites
# Counter({True: 9799, False: 408, 'multiple words': 41})
# 146892
# actual: ephraimites   pred: the
# Counter({True: 9809, False: 409, 'multiple words': 41})
# 146973
# actual: jordan   pred: exhausted
# Counter({True: 9816, False: 410, 'multiple words': 41})
# 147013
# actual: zalmunna   pred: zebah
# Counter({True: 9818, False: 411, 'multiple words': 41})
# 147024
# actual: zalmunna   pred: zebah
# Counter({True: 9821, False: 412, 'multiple words': 41})
# 147047
# actual: zalmunna   pred: zebah
# Counter({True: 9823, False: 413, 'multiple words': 41})
# 147108
# actual: zalmunna   pred: zebah
# Counter({True: 9827, False: 414, 'multiple words': 41})
# 147167
# actual: zalmunna   pred: zebah
# Counter({True: 9831, False: 415, 'multiple words': 41})
# 147235
# actual: zalmunna   pred: zebah
# Counter({True: 9838, False: 416, 'multiple words': 41})
# 147246
# actual: zalmunna   pred: zebah
# Counter({True: 9839, False: 417, 'multiple words': 41})
# 147298
# actual: zalmunna   pred: zebah
# Counter({True: 9842, False: 418, 'multiple words': 41})
# 147338
# actual: jether   pred: only
# Counter({True: 9844, False: 419, 'multiple words': 41})
# 147362
# actual: zalmunna   pred: zebah
# Counter({True: 9845, False: 420, 'multiple words': 41})
# 147580
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9860, False: 421, 'multiple words': 41})
# 147689
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9871, False: 422, 'multiple words': 41})
# 147703
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9873, False: 423, 'multiple words': 41})
# 147743
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9875, False: 424, 'multiple words': 41})
# 147824
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9879, False: 425, 'multiple words': 41})
# 147834
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9880, False: 426, 'multiple words': 41})
# 148076
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9888, False: 427, 'multiple words': 41})
# 148152
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9891, False: 428, 'multiple words': 41})
# 148246
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9904, False: 429, 'multiple words': 41})
# 148304
# actual: ebed   pred: his
# Counter({True: 9909, False: 430, 'multiple words': 41})
# 148349
# actual: ebed   pred: serve
# Counter({True: 9912, False: 431, 'multiple words': 41})
# 148361
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9914, False: 432, 'multiple words': 41})
# 148412
# actual: ebed   pred: he
# Counter({True: 9920, False: 433, 'multiple words': 41})
# 148423
# actual: cover   pred: abimelech
# Counter({True: 9921, False: 434, 'multiple words': 41})
# 148429
# actual: ebed   pred: he
# Counter({True: 9922, False: 435, 'multiple words': 41})
# 148518
# actual: ebed   pred: as
# Counter({True: 9926, False: 436, 'multiple words': 41})
# 148581
# actual: centre   pred: center
# Counter({True: 9931, False: 437, 'multiple words': 41})
# 149052
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9956, False: 438, 'multiple words': 41})
# 149063
# actual: puah   pred: tola
# Counter({True: 9959, False: 439, 'multiple words': 41})
# 149096
# actual: gilead   pred: jair
# Counter({True: 9966, False: 440, 'multiple words': 41})
# 149513
# actual: tob   pred: the
# Counter({True: 10017, False: 441, 'multiple words': 41})
# 149553
# actual: tob   pred: the
# Counter({True: 10021, False: 442, 'multiple words': 41})
# 149719
# actual: ammonite   pred: jephthah
# Counter({True: 10035, False: 443, 'multiple words': 41})
# 149784
# actual: ammonite   pred: jephthah
# Counter({True: 10043, False: 444, 'multiple words': 41})
# 150446
# actual: israelite   pred: the
# Counter({True: 10123, False: 445, 'multiple words': 41})
# 150472
# actual: zaphon   pred: the
# Counter({True: 10127, False: 446, 'multiple words': 41})
# 150585
# actual: gileadites   pred: gilead
# Counter({True: 10136, False: 447, 'multiple words': 41})
# 150590
# actual: gileadites   pred: gilead
# Counter({True: 10136, False: 448, 'multiple words': 41})
# 150592
# actual: ephraimites   pred: ephraim
# Counter({True: 10136, False: 449, 'multiple words': 41})
# 150602
# actual: gileadites   pred: gilead
# Counter({True: 10138, False: 450, 'multiple words': 41})
# 150663
# actual: ephraimites   pred: the
# Counter({True: 10144, False: 451, 'multiple words': 41})
# 150767
# actual: hillel   pred: pirathon
# Counter({True: 10161, False: 452, 'multiple words': 41})
# 150794
# actual: hillel   pred: pirathon
# Counter({True: 10164, False: 453, 'multiple words': 41})
# 150837
# actual: danites   pred: the
# Counter({True: 10172, False: 454, 'multiple words': 41})
# 151006
# actual: lord   pred: beg
# Counter({True: 10178, False: 455, 'multiple words': 41})
# 152136
# actual: timnite   pred: samson
# Counter({True: 10233, False: 456, 'multiple words': 41})
# 153028
# actual: philistines   pred: to
# Counter({True: 10276, False: 457, 'multiple words': 42})
# 153046
# actual: rulers   pred: philistines
# Counter({True: 10276, False: 458, 'multiple words': 42})
# 153127
# actual: gaza   pred: binding
# Counter({True: 10280, False: 459, 'multiple words': 42})
# 153315
# actual: lord   pred: sovereign
# Counter({True: 10290, False: 460, 'multiple words': 42})
# 153317
# actual: sovereign   pred: lord
# Counter({True: 10290, False: 461, 'multiple words': 42})
# 153457
# actual: micah   pred: ephraim
# Counter({True: 10299, False: 462, 'multiple words': 42})
# 153567
# actual: micah   pred: lord
# Counter({True: 10301, False: 463, 'multiple words': 42})
# 153794
# actual: danites   pred: the
# Counter({True: 10319, False: 464, 'multiple words': 42})
# 154090
# actual: danites   pred: men
# Counter({True: 10334, False: 465, 'multiple words': 42})
# 154598
# actual: danites   pred: dan
# Counter({True: 10360, False: 466, 'multiple words': 42})
# 154607
# actual: moses   pred: of
# Counter({True: 10362, False: 467, 'multiple words': 42})
# 154617
# actual: dan   pred: the
# Counter({True: 10362, False: 468, 'multiple words': 42})
# 155093
# actual: benjamites   pred: fields
# Counter({True: 10378, False: 469, 'multiple words': 42})
# 156338
# actual: israelite   pred: israel
# Counter({True: 10458, False: 470, 'multiple words': 42})
# 156385
# actual: israelites   pred: israel
# Counter({True: 10463, False: 471, 'multiple words': 42})
# 156387
# actual: benjamites   pred: benjamin
# Counter({True: 10463, False: 472, 'multiple words': 42})
# 156407
# actual: benjamites   pred: benjamin
# Counter({True: 10463, False: 473, 'multiple words': 42})
# 156548
# actual: israelites   pred: israel
# Counter({True: 10474, False: 474, 'multiple words': 42})
# 156789
# actual: israelites   pred: israel
# Counter({True: 10489, False: 475, 'multiple words': 42})
# 156824
# actual: israelites   pred: israel
# Counter({True: 10493, False: 476, 'multiple words': 42})
# 157062
# actual: benjamite   pred: tribe
# Counter({True: 10508, False: 477, 'multiple words': 47})
# 157336
# actual: mahlon   pred: kilion
# Counter({True: 10526, False: 478, 'multiple words': 47})
# 157368
# actual: moabite   pred: orpah
# Counter({True: 10532, False: 479, 'multiple words': 47})
# 157389
# actual: mahlon   pred: kilion
# Counter({True: 10534, False: 480, 'multiple words': 47})
# 159049
# actual: mahlon   pred: kilion
# Counter({True: 10622, False: 481, 'multiple words': 47})
# 159058
# actual: moabitess   pred: ruth
# Counter({True: 10624, False: 482, 'multiple words': 47})
# 159405
# actual: phinehas   pred: hophni
# Counter({True: 10680, False: 483, 'multiple words': 47})
# 159696
# actual: eli   pred: you
# Counter({True: 10702, False: 484, 'multiple words': 47})
# 160375
# actual: eli   pred: you
# Counter({True: 10747, False: 485, 'multiple words': 47})
# 160609
# actual: israelites   pred: israel
# Counter({True: 10766, False: 486, 'multiple words': 47})
# 160902
# actual: eli   pred: you
# Counter({True: 10780, False: 487, 'multiple words': 47})
# 160933
# actual: eli   pred: you
# Counter({True: 10783, False: 488, 'multiple words': 47})
# 160976
# actual: eli   pred: you
# Counter({True: 10789, False: 489, 'multiple words': 47})
# 160987
# actual: eli   pred: you
# Counter({True: 10789, False: 490, 'multiple words': 47})
# 160996
# actual: eli   pred: you
# Counter({True: 10790, False: 491, 'multiple words': 47})
# 161282
# actual: israelites   pred: israel
# Counter({True: 10823, False: 492, 'multiple words': 47})
# 161440
# actual: hebrew   pred: the
# Counter({True: 10843, False: 493, 'multiple words': 47})
# 161528
# actual: israelites   pred: israel
# Counter({True: 10848, False: 494, 'multiple words': 47})
# 162265
# actual: philistine   pred: philistines
# Counter({True: 10899, False: 495, 'multiple words': 50})
# 162983
# actual: israelites   pred: israel
# Counter({True: 10955, False: 496, 'multiple words': 50})
# 163069
# actual: israelites   pred: israel
# Counter({True: 10965, False: 497, 'multiple words': 50})
# 163130
# actual: israelite   pred: the
# Counter({True: 10973, False: 498, 'multiple words': 50})
# 163704
# actual: kish   pred: name
# Counter({True: 11012, False: 499, 'multiple words': 50})
# 163708
# actual: son   pred: abiel
# Counter({True: 11012, False: 500, 'multiple words': 50})
# 163710
# actual: son   pred: a
# Counter({True: 11012, False: 501, 'multiple words': 50})
# 163712
# actual: son   pred: zeror
# Counter({True: 11012, False: 502, 'multiple words': 50})
# 163714
# actual: benjamin   pred: becorath
# Counter({True: 11012, False: 503, 'multiple words': 50})
# 163716
# actual: benjamin   pred: man
# Counter({True: 11012, False: 504, 'multiple words': 50})
# 163800
# actual: shaalim   pred: shalisha
# Counter({True: 11020, False: 505, 'multiple words': 50})
# 164553
# actual: zelzah   pred: benjamin
# Counter({True: 11059, False: 506, 'multiple words': 50})
# 164594
# actual: great tree   pred: tree
# Counter({True: 11059, False: 506, 'multiple words': 51})
# 165046
# actual: matri   pred: the
# Counter({True: 11088, False: 507, 'multiple words': 51})
# 165050
# actual: son   pred: saul
# Counter({True: 11088, False: 508, 'multiple words': 51})
# 165051
# actual: kish   pred: son
# Counter({True: 11088, False: 509, 'multiple words': 51})
# 165862
# actual: lord   pred: the
# Counter({True: 11157, False: 510, 'multiple words': 53})
# 165888
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 11158, False: 511, 'multiple words': 53})
# 165891
# actual: barak   pred: jephthah
# Counter({True: 11158, False: 512, 'multiple words': 53})
# 166272
# actual: michmash   pred: micmash
# Counter({True: 11188, False: 513, 'multiple words': 53})
# 166300
# actual: philistine   pred: philistines
# Counter({True: 11192, False: 514, 'multiple words': 53})
# 166332
# actual: philistine   pred: philistines
# Counter({True: 11198, False: 515, 'multiple words': 53})
# 166379
# actual: michmash   pred: micmash
# Counter({True: 11203, False: 516, 'multiple words': 53})
# 166529
# actual: michmash   pred: micmash
# Counter({True: 11215, False: 517, 'multiple words': 53})
# 166615
# actual: gibeah   pred: gilgal
# Counter({True: 11224, False: 518, 'multiple words': 53})
# 166653
# actual: michmash   pred: micmash
# Counter({True: 11231, False: 519, 'multiple words': 53})
# 166801
# actual: michmash   pred: micmash
# Counter({True: 11244, False: 520, 'multiple words': 53})
# 166862
# actual: ichabod   pred: ephod
# Counter({True: 11252, False: 521, 'multiple words': 53})
# 166928
# actual: michmash   pred: micmash
# Counter({True: 11262, False: 522, 'multiple words': 53})
# 167056
# actual: philistine   pred: philistines
# Counter({True: 11269, False: 523, 'multiple words': 53})
# 167585
# actual: michmash   pred: micmash
# Counter({True: 11303, False: 524, 'multiple words': 53})
# 167586
# actual: aijalon   pred: micmash
# Counter({True: 11303, False: 525, 'multiple words': 53})
# 168083
# actual: abner   pred: ner
# Counter({True: 11355, False: 526, 'multiple words': 53})
# 170031
# actual: israelites   pred: israel
# Counter({True: 11578, False: 527, 'multiple words': 53})
# 170851
# actual: gath   pred: of
# ...
# 238506
# actual: epher   pred: jalon
# Counter({True: 17821, False: 829, 'multiple words': 106})
# 238525
# actual: judean   pred: jered
# Counter({True: 17826, False: 830, 'multiple words': 106})
# 238528
# actual: jered   pred: the
# Counter({True: 17826, False: 831, 'multiple words': 106})
# 238538
# actual: jekuthiel   pred: soco
# Counter({True: 17829, False: 832, 'multiple words': 106})
# 238575
# actual: ishi   pred: sons
# Counter({True: 17841, False: 833, 'multiple words': 106})
# 238576
# actual: zoheth   pred: ishi
# Counter({True: 17841, False: 834, 'multiple words': 106})
# 238764
# actual: baalath   pred: the
# Counter({True: 17880, False: 835, 'multiple words': 107})
# 238774
# actual: meshobab   pred: jamlech
# Counter({True: 17880, False: 836, 'multiple words': 107})
# 238776
# actual: jamlech   pred: joshah
# Counter({True: 17880, False: 837, 'multiple words': 107})
# 238786
# actual: joshibiah   pred: seraiah
# Counter({True: 17884, False: 838, 'multiple words': 107})
# 238796
# actual: jeshohaiah   pred: jaakobah
# Counter({True: 17888, False: 839, 'multiple words': 107})
# 239042
# actual: assyria   pred: the
# Counter({True: 17930, False: 840, 'multiple words': 107})
# 239168
# actual: sheba   pred: seven
# Counter({True: 17952, False: 841, 'multiple words': 107})
# 239170
# actual: jorai   pred: jacan
# Counter({True: 17952, False: 842, 'multiple words': 107})
# 239172
# actual: jacan   pred: zia
# Counter({True: 17952, False: 843, 'multiple words': 107})
# 239632
# actual: gershon   pred: levi
# Counter({True: 18066, False: 844, 'multiple words': 107})
# 239913
# actual: gershon   pred: levi
# Counter({True: 18157, False: 845, 'multiple words': 107})
# 239940
# actual: bani   pred: the
# Counter({True: 18167, False: 846, 'multiple words': 107})
# 240209
# actual: asher   pred: the
# Counter({True: 18209, False: 847, 'multiple words': 107})
# 240385
# actual: gershonites   pred: of
# Counter({True: 18230, False: 848, 'multiple words': 107})
# 240425
# actual: ramoth   pred: anem
# Counter({True: 18236, False: 849, 'multiple words': 107})
# 240440
# actual: asher   pred: the
# Counter({True: 18237, False: 850, 'multiple words': 107})
# 240504
# actual: rimmono   pred: received
# Counter({True: 18246, False: 851, 'multiple words': 107})
# 240599
# actual: puah   pred: jashub
# Counter({True: 18261, False: 852, 'multiple words': 107})
# 240615
# actual: ibsam   pred: jahmai
# Counter({True: 18268, False: 853, 'multiple words': 107})
# 240740
# actual: joash   pred: zemirah
# Counter({True: 18291, False: 854, 'multiple words': 107})
# 240788
# actual: kenaanah   pred: ehud
# Counter({True: 18305, False: 855, 'multiple words': 107})
# 240816
# actual: shuppites   pred: huppites
# Counter({True: 18309, False: 856, 'multiple words': 107})
# 240818
# actual: huppites   pred: ir
# Counter({True: 18309, False: 857, 'multiple words': 107})
# 240820
# actual: ir   pred: hushites
# Counter({True: 18309, False: 858, 'multiple words': 107})
# 240832
# actual: shillem   pred: descendants
# Counter({True: 18315, False: 859, 'multiple words': 107})
# 240843
# actual: aramean   pred: concubine
# Counter({True: 18318, False: 860, 'multiple words': 107})
# 240857
# actual: shuppites   pred: huppites
# Counter({True: 18322, False: 861, 'multiple words': 107})
# 240924
# actual: ahian   pred: shemida
# Counter({True: 18340, False: 862, 'multiple words': 107})
# 241080
# actual: naaran   pred: joshua
# Counter({True: 18364, False: 863, 'multiple words': 107})
# 241129
# actual: asher   pred: the
# Counter({True: 18373, False: 864, 'multiple words': 107})
# 241184
# actual: aram   pred: hubbah
# Counter({True: 18394, False: 865, 'multiple words': 107})
# 241189
# actual: helem   pred: sons
# Counter({True: 18394, False: 866, 'multiple words': 107})
# 241201
# actual: suah   pred: zophah
# Counter({True: 18398, False: 867, 'multiple words': 107})
# 241203
# actual: harnepher   pred: zophah
# Counter({True: 18398, False: 868, 'multiple words': 107})
# 241223
# actual: jether   pred: of
# Counter({True: 18407, False: 869, 'multiple words': 107})
# 241231
# actual: ulla   pred: of
# Counter({True: 18410, False: 870, 'multiple words': 107})
# 241240
# actual: asher   pred: the
# Counter({True: 18413, False: 871, 'multiple words': 107})
# 241353
# actual: hushim   pred: divorced
# Counter({True: 18439, False: 872, 'multiple words': 107})
# 241356
# actual: baara   pred: hushim
# Counter({True: 18439, False: 873, 'multiple words': 107})
# 241369
# actual: zibia   pred: jobab
# Counter({True: 18441, False: 874, 'multiple words': 107})
# 241372
# actual: mesha   pred: zibia
# Counter({True: 18441, False: 875, 'multiple words': 107})
# 241378
# actual: jeuz   pred: sakia
# Counter({True: 18442, False: 876, 'multiple words': 107})
# 241381
# actual: sakia   pred: mirmah
# Counter({True: 18442, False: 877, 'multiple words': 107})
# 241447
# actual: ishpah   pred: joha
# Counter({True: 18461, False: 878, 'multiple words': 107})
# 241449
# actual: joha   pred: sons
# Counter({True: 18461, False: 879, 'multiple words': 107})
# 241461
# actual: ishmerai   pred: izliah
# Counter({True: 18466, False: 880, 'multiple words': 107})
# 241463
# actual: izliah   pred: jobab
# Counter({True: 18466, False: 881, 'multiple words': 107})
# 241483
# actual: beraiah   pred: shimrath
# Counter({True: 18475, False: 882, 'multiple words': 107})
# 241485
# actual: shimrath   pred: sons
# Counter({True: 18475, False: 883, 'multiple words': 107})
# 241509
# actual: sons   pred: penuel
# Counter({True: 18485, False: 884, 'multiple words': 107})
# 241510
# actual: shashak   pred: sons
# Counter({True: 18485, False: 885, 'multiple words': 107})
# 241572
# actual: shimeah   pred: mikloth
# Counter({True: 18505, False: 886, 'multiple words': 107})
# 241609
# actual: esh-baal   pred: eshbaal
# Counter({True: 18513, False: 887, 'multiple words': 107})
# 241626
# actual: melech   pred: of
# Counter({True: 18517, False: 888, 'multiple words': 107})
# 241795
# actual: son   pred: perez
# Counter({True: 18561, False: 889, 'multiple words': 107})
# 241811
# actual: zerahites   pred: jeuel
# Counter({True: 18563, False: 890, 'multiple words': 107})
# 241849
# actual: ibnijah   pred: ibneiah
# Counter({True: 18577, False: 891, 'multiple words': 107})
# 241905
# actual: maasai   pred: adiel
# Counter({True: 18590, False: 892, 'multiple words': 107})
# 241909
# actual: jahzerah   pred: son
# Counter({True: 18591, False: 893, 'multiple words': 107})
# 241915
# actual: immer   pred: of
# Counter({True: 18593, False: 894, 'multiple words': 107})
# 241952
# actual: bakbakkar   pred: heresh
# Counter({True: 18599, False: 895, 'multiple words': 107})
# 241953
# actual: heresh   pred: galal
# Counter({True: 18599, False: 896, 'multiple words': 107})
# 241990
# actual: talmon   pred: ahiman
# Counter({True: 18614, False: 897, 'multiple words': 107})
# 242066
# actual: meshelemiah   pred: gatekeeper
# Counter({True: 18627, False: 898, 'multiple words': 107})
# 242256
# actual: levite   pred: the
# Counter({True: 18634, False: 899, 'multiple words': 107})
# 242400
# actual: esh-baal   pred: eshbaal
# Counter({True: 18662, False: 900, 'multiple words': 107})
# 242417
# actual: melech   pred: of
# Counter({True: 18666, False: 901, 'multiple words': 107})
# 242486
# actual: israelites   pred: israel
# Counter({True: 18690, False: 902, 'multiple words': 107})
# 243413
# actual: tekoa   pred: ikkesh
# Counter({True: 18796, False: 903, 'multiple words': 109})
# 243516
# actual: reubenite   pred: reubenites
# Counter({True: 18858, False: 904, 'multiple words': 109})
# 243540
# actual: aroerite   pred: the
# Counter({True: 18865, False: 905, 'multiple words': 109})
# 243627
# actual: sons   pred: pelet
# Counter({True: 18890, False: 906, 'multiple words': 109})
# 243628
# actual: azmaveth   pred: sons
# Counter({True: 18890, False: 907, 'multiple words': 109})
# 243630
# actual: beracah   pred: the
# Counter({True: 18890, False: 908, 'multiple words': 109})
# 243632
# actual: jehu   pred: the
# Counter({True: 18890, False: 909, 'multiple words': 109})
# 243634
# actual: anathothite   pred: the
# Counter({True: 18890, False: 910, 'multiple words': 109})
# 243637
# actual: ishmaiah   pred: the
# Counter({True: 18890, False: 911, 'multiple words': 109})
# 243639
# actual: gibeonite   pred: the
# Counter({True: 18890, False: 912, 'multiple words': 109})
# 243884
# actual: jesse   pred: son
# Counter({True: 18930, False: 913, 'multiple words': 109})
# 243958
# actual: adnah   pred: defected
# Counter({True: 18938, False: 914, 'multiple words': 109})
# 244214
# actual: dan   pred: men
# Counter({True: 18967, False: 915, 'multiple words': 109})
# 244226
# actual: asher   pred: of
# Counter({True: 18967, False: 916, 'multiple words': 109})
# 244242
# actual: reuben   pred: the
# Counter({True: 18967, False: 917, 'multiple words': 109})
# 244245
# actual: gad   pred: manasseh
# Counter({True: 18967, False: 918, 'multiple words': 109})
# 244282
# actual: israelites   pred: israel
# Counter({True: 18971, False: 919, 'multiple words': 109})
# 245312
# actual: jaaziel   pred: rank
# Counter({True: 19099, False: 920, 'multiple words': 110})
# 245327
# actual: eliphelehu   pred: mikneiah
# Counter({True: 19106, False: 921, 'multiple words': 110})
# 245352
# actual: aziel   pred: shemiramoth
# Counter({True: 19112, False: 922, 'multiple words': 110})
# 245372
# actual: eliphelehu   pred: mikneiah
# Counter({True: 19119, False: 923, 'multiple words': 110})
# 245393
# actual: levite   pred: the
# Counter({True: 19123, False: 924, 'multiple words': 110})
# 245412
# actual: shebaniah   pred: joshaphat
# Counter({True: 19125, False: 925, 'multiple words': 110})
# 245439
# actual: jehiah   pred: doorkeepers
# Counter({True: 19131, False: 926, 'multiple words': 110})
# 245628
# actual: israelite   pred: of
# Counter({True: 19150, False: 927, 'multiple words': 110})
# 247037
# actual: tebah   pred: cun
# Counter({True: 19267, False: 928, 'multiple words': 110})
# 247102
# actual: hadadezer   pred: in
# Counter({True: 19278, False: 929, 'multiple words': 110})
# 247110
# actual: brought   pred: tou
# Counter({True: 19278, False: 930, 'multiple words': 110})
# 247111
# actual: hadoram   pred: had
# Counter({True: 19278, False: 931, 'multiple words': 110})
# 247178
# actual: edomites   pred: edom
# Counter({True: 19289, False: 932, 'multiple words': 111})
# 247309
# actual: ammonite   pred: hanun
# Counter({True: 19317, False: 933, 'multiple words': 111})
# 247882
# actual: sippai   pred: hushathite
# Counter({True: 19385, False: 934, 'multiple words': 111})
# 247901
# actual: lahmi   pred: goliath
# Counter({True: 19387, False: 935, 'multiple words': 111})
# 249328
# actual: shelomoth   pred: haziel
# Counter({True: 19547, False: 936, 'multiple words': 111})
# 249919
# actual: seorim   pred: the
# Counter({True: 19650, False: 937, 'multiple words': 111})
# 249943
# actual: shecaniah   pred: tenth
# Counter({True: 19654, False: 938, 'multiple words': 111})
# 249955
# actual: huppah   pred: thirteenth
# Counter({True: 19656, False: 939, 'multiple words': 111})
# 249959
# actual: jeshebeab   pred: fourteenth
# Counter({True: 19656, False: 940, 'multiple words': 111})
# 249967
# actual: immer   pred: to
# Counter({True: 19657, False: 941, 'multiple words': 111})
# 249984
# actual: jehezkel   pred: twentieth
# Counter({True: 19659, False: 942, 'multiple words': 111})
# 250003
# actual: maaziah   pred: twentyfourth
# Counter({True: 19662, False: 943, 'multiple words': 111})
# 250066
# actual: amariah   pred: jeriah
# Counter({True: 19677, False: 944, 'multiple words': 111})
# 250105
# actual: shoham   pred: and
# Counter({True: 19693, False: 945, 'multiple words': 111})
# 250223
# actual: asarelah   pred: asaph
# Counter({True: 19717, False: 946, 'multiple words': 111})
# 250241
# actual: zeri   pred: his
# Counter({True: 19721, False: 947, 'multiple words': 111})
# 250656
# actual: kore   pred: the
# Counter({True: 19770, False: 948, 'multiple words': 111})
# 250898
# actual: shuppim   pred: lots
# Counter({True: 19806, False: 949, 'multiple words': 113})
# 250989
# actual: gershonites   pred: gershonite
# Counter({True: 19812, False: 950, 'multiple words': 113})
# 251182
# actual: jeriah   pred: hebronites
# Counter({True: 19844, False: 951, 'multiple words': 113})
# 251238
# actual: manasseh   pred: pertaining
# Counter({True: 19850, False: 952, 'multiple words': 113})
# 251454
# actual: tekoite   pred: ikkesh
# Counter({True: 19867, False: 953, 'multiple words': 113})
# 251475
# actual: ephraimite   pred: the
# Counter({True: 19869, False: 954, 'multiple words': 113})
# 251518
# actual: division   pred: benjamite
# Counter({True: 19872, False: 955, 'multiple words': 113})
# 251560
# actual: ephraimite   pred: the
# Counter({True: 19876, False: 956, 'multiple words': 113})
# 251638
# actual: ephraimites   pred: the
# Counter({True: 19901, False: 957, 'multiple words': 113})
# 251766
# actual: ezri   pred: farmed
# Counter({True: 19928, False: 958, 'multiple words': 113})
# 251775
# actual: ramathite   pred: shiphmite
# Counter({True: 19930, False: 959, 'multiple words': 113})
# 251788
# actual: shiphmite   pred: vats
# Counter({True: 19931, False: 960, 'multiple words': 113})
# 251803
# actual: gederite   pred: joash
# Counter({True: 19931, False: 961, 'multiple words': 113})
# 251809
# actual: joash   pred: olive
# Counter({True: 19931, False: 962, 'multiple words': 113})
# 251819
# actual: shitrai   pred: sharon
# Counter({True: 19931, False: 963, 'multiple words': 113})
# 251821
# actual: sharonite   pred: adlai
# Counter({True: 19931, False: 964, 'multiple words': 113})
# 251831
# actual: adlai   pred: valleys
# Counter({True: 19932, False: 965, 'multiple words': 113})
# 251836
# actual: obil   pred: ishmaelite
# Counter({True: 19932, False: 966, 'multiple words': 113})
# 251838
# actual: ishmaelite   pred: meronothite
# Counter({True: 19932, False: 967, 'multiple words': 113})
# 251845
# actual: meronothite   pred: donkeys
# Counter({True: 19933, False: 968, 'multiple words': 113})
# 251850
# actual: jaziz   pred: hagrite
# Counter({True: 19933, False: 969, 'multiple words': 113})
# 251852
# actual: hagrite   pred: flocks
# Counter({True: 19933, False: 970, 'multiple words': 113})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [767], line 20
#      17     candidate_words = set(NIV84_df.loc[vref_index, 'words'])  if vref_index in NIV84_df.index else set([])
#      18     candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
# ---> 20     candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
#      21 #     reverse_candidate_df = reverse_model_df[reverse_model_df['normalized_source'] == hebrew_source_normalized]
#      23     pred_index = get_best_match_id(hebrew_source_normalized, candidate_df)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/arraylike.py:43, in OpsMixin.__eq__(self, other)
#      41 @unpack_zerodim_and_defer("__eq__")
#      42 def __eq__(self, other):
# ---> 43     return self._cmp_method(other, operator.eq)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/series.py:6246, in Series._cmp_method(self, other, op)
#    6243 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6245 with np.errstate(all="ignore"):
# -> 6246     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6248 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
line = 236711

# %%
gold_data.iloc[line-8: line+8, [0, 1, 2, 3, 4, 5, 10,11, 32]]
# Out:
#          index book  chapter  verse  word  subword        text lemma  \
# 236703  236703  1CH        1     10     8        1   גִּבּ֖וֹר  1368
# 236704  236704  1CH        1     10     9        1         בָּ     b
# 236705  236705  1CH        1     10     9        1        None     d
# 236706  236706  1CH        1     10     9        2      אָֽרֶץ   776
# 236707  236707  1CH        1     11     1        1          וּ     c
# 236708  236708  1CH        1     11     1        2  מִצְרַ֡יִם  4714
# 236709  236709  1CH        1     11     2        1      יָלַ֞ד  3205
# 236710  236710  1CH        1     11     3        1         אֶת   853
# 236711  236711  1CH        1     11     5        1    לוּדִ֧ים  3866
# 236712  236712  1CH        1     11     6        1          וְ     c
# 236713  236713  1CH        1     11     6        2         אֶת   853
# 236714  236714  1CH        1     11     7        1   עֲנָמִ֛ים  6047
# 236715  236715  1CH        1     11     8        1          וְ     c
# 236716  236716  1CH        1     11     8        2         אֶת   853
# 236717  236717  1CH        1     11     9        1   לְהָבִ֖ים  3853
# 236718  236718  1CH        1     11    10        1          וְ     c
#
#                  NIV84
# 236703  mighty warrior
# 236704            None
# 236705            None
# 236706            None
# 236707            None
# 236708         Mizraim
# 236709  was the father
# 236710            None
# 236711         Ludites
# 236712            None
# 236713            None
# 236714        Anamites
# 236715            None
# 236716            None
# 236717       Lehabites
# 236718            None

# %%
word = bible_df.loc[line, ['text']].values[0]
hebrew_source_normalized = normalize_word(word)
book = bible_df.loc[line, ['book']].values[0]
chapter = bible_df.loc[line, ['chapter']].values[0]
verse = bible_df.loc[line, ['verse']].values[0]
ref = f'{book} {chapter}:{verse}\n'
vref_index = vref_data.index(ref)

def normalize_word(word):
    return re.sub("[^\w\s]", "", word.lower()) if word else ''

candidate_words = set(NIV84_df.loc[vref_index, 'words']) if vref_index in NIV84_df.index else set([])
candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
candidate_words
# Out:
# ['',
#  'was',
#  'ludites',
#  'naphtuhites',
#  'father',
#  'the',
#  'mizraim',
#  'anamites',
#  'lehabites',
#  'of']

# %%
vref_index
# Out:
# 10266

# %%
candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
candidate_df
# Out:
#        Unnamed: 0   source    target  align_count  word score  \
# 44101       44101   father  לוּדִ֧ים            2    0.902797
# 79838       79838    lydia  לוּדִ֕ים            1    0.701462
# 84643       84643  mizraim  לוּדִ֧ים            2    0.114203
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 44101            father             לודים  0.000000             0     0.902797
# 79838             lydia             לודים  0.200000             1     1.701462
# 84643           mizraim             לודים  0.333333             2     1.780869

# %%
all_df[all_df['target'] == word].sort_values('word score', ascending=False)
# Out:
#          Unnamed: 0       vref       source    target    word score
# 125107       125107  GEN 10:13       father  לוּדִ֧ים  9.027971e-01
# 6747034     6747034   1CH 1:11       father  לוּדִ֧ים  9.027971e-01
# 125065       125065  GEN 10:13      mizraim  לוּדִ֧ים  1.142026e-01
# 6746992     6746992   1CH 1:11      mizraim  לוּדִ֧ים  1.142026e-01
# 125135       125135  GEN 10:13          the  לוּדִ֧ים  1.302155e-05
# 6747020     6747020   1CH 1:11          the  לוּדִ֧ים  1.302155e-05
# 125093       125093  GEN 10:13          the  לוּדִ֧ים  1.302155e-05
# 6747062     6747062   1CH 1:11          the  לוּדִ֧ים  1.302155e-05
# 125121       125121  GEN 10:13           of  לוּדִ֧ים  1.252464e-44
# 125149       125149  GEN 10:13      ludites  לוּדִ֧ים  1.252464e-44
# 125163       125163  GEN 10:13     anamites  לוּדִ֧ים  1.252464e-44
# 125177       125177  GEN 10:13    lehabites  לוּדִ֧ים  1.252464e-44
# 125191       125191  GEN 10:13  naphtuhites  לוּדִ֧ים  1.252464e-44
# 125079       125079  GEN 10:13          was  לוּדִ֧ים  1.252464e-44
# 6747006     6747006   1CH 1:11          was  לוּדִ֧ים  1.252464e-44
# 6747048     6747048   1CH 1:11           of  לוּדִ֧ים  1.252464e-44
# 6747076     6747076   1CH 1:11      ludites  לוּדִ֧ים  1.252464e-44
# 6747090     6747090   1CH 1:11     anamites  לוּדִ֧ים  1.252464e-44
# 6747104     6747104   1CH 1:11    lehabites  לוּדִ֧ים  1.252464e-44
# 6747118     6747118   1CH 1:11  naphtuhites  לוּדִ֧ים  1.252464e-44

# %%
candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].sort_values('total_score', ascending=False)
# Out:
#        Unnamed: 0   source    target  align_count  word score  \
# 84643       84643  mizraim  לוּדִ֧ים            2    0.114203
# 44101       44101   father  לוּדִ֧ים            2    0.902797
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 84643           mizraim             לודים  0.333333             2     1.780869
# 44101            father             לודים  0.000000             0     0.902797

# %% [markdown]
# Total number of names:

# %%
word
# Out:
# 'לוּדִ֧ים'

# %%
df[df['source'] == 'shemeber']
# Out:
#        Unnamed: 0    source    target  align_count  word score  verse score  \
# 80989       80989  shemeber  אַדְמָ֗ה            1     0.78108     0.330563
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 80989          shemeber              אדמה     -1.0             0     -0.78108

# %% [markdown]
# Number of matched names:

# %%
vref_index
# Out:
# 464

# %%
df[df['target'] == 'עֵ֖דֶן']
# Out:
#        Unnamed: 0 source  target  align_count  word score  verse score  \
# 26110       26110   eden  עֵ֖דֶן            2    0.799089     0.322273
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 26110              eden               עדן  0.818182            18      3.79264

# %%
matched_names['predicted'] = matched_names['text'].progress_apply(lambda x: df.loc[df[df['target'] == x]['total_score'].idxmax()]['source'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32282/32282 [06:18<00:00, 85.21it/s]

# %%
matched_names
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [32282 rows x 15 columns]

# %%
def is_word_correct(row):
    word = row['english'].split("’")[0] if row['english'] is not None else ''
    return word == row['predicted']

# %%
matched_names[matched_names.apply(is_word_correct, axis=1)]
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [29972 rows x 15 columns]

# %%
matched_names[~matched_names.apply(is_word_correct, axis=1)].head(100)
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 1591   GEN        3     17     1        3  o010030170013  00100301700006
# 1682   GEN        3     21     4        2  o010030210042  00100302100012
# 1809   GEN        4      2    11        2  o010040020112  00100400200030
# 1845   GEN        4      4    11        1  o010040040111  00100400400032
# 1927   GEN        4      8    12        1  o010040080121  00100400800036
# 2114   GEN        4     18     2        2  o010040180022  00100401800008
# 2198   GEN        4     23     4        1  o010040230041  00100402300012
# 2231   GEN        4     25     2        1  o010040250021  00100402500006
# 2270   GEN        4     26     9        1  o010040260091  00100402600024
# 2281   GEN        5      1     4        1  o010050010041  00100500100008
# 2314   GEN        5      3     2        1  o010050030021  00100500300006
# 2336   GEN        5      4     3        1  o010050040031  00100500400008
# 2354   GEN        5      5     4        1  o010050050041  00100500500010
# 2412   GEN        5      9     2        1  o010050090021  00100500900006
# 2777   GEN        5     32    10        1  o010050320101  00100503200024
# 2980   GEN        6     10     6        1  o010060100061  00100601000014
# 3519   GEN        7     13     6        2  o010070130062  00100701300020
# 4687   GEN        9     18     7        1  o010090180071  00100901800020
# 4750   GEN        9     23     2        1  o010090230021  00100902300006
# 4813   GEN        9     26     5        1  o010090260051  00100902600012
# 4816   GEN        9     26     7        1  o010090260071  00100902600018
# 4828   GEN        9     27     6        1  o010090270061  00100902700018
# 4831   GEN        9     27     8        1  o010090270081  00100902700024
# 4865   GEN       10      1     5        1  o010100010051  00101000100012
# 4879   GEN       10      2     3        1  o010100020031  00101000200006
# 4883   GEN       10      2     5        2  o010100020052  00101000200014
# 4902   GEN       10      4     2        1  o010100040021  00101000400006
# 4933   GEN       10      6     4        2  o010100060042  00101000600012
# 4935   GEN       10      6     5        2  o010100060052  00101000600016
# 4991   GEN       10     10     4        1  o010100100041  00101001000010
# 4993   GEN       10     10     5        2  o010100100052  00101001000014
# 5042   GEN       10     13     8        1  o010100130081  00101001300022
# 5073   GEN       10     16     2        2  o010100160022  00101001600008
# 5081   GEN       10     16     6        2  o010100160062  00101001600024
# 5085   GEN       10     17     2        2  o010100170022  00101001700008
# 5089   GEN       10     17     4        2  o010100170042  00101001700016
# 5093   GEN       10     17     6        2  o010100170062  00101001700024
# 5097   GEN       10     18     2        2  o010100180022  00101001800008
# 5101   GEN       10     18     4        2  o010100180042  00101001800016
# 5111   GEN       10     18    10        2  o010100180102  00101001800036
# 5154   GEN       10     21     1        3  o010100210013  00101002100006
# 5167   GEN       10     22     2        1  o010100220021  00101002200004
# 5170   GEN       10     22     4        2  o010100220042  00101002200010
# 5193   GEN       10     24     5        2  o010100240052  00101002400014
# 5226   GEN       10     26     6        1  o010100260061  00101002600016
# 5229   GEN       10     26     8        1  o010100260081  00101002600022
# 5256   GEN       10     29     4        1  o010100290041  00101002900012
# 5279   GEN       10     31     3        1  o010100310031  00101003100006
# 5483   GEN       11      9     5        1  o010110090051  00101100900010
# 5505   GEN       11     10     3        1  o010110100031  00101101000006
# 5535   GEN       11     12     1        2  o010110120012  00101101200004
# 5624   GEN       11     18     2        1  o010110180021  00101101800006
# 5704   GEN       11     24     2        1  o010110240021  00101102400006
# 5939   GEN       12      4     9        1  o010120040091  00101200400024
# 5955   GEN       12      5     2        1  o010120050021  00101200500006
# 6348   GEN       13      3     3        2  o010130030032  00101300300012
# 6434   GEN       13      7    10        1  o010130070101  00101300700024
# 6440   GEN       13      7    12        3  o010130070123  00101300700036
# 6604   GEN       13     14    19        2  o010130140192  00101301400048
# 6705   GEN       14      1    14        1  o010140010141  00101400100034
# 6782   GEN       14      5    19        2  o010140050192  00101400500060
# 6859   GEN       14      9     7        1  o010140090071  00101400900016
# 6943   GEN       14     13     8        2  o010140130082  00101401300030
# 6946   GEN       14     13    10        2  o010140130102  00101401300036
# 7031   GEN       14     17     3        1  o010140170031  00101401700008
# 7339   GEN       15      8     3        1  o010150080031  00101500800008
# 7548   GEN       15     19     2        2  o010150190022  00101501900006
# 7552   GEN       15     19     4        2  o010150190042  00101501900014
# 7556   GEN       15     19     6        2  o010150190062  00101501900022
# 7560   GEN       15     20     2        2  o010150200022  00101502000008
# 7564   GEN       15     20     4        2  o010150200042  00101502000016
# 7580   GEN       15     21     6        2  o010150210062  00101502100024
# 7584   GEN       15     21     8        2  o010150210082  00101502100032
# 7597   GEN       16      1     9        1  o010160010091  00101600100022
# 7637   GEN       16      3     7        2  o010160030072  00101600300018
# 8225   GEN       17     15    11        1  o010170150111  00101701500024
# 10066  GEN       19     37     9        1  o010190370091  00101903700024
# 10098  GEN       20      1     5        2  o010200010052  00102000100016
# 10777  GEN       21     14    20        1  o010210140201  00102101400064
# 11122  GEN       21     31     6        1  o010210310061  00102103100018
# 11276  GEN       22      4     4        1  o010220040041  00102200400016
# 11645  GEN       22     19     9        1  o010220190091  00102201900024
# 11651  GEN       22     19    13        2  o010220190132  00102201900036
# 12055  GEN       23     16     2        1  o010230160021  00102301600006
# 12083  GEN       23     17     3        1  o010230170031  00102301700008
# 12968  GEN       24     36     2        1  o010240360021  00102403600006
# 13241  GEN       24     47    11        1  o010240470111  00102404700028
# 13568  GEN       24     62    10        2  o010240620102  00102406200028
# 13724  GEN       25      3    12        2  o010250030122  00102500300034
# 13901  GEN       25     13    10        2  o010250130102  00102501300028
# 13974  GEN       25     18    10        1  o010250180101  00102501800024
# 14008  GEN       25     20    12        2  o010250200122  00102502000032
# 14305  GEN       26      1    14        1  o010260010141  00102600100046
# 14753  GEN       26     22    11        1  o010260220111  00102602200032
# 14771  GEN       26     23     3        1  o010260230031  00102602300010
# 14837  GEN       26     26     5        2  o010260260052  00102602600016
# 14980  GEN       26     33     3        1  o010260330031  00102603300008
# 14986  GEN       26     33     8        1  o010260330081  00102603300020
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
# 16052  GEN       27     46     9        1  o010270460091  00102704600024
#
#       ot-nt          unicode            text   lemma normalized      english  \
# 1591     OT           אָדָ֣ם          אָדָ֣ם     121       None         adam
# 1682     OT           אָדָ֧ם          אָדָ֧ם     120       None         adam
# 1809     OT           קַ֕יִן          קַ֕יִן  7014 b       None         cain
# 1845     OT           הֶ֖בֶל          הֶ֖בֶל    1893       None         abel
# 1927     OT           הֶ֥בֶל          הֶ֥בֶל    1893       None         abel
# 2114     OT         חֲנוֹךְ֙        חֲנוֹךְ֙    2585       None        enoch
# 2198     OT           עָדָ֤ה          עָדָ֤ה    5711       None         adah
# 2231     OT           אָדָ֥ם          אָדָ֥ם     121       None         adam
# 2270     OT         אֱנ֑וֹשׁ        אֱנ֑וֹשׁ     583       None        enosh
# 2281     OT           אָדָ֑ם          אָדָ֑ם     121       None         adam
# 2314     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2336     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2354     OT           אָדָם֙          אָדָם֙     121       None         adam
# 2412     OT         אֱנ֖וֹשׁ        אֱנ֖וֹשׁ     583       None        enosh
# 2777     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 2980     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 3519     OT            שֵׁם־            שֵׁם    8035       None         shem
# 4687     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4750     OT            שֵׁ֨ם           שֵׁ֨ם    8035       None         shem
# 4813     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4816     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4828     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4831     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4865     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4879     OT          גֹּ֣מֶר         גֹּ֣מֶר    1586       None        gomer
# 4883     OT           מָדַ֖י          מָדַ֖י    4074       None        madai
# 4902     OT           יָוָ֖ן          יָוָ֖ן    3120       None        javan
# 4933     OT       מִצְרַ֖יִם      מִצְרַ֖יִם    4714       None      mizraim
# 4935     OT            פ֥וּט           פ֥וּט    6316       None          put
# 4991     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 4993     OT          אֶ֖רֶךְ         אֶ֖רֶךְ     751       None        erech
# 5042     OT        לְהָבִ֖ים       לְהָבִ֖ים    3853       None      lehabim
# 5073     OT        יְבוּסִי֙       יְבוּסִי֙    2983       None    jebusites
# 5081     OT    גִּרְגָּשִֽׁי   גִּרְגָּשִֽׁי    1622       None  girgashites
# 5085     OT          חִוִּ֥י         חִוִּ֥י    2340       None      hivites
# 5089     OT         עַרְקִ֖י        עַרְקִ֖י    6208       None      arkites
# 5093     OT         סִּינִֽי        סִּינִֽי    5513       None      sinites
# 5097     OT       אַרְוָדִ֥י      אַרְוָדִ֥י     721       None    arvadites
# 5101     OT        צְּמָרִ֖י       צְּמָרִ֖י    6786       None    zemarites
# 5111     OT      כְּנַעֲנִֽי     כְּנַעֲנִֽי  3669 a       None    canaanite
# 5154     OT            שֵׁ֥ם           שֵׁ֥ם    8035       None         shem
# 5167     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 5170     OT        אַשּׁ֑וּר       אַשּׁ֑וּר     804       None       asshur
# 5193     OT          שֶׁ֖לַח         שֶׁ֖לַח    7974       None       shelah
# 5226     OT          שָׁ֑לֶף         שָׁ֑לֶף    8026       None      sheleph
# 5229     OT     חֲצַרְמָ֖וֶת    חֲצַרְמָ֖וֶת    2700       None  hazarmaveth
# 5256     OT        חֲוִילָ֖ה       חֲוִילָ֖ה    2341       None      havilah
# 5279     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5483     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 5505     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5535     OT   אַרְפַּכְשַׁ֣ד  אַרְפַּכְשַׁ֣ד     775       None   arpachshad
# 5624     OT           פֶ֖לֶג          פֶ֖לֶג    6389       None        peleg
# 5704     OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 5939     OT            ל֑וֹט           ל֑וֹט    3876       None          lot
# 5955     OT         אַבְרָם֩        אַבְרָם֩      87       None        abram
# 6348     OT          נֶּ֖גֶב         נֶּ֖גֶב    5045       None        negev
# 6434     OT            ל֑וֹט           ל֑וֹט    3876       None        lot’s
# 6440     OT       פְּרִזִּ֔י      פְּרִזִּ֔י    6522       None   perizzites
# 6604     OT          נֶ֖גְבּ        נֶ֖גְבָּ    5045       None        south
# 6705     OT         גּוֹיִֽם        גּוֹיִֽם  1471 b       None        goiim
# 6782     OT          שָׁוֵ֖ה         שָׁוֵ֖ה    7740       None       shaveh
# 6859     OT         גּוֹיִ֔ם        גּוֹיִ֔ם  1471 b       None        goiim
# 6943     OT        אֵֽלֹנֵ֜י       אֵֽלֹנֵ֜י     436       None         oaks
# 6946     OT         אֱמֹרִ֗י        אֱמֹרִ֗י     567       None      amorite
# 7031     OT           סְדֹם֮          סְדֹם֮    5467       None        sodom
# 7339     OT          יֱהוִ֔ה         יֱהוִ֔ה    3069       None          god
# 7548     OT         קֵּינִי֙        קֵּינִי֙    7017       None      kenites
# 7552     OT       קְּנִזִּ֔י      קְּנִזִּ֔י    7074       None   kenizzites
# 7556     OT      קַּדְמֹנִֽי     קַּדְמֹנִֽי    6935       None   kadmonites
# 7560     OT          חִתִּ֥י         חִתִּ֥י    2850       None     hittites
# 7564     OT       פְּרִזִּ֖י      פְּרִזִּ֖י    6522       None   perizzites
# 7580     OT    גִּרְגָּשִׁ֖י   גִּרְגָּשִׁ֖י    1622       None  girgashites
# 7584     OT        יְבוּסִֽי       יְבוּסִֽי    2983       None    jebusites
# 7597     OT        מִצְרִ֖ית       מִצְרִ֖ית    4713       None     egyptian
# 7637     OT       מִּצְרִית֙      מִּצְרִית֙    4713       None     egyptian
# 8225     OT          שָׂרָ֑י         שָׂרָ֑י    8297       None        sarai
# 10066    OT          מוֹאָ֖ב         מוֹאָ֖ב    4124       None     moabites
# 10098    OT          נֶּ֔גֶב         נֶּ֔גֶב    5045       None        negev
# 10777    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 11122    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11276    OT       אַבְרָהָ֧ם      אַבְרָהָ֧ם      85       None      abraham
# 11645    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11651    OT   בְאֵ֥ר שָֽׁבַע          בְאֵ֥ר    884+       None         None
# 12055    OT       אַבְרָהָם֮      אַבְרָהָם֮      85       None      abraham
# 12083    OT        עֶפְר֗וֹן       עֶפְר֗וֹן    6085       None     ephron’s
# 12968    OT          שָׂרָה֩         שָׂרָה֩    8283       None        sarah
# 13241    OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 13568    OT          נֶּֽגֶב         נֶּֽגֶב    5045       None        negev
# 13724    OT       לְאֻמִּֽים      לְאֻמִּֽים    3817       None      leummim
# 13901    OT           קֵדָ֥ר          קֵדָ֥ר    6938       None        kedar
# 13974    OT        אַשּׁ֑וּר      אַשּׁ֑וּרָ     804       None       asshur
# 14008    OT  פַּדַּ֖נ אֲרָ֑ם        פַּדַּ֖ן   6307+       None         None
# 14305    OT    אֲבִימֶּ֥לֶךְ   אֲבִימֶּ֥לֶךְ      40       None    abimelech
# 14753    OT        רְחֹב֔וֹת       רְחֹב֔וֹת    7344       None     rehoboth
# 14771    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 14837    OT        אֲחֻזַּת֙       אֲחֻזַּת֙     276       None     ahuzzath
# 14980    OT        שִׁבְעָ֑ה       שִׁבְעָ֑ה    7656       None       shibah
# 14986    OT  בְּאֵ֣ר שֶׁ֔בַע         בְּאֵ֣ר    884+       None         None
# 15003    OT       יְהוּדִ֔ית      יְהוּדִ֔ית    3067       None       judith
# 16052    OT             חֵ֑ת            חֵ֑ת    2845       None      hittite
#
#               greek         predicted
# 1591           αδαμ               man
# 1682           αδαμ                of
# 1809           καιν            tiller
# 1845           αβελ            vanity
# 1927           αβελ          futility
# 2114           ενωξ            hanoch
# 2198            αδα            zillah
# 2231           αδαμ               man
# 2270           ενως               man
# 2281       ἀνθρώπων               man
# 2314           αδαμ               man
# 2336           αδαμ               man
# 2354           αδαμ               man
# 2412           ενως            mortal
# 2777            σημ              name
# 2980            σημ              name
# 3519            σημ              name
# 4687            σημ              name
# 4750            σημ              name
# 4813            σημ              name
# 4816         ξανααν              shem
# 4828            σημ              name
# 4831         ξανααν              shem
# 4865            σημ              name
# 4879          γαμερ           japheth
# 4883          μαδαι             gomer
# 4902          ιωυαν            greece
# 4933        μεσραιμ             egypt
# 4935           φουδ           mizraim
# 4991        βαβυλὼν           babylon
# 4993           ορεξ              slow
# 5042           None              anam
# 5073     ιεβουσαῖον          jebusite
# 5081     γεργεσαῖον        girgashite
# 5085         ευαῖον            hivite
# 5089      αρουκαῖον            arkite
# 5093      ασενναῖον            sinite
# 5097        ἀράδιον          arvadite
# 5101      σαμαραῖον         hamathite
# 5111      ξαναναίων         tradesmen
# 5154            σημ              name
# 5167            σημ              name
# 5170         ασσουρ           assyria
# 5193           σαλα            became
# 5226           None           almodad
# 5229        ασαρμωθ           sheleph
# 5256          ευιλα             jobab
# 5279            σημ              name
# 5483       σύγξυσις           babylon
# 5505            σημ              name
# 5535         ἔζησεν        thirtyfive
# 5624          φαλεκ            thirty
# 5704          ναξωρ        twentynine
# 5939            λωτ             lot’s
# 5955          αβραμ             sarai
# 6348           None             south
# 6434            λωτ             lot’s
# 6440      φερεζαῖοι         perizzite
# 6604           None         southward
# 6705          ἐθνῶν           nations
# 6782           σαυη  shavehkiriathaim
# 6859          ἐθνῶν           nations
# 6943           δρυὶ             mamre
# 6946         αμορις          amorites
# 7031        σοδομων            defeat
# 7339           None               may
# 7548      καιναίους            kenite
# 7552     κενεζαίους         kenizzite
# 7556    κεδμωναίους         kadmonite
# 7560      ξετταίους           hittite
# 7564     φερεζαίους         perizzite
# 7580    γεργεσαίους        girgashite
# 7584    ιεβουσαίους          jebusite
# 7597       αἰγυπτία              maid
# 7637      αἰγυπτίαν           abram’s
# 8225           σαρα           princes
# 10066      μωαβιτῶν              moab
# 10098          λίβα             south
# 10777          None         beersheba
# 11122          None         beersheba
# 11276        αβρααμ            raised
# 11645          None         beersheba
# 11651          None         beersheba
# 12055        αβρααμ            ephron
# 12083         εφρων          ephron’s
# 12968         σαρρα          master’s
# 13241         ναξωρ        twentynine
# 13568          None             south
# 13724        λοωμιμ           peoples
# 13901         κηδαρ          nebaioth
# 13974          πρὸς           assyria
# 14008  μεσοποταμίας           aramean
# 14305      αβιμελεξ             gerar
# 14753     εὐρυξωρία           squares
# 14771          None         beersheba
# 14837        οξοζαθ           adviser
# 14980         ὅρκος             seven
# 14986          None         beersheba
# 15003        ιουδιν            judean
# 16052           ξετ              heth

# %%
hebrew_names = set(hebrew_names)
hebrew_matched_names = set(hebrew_matched_names)
list(hebrew_names - hebrew_matched_names)
# Out:
# ['מָכִֽי',
#  'יְה֗וּד',
#  'מִיכָיָ֜ה',
#  'זִ֥יעַ',
#  'נָב֗וֹת',
#  'נְבַלָּֽט',
#  'כִּנֶּ֔רֶת',
#  'נְבֽוּכַדְרֶאצַּ֥ר',
#  'זְבֻל֑וּן',
#  'רֶ֧גֶם',
#  'מּוֹאֲבִיָּ֜ה',
#  'הֶ֨בֶל֙',
#  'עֵ֠ילָם',
#  'מֵידָ֔ד',
#  'יִּשְׂרְאֵלִֽי',
#  'אֱלִישָׁ֖ה',
#  'הוֹמָ֑ם',
#  'בְאֵרָֽא',
#  'אַשְׁבֵּלִ֑י',
#  'אֲגַ֥ג',
#  'רֽאוּבֵנִ֗י',
#  'תַפֻּ֖חַ',
#  'אָצַל֒',
#  'כִּסְלֵיו֙',
#  'רְפָיָ֧ה',
#  'מִיכָיָ֧ה',
#  'בִּתִּ֞',
#  'שִׁמְעָתִ֖ים',
#  'תַּ֠תְּנַי',
#  'יִצְחָ֨ק',
#  'אֲשִׁימָֽא',
#  'יֵשׁ֛וּעַ',
#  'אֲחַזְיָ֤ה',
#  'אֲרִיאֵ֡ל',
#  'גִּבְעָ֨תָ',
#  'דָּ֣ן',
#  'שְׁבָ֔ט',
#  'בָּשָׁ֞ן',
#  'יִבְלְעָ֨ם',
#  'עִיּ֡וֹן',
#  'תֻּבַ֣ל',
#  'בִּנְיָמִ֣ין',
#  'צָפ֥וֹן',
#  'חֶלְקָֽי',
#  'שָׁמָע֙',
#  'מֹּ֣רַשְׁתִּ֔י',
#  'כְּנַעֲנִ֨י',
#  'אֲחִיה֖וּד',
#  'פַּלְטִ֔י',
#  'קְעִלָ֔ה',
#  'צוֹפִ֖ים',
#  'אַבְרָ֫הָ֥ם',
#  'שִׁרְטַ֖י',
#  'בַקְבֻּֽקְיָ֛ה',
#  'מֹּצָֽה',
#  'כְנָ֑נִי',
#  'יַּעֲקֹ֑ב',
#  'יְהוּדִי֙',
#  'נַעֲמָֽן',
#  'מָע֖וֹךְ',
#  'פְּרָ֔ת',
#  'שַׁלְמַ֖י',
#  'שִׁמְשַׁ֥י',
#  'חֲשֻׂפָ֖א',
#  'שִׁפְעִ֧י',
#  'אַמְנֹ֗ן',
#  'יַֽאֲזַנְיָ֨הוּ֙',
#  'בּוּנִּֽי',
#  'עֵיבָ֖ל',
#  'ירִימ֤וֹת',
#  'אֵ֔צֶר',
#  'אֲשַׂרְאֵ֖לָה',
#  'עֶקְרוֹן֮',
#  'מּוֹרָֽא',
#  'שִּׁטִּים֙',
#  'צְֽרֵרָ֔תָ',
#  'יְדוּת֑וּן',
#  'נֽוֹעַדְיָ֥ה',
#  'זְבֻ֣ל',
#  'דַּמֶּ֤שֶׂק',
#  'נֹ֑ף',
#  'גָדִ֜י',
#  'יִשָּׂשכָ֣ר',
#  'יִתְמָ֖ה',
#  'עָמְרִ֨י',
#  'שֵׁשַׁ֥י',
#  'בְּאֵ֣רֹתִ֔י',
#  'לֶ֗מֶךְ',
#  'שֵׁלָ֗ה',
#  'שָׁ֠אוּל',
#  'פַרְעֹ֖שׁ',
#  'מְשִׁלֵּמ֔וֹת',
#  'גִּלְעָדִֽי',
#  'אַבְנֵר֩',
#  'אֶסְתֵּֽר',
#  'אֲרִדַ֖י',
#  'אַרְבִּֽי',
#  'פַרְעֹה֒',
#  'עַבְדִּיאֵ֣ל',
#  'נָבָ֡ל',
#  'יְקַמְיָ֥ה',
#  'טֶ֣בַח',
#  'ס֧וּחַ',
#  'בֵּ֣לְטְשַׁאצַּ֗ר',
#  'נְתַנְיָ֥ה',
#  'יִֽזְרַחְיָ֖ה',
#  'עֵיטָם֒',
#  'קְוֵ֕א',
#  'מִכְמָ֔ס',
#  'נְבֽוּכַדְרֶאצַּר֒',
#  'יַעֲקֹב֮',
#  'יִגְאָל',
#  'גַעְתָּ֔ם',
#  'שִׁמְשׁ֥וֹן',
#  'בִּנְיָמִן֒',
#  'כַרְכַּ֔ס',
#  'חִלְקִיָּ֛הוּ',
#  'מֵּרֹ֣נֹתִ֔י',
#  'פִּרְעָתוֹנִ֑י',
#  'פַרְעֹה֮',
#  'גְדֵרֹתָ֑יִם',
#  'עֲשְׁתְּרָתִ֑י',
#  'מָֽרֵשָׁ֑ה',
#  'זַכַּ֖י',
#  'אַהֲרֹן֮',
#  'חֵ֨לֶף',
#  'נְבָ֗ט',
#  'אַרְנ֑וֹן',
#  'דָּוִ֡ד',
#  'ירִיחוֹ֮',
#  'אֶלְעָלֵ֔ה',
#  'נְּמ֣וּאֵלִ֔י',
#  'זָ֑רֶד',
#  'מֵישַׁךְ֙',
#  'שֵׁשַׁ֖ךְ',
#  'אֲדֹמִי֮',
#  'הוֹדַוְיָ֡הוּ',
#  'דּוּרָ֔א',
#  'אֹ֛רֶן',
#  'כּ֗וּשׁ',
#  'הָמָ֡ן',
#  'חָגָ֥ב',
#  'עֲתַלְיָ֑ה',
#  'אֱלִיאָ֣ב',
#  'אֲחִֽינָדָ֥ב',
#  'חָֽרֶת',
#  'יֽוֹצָדָ֔ק',
#  'זְרַֽחְיָ֑ה',
#  'אֲדוֹמִ֔ים',
#  'אֱלִיפַ֣ז',
#  'בְּנָיָֽה',
#  'צִיד֜וֹן',
#  'נְבֽוּכַדְנֶאצַּ֔ר',
#  'חֹרֵֽבָ',
#  'אַשּׁוּר֮',
#  'נָ֭הָר',
#  'חֲזָיָ֨ה',
#  'יְהוּכַ֣ל',
#  'בֵּבָ֑י',
#  'שָׂרָ֗ה',
#  'אֲבִיגַ֗יִל',
#  'נְתַנְיָ֔ה',
#  'יהוּדָ֧ה',
#  'אֲחַסְבַּ֖י',
#  'דָנִיֵּ֡אל',
#  'עֹג֙',
#  'בָלָ֜ק',
#  'שֹֽׁמְר֗וֹן',
#  'צְבֹעִ֖ים',
#  'נְבֻכַדְנֶאצַּ֨ר',
#  'מַלְכִּיָּ֔ה',
#  'עוּתַ֨י',
#  'שְׁבַנְיָ֡הוּ',
#  'הָמָ֥ן',
#  'הָגָ֑ר',
#  'אֲחוֹחִי֙',
#  'יְ֠הוֹחָנָן',
#  'אֲחַשְׁוֵר֜וֹשׁ',
#  'לֵּוִ֜י',
#  'דִינָה֙',
#  'בָשָׁן֙',
#  'אַבְרָם֮',
#  'יְהֽוֹעַדָּ֖ן',
#  'יוֹיָרִ֥יב',
#  'עַכְבּ֨וֹר',
#  'צֹּרִ֔ים',
#  'שְׂר֔וּג',
#  'שָׂרָ֔י',
#  'אַשְׁדּוֹדִ֔ית',
#  'זֶ֨רֶשׁ',
#  'כִּנְר֔וֹת',
#  'לוּדִ֕ים',
#  'עֶזְרָ֨א',
#  'פִּלְדָּ֖שׁ',
#  'שְׁכַנְיָ֖הוּ',
#  'כָּב֖וּל',
#  'קִדְר֜וֹן',
#  'טַבָּעֽוֹת',
#  'אִדּ֨וֹ',
#  'צְבוֹיִ֔ים',
#  'יְהוֹעַדָּ֖ן',
#  'סְכָכָֽה',
#  'מַֽעַזְיָ֖הוּ',
#  'פֻוָּ֖ה',
#  'מִֽיכָאֵ֗ל',
#  'בָלָ֗ק',
#  'בְּאֵֽרֹתִ֖י',
#  'נְעַרְיָה',
#  'אוּלָ֖ם',
#  'יִמְנָ֖ע',
#  'דָֽנִיֵּ֑אל',
#  'תַּרְשִׁישׁ֙',
#  'חָ֕ם',
#  'דְבִ֨רָ',
#  'מַלּוּךְ֙',
#  'חֲשַׁבְיָ֨ה',
#  'יְשַֽׁעְיָ֖ה',
#  'יִדְבָּ֑שׁ',
#  'גְּמַרְיָהוּ֩',
#  'אֶתְנִ֥י',
#  'גָד֩',
#  'אָסָף֩',
#  'דְלָיָ֨הוּ֙',
#  'אֶ֠לְקָנָה',
#  'יוֹזָבָ֔ד',
#  'שַׁלְתִּיאֵל֙',
#  'עָ֤ר',
#  'יֵ֥שֶׁר',
#  'כְּרֵתִ֛י',
#  'צַֽאֲנָ֔ן',
#  'פְּלִשְׁתִּים֒',
#  'שְׁמַעְיָ֔הוּ',
#  'נִמְשִׁ֖י',
#  'צָפֹ֛נָ',
#  'עָמְרִ֤י',
#  'גִבְע֨וֹן',
#  'שְׁמַעְיָ֧ה',
#  'יָ֣מָּ',
#  'לְּבָנ֞וֹן',
#  'מִּצְפָּה֒',
#  'קְצִיעָ֑ה',
#  'תְּקוֹעִ֑י',
#  'מִצְרַ֤יִם',
#  'נְ֠תַנְיָהוּ',
#  'קַבְצְאֵ֑ל',
#  'מַעֲכָה֙',
#  'עֲתַלְיָ֔ה',
#  'חֶצְר֗וֹן',
#  'דָּרְיָ֔וֶשׁ',
#  'רֶ֧שֶׁף',
#  'פּוּנִֽי',
#  'ירוּשְׁלֶ֛ם',
#  'חִלְקִיָּהוּ֩',
#  'בֵלְטְשַׁאצַּר֙',
#  'אֲמַצְיָ֣ה',
#  'ראוּבֵנִ֤י',
#  'זִיזָ֨א',
#  'עָלָ֑מֶת',
#  'לָכִ֛ישׁ',
#  'צִ֫יּ֥וֹן',
#  'אָ֣שֵׁרִ֔י',
#  'קַרְתָּ֖ן',
#  'נְ֠חֶמְיָה',
#  'נְּתִינִים֙',
#  'גִבְע֔וֹן',
#  'יְרִיח֥וֹ',
#  'זְאֵ֑ב',
#  'עַמִּיזָבָ֖ד',
#  'תְק֨וֹעַ֙',
#  'צִדְקִיָּ֤ה',
#  'שֵׁ֑ת',
#  'סַּרְדִּ֔י',
#  'צְּרֵדָ֗ה',
#  'פּוּעָֽה',
#  'יוֹיָכִֽין',
#  'פִרְעָתוֹן֙',
#  'מֵּרֹנֹתִֽי',
#  'גַ֨עַל',
#  'אַחְאָב֒',
#  'בְרִעָ֣ה',
#  'אַרְדִּ֔י',
#  'עַלְיָ֧ן',
#  'גִּרְגָּשִׁ֨י',
#  'מַקֵּדָ֔ה',
#  'אֶשְׁתָּאֹ֗ל',
#  'שְׁבָ֑א',
#  'עַמּ֧וֹן',
#  'קַּדְמֹנִֽי',
#  'יִבְנִיָּֽה',
#  'בֶּ֚לַע',
#  'גִּבְלִ֑ים',
#  'רְעוּאֵ֣ל',
#  'יְשַֽׁעְיָ֖הוּ',
#  'גִּבְעָ֜ה',
#  'יְשֻׁרוּן֙',
#  'אדֹנָ֔',
#  'אֶלְחָנָן֩',
#  'שִׁישַׁ֣ק',
#  'יְהוּדִ֔י',
#  'נָבָל֒',
#  'לֶּ֗חִי',
#  'חֵלֽוֹן',
#  'שּׁוּנַמִּ֖ית',
#  'חִזְקִיָּהוּ֒',
#  'מֶ֤שֶׁךְ',
#  'שִׁפְרָ֔ה',
#  'מִּצְפָּ֛ה',
#  'חָנֵ֥ס',
#  'גִיח֨וֹן',
#  'רוּמָ֖ה',
#  'נַחֲמָ֜נִי',
#  'יְהוּדָיֵ',
#  'וַיְזָֽתָא',
#  'גֹּ֖שֶׁן',
#  'יְהוֹאָחָ֤ז',
#  'בְּאֵרֹתִ֖ים',
#  'אֶלְתְּקֵ֥ה',
#  'בֵּלְטְשַׁאצַּ֗ר',
#  'יְהֻדִיָּ֗ה',
#  'חִירָ֜ם',
#  'זְכַרְיָ֡הוּ',
#  'אוּפָ֔ז',
#  'לְוִיִּ֨ם',
#  'יָרִ֖יב',
#  'רֵכָ֨ב',
#  'גֵֽי',
#  'שֶֽׁלֶמְיָ֥ה',
#  'בְנָיָ֖הוּ',
#  'מִּדְיָנִ֖ית',
#  'צְבֹאיִ֑ם',
#  'יִּזְרָ֑ח',
#  'שַׁלּ֣וּן',
#  'קֵדָ֛ר',
#  'תָּמָ֔ר',
#  'יוֹסֵ֨ף',
#  'זָנוֹחַ֒',
#  'יֹאושִׁיָּ֖הוּ',
#  'יְאֹר֒',
#  'דֶּ֛קֶר',
#  'רְפִידִ֔ם',
#  'גִּבְעוֹנִ֛י',
#  'יִּזְרְעֵאלִ֖י',
#  'יְאֹר֮',
#  'גַּרְמִ֑י',
#  'בֶרֶכְיָ֤ה',
#  'יְ֠רוּשָׁלִַם',
#  'חֲשַׁבְנְיָ֜ה',
#  'נָח֛וֹר',
#  'אֲחִֽיסָמָךְ֙',
#  'לוּבִ֥ים',
#  'סִ֛ין',
#  'אֲרָמִ֖ית',
#  'יָּ֑מָּ',
#  'ידִֽיעֲאֵל֙',
#  'בְּרִיעִֽי',
#  'מְלַטְיָ֣ה',
#  'גָ֑ד',
#  'בֶּ֣לַע',
#  'טוֹבִיָּ֑ה',
#  'לְבָנ֗וֹנָ',
#  'סֻכִּיִּ֖ים',
#  'גֵ֣י',
#  'תֶ֜רֶשׁ',
#  'עֶפְרוֹן֒',
#  'שָׁגֵ֖ה',
#  'תֵּימָ֔ן',
#  'יְה֣וֹנָדָ֔ב',
#  'בַּעַל',
#  'צֹ֔חַר',
#  'עִדּ֑וֹא',
#  'קָּרְחִ֑י',
#  'אַרְכִּ֔י',
#  'אֲחִימַ֗עַץ',
#  'יְהוָ֘ה',
#  'חֲמָ֛ת',
#  'אַחְיָ֣ן',
#  'יִרְמְיָ֨ה',
#  'אוּרִיָּה֙',
#  'אֲרָמִֽית',
#  'צְמָרַ֔יִם',
#  'שְׁכֶ֜ם',
#  'יַּרְדֵּן',
#  'אֱד֞וֹם',
#  'מַעֲשֵׂיָ֖ה',
#  'יְהוּדִ֜י',
#  'נֹּ֔א',
#  'אֶבְיָתָ֗ר',
#  'אֲמָ֥ם',
#  'יִּשְׂרָאֵ֛ל',
#  'מוֹאֲבִיּֽוֹת',
#  'פָּ֑עוּ',
#  'גִּבְע֑וֹן',
#  'חֲשַׁבְיָ֛ה',
#  'כְּלֽוּב',
#  'אֵימִ֔ים',
#  'יְרֵח֥וֹ',
#  'גָּ֑בַע',
#  'שְׁמוּאֵ֞ל',
#  'שִּׁילֹנִ֨י',
#  'חִוִּ֧י',
#  'אֱלִיעֶ֔זֶר',
#  'דַרְדַּ֖ע',
#  'נְתַנְיָ֑ה',
#  'הָרָא֙',
#  'יָבִ֔ין',
#  'יְע֛וּשׁ',
#  'רִצְיָֽא',
#  'בַרְזִלַּ֗י',
#  'אוּלָ֑י',
#  'אֶלְתְּקֵ֖א',
#  'לָֽשַׁע',
#  'צָּרְעָ֣ה',
#  'חֶפְצִי',
#  'אָשֵׁ֤ר',
#  'אֲבִינֹ֖עַם',
#  'צִֽקְלַ֖ג',
#  'בָבְלָיֵ',
#  'תָמָר֙',
#  'הֹרָם֙',
#  'יְהֹוָה֙',
#  'שַֽׁעֲלַבִּ֥ין',
#  'לְמוּאֵ֣ל',
#  'יהוֹשֻׁ֔עַ',
#  'חִילֵז֙',
#  'יְרֹחָ֧ם',
#  'ישַׁעְיָהוּ',
#  'קָֽיִן',
#  'יִּשְׂרָאֵל֒',
#  'פְּלִשְׁתִּ֤ים',
#  'חֲנֹ֔ךְ',
#  'אֵל֛וֹת',
#  'מַלְכִּיָּ֖ה',
#  'עֲדִינָ֨א',
#  'סְבָ֗א',
#  'אֲבִישׁ֗וּעַ',
#  'שִׁיאֹ֖ן',
#  'אִיזֶ֥בֶל',
#  'כַשְׂדָּֽי',
#  'אֲזַנְיָ֔ה',
#  'רַבָּה֒',
#  'יַעְכָּ֛ן',
#  'יְרוּשָׁלְַ֗מָ',
#  'אַשְׁפְּנַ֖ז',
#  'אָמוֹץ֙',
#  'אֲחִיָּ֣הוּ',
#  'צָפ֥וֹנָ',
#  'מֵּשָׁ֑א',
#  'מֹ֣ף',
#  'נֵ֜ר',
#  'זִפְרֹ֔נָ',
#  'יהוֹנָתָ֜ן',
#  'אֱלִיאָב֮',
#  'בִּזְּתָ֨א',
#  'זַמְזֻמִּֽים',
#  'דִֽימוֹנָ֖ה',
#  'יֽוֹשָׁפָ֡ט',
#  'שִׁמְשׁוֹן֮',
#  'אֶפְרַיִם֒',
#  'מִּצְרַיִם֒',
#  'פַשְׁחוּר֙',
#  'בְעֹֽן',
#  'פְּלַטְיָ֥הוּ',
#  'דָּוִיד֩',
#  'כְּבָ֔ר',
#  'שִׁיל֑וֹ',
#  'אֵלֹנִ֑י',
#  'יְהֹוָ֔ה',
#  'בִּדְקַר֙',
#  'יוֹשָׁ֖ה',
#  'יָרְקֳעָ֑ם',
#  'חֻבָּ֥ה',
#  'בָבֶ֛ל',
#  'יֹאשִׁיָּ֤הוּ',
#  'יְרִיח֑וֹ',
#  'תֵּימָ֤ן',
#  'גִדְע֥וֹן',
#  'גִּ֣זוֹנִ֔י',
#  'עֲמָלֵק֙',
#  'בַּעֲנָ֣ה',
#  'הַגְרִֽי',
#  'שְׁכֶ֧ם',
#  'אֲדוֹנָ֔',
#  'זְבַדְיָ֖ה',
#  'יִסְכָּֽה',
#  'דָ֠וִד',
#  'חֵ֤פֶר',
#  'בַּרְזִלַּ֤י',
#  'גֶּ֣בַע',
#  'צּוֹבָ֔ה',
#  'שֻּׁנַמִּית֙',
#  'שִּֽׁילוֹנִ֗י',
#  'גָּזֵֽז',
#  'מַעֲשֵׂיָ֧הוּ',
#  'יְהוֹשֻׁעַ֒',
#  'עֲרָבִ֔י',
#  'ל֑וֹט',
#  'נְח֣וּם',
#  'פְרִידָֽא',
#  'יַּחְלְאֵלִֽי',
#  'שֶׁבַע',
#  'נְבֽוּכַדְנֶצַּ֜ר',
#  'יֵ֠הוּא',
#  'פְּנוּאֵ֖ל',
#  'דְּבֹרָ֔ה',
#  'שִּׁל֤וֹ',
#  'דָוִ֜יד',
#  'אֲדֹ֣מִיֹּ֔ת',
#  'יְהֽוֹיָקִ֜ים',
#  'יִתְר֛וֹ',
#  'עַמֹּנִ֜ים',
#  'יְרֵחוֹ֒',
#  'חֲשַׁבְיָ֨הוּ',
#  'יֵהוּא֮',
#  'יָעֵל֙',
#  'אֱלִיעֶ֡זֶר',
#  'יְהֹוָ֧ה',
#  'לֵוָיֵ֜',
#  'אָמוֹן֩',
#  'גֹּעָֽתָ',
#  'חֲנַמְאֵ֨ל',
#  'מְּנַשֶּׁ֡ה',
#  'שַׁמְה֣וּת',
#  'פֶּ֧רֶץ',
#  'ישׁוֹחָיָה',
#  'יִתְר֖וֹ',
#  'שַׁלֻּם֙',
#  'מִרְיָ֛ם',
#  'אַבְשָׁלֹ֛ם',
#  'יַעְנַ֥י',
#  'מֵישַׁ֧ךְ',
#  'בַעֲנָ֔ה',
#  'יהֽוֹנָתָ֥ן',
#  'בָּבֶ֔לָ',
#  'יהוֹיָדָ֜ע',
#  'גָּ֞ד',
#  'אָזְנִ֕י',
#  'נֵיבָֽי',
#  'אֲבִישַׁ֨י',
#  'יָרָבְעָ֨ם',
#  'יהוֹיָקִ֨ים',
#  'אֶפְרַיִם֮',
#  'יהוֹשֻׁ֗עַ',
#  'דָּרְיָ֖וֶשׁ',
#  'קְּנִזִּי֙',
#  'בֶּֽרֶכְיָ֑הוּ',
#  'נַּחֲלִיאֵ֖ל',
#  'יְהוֹרָ֡ם',
#  'יַדּ֔וּעַ',
#  'גִּבְעָה֮',
#  'אוּרִיָּ֨ה',
#  'אֲחַזְיָ֛הוּ',
#  'תָֽמַח',
#  'נְצִ֖יחַ',
#  'עֲקָֽן',
#  'פוּאָ֛ה',
#  'בָלָ֧ק',
#  'סְפַרְוַ֔יִם',
#  'עֲנָקִים֙',
#  'אַבְשָׁל֧וֹם',
#  'אַרְדּֽוֹן',
#  'אֲבִימֶ֧לֶךְ',
#  'קַדְמִיאֵ֥ל',
#  'תַעְנַךְ֙',
#  'עַֽלְוָ֖ה',
#  'מַֽעֲכָת֙',
#  'יֽוֹצָדָ֜ק',
#  'בָּרָק֙',
#  'חַשּׁ֛וּב',
#  'אֶלְנָתָ֧ן',
#  'יִרְמְיָ֑ה',
#  'נְבוּכַדְרֶאצַּ֨ר',
#  'עֲשָׂהאֵ֛ל',
#  'כַלְכֹּ֥ל',
#  'פִּרְעָתוֹנִֽי',
#  'אֱמֹרִ֤י',
#  'מְהֵֽיטַבְאֵל֙',
#  'יוֹקִ֞ים',
#  'בַעְשָׁ֛א',
#  'הַגְרִֽים',
#  'יהוֹנָתָן',
#  'שָּׁא֖וּל',
#  'עֲנָ֔ב',
#  'חֲנַנְיָה',
#  'מִיכַל֒',
#  'יֶ֨רֶד',
#  'עַכּ֔וֹ',
#  'אֱלִיחֹ֧רֶף',
#  'דָויִ֔ד',
#  'כַשְׂדָּאָֽ',
#  'יְהֽוֹחָנָן֙',
#  'יִגְדַּלְיָ֖הוּ',
#  'גִּבְעָ֔תָ',
#  'ירֽוּשְׁלֶ֑ם',
#  'כְּנַעַן֒',
#  'שׁ֖וּרָ',
#  'דְּבִ֑יר',
#  'יְכָלְיָ֖הוּ',
#  'בַּעֲשֵׂיָ֖ה',
#  'עֲשָׂהאֵ֜ל',
#  'מִגְדּ֔וֹל',
#  'עֵינַ֔יִם',
#  'נָתָ֧ן',
#  'חֶלְקִֽי',
#  'בַּ֨עַל֙',
#  'צְרוּיָ֑ה',
#  'נְ֠תַנְיָה',
#  'יִתְנָֽן',
#  'עִירִ֜י',
#  'נְתַנְאֵ֡ל',
#  'עַקּֽוּב',
#  'חִירָ֛ה',
#  'פָדֽוֹן',
#  'נְתַנְיָ֤ה',
#  'ירֽוּשָׁלִַ֔ם',
#  'עֲרוֹעֵ֗ר',
#  'חֳרֵ֥ם',
#  'חֲנַנְיָה֙',
#  'גַזָּֽם',
#  'יהוּדָ֤ה',
#  'נ֟וּן',
#  'עֲרוֹעֵ֖ר',
#  'בָּשָׁן֒',
#  'צֵלַ֡ע',
#  'מְעוּנִ֖ים',
#  'אֲדֹנִיָּ֨הוּ֙',
#  'צְרֵדָֽתָ',
#  'דִּימ֖וֹן',
#  'גִּֽילֹנִ֜י',
#  'שַׁלֻּ֖ם',
#  'מִּצְפָּ֔תָ',
#  'תּוֹלָעִ֑י',
#  'נְבֽוּכַדְנֶצַּר֙',
#  'אֲמָנָ֗ה',
#  'לֶ֜שֶׁם',
#  'אֱלִיעֶ֧זֶר',
#  'אֲחִיָּ֗הוּ',
#  'מָכִ֤יר',
#  'טַבּ֣וּר',
#  'בַקְבּ֥וּק',
#  'יַֽעֲק֔וֹב',
#  'יֹ֣אשִׁיָּ֔הוּ',
#  'אֽוּרִיָּ֗ה',
#  'אַדְמָ֣תָא',
#  'חַרְחֽוּר',
#  'אַיָּל֜וֹן',
#  'רָפֽוּא',
#  'מַתַּנְיָה֙',
#  'חֲכִילָ֗ה',
#  'קֵֽלָיָה֙',
#  'בְּנְיָמִ֥ן',
#  'אֶלְיָשִׁ֜יב',
#  'אִֽיתִיאֵ֑ל',
#  'יהוֹשֻׁ֪עַ',
#  'פְנוּאֵ֔ל',
#  'מַֽשׁ',
#  'בָּ֠בֶל',
#  'אַדָּ֖ן',
#  'יְּהוּדִ֗י',
#  'שַׁבְּתַ֥י',
#  'חֶשְׁבּ֧וֹן',
#  'מָרָ֔תָ',
#  'עֲזַרְיָ֔הוּ',
#  'יִּשְׂרָאֵ֜ל',
#  'גָמ֖וּל',
#  'עֲזַרְיָ֨הוּ',
#  'אֲחִימֶ֜לֶךְ',
#  'פְּלִשְׁתִּים',
#  'רָ֣אמַת',
#  'גַ֖חַר',
#  'אֱלִ֨ישָׁמָ֜ע',
#  'צְרִ֡י',
#  'תִּרְשָׁ֜תָא',
#  'שְֽׁמַֽעְיָה֩',
#  'יְ֠הוֹיָקִים',
#  'אֲגַ֖ג',
#  'וָפְסִֽי',
#  'לוּד֙',
#  'גֶּ֥בֶר',
#  'אֲחִיָּ֜הוּ',
#  'זְאֵב֙',
#  'טָֽבְאֵל֙',
#  'ט֣וֹבִיָּ֔ה',
#  'דַבָּ֑שֶׁת',
#  'אֶבְיָתָ֨ר',
#  'נְבוּכַדְנֶצַּ֑ר',
#  'שִֽׁמְעִ֨י',
#  'צָּפ֛וֹן',
#  'גָּלִ֔ילָ',
#  'אַסְפָּֽתָא',
#  'עֶזְרָ֡א',
#  'צִפּ֔וֹר',
#  'ירוּשְׁלֶם֙',
#  'אֹ֖ן',
#  'שִּׁטִּ֗ים',
#  'בְרִיעָה֙',
#  'כְּלוּבָֽי',
#  'צְפַנְיָ֔ה',
#  'שֶּׂ֔כוּ',
#  'פֶּ֥קַח',
#  'ע֨וֹג',
#  'אַרְפַּכְשָׁ֔ד',
#  'רַעַמְסֵֽס',
#  'מַלְאָכִֽי',
#  'עֻזִּיאֵ֤ל',
#  'תּֽוֹגַרְמָ֔ה',
#  'צִיּ֞וֹן',
#  'עַזָּֽן',
#  'מִדְיָנִ֜ים',
#  'מַֽעַזְיָ֥ה',
#  'סְפָרַ֑ד',
#  'שַׂלְמָ֖א',
#  'נָ֣פַת',
#  'אַרְתַּחְשַׁ֖שְׂתְּ',
#  'פִּלְחָ֖א',
#  'יהֻ֥ד',
#  'דַנָּ֥ה',
#  'תִּרְשָׁ֡תָא',
#  'עֵלְמָיֵֽ',
#  'פּ֥וּל',
#  'דָּרְיָ֧וֶשׁ',
#  'קְלִיטָ֔א',
#  'יְהוִ֡ה',
#  'עֶקְרֹנִ֜ים',
#  'יָּ֧ם',
#  'פְּלֵתִ֖י',
#  'עֲנַמֶּ֖לֶךְ',
#  'יהוּדָה֒',
#  'נָב֨וֹת',
#  'וַשְׁתִּי֙',
#  'שִׁלוֹ֙',
#  'אֲרַ֥ב',
#  'כּוּשׁ֮',
#  'פְלִשְׁתִּיִּ֥ים',
#  'עֲנָ֖נִי',
#  'תְחַפְנְחֵס֙',
#  'יְר֣וּשְׁלֶ֔ם',
#  'שִּׁלֹ֗ה',
#  'שָּׁאוּלִֽי',
#  'אֲבִיגַ֣ל',
#  'נְבוּכַדנֶאצַּ֤ר',
#  'צִדְקִיָּ֡הוּ',
#  'רְחֻ֖ם',
#  'יְבוּסִ֥י',
#  'עַשְׁתָּרֹ֑ת',
#  'יְדוּתוּן֙',
#  'קִבְצַ֨יִם֙',
#  'יָ֥הּ',
#  'יֽוֹנָתָן֙',
#  'רְמַלְיָ֤הוּ',
#  'חֵ֤ת',
#  'יַבְנֵ֔ה',
#  'גַּדִּ֖י',
#  'ידַֽעְיָ֔ה',
#  'נְב֑וֹ',
#  'מֹּלֶךְ֒',
#  'אֲבִיגַ֡יִל',
#  'נְבוּכַדְנֶצַּר֒',
#  'מִּצְפָּה֮',
#  'תְּקוֹעִ֑ים',
#  'מִתְרְדָ֣ת',
#  'אֵלִיָּ֛הוּ',
#  'יְּהוּדִ֑ים',
#  'בִנּ֖וּי',
#  'לַ֥יִשׁ',
#  'אֽוּרִיאֵ֤ל',
#  'מָנ֜וֹחַ',
#  'יִשְׁמָעֵ֥אל',
#  'שָׁאוּל֒',
#  'אִבְצָ֖ן',
#  'יוֹזָבָד֙',
#  'אֲמַצְיָ֔ה',
#  'בִּלְהָ֔ה',
#  'תַחְפְּנֵ֔ס',
#  'יוֹרָ֤ם',
#  'כָּנְיָ֔הוּ',
#  'פְּתוּאֵֽל',
#  'שְׁכַנְיָ֔ה',
#  'שְׁלוֹמִ֖ית',
#  'גִלְעָ֛ד',
#  'מוֹאָ֧ב',
#  'הָרָרִ֑י',
#  'נִבְחַ֖ז',
#  'דָוִ֞יד',
#  'דַרְק֖וֹן',
#  'גִּדְעוֹנִֽי',
#  'דָּֽנִיֵּ֜אל',
#  'אֲחִיקָ֑ם',
#  'מַכְבֵּנָ֖ה',
#  'נְחֶמְיָ֧ה',
#  'אֲבִיה֛וּא',
#  'דִשׁ֥וֹן',
#  'צִלָּה֙',
#  'כַבּ֥וֹן',
#  'יְחִיאֵ֑ל',
#  'יָגְלִֽי',
#  'שֻּׁ֣תַלְחִ֔י',
#  'עֲמֹרָה֙',
#  'מִיכָ֣יְהוּ',
#  'יְרִיח֜וֹ',
#  'יִשָּׂשכָ֤ר',
#  'אַרְכְּוָיֵ֤',
#  'בְּנָיָ֣הוּ',
#  'שַׂלְמָֽה',
#  'עֻזִיָּ֖א',
#  'פ֔וּל',
#  'אַבְרָהָם֩',
#  'צִקְלַ֖ג',
#  'רֶ֔סֶן',
#  'מְרָרִי֒',
#  'עֻזִּיאֵל',
#  'צִידֹנִ֗ים',
#  'יְה֖וּד',
#  'עַיָּ֖ה',
#  'נַחֲלִיאֵ֑ל',
#  'יְבֻסִ֖י',
#  'בִּנְיָמִ֑ין',
#  'גַּ֣ת',
#  'שָׁ֑מֶד',
#  'אַמְצִ֣י',
#  'בָלָ֤ק',
#  'חוּקֹ֑קָ',
#  'מְּכֵ֣רָתִ֔י',
#  'עֲשִׂיאֵֽל',
#  'בִּנּ֖וּי',
#  'יְּהוּדִ֨ים',
#  'שְׁחַרְיָ֖ה',
#  'אֲחִיָּה֙',
#  'נְחֶמְיָ֗ה',
#  'אֲדֹנִיקָם֮',
#  'נְצִֽיב',
#  'אֱלִיָּ֔תָה',
#  'יְחִזְקִיָּ֡הוּ',
#  'נָּהָ֣ר',
#  'יְּהוּדִים֩',
#  'בְנָיָ֡הוּ',
#  'סַלּוּא֙',
#  'י֠וֹסֵף',
#  'אַשְׁקְל֗וֹן',
#  'זּוּזִ֖ים',
#  'כִּסְלֽוֹן',
#  'מָנ֤וֹחַ',
#  'זִ֗ו',
#  'צָפֹ֣נָ',
#  'מַּכְפֵּלָה֙',
#  'פִינְחָס',
#  'אָשֵׁ֜ר',
#  'תַּרְתָּ֑ק',
#  'צְלָפְחָד֮',
#  'יָבִ֗ין',
#  'יְהוִה֮',
#  'עָנִֽים',
#  'אֱלִיה֛וּא',
#  'תִּרְצָ֔ה',
#  'יְרֽוּשָׁלִַם֮',
#  'יָל֑וֹן',
#  'חֲתַֽת',
#  'שִּׁלֹנִֽי',
#  'זִיזָ֖ה',
#  'מְּדָנִ֔ים',
#  'פָֽרַס',
#  'מִֽיכָאֵ֜ל',
#  'שַׁלֻּ֔ם',
#  'שׁוּשָׁ֖ן',
#  'נְבֻכַדְנֶאצַּ֣ר',
#  'צִיעֹ֑ר',
#  'אֲחַזְיָ֜הוּ',
#  'מְהוּמָן',
#  'אֶלְיוֹעֵינַ֗י',
#  'מַכְנַדְבַ֥י',
#  'יְרַחְמְאֵ֑ל',
#  'יוֹרָם֩',
#  'מָכִיר֩',
#  'בָּלָ֥ק',
#  'תֵּמָ֑א',
#  'אַׄהֲׄרֹ֛ׄןׄ',
#  'מִֽיכָאֵ֑ל',
#  'אֲחִיט֜וּב',
#  'עַתְלָֽי',
#  'עֲזַרְיָהוּ֩',
#  'סְדֹ֜ם',
#  'שְׁמַעְיָה',
#  'הֵגַ֖י',
#  'בֵסַ֥י',
#  'סִֽיסְרָא֩',
#  'תֵּֽימָנִ֗י',
#  'צֹ֜ר',
#  'זְבוּב֮',
#  'חָצֹ֥ר',
#  'שָּׂטָן֙',
#  'יְדִידָ֥ה',
#  'לָכִ֨ישָׁ',
#  'נְבָ֨ט',
#  'הֵשִׁ֨יב',
#  'מְעוֹנֹתַ֖י',
#  'טְּלָאִ֔ים',
#  'עַ֗יִשׁ',
#  'אֲדֹ֨נִיָּ֧הוּ',
#  'שָׁוֵ֔ה',
#  'בִזְיוֹתְיָֽה',
#  'אֲחִיָּ֗ה',
#  'מִכָ֔יְהוּ',
#  'גָּדִ֖י',
#  'סֶ֣לֶד',
#  'גִּבְעֹנִ֞ים',
#  'צִידֹ֥ן',
#  'יְהוִ֤הּ',
#  'הוֹשָׁמָ֖ע',
#  'הָ֑ם',
#  'אַיָּ֑ה',
#  'עַמּוֹנִ֛ים',
#  'בִּנְיָמִין֒',
#  'קַּדְמוֹנִ֔י',
#  'כִּנֶּ֗רֶת',
#  'שְׁמוּאֵל֒',
#  'גֶ֨שֶׁם',
#  'אֲבִיהוּא֙',
#  'יוֹאָחָ֣ז',
#  'נְטָעִ֖ים',
#  'עֶקְרוֹן֒',
#  'פָּ֑עִי',
#  'בְּעֶשְׁתְּרָ֖ה',
#  'שָׁרָ֖ר',
#  'בְרִיעָ֑ה',
#  'עַשְׁתֹּרֶת֮',
#  'מְ֠נַחֵם',
#  'מַתִּתְיָ֜הוּ',
#  'יַעֲקוֹב֩',
#  'רֵ֠כָב',
#  'עֵרִֽי',
#  'יִ֠שְׁמָעֵאל',
#  'אָבִֽיב',
#  'יִשְׁפָּ֥ן',
#  'גָֽחַר',
#  'עֶפְרֹ֔ן',
#  'עֲמָשַׂ֞י',
#  'עַדְנָ֣ה',
#  'יִדְאֲלָ֖ה',
#  'גֵּבִ֖ים',
#  'סֶֽנֶּה',
#  'חֲנַמְאֵ֣ל',
#  'אֲחַשְׁוֵרֹ֔שׁ',
#  'קִישִׁ֔י',
#  'אֲחִימֶ֑לֶךְ',
#  'מַרְסְנָ֖א',
#  'שִׁמְרָ֖ת',
#  'חוּקֹק֙',
#  'אֶלְקָנָ֨ה',
#  'יֽוֹרָם',
#  'עֲנָת֑וֹת',
#  'בְנָיָהוּ֩',
#  'יְכָנְיָ֣הוּ',
#  'עַזּ֨וּר',
#  'לַעְדָּ֖ה',
#  'יַעֲק֗וֹב',
#  'צָּפוֹן֮',
#  'יְהוֹאָ֤שׁ',
#  'עֶפְרַ֖יִן',
#  'סַלּ֣וּ',
#  'חֹרֵב֙',
#  'דָנִיֵּ֤אל',
#  'יְהוּדָיֵ֔',
#  'סֶ֖לֶד',
#  'יִזִּיָּ֤ה',
#  'מוּשִׁ֗י',
#  'מְשֻׁלֶּ֥מֶת',
#  'כּוּשִׁ֑י',
#  'בֵּֽרֹתַ֖י',
#  'נַעֲמָ֣ן',
#  'יְהֹוִ֔ה',
#  'יֹֽ֠אשִׁיָּהוּ',
#  'יָבֵ֔שָׁ',
#  'זָבָ֣ד',
#  'זְבִינָ֔א',
#  'עַי֮',
#  'שָׂטָ֖ן',
#  'יְהוֹשׁ֔וּעַ',
#  'יְהוֹנָתָ֧ן',
#  'חַגִּ֑י',
#  'עֲטָר֣וֹת',
#  'נְטֹפָ֖ה',
#  'דְּלִילָה֩',
#  'יֽוֹאָחָז֙',
#  'גִלְעָ֑ד',
#  'חַלְח֥וּל',
#  'צ֕וֹר',
#  'עֻזִּיָּ֗הוּ',
#  'חִלְקִיָּ֖הוּ',
#  'יְהוֹצָדָק֙',
#  'גִלְעָדִ֑ים',
#  'בִּכְרִי֙',
#  'בְּעָלִ֑ים',
#  'אֱד֨וֹם',
#  'הַרְמ֖וֹנָ',
#  'פּ֣וּל',
#  'רִמּוֹן֩',
#  'עַמּוֹנִ֑י',
#  'עַזְרִיאֵ֗ל',
#  'בִנְיָמִ֧ן',
#  'יִּזְרְעֶ֗אל',
#  'יְרוּשְׁלֶֽם',
#  ...]

# %%
df[df['source'] == 'judith']
# Out:
#        Unnamed: 0  source    target  align_count  word score  verse score  \
# 48917       48917  judith  אִשָּׁה֙            1    0.333115     0.380322
# 48918       48918  judith  יִּקַּ֤ח            1    0.332959     0.380322
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 48917            judith               אשה     -1.0             0         -0.0
# 48918            judith               יקח     -1.0             0         -0.0

# %%
bible_df[bible_df['text'] == 'יְהוּדִ֔ית']
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 15003   GEN       26     34     9        1  o010260340091  00102603400022
# 231296  2KI       18     26    21        1  o120180260211  01201802600048
# 366489  ISA       36     11    19        1  o230360110191  02303601100044
#
#        ot-nt     unicode        text lemma normalized            english  \
# 15003     OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None             Judith
# 231296    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None          in Hebrew
# 366489    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None  language of Judah
#
#             greek      hebrew mandarin domain_codes               domains  \
# 15003      ιουδιν  יְהוּדִ֔ית       犹滴  [003001007]     [Names of People]
# 231296  ιουδαϊστί  יְהוּדִ֔ית    用希伯来语  [003001009]  [Names of Languages]
# 366489  ιουδαϊστί  יְהוּדִ֔ית      犹大语  [003001009]  [Names of Languages]
#
#                sdbh_codes top_domains
# 15003   [002822001001000]    [003001]
# 231296  [002820001001000]    [003001]
# 366489  [002820001001000]    [003001]

# %%
df[df['normalized_target'] == 'יהודית']
# Out:
#        Unnamed: 0  source      target  align_count  word score  verse score  \
# 10354       10354   beeri  יְהוּדִ֔ית            1    0.195174     0.380322
# 48762       48762  judean  יְהוּדִ֑ית            2    0.570450     0.319680
# 48763       48763  judean  יְהוּדִ֔ית            2    0.523498     0.333000
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 10354             beeri            יהודית  0.125000             1     0.009279
# 48762            judean            יהודית  0.571429             4     0.416827
# 48763            judean            יהודית  0.571429             4     0.398457

# %%
bible_df[bible_df['english'] == 'Judith']
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
#
#       ot-nt     unicode        text lemma normalized english   greek  \
# 15003    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None  Judith  ιουδιν
#
#            hebrew mandarin domain_codes            domains         sdbh_codes  \
# 15003  יְהוּדִ֔ית       犹滴  [003001007]  [Names of People]  [002822001001000]
#
#       top_domains
# 15003    [003001]

# %%
normalize_word('יְהוּדִ֔ית')
# Out:
# 'יהודית'

# %%
old_matched_names = matched_names
