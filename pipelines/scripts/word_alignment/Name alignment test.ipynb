# %%
from pathlib import Path
from combined import run_fa, run_match_words, combine_df
import os
from match import normalize_word
import pandas as pd
from tqdm import tqdm
from machine.tokenization import LatinWordTokenizer
from typing import Iterable, Tuple, List
import re
tqdm.pandas()
from collections import Counter

pd.set_option('display.max_rows', 500)

# %%
# reverse_model_df = pd.read_csv('pfs/out/hbo-MaculaHebTok_en-NIV84_combined/hbo-MaculaHebTok_en-NIV84_combined.csv')
bible_df = pd.read_parquet('../../../../new2old/data/bible_words.parquet')
# all_df = pd.read_csv('pfs/out/en-NIV84_hbo-MaculaHebTok_align/in_context.csv')

# %%
# ref_trans = 'NIV84'
# ref_lang = 'en'
# gold_data_col = 'NIV84'
ref_lang = 'swh'
# ref_trans = 'ONEN'
ref_trans = 'SRUV06'
gold_data_col = 'SRUV06'
ref_trans_file = f'pfs/text_data/{ref_lang}-{ref_trans}.txt'
model_df = pd.read_csv(f'pfs/out/{ref_lang}-{ref_trans}_hbo-MaculaHebTok_combined/{ref_lang}-{ref_trans}_hbo-MaculaHebTok_combined.csv')

# %%
vref_file = 'pfs/ref_data/vref.txt'
with open(vref_file) as f:
    vref_data = f.readlines()

# %%
def text_to_words(text: str) -> List[str]:
    """
    Inputs:
        text:   Normally a sentence, or Bible verse
    Outputs:
        A list of words, where the sentence has had its punctuation removed, and words splits into a list of words
    """
    # word_list = re.sub("[^\w\s]", "", text.lower()).split()
    # word_list = text.lower().replace('.', '').replace(',', '').replace('?', '').replace('!', '').split()
    word_tokenizer = LatinWordTokenizer()
    word_list = [normalize_word(word) for word in word_tokenizer.tokenize(text)]
    return word_list


def vref_to_df(file):
    with open(file, 'r') as f:
        bible_data = f.readlines()
    words = [text_to_words(line) for line in bible_data]
    normalized_words = [[normalize_word(word) if word else '' for word in word_list] if word_list else [] for word_list in words]
    df = pd.DataFrame({'text': bible_data, 'words': words, 'normalized_words': normalized_words})
    df = df[df['text'].apply(lambda x: len(x) > 2)]
    df = df[df['text'] != "b'\n'"]
    return df

# %%
ref_trans_df = vref_to_df(ref_trans_file)

# %%
gold_data = pd.read_parquet('../../../../new2old/data/gold_translation_data.parquet')

# %%
gold_data.columns
# Out:
# Index(['index', 'book', 'chapter', 'verse', 'word', 'subword', 'id', 'marble',
#        'ot-nt', 'unicode', 'text', 'lemma', 'normalized', 'english', 'greek',
#        'hebrew', 'mandarin', 'domain_codes', 'domains', 'sdbh_codes',
#        'top_domains', 'BHS', 'BSB', 'CU2010S', 'CU2010T', 'ESVUK16', 'GNTUK',
#        'HCB', 'KJV', 'LSG10', 'NBS11', 'NIV11', 'NIV84', 'NRS89', 'RA293',
#        'RSO94', 'RSV52', 'RVR60', 'SRUV06', 'TBI', 'TCV95S', 'TPB08'],
#       dtype='object')

# %%
model_df.loc[:, 'total_score'] = model_df.progress_apply(lambda row: row['FA_translation_score'] + 4 * row['avg_aligned'] + 5 * row['jac_sim'], axis=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4224650/4224650 [01:29<00:00, 47030.72it/s]

# %%
domains = ['003001001', '003001002','003001004','003001006', '003001007','003001008','003001009','003001010', '003001012' ,'003001013' , '003001014', '003001015' , '003001017']
names_df = bible_df[bible_df['domain_codes'].apply(lambda x: len(set(domains).intersection(set(x))) > 0)]
names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)
# print(names)
english_names = names_df['english'].unique()
english_names = [name.lower() for name in english_names if name is not None]
hebrew_names = names_df['text'].unique()
hebrew_names = [name.lower() for name in hebrew_names if name is not None]
# Out:
# /tmp/ipykernel_3814593/892064452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)

# %%
hebrew_matched_names = list(set(hebrew_names).intersection(model_df[model_df['jac_sim'] > 0]['target'].unique()))
english_matched_names = list(set(english_names).intersection(model_df[model_df['jac_sim'] > 0]['source'].unique()))

# %%
print(len(hebrew_names))
print(len(hebrew_matched_names))
print(len(english_names))
print(len(english_matched_names))
# Out:
# 9744
# 9498
# 2649
# 2227

# %%
names = names_df[names_df['text'].apply(lambda x: x in hebrew_names)]

# %%
names = names[gold_data[f'{ref_lang}-{ref_trans}'].apply(lambda x: x is not None)]
# Out:
# /tmp/ipykernel_3814593/1840373318.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   names = names[gold_data['NIV84'].apply(lambda x: x is not None)]

# %%
max_rows = -1
counter = Counter()
for index, row in names.iloc[:max_rows, :].iterrows():
    hebrew_source = row['text']
    hebrew_source_normalized = normalize_word(hebrew_source)    
    book = row['book']
    chapter = row['chapter']
    verse = row['verse']
    ref = f'{book} {chapter}:{verse}\n'
    vref_index = vref_data.index(ref)
    candidate_words = set(ref_trans_df.loc[vref_index, 'words'])  if vref_index in ref_trans_df.index else set([])
    candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]

    candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
    candidate_df = candidate_df[candidate_df['normalized_source'].apply(lambda x: x in list(candidate_words))]
    
    if candidate_df.shape[0] > 0:
        pred_index = candidate_df['total_score'].idxmax()
        score = candidate_df.loc[pred_index, 'total_score']
        pred = candidate_df.loc[pred_index, 'source']
    else:
        pred = None
    actual = gold_data.loc[index, gold_data_col] if index in gold_data.index else None  # .values[0]
    actual = actual.lower() if actual else ''
    if len(actual.split()) > 1:
        counter['multiple words'] += 1
    elif pred == None:
        counter['no prediction'] += 1
    else:
        correct = pred == actual or pred == actual.split("ʼ")[0] or actual == pred.split("ʼ")[0] 
        counter.update([correct]) 
    if not correct:
        print(index)
        print(f"actual: {actual}   pred: {pred}")
#         print(candidate_df)
        print(counter)
# Out:
# 1670
# actual: hawa   pred: ndiye
# Counter({True: 25, 'multiple words': 6, False: 1})
# 1779
# actual: hawa   pred: akamjua
# Counter({True: 30, 'multiple words': 7, False: 2})
# 5118
# actual: sidoni   pred: ulianza
# Counter({True: 246, 'multiple words': 42, False: 3})
# 6177
# actual: wamisri   pred: misri
# Counter({True: 380, 'multiple words': 57, False: 4})
# 6776
# actual: hamu   pred: wazuzi
# Counter({True: 441, 'multiple words': 72, False: 5})
# 6837
# actual: seboimu   pred: adma
# Counter({True: 450, 'multiple words': 74, False: 6})
# 7211
# actual: mungu   pred: ee
# Counter({True: 496, 'multiple words': 81, False: 7})
# 7213
# actual: ee bwana   pred: bwana
# Counter({True: 496, 'multiple words': 82, False: 7})
# 7339
# actual: mungu   pred: bwana
# Counter({True: 503, 'multiple words': 84, False: 8})
# 8910
# actual: sodoma   pred: wakaelekea
# Counter({True: 609, 'multiple words': 94, False: 9})
# 10066
# actual: wamoabi   pred: moabu
# Counter({True: 653, 'multiple words': 98, False: 10})
# 10086
# actual: wa waamoni   pred: waamoni
# Counter({True: 653, 'multiple words': 99, False: 10})
# 10531
# actual: akamfanyia   pred: sara
# Counter({True: 681, 'multiple words': 104, False: 11})
# 11133
# actual: beer   pred: beersheba
# Counter({True: 723, 'multiple words': 106, False: 12})
# 11152
# actual: beer   pred: beersheba
# Counter({True: 726, 'multiple words': 106, False: 13})
# 14771
# actual: mpaka   pred: beersheba
# Counter({True: 999, 'multiple words': 137, False: 14})
# 14837
# actual: ahuzathi   pred: rafiki
# Counter({True: 1004, 'multiple words': 139, False: 15})
# 14986
# actual: beer   pred: beersheba
# Counter({True: 1010, 'multiple words': 140, False: 16})
# 16095
# actual: padan   pred: padanaramu
# Counter({True: 1076, 'multiple words': 145, False: 17})
# 16100
# actual: ya bethueli   pred: bethueli
# Counter({True: 1076, 'multiple words': 146, False: 17})
# 16168
# actual: padan   pred: padanaramu
# Counter({True: 1083, 'multiple words': 146, False: 18})
# 16195
# actual: padan   pred: padanaramu
# Counter({True: 1092, 'multiple words': 146, False: 19})
# 16221
# actual: za kanaani   pred: kanaani
# Counter({True: 1092, 'multiple words': 147, False: 19})
# 16234
# actual: padan   pred: padanaramu
# Counter({True: 1093, 'multiple words': 147, False: 20})
# 16257
# actual: mahalathi   pred: ishmaeli
# Counter({True: 1096, 'multiple words': 148, False: 21})
# 16275
# actual: beer   pred: beersheba
# Counter({True: 1100, 'multiple words': 148, False: 22})
# 17099
# actual:    pred: ni
# Counter({True: 1138, 'multiple words': 162, False: 23})
# 19240
# actual: lakini   pred: yegarsahadutha
# Counter({True: 1274, 'multiple words': 168, False: 24})
# 20088
# actual: penieli   pred: nimeonana
# Counter({True: 1318, 'multiple words': 170, False: 25})
# 20576
# actual: israeli   pred: eleloheisraeli
# Counter({True: 1342, 'multiple words': 175, False: 26})
# 22351
# actual: hushamu   pred: watemani
# Counter({True: 1573, 'multiple words': 216, False: 27})
# 22355
# actual: watemani   pred: badala
# Counter({True: 1573, 'multiple words': 216, False: 28})
# 22358
# actual: hushamu   pred: akamiliki
# Counter({True: 1573, 'multiple words': 216, False: 29})
# 22365
# actual: bedadi   pred: aliyepiga
# Counter({True: 1574, 'multiple words': 216, False: 30})
# 22385
# actual: samla   pred: masreka
# Counter({True: 1577, 'multiple words': 217, False: 31})
# 22390
# actual: samla   pred: shauli
# Counter({True: 1578, 'multiple words': 217, False: 32})
# 22395
# actual: na shauli   pred: shauli
# Counter({True: 1578, 'multiple words': 218, False: 32})
# 22397
# actual: wa rehobothi   pred: rehobothi
# Counter({True: 1578, 'multiple words': 219, False: 32})
# 22399
# actual: ulio karibu na mto   pred: mto
# Counter({True: 1578, 'multiple words': 220, False: 32})
# 22421
# actual: hadadi   pred: wa
# Counter({True: 1579, 'multiple words': 222, False: 33})
# 22864
# actual: dothani   pred: twendeni
# Counter({True: 1608, 'multiple words': 226, False: 34})
# 22868
# actual: basi yusufu   pred: yusufu
# Counter({True: 1608, 'multiple words': 227, False: 34})
# 23274
# actual: wamidiani   pred: wakamuuza
# Counter({True: 1621, 'multiple words': 230, False: 35})
# 23954
# actual: misri   pred: wa
# Counter({True: 1674, 'multiple words': 232, False: 36})
# 23958
# actual: hao waishmaeli   pred: waishmaeli
# Counter({True: 1674, 'multiple words': 233, False: 36})
# 25036
# actual: mtoni   pred: ngombe
# Counter({True: 1718, 'multiple words': 236, False: 37})
# 25057
# actual: mtoni   pred: mto
# Counter({True: 1718, 'multiple words': 236, False: 38})
# 25365
# actual: mtoni   pred: ngombe
# Counter({True: 1737, 'multiple words': 236, False: 39})
# 25402
# actual: ya misri   pred: misri
# Counter({True: 1737, 'multiple words': 237, False: 39})
# 25906
# actual: asenathi   pred: oni
# Counter({True: 1765, 'multiple words': 240, False: 40})
# 25911
# actual: oni   pred: potifera
# Counter({True: 1765, 'multiple words': 240, False: 41})
# 26020
# actual: asenathi   pred: oni
# Counter({True: 1776, 'multiple words': 240, False: 42})
# 26119
# actual: wamisri   pred: misri
# Counter({True: 1786, 'multiple words': 240, False: 43})
# 26148
# actual: wamisri   pred: misri
# Counter({True: 1788, 'multiple words': 240, False: 44})
# 29455
# actual: padan   pred: padanaramu
# Counter({True: 1946, 'multiple words': 259, False: 45})
# 29543
# actual: asenathi   pred: oni
# Counter({True: 1971, 'multiple words': 262, False: 46})
# 29548
# actual: oni   pred: potifera
# Counter({True: 1971, 'multiple words': 262, False: 47})
# 29567
# actual: roshi   pred: wa
# Counter({True: 1978, 'multiple words': 264, False: 48})
# 29568
# actual: na mupimu   pred: mupimu
# Counter({True: 1978, 'multiple words': 265, False: 48})
# 30180
# actual: wamisri   pred: misri
# Counter({True: 2043, 'multiple words': 271, False: 49})
# 30363
# actual: wamisri   pred: misri
# Counter({True: 2050, 'multiple words': 271, False: 50})
# 30378
# actual: mali yake farao   pred: farao
# Counter({True: 2050, 'multiple words': 272, False: 50})
# 31585
# actual: atakayekusaidia   pred: maziwa
# Counter({True: 2132, 'multiple words': 295, False: 51})
# 31616
# actual: cha yusufu   pred: yusufu
# Counter({True: 2132, 'multiple words': 296, False: 51})
# 31623
# actual: benyamini ni   pred: benyamini
# Counter({True: 2132, 'multiple words': 297, False: 51})
# 32666
# actual: kimisri   pred: hajapata
# Counter({True: 2205, 'multiple words': 322, False: 52})
# 32668
# actual: hao wanawake wa kiebrania   pred: kiebrania
# Counter({True: 2205, 'multiple words': 323, False: 52})
# 32710
# actual: huyo farao   pred: farao
# Counter({True: 2205, 'multiple words': 324, False: 52})
# 32723
# actual: mtoni   pred: mtamtupa
# Counter({True: 2205, 'multiple words': 324, False: 53})
# 32821
# actual: mtoni   pred: mto
# Counter({True: 2208, 'multiple words': 325, False: 54})
# 32829
# actual: ya mto   pred: mto
# Counter({True: 2208, 'multiple words': 326, False: 54})
# 34135
# actual: bwana   pred: ee
# Counter({True: 2295, 'multiple words': 349, False: 55})
# 34204
# actual: bwana   pred: ee
# Counter({True: 2297, 'multiple words': 349, False: 56})
# 34323
# actual: yethro   pred: kwa
# Counter({True: 2301, 'multiple words': 350, False: 57})
# 35175
# actual: yehova   pred: mungu
# Counter({True: 2361, 'multiple words': 364, False: 58})
# 35194
# actual: ya kanaani   pred: kanaani
# Counter({True: 2361, 'multiple words': 365, False: 58})
# 35796
# actual: wamisri   pred: misri
# Counter({True: 2417, 'multiple words': 434, False: 59})
# 35799
# actual: ndimi bwana   pred: bwana
# Counter({True: 2417, 'multiple words': 435, False: 59})
# 36200
# actual: wamisri   pred: misri
# Counter({True: 2449, 'multiple words': 449, False: 60})
# 36214
# actual: ya misri   pred: misri
# Counter({True: 2449, 'multiple words': 450, False: 60})
# 36219
# actual: wa misri   pred: misri
# Counter({True: 2449, 'multiple words': 451, False: 60})
# 39564
# actual: wamisri   pred: misri
# Counter({True: 2613, 'multiple words': 548, False: 61})
# 39581
# actual: wa israeli   pred: israeli
# Counter({True: 2613, 'multiple words': 549, False: 61})
# 39638
# actual: wamisri   pred: misri
# Counter({True: 2617, 'multiple words': 552, False: 62})
# 39644
# actual: katika misri   pred: misri
# Counter({True: 2617, 'multiple words': 553, False: 62})
# 40821
# actual: wamisri   pred: misri
# Counter({True: 2664, 'multiple words': 613, False: 63})
# 40828
# actual: wamisri   pred: misri
# Counter({True: 2664, 'multiple words': 613, False: 64})
# 41149
# actual: anawapigania   pred: wamisri
# Counter({True: 2675, 'multiple words': 628, False: 65})
# 41278
# actual: waisraeli   pred: israeli
# Counter({True: 2682, 'multiple words': 632, False: 66})
# 41574
# actual: bwana   pred: ee
# Counter({True: 2695, 'multiple words': 643, False: 67})
# 41708
# actual: mara   pred: machungu
# Counter({True: 2703, 'multiple words': 648, False: 68})
# 46225
# actual: mungu   pred: bwana
# Counter({True: 2852, 'multiple words': 731, False: 69})
# 46247
# actual: ya bwana   pred: bwana
# Counter({True: 2852, 'multiple words': 732, False: 69})
# 54248
# actual:    pred: bwana
# Counter({True: 3004, 'multiple words': 899, False: 70})
# 59932
# actual:    pred: bwana
# Counter({True: 3091, 'multiple words': 979, False: 71})
# 79148
# actual: walawi   pred: ni
# Counter({True: 3554, 'multiple words': 1255, False: 72})
# 79743
# actual:    pred: bwana
# Counter({True: 3588, 'multiple words': 1285, False: 73})
# 80141
# actual:    pred: bwana
# Counter({True: 3597, 'multiple words': 1285, False: 74})
# 80209
# actual:    pred: bwana
# Counter({True: 3602, 'multiple words': 1285, False: 75})
# 80218
# actual:    pred: gershoni
# Counter({True: 3603, 'multiple words': 1285, False: 76})
# 80570
# actual:    pred: bwana
# Counter({True: 3618, 'multiple words': 1285, False: 77})
# 80577
# actual:    pred: gershoni
# Counter({True: 3619, 'multiple words': 1285, False: 78})
# 80630
# actual:    pred: gershoni
# Counter({True: 3619, 'multiple words': 1285, False: 79})
# 80644
# actual:    pred: bwana
# Counter({True: 3621, 'multiple words': 1285, False: 80})
# 80700
# actual: na   pred: haruni
# Counter({True: 3624, 'multiple words': 1285, False: 81})
# 80703
# actual:    pred: bwana
# Counter({True: 3624, 'multiple words': 1285, False: 82})
# 80767
# actual:    pred: bwana
# Counter({True: 3629, 'multiple words': 1285, False: 83})
# 80788
# actual:    pred: bwana
# Counter({True: 3630, 'multiple words': 1285, False: 84})
# 80793
# actual:    pred: bwana
# Counter({True: 3631, 'multiple words': 1285, False: 85})
# 80860
# actual:    pred: bwana
# Counter({True: 3634, 'multiple words': 1285, False: 86})
# 80869
# actual:    pred: bwana
# Counter({True: 3635, 'multiple words': 1285, False: 87})
# 80892
# actual:    pred: bwana
# Counter({True: 3637, 'multiple words': 1285, False: 88})
# 80945
# actual:    pred: bwana
# Counter({True: 3637, 'multiple words': 1285, False: 89})
# 80996
# actual:    pred: bwana
# Counter({True: 3638, 'multiple words': 1285, False: 90})
# 81128
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 91})
# 81165
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 92})
# 81270
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 93})
# 81376
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 94})
# 81498
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 95})
# 81528
# actual:    pred: bwana
# Counter({True: 3640, 'multiple words': 1285, False: 96})
# 81553
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 97})
# 81616
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 98})
# 81629
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 99})
# 81670
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 100})
# 81754
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 101})
# 81801
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 102})
# 81853
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 103})
# 81871
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 104})
# 81958
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 105})
# 81988
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 106})
# 82013
# actual:    pred: bwana
# Counter({True: 3642, 'multiple words': 1285, False: 107})
# 82037
# actual:    pred: bwana
# Counter({True: 3645, 'multiple words': 1285, False: 108})
# 82042
# actual:    pred: bwana
# Counter({True: 3645, 'multiple words': 1285, False: 109})
# 82051
# actual:    pred: bwana
# Counter({True: 3645, 'multiple words': 1285, False: 110})
# 82138
# actual:    pred: bwana
# Counter({True: 3648, 'multiple words': 1285, False: 111})
# 82165
# actual:    pred: bwana
# Counter({True: 3648, 'multiple words': 1285, False: 112})
# 82223
# actual:    pred: gershoni
# Counter({True: 3652, 'multiple words': 1285, False: 113})
# 82295
# actual:    pred: bwana
# Counter({True: 3656, 'multiple words': 1285, False: 114})
# 82328
# actual:    pred: nashoni
# Counter({True: 3657, 'multiple words': 1285, False: 115})
# 82405
# actual:    pred: nashoni
# Counter({True: 3659, 'multiple words': 1285, False: 116})
# 82418
# actual:    pred: isakari
# Counter({True: 3662, 'multiple words': 1285, False: 117})
# 82505
# actual:    pred: heloni
# Counter({True: 3666, 'multiple words': 1285, False: 118})
# 82590
# actual:    pred: shedeuri
# Counter({True: 3670, 'multiple words': 1285, False: 119})
# 82672
# actual:    pred: simeoni
# Counter({True: 3672, 'multiple words': 1285, False: 120})
# 82675
# actual:    pred: surishadai
# Counter({True: 3673, 'multiple words': 1285, False: 121})
# 82748
# actual:    pred: surishadai
# Counter({True: 3674, 'multiple words': 1285, False: 122})
# 82760
# actual:    pred: deueli
# Counter({True: 3676, 'multiple words': 1285, False: 123})
# 82842
# actual:    pred: efraimu
# Counter({True: 3678, 'multiple words': 1285, False: 124})
# 82845
# actual:    pred: amihudi
# Counter({True: 3679, 'multiple words': 1285, False: 125})
# 82928
# actual: pedasuri   pred: gamalieli
# Counter({True: 3682, 'multiple words': 1285, False: 126})
# 83002
# actual: pedasuri pedasuri   pred: gamalieli
# Counter({True: 3682, 'multiple words': 1286, False: 126})
# 83014
# actual:    pred: benyamini
# Counter({True: 3682, 'multiple words': 1286, False: 127})
# 83017
# actual:    pred: gideoni
# Counter({True: 3683, 'multiple words': 1286, False: 128})
# 83088
# actual: abidani abidani   pred: abidani
# Counter({True: 3683, 'multiple words': 1287, False: 128})
# 83090
# actual: abidani abidani   pred: gideoni
# Counter({True: 3683, 'multiple words': 1288, False: 128})
# 83100
# actual:    pred: ahiezeri
# Counter({True: 3684, 'multiple words': 1288, False: 129})
# 83102
# actual:    pred: amishadai
# Counter({True: 3684, 'multiple words': 1288, False: 130})
# 83173
# actual:    pred: ahiezeri
# Counter({True: 3684, 'multiple words': 1288, False: 131})
# 83175
# actual:    pred: amishadai
# Counter({True: 3684, 'multiple words': 1288, False: 132})
# 83187
# actual:    pred: okrani
# Counter({True: 3686, 'multiple words': 1288, False: 133})
# 83272
# actual:    pred: enani
# Counter({True: 3690, 'multiple words': 1288, False: 134})
# 83510
# actual:    pred: bwana
# Counter({True: 3694, 'multiple words': 1288, False: 135})
# 83552
# actual:    pred: bwana
# Counter({True: 3697, 'multiple words': 1288, False: 136})
# 83575
# actual:    pred: bwana
# Counter({True: 3698, 'multiple words': 1288, False: 137})
# 83585
# actual:    pred: bwana
# Counter({True: 3699, 'multiple words': 1288, False: 138})
# 83672
# actual:    pred: bwana
# Counter({True: 3705, 'multiple words': 1288, False: 139})
# 83692
# actual:    pred: bwana
# Counter({True: 3708, 'multiple words': 1288, False: 140})
# 83703
# actual:    pred: bwana
# Counter({True: 3709, 'multiple words': 1288, False: 141})
# 83727
# actual:    pred: bwana
# Counter({True: 3710, 'multiple words': 1288, False: 142})
# 83752
# actual:    pred: bwana
# Counter({True: 3713, 'multiple words': 1288, False: 143})
# 83835
# actual:    pred: misri
# Counter({True: 3720, 'multiple words': 1288, False: 144})
# 83889
# actual:    pred: israeli
# Counter({True: 3726, 'multiple words': 1288, False: 145})
# 83943
# actual:    pred: bwana
# Counter({True: 3731, 'multiple words': 1289, False: 146})
# 83977
# actual:    pred: bwana
# Counter({True: 3733, 'multiple words': 1289, False: 147})
# 83989
# actual:    pred: bwana
# Counter({True: 3735, 'multiple words': 1289, False: 148})
# 86068
# actual: mkushi   pred: amemwoa
# Counter({True: 3851, 'multiple words': 1320, False: 149})
# 86073
# actual: mkushi   pred: amemwoa
# Counter({True: 3851, 'multiple words': 1320, False: 150})
# 90654
# actual: walawi   pred: watatumika
# Counter({True: 4117, 'multiple words': 1430, False: 151})
# 90674
# actual: wa israeli   pred: israeli
# Counter({True: 4117, 'multiple words': 1431, False: 151})
# 90682
# actual: wa israeli   pred: israeli
# Counter({True: 4117, 'multiple words': 1432, False: 151})
# 90686
# actual: kwa bwana   pred: bwana
# Counter({True: 4117, 'multiple words': 1433, False: 151})
# 90702
# actual: wa israeli   pred: israeli
# Counter({True: 4117, 'multiple words': 1434, False: 151})
# 91792
# actual: wamisri   pred: misri
# Counter({True: 4143, 'multiple words': 1463, False: 152})
# 92245
# actual:    pred: wakafa
# Counter({True: 4178, 'multiple words': 1481, False: 153})
# 92258
# actual: mungu   pred: bwana
# Counter({True: 4179, 'multiple words': 1481, False: 154})
# 93136
# actual:    pred: wakuu
# Counter({True: 4246, 'multiple words': 1534, False: 155})
# 95294
# actual: wakarmi   pred: karmi
# Counter({True: 4369, 'multiple words': 1621, False: 156})
# 95436
# actual: wahagi   pred: hagi
# Counter({True: 4390, 'multiple words': 1631, False: 157})
# 95441
# actual: washuni   pred: shuni
# Counter({True: 4391, 'multiple words': 1631, False: 158})
# 95446
# actual: waezboni   pred: ezboni
# Counter({True: 4392, 'multiple words': 1631, False: 159})
# 95451
# actual: waeri   pred: eri
# Counter({True: 4393, 'multiple words': 1631, False: 160})
# 95456
# actual: waarodi   pred: arodi
# Counter({True: 4394, 'multiple words': 1631, False: 161})
# 95461
# actual: waareli   pred: areli
# Counter({True: 4395, 'multiple words': 1631, False: 162})
# 95465
# actual: wa gadi   pred: gadi
# Counter({True: 4395, 'multiple words': 1632, False: 162})
# 95475
# actual: wa yuda   pred: yuda
# Counter({True: 4395, 'multiple words': 1633, False: 162})
# 95680
# actual: nuhu   pred: mala
# Counter({True: 4437, 'multiple words': 1651, False: 163})
# 95681
# actual: na hogla   pred: hogla
# Counter({True: 4437, 'multiple words': 1652, False: 163})
# 95682
# actual: na milka   pred: milka
# Counter({True: 4437, 'multiple words': 1653, False: 163})
# 95849
# actual: waimna   pred: imna
# Counter({True: 4464, 'multiple words': 1665, False: 164})
# 95854
# actual: waishvi   pred: ishvi
# Counter({True: 4465, 'multiple words': 1665, False: 165})
# 95906
# actual: waguni   pred: guni
# Counter({True: 4475, 'multiple words': 1669, False: 166})
# 96012
# actual: walawi   pred: ni
# Counter({True: 4479, 'multiple words': 1672, False: 167})
# 96030
# actual: wamerari   pred: merari
# Counter({True: 4484, 'multiple words': 1672, False: 168})
# 96033
# actual: za lawi   pred: lawi
# Counter({True: 4484, 'multiple words': 1673, False: 168})
# 96039
# actual: wahebroni   pred: wamala
# Counter({True: 4485, 'multiple words': 1673, False: 169})
# 96042
# actual: wamala   pred: wamushi
# Counter({True: 4485, 'multiple words': 1673, False: 170})
# 100742
# actual: hori   pred: mlima
# Counter({True: 4691, 'multiple words': 1837, False: 171})
# 100748
# actual: ya edomu   pred: edomu
# Counter({True: 4691, 'multiple words': 1838, False: 171})
# 100823
# actual: hori   pred: mlima
# Counter({True: 4694, 'multiple words': 1846, False: 172})
# 101168
# actual: sini   pred: akrabimu
# Counter({True: 4707, 'multiple words': 1872, False: 173})
# 101195
# actual: cha misri   pred: misri
# Counter({True: 4707, 'multiple words': 1873, False: 173})
# 102716
# actual: ashtarothi   pred: iliyo
# Counter({True: 4756, 'multiple words': 1964, False: 174})
# 102718
# actual: iliyo katika edrei   pred: edrei
# Counter({True: 4756, 'multiple words': 1965, False: 174})
# 104530
# actual:    pred: na
# Counter({True: 4832, 'multiple words': 2012, False: 175})
# 104536
# actual: wa yaboki   pred: yaboki
# Counter({True: 4832, 'multiple words': 2013, False: 175})
# 105069
# actual: yoshua   pred: nikamwamuru
# Counter({True: 4852, 'multiple words': 2060, False: 176})
# 105132
# actual: mungu   pred: bwana
# Counter({True: 4856, 'multiple words': 2061, False: 177})
# 105181
# actual: ya yordani   pred: yordani
# Counter({True: 4856, 'multiple words': 2062, False: 177})
# 105190
# actual: na lebanoni   pred: lebanoni
# Counter({True: 4856, 'multiple words': 2063, False: 177})
# 105712
# actual:    pred: kati
# Counter({True: 4866, 'multiple words': 2072, False: 178})
# 106459
# actual: beseri   pred: golani
# Counter({True: 4885, 'multiple words': 2078, False: 179})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [86], line 14
#      11 candidate_words = set(ref_trans_df.loc[vref_index, 'words'])  if vref_index in ref_trans_df.index else set([])
#      12 candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
# ---> 14 candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
#      15 candidate_df = candidate_df[candidate_df['normalized_source'].apply(lambda x: x in list(candidate_words))]
#      17 if candidate_df.shape[0] > 0:
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/arraylike.py:43, in OpsMixin.__eq__(self, other)
#      41 @unpack_zerodim_and_defer("__eq__")
#      42 def __eq__(self, other):
# ---> 43     return self._cmp_method(other, operator.eq)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/series.py:6246, in Series._cmp_method(self, other, op)
#    6243 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6245 with np.errstate(all="ignore"):
# -> 6246     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6248 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
index = 0
gold_data.loc[index, gold_data_col]
# Out:
# 'Hapo mwanzo'

# %%
line = 100742

# %%
gold_data.iloc[line-8: line+8, [0, 1, 2, 3, 4, 5, 10,11, 38
                               ]]
# Out:
#          index book  chapter  verse  word  subword       text   lemma  \
# 100734  100734  NUM       33     36     8        1    קָדֵֽשׁ    6946
# 100735  100735  NUM       33     37     1        1         וַ       c
# 100736  100736  NUM       33     37     1        2  יִּסְע֖וּ    5265
# 100737  100737  NUM       33     37     2        1         מִ       m
# 100738  100738  NUM       33     37     2        2   קָּדֵ֑שׁ    6946
# 100739  100739  NUM       33     37     3        1        וַֽ       c
# 100740  100740  NUM       33     37     3        2  יַּחֲנוּ֙    2583
# 100741  100741  NUM       33     37     4        1        בְּ       b
# 100742  100742  NUM       33     37     4        2       הֹ֣ר    2023
# 100743  100743  NUM       33     37     5        1         הָ       d
# 100744  100744  NUM       33     37     5        2       הָ֔ר    2022
# 100745  100745  NUM       33     37     6        1        בִּ       b
# 100746  100746  NUM       33     37     6        2     קְצֵ֖ה  7097 a
# 100747  100747  NUM       33     37     7        1     אֶ֥רֶץ     776
# 100748  100748  NUM       33     37     8        1    אֱדֽוֹם     123
# 100749  100749  NUM       33     38     1        1         וַ       c
#
#                 SRUV06
# 100734      ni Kadeshi
# 100735      Wakasafiri
# 100736      Wakasafiri
# 100737          kutoka
# 100738         Kadeshi
# 100739  wakapiga kambi
# 100740  wakapiga kambi
# 100741              wa
# 100742            Hori
# 100743          katika
# 100744           mlima
# 100745          katika
# 100746           mpaka
# 100747         wa nchi
# 100748        ya Edomu
# 100749         akakwea

# %%
word = bible_df.loc[line, ['text']].values[0][0]
hebrew_source_normalized = normalize_word(word)
book = bible_df.loc[line, ['book']].values[0][0]
chapter = bible_df.loc[line, ['chapter']].values[0][0]
verse = bible_df.loc[line, ['verse']].values[0][0]
ref = f'{book} {chapter}:{verse}\n'
vref_index = vref_data.index(ref)

def normalize_word(word):
    return re.sub("[^\w\s]", "", word.lower()) if word else ''

candidate_words = set(ref_trans_df.loc[vref_index, 'words']) if vref_index in ref_trans_df.index else set([])
candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
candidate_words
# Out:
# ['',
#  'hori',
#  'wakapiga',
#  'edomu',
#  'kutoka',
#  'wakasafiri',
#  'katika',
#  'ya',
#  'mlima',
#  'nchi',
#  'kadeshi',
#  'mpaka',
#  'wa',
#  'kambi']

# %%
vref_index
# Out:
# 4798

# %%
candidate_df = model_df[model_df['normalized_target'] == hebrew_source_normalized]
candidate_df
# Out:
#          Unnamed: 0    source target  co-occurrences  FA_translation_score  \
# 863             863   aamkapo   הַ֥ר               2                   0.0
# 1565           1565   abarimu   הַ֥ר               1                   0.0
# 1566           1566   abarimu    הַר               1                   0.0
# 1567           1567   abarimu   הַר֩               1                   0.0
# 1737           1737    abdoni   הַ֖ר               1                   0.0
# ...             ...       ...    ...             ...                   ...
# 4219126     4219126      zote   הָ֜ר               1                   0.0
# 4219178     4219178      zote    הָר               1                   0.0
# 4219179     4219179      zote   הָר֙               1                   0.0
# 4219185     4219185      zote  הָרַ֖               1                   0.0
# 4224458     4224458  zungumza   הַ֣ר               1                   0.0
#
#          FA_align_count  alignment_count  FA_verse_score  avg_aligned  \
# 863                 0.0              0.0             NaN          0.0
# 1565                0.0              0.0             NaN          0.0
# 1566                0.0              0.0             NaN          0.0
# 1567                0.0              0.0             NaN          0.0
# 1737                0.0              0.0             NaN          0.0
# ...                 ...              ...             ...          ...
# 4219126             0.0              0.0             NaN          0.0
# 4219178             0.0              0.0             NaN          0.0
# 4219179             0.0              0.0             NaN          0.0
# 4219185             0.0              0.0             NaN          0.0
# 4224458             0.0              0.0             NaN          0.0
#
#          verse score normalized_source normalized_target  jac_sim  \
# 863              0.0           aamkapo                הר      0.0
# 1565             0.0           abarimu                הר      0.0
# 1566             0.0           abarimu                הר      0.0
# 1567             0.0           abarimu                הר      0.0
# 1737             0.0            abdoni                הר      0.0
# ...              ...               ...               ...      ...
# 4219126          0.0              zote                הר      0.0
# 4219178          0.0              zote                הר      0.0
# 4219179          0.0              zote                הר      0.0
# 4219185          0.0              zote                הר      0.0
# 4224458          0.0          zungumza                הר      0.0
#
#          match_counts  total_score
# 863                 0          0.0
# 1565                0          0.0
# 1566                0          0.0
# 1567                0          0.0
# 1737                0          0.0
# ...               ...          ...
# 4219126             0          0.0
# 4219178             0          0.0
# 4219179             0          0.0
# 4219185             0          0.0
# 4224458             0          0.0
#
# [4842 rows x 15 columns]

# %%
candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].sort_values('total_score', ascending=False)
# Out:
#          Unnamed: 0      source target  co-occurrences  FA_translation_score  \
# 2113778     2113778       mlima   הַר֙               3              0.797552
# 2113761     2113761       mlima   הַ֖ר               5              0.775821
# 2113770     2113770       mlima   הַֽר               2              0.735050
# 2113797     2113797       mlima   הָ֣ר               5              0.388119
# 2113840     2113840       mlima   הֹ֥ר               5              0.328258
# 2113790     2113790       mlima   הָ֗ר               4              0.168721
# 2113765     2113765       mlima   הַ֤ר               9              0.827329
# 2113767     2113767       mlima   הַ֥ר              52              0.477814
# 2113764     2113764       mlima   הַ֣ר              58              0.416422
# 2113838     2113838       mlima   הֹ֣ר               6              0.246696
# 2113800     2113800       mlima   הָ֥ר               5              0.353478
# 2113777     2113777       mlima    הַר              66              0.441297
# 2113787     2113787       mlima   הָ֔ר              15              0.452476
# 2113768     2113768       mlima   הַ֨ר              10              0.513680
# 2113829     2113829       mlima   הָר֙               7              0.349177
# 2113789     2113789       mlima   הָ֖ר              19              0.451200
# 2113786     2113786       mlima   הָ֑ר              17              0.423771
# 915222       915222        hori   הֹ֤ר               1              0.771748
# 2113788     2113788       mlima   הָ֕ר               2              0.001979
# 915221       915221        hori   הֹ֣ר               6              0.452298
# 2113803     2113803       mlima   הָֽר              14              0.298458
# 915223       915223        hori   הֹ֥ר               5              0.300512
# 915217       915217        hori   הָֽר               4              0.107406
# 915214       915214        hori   הָ֔ר               4              0.095567
# 915213       915213        hori   הָ֑ר               2              0.025210
# 2113791     2113791       mlima  הָ֗רָ               1              0.000000
# 2113792     2113792       mlima   הָ֛ר               4              0.000000
# 2113793     2113793       mlima   הָ֞ר               2              0.000000
# 2113798     2113798       mlima   הָ֤ר               1              0.000000
# 2113828     2113828       mlima    הָר               1              0.000000
# 2113837     2113837       mlima  הָרַ֖               1              0.000000
# 2113779     2113779       mlima   הַר֩               1              0.000000
# 2113839     2113839       mlima   הֹ֤ר               1              0.000000
# 3416360     3416360          wa   הֹ֣ר               8              0.177943
# 3924017     3924017          ya   הָ֜ר              10              0.725605
# 3416363     3416363          wa   הֹ֥ר              13              0.231602
# 2502372     2502372        nchi   הָר֩               5              0.756792
# 1505453     1505453      kutoka   הָ֕ר               1              0.000000
# 1505440     1505440      kutoka    הַר              13              0.000000
# 1505458     1505458      kutoka   הָ֛ר               3              0.000000
# 1505464     1505464      kutoka   הָ֤ר               5              0.000000
# 1505467     1505467      kutoka   הָ֥ר               1              0.000000
# 1505535     1505535      kutoka   הֹ֣ר               3              0.000000
# 1505473     1505473      kutoka   הָֽר               7              0.000000
# 1505525     1505525      kutoka    הָר               1              0.000000
# 1505526     1505526      kutoka   הָר֙               3              0.000000
# 1505462     1505462      kutoka   הָ֣ר               1              0.000000
# 2502235     2502235        nchi   הָ֔ר              10              0.005438
# 1213804     1213804      katika   הַ֥ר              45              0.027643
# 1214086     1214086      katika   הָ֔ר              22              0.027039
# 2502238     2502238        nchi   הָ֛ר               4              0.000000
# 2502236     2502236        nchi   הָ֖ר               3              0.000000
# 2502104     2502104        nchi   הַ֥ר              24              0.000000
# 2502198     2502198        nchi   הַר֩               2              0.000000
# 2502119     2502119        nchi   הַֽר               3              0.000000
# 2502107     2502107        nchi   הַ֨ר               1              0.000000
# 2502246     2502246        nchi   הָ֣ר               4              0.000000
# 2502239     2502239        nchi   הָ֜ר               3              0.000000
# 2502393     2502393        nchi  הָרַ֗               1              0.000000
# 2502250     2502250        nchi   הָ֤ר               9              0.000000
# 2502255     2502255        nchi   הָ֥ר               2              0.000000
# 2502275     2502275        nchi   הָֽר               4              0.000000
# 2502370     2502370        nchi    הָר               1              0.000000
# 2502371     2502371        nchi   הָר֙               3              0.000000
# 2502373     2502373        nchi   הָר֮               2              0.000000
# 2502392     2502392        nchi  הָרַ֖               1              0.000000
# 2502094     2502094        nchi   הַ֖ר               3              0.000000
# 2502408     2502408        nchi   הֹ֣ר               2              0.000000
# 2502409     2502409        nchi   הֹ֤ר               1              0.000000
# 2502410     2502410        nchi   הֹ֥ר               1              0.000000
# 2502102     2502102        nchi   הַ֤ר               2              0.000000
# 2502256     2502256        nchi   הָ֧ר               2              0.000000
# 915220       915220        hori   הָר֙               2              0.000000
# 915215       915215        hori   הָ֛ר               1              0.000000
# 1214016     1214016      katika    הַר              52              0.006658
# 1214093     1214093      katika   הָ֛ר               3              0.000000
# 1214416     1214416      katika   הֹ֥ר               3              0.000000
# 1214415     1214415      katika   הֹ֣ר               6              0.000000
# 1214389     1214389      katika  הָרַ֖               1              0.000000
# 1214387     1214387      katika   הָרַ               1              0.000000
# 1214364     1214364      katika   הָר֮               2              0.000000
# 1214119     1214119      katika  הָ֥רָ               1              0.000000
# 1214118     1214118      katika   הָ֥ר               5              0.000000
# 1214112     1214112      katika   הָ֤ר               4              0.000000
# 1214094     1214094      katika   הָ֜ר               6              0.000000
# 1214363     1214363      katika   הָר֙               2              0.000000
# 1214091     1214091      katika   הָ֗ר               5              0.000000
# 1214017     1214017      katika   הַר֙               3              0.000000
# 1214090     1214090      katika   הָ֖ר               4              0.000000
# 1213807     1213807      katika   הַ֨ר               8              0.000000
# 1213826     1213826      katika   הַֽר               1              0.000000
# 3523581             0.0              0.0             NaN     0.000000
# 3523572             0.0              0.0             NaN     0.000000
# 3523568             0.0              0.0             NaN     0.000000
# 3523567             0.0              0.0             NaN     0.000000
# 3523564             0.0              0.0             NaN     0.000000
# 3523549             0.0              0.0             NaN     0.000000
# 1185091             0.0              0.0             NaN     0.000000
# 1185074             0.0              0.0             NaN     0.000000
# 1185065             0.0              0.0             NaN     0.000000
# 1185050             0.0              0.0             NaN     0.000000
# 1185060             0.0              0.0             NaN     0.000000
# 1185064             0.0              0.0             NaN     0.000000
# 1158713             0.0              0.0             NaN     0.000000
# 1158714             0.0              0.0             NaN     0.000000
# 1158715             0.0              0.0             NaN     0.000000
# 1158709             0.0              0.0             NaN     0.000000
#
#          verse score normalized_source normalized_target   jac_sim  \
# 2113778     0.311311             mlima                הר  0.576503
# 2113761     0.398463             mlima                הר  0.576503
# 2113770     0.315051             mlima                הר  0.576503
# 2113797     0.247347             mlima                הר  0.576503
# 2113840     0.280039             mlima                הר  0.576503
# 2113790     0.244900             mlima                הר  0.576503
# 2113765     0.306713             mlima                הר  0.576503
# 2113767     0.308502             mlima                הר  0.576503
# 2113764     0.319280             mlima                הר  0.576503
# 2113838     0.294278             mlima                הר  0.576503
# 2113800     0.257133             mlima                הר  0.576503
# 2113777     0.299667             mlima                הר  0.576503
# 2113787     0.271558             mlima                הר  0.576503
# 2113768     0.251142             mlima                הר  0.576503
# 2113829     0.238702             mlima                הר  0.576503
# 2113789     0.258955             mlima                הר  0.576503
# 2113786     0.295493             mlima                הר  0.576503
# 915222      0.313451              hori                הר  0.033994
# 2113788     0.199320             mlima                הר  0.576503
# 915221      0.300117              hori                הר  0.033994
# 2113803     0.259870             mlima                הר  0.576503
# 915223      0.280039              hori                הר  0.033994
# 915217      0.277461              hori                הר  0.033994
# 915214      0.292877              hori                הר  0.033994
# 915213      0.314598              hori                הר  0.033994
# 2113791     0.000000             mlima                הר  0.576503
# 2113792     0.000000             mlima                הר  0.576503
# 2113793     0.000000             mlima                הר  0.576503
# 2113798     0.000000             mlima                הר  0.576503
# 2113828     0.000000             mlima                הר  0.576503
# 2113837     0.000000             mlima                הר  0.576503
# 2113779     0.000000             mlima                הר  0.576503
# 2113839     0.000000             mlima                הר  0.576503
# 3416360     0.306253                wa                הר  0.022596
# 3924017     0.320740                ya                הר  0.020682
# 3416363     0.280039                wa                הר  0.022596
# 2502372     0.246677              nchi                הר  0.036394
# 2502100     0.257093              nchi                הר  0.036394
# 3415499     0.249399                wa                הר  0.022596
# 2502233     0.225871              nchi                הר  0.036394
# 1214120     0.199060            katika                הר  0.031679
# 3923503     0.241233                ya                הר  0.020682
# 1505454     0.248442            kutoka                הר  0.043732
# 3415495     0.301512                wa                הר  0.022596
# 1213795     0.268001            katika                הר  0.031679
# 1214107     0.255864            katika                הר  0.031679
# 3924016     0.246780                ya                הר  0.020682
# 3415488     0.313615                wa                הר  0.022596
# 3415830     0.312669                wa                הר  0.022596
# 2502197     0.206337              nchi                הר  0.036394
# 1213800           164     0.158393
# 1214018           164     0.158393
# 1214087           164     0.158393
# 1214088           164     0.158393
# 3923462           213     0.129453
# 3924007           213     0.113650
# 3415937           195     0.112978
# 3415918           195     0.112978
# 3415920           195     0.112978
# 3415921           195     0.112978
# 3415923           195     0.112978
# 3415924           195     0.112978
# 3415950           195     0.112978
# 3415943           195     0.112978
# 3415949           195     0.112978
# 3416267           195     0.112978
# 3415982           195     0.112978
# 3415983           195     0.112978
# 3415916           195     0.112978
# 3415910           195     0.112978
# 3415359           195     0.112978
# 3415915           195     0.112978
# 3415909           195     0.112978
# 3415832           195     0.112978
# 3415831           195     0.112978
# 3416271           195     0.112978
# 3416306           195     0.112978
# 3416311           195     0.112978
# 3415491           195     0.112978
# 3416316           195     0.112978
# 3415482           195     0.112978
# 3416270           195     0.112978
# 3416362           195     0.112978
# 3416268           195     0.112978
# 3924031           213     0.105067
# 3924431           213     0.103408
# 3923893           213     0.103408
# 3923892           213     0.103408
# 3924385           213     0.103408
# 3924433           213     0.103408
# 3924490           213     0.103408
# 3923457           213     0.103408
# 3924491           213     0.103408
# 3924430           213     0.103408
# 3924023           213     0.103408
# 3924013           213     0.103408
# 3924384           213     0.103408
# 3924381           213     0.103408
# 3924380           213     0.103408
# 3924081           213     0.103408
# 3924079           213     0.103408
# 3923287           213     0.103408
# 3924042           213     0.103408
# 3924040           213     0.103408
# 3924035           213     0.103408
# 3923445           213     0.103408
# 3924492           213     0.103408
# 3526177             7     0.086849
# 3526176             7     0.086849
# 3526175             7     0.086849
# 3526172             7     0.086849
# 3526170             7     0.086849
# 3526166             7     0.086849
# 3526165             7     0.086849
# 3526163             7     0.086849
# 3526155             7     0.086849
# 638018              7     0.081776
# 638029              7     0.081776
# 638031              7     0.081776
# 638032              7     0.081776
# 638044              7     0.081776
# 638045              7     0.081776
# 638046              7     0.081776
# 638016              7     0.081776
# 638017              7     0.081776
# 3523581             6     0.068807
# 3523572             6     0.068807
# 3523568             6     0.068807
# 3523567             6     0.068807
# 3523564             6     0.068807
# 3523549             6     0.068807
# 1185091             6     0.058824
# 1185074             6     0.058824
# 1185065             6     0.058824
# 1185050             6     0.058824
# 1185060             6     0.058824
# 1185064             6     0.058824
# 1158713             0     0.000000
# 1158714             0     0.000000
# 1158715             0     0.000000
# 1158709             0     0.000000

# %%
word
# Out:
# 'לוּדִ֧ים'

# %%
df[df['source'] == 'shemeber']
# Out:
#        Unnamed: 0    source    target  align_count  word score  verse score  \
# 80989       80989  shemeber  אַדְמָ֗ה            1     0.78108     0.330563
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 80989          shemeber              אדמה     -1.0             0     -0.78108

# %% [markdown]
# Number of matched names:

# %%
vref_index
# Out:
# 464

# %%
df[df['target'] == 'עֵ֖דֶן']
# Out:
#        Unnamed: 0 source  target  align_count  word score  verse score  \
# 26110       26110   eden  עֵ֖דֶן            2    0.799089     0.322273
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 26110              eden               עדן  0.818182            18      3.79264
