# %%
from pathlib import Path
from combined import run_fa, run_match_words, combine_df
import os
from match import normalize_word
import pandas as pd
from tqdm import tqdm
from machine.tokenization import LatinWordTokenizer
from typing import Iterable, Tuple, List
import re
tqdm.pandas()
from collections import Counter

pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('pfs/out/en-NIV84_combined.csv')
bible_df = pd.read_parquet('../../../../new2old/data/bible_words.parquet')

# %%
vref_file = 'pfs/ref_data/vref.txt'
with open(vref_file) as f:
    vref_data = f.readlines()

# %%
def text_to_words(text: str) -> List[str]:
    """
    Inputs:
        text:   Normally a sentence, or Bible verse
    Outputs:
        A list of words, where the sentence has had its punctuation removed, and words splits into a list of words
    """
    # word_list = re.sub("[^\w\s]", "", text.lower()).split()
    # word_list = text.lower().replace('.', '').replace(',', '').replace('?', '').replace('!', '').split()
    word_tokenizer = LatinWordTokenizer()
    word_list = [normalize_word(word) for word in word_tokenizer.tokenize(text)]
    return word_list


def vref_to_df(file):
    with open(file, 'r') as f:
        bible_data = f.readlines()
    words = [text_to_words(line) for line in bible_data]
    normalized_words = [[normalize_word(word) if word else '' for word in word_list] if word_list else [] for word_list in words]
    df = pd.DataFrame({'text': bible_data, 'words': words, 'normalized_words': normalized_words})
    df = df[df['text'].apply(lambda x: len(x) > 2)]
    df = df[df['text'] != "b'\n'"]
    return df

# %%
NIV84_df = vref_to_df('pfs/text_data/en-NIV84.txt')

# %%
gold_data = pd.read_parquet('../../../../new2old/data/gold_translation_data.parquet')

# %%
df.loc[:, 'total_score'] = df.apply(lambda row: row['word score'] * row['jac_sim'], axis=1)

# %%
domains = ['003001001', '003001002','003001004','003001006', '003001007','003001008','003001009','003001010', '003001012' ,'003001013' , '003001014', '003001015' , '003001017']
names_df = bible_df[bible_df['domain_codes'].apply(lambda x: len(set(domains).intersection(set(x))) > 0)]
names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)
# print(names)
english_names = names_df['english'].unique()
english_names = [name.lower() for name in english_names if name is not None]
hebrew_names = names_df['text'].unique()
hebrew_names = [name.lower() for name in hebrew_names if name is not None]
# Out:
# /tmp/ipykernel_259064/892064452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)

# %%
hebrew_matched_names = list(set(hebrew_names).intersection(df[df['jac_sim'] > 0]['target'].unique()))
english_matched_names = list(set(english_names).intersection(df[df['jac_sim'] > 0]['source'].unique()))

# %%
print(len(hebrew_names))
print(len(hebrew_matched_names))
print(len(english_names))
print(len(english_matched_names))
# Out:
# 9744
# 7245
# 2649
# 2155

# %%
names = names_df[names_df['text'].apply(lambda x: x in hebrew_names)]
# print(names_df.iloc[:, :14][names_df['english'].apply(lambda x: x in english_matched_names)])

# %%
names = names[gold_data['NIV84'].apply(lambda x: x is not None)]
# Out:
# /tmp/ipykernel_259064/1840373318.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   names = names[gold_data['NIV84'].apply(lambda x: x is not None)]

# %%
max_rows = -1
counter = Counter()
for index, row in names.iloc[:max_rows, :].iterrows():
    hebrew_source = row['text']
    hebrew_source_normalized = normalize_word(hebrew_source)    
    book = row['book']
    chapter = row['chapter']
    verse = row['verse']
#     word = row['word']
#     subword = row['subword']
    ref = f'{book} {chapter}:{verse}\n'
    vref_index = vref_data.index(ref)
#     print(ref)
#     print(vref_index)
#     candidate_words = set(gold_data[(gold_data['book'] == book) & (gold_data['chapter'] == chapter) & (gold_data['verse'] == verse)]['NIV84'])
#     candidate_words = [word.lower() for word in candidate_words if word is not None]
    candidate_words = set(NIV84_df.loc[vref_index, 'words'])  if vref_index in NIV84_df.index else set([])
    candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]

    candidate_df = df[(df['normalized_target'] == hebrew_source_normalized) | (df['normalized_source'] == hebrew_source_normalized)]
#     actual = row['english']
    actual = gold_data.loc[index, ['NIV84']].values[0] if index in gold_data.index else None
    actual = actual.lower() if actual else ''
    if len(actual.split()) > 1:
        counter['multiple words'] += 1
    elif candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words) or x['normalized_target'] in list(candidate_words), axis=1)].shape[0] > 0:
        pred = candidate_df.loc[candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words) or x['normalized_target'] in list(candidate_words), axis=1)]['total_score'].idxmax()]['source']
        correct = pred == actual or pred == actual.split("ʼ")[0] or actual == pred.split("ʼ")[0] 
        counter.update([correct]) 
    else:
        pred = ''
        counter['no prediction'] += 1

    if not correct:
        print(index)
        print(f"actual: {actual}   pred: {pred}")
#         print(candidate_df)
        print(counter)
# Out:
# 920
# actual: pishon   pred: first
# Counter({True: 7, False: 1})
# 1591
# actual: adam   pred: of
# Counter({True: 29, False: 2})
# 1670
# actual: eve   pred: would
# Counter({True: 29, False: 3})
# 1682
# actual: adam   pred: of
# Counter({True: 30, False: 4})
# 1779
# actual: eve   pred: pregnant
# Counter({True: 34, False: 5})
# 2231
# actual: adam   pred: of
# Counter({True: 88, False: 6})
# 2281
# actual: adam   pred: man
# Counter({True: 94, False: 7})
# 2314
# actual: adam   pred: in
# Counter({True: 94, False: 8})
# 2777
# actual: shem   pred: the
# Counter({True: 141, False: 9})
# 3519
# actual: shem   pred: the
# Counter({True: 168, False: 10})
# 4687
# actual: shem   pred: the
# Counter({True: 187, False: 11})
# 4750
# actual: shem   pred: in
# Counter({True: 195, False: 12})
# 4813
# actual: shem   pred: the
# Counter({True: 199, False: 13})
# 4828
# actual: shem   pred: in
# Counter({True: 201, False: 14})
# 4865
# actual: shem   pred: the
# Counter({True: 205, False: 15})
# 4883
# actual: madai   pred: gomer
# Counter({True: 210, False: 16})
# 4933
# actual: mizraim   pred: of
# Counter({True: 225, False: 17})
# 4935
# actual: put   pred: mizraim
# Counter({True: 225, False: 18})
# 4993
# actual: erech   pred: the
# Counter({True: 239, False: 19})
# 4995
# actual: akkad   pred: erech
# Counter({True: 239, False: 20})
# 5033
# actual: mizraim   pred: of
# Counter({True: 247, False: 21})
# 5036
# actual: ludites   pred: father
# Counter({True: 247, False: 22})
# 5039
# actual: anamites   pred: ludites
# Counter({True: 247, False: 23})
# 5042
# actual: lehabites   pred: anamites
# Counter({True: 247, False: 24})
# 5048
# actual: pathrusites   pred: casluhites
# Counter({True: 248, False: 25})
# 5101
# actual: zemarites   pred: hamathites
# Counter({True: 261, False: 26})
# 5116
# actual: canaan   pred: the
# Counter({True: 263, False: 27})
# 5132
# actual: admah   pred: zeboiim
# Counter({True: 268, False: 28})
# 5134
# actual: zeboiim   pred: as
# Counter({True: 268, False: 29})
# 5154
# actual: shem   pred: the
# Counter({True: 270, False: 30})
# 5167
# actual: shem   pred: the
# Counter({True: 271, False: 31})
# 5223
# actual: almodad   pred: father
# Counter({True: 287, False: 32})
# 5226
# actual: sheleph   pred: almodad
# Counter({True: 287, False: 33})
# 5229
# actual: hazarmaveth   pred: sheleph
# Counter({True: 287, False: 34})
# 5253
# actual: ophir   pred: havilah
# Counter({True: 294, False: 35})
# 5272
# actual: sephar   pred: they
# Counter({True: 298, False: 36})
# 5279
# actual: shem   pred: in
# Counter({True: 298, False: 37})
# 5483
# actual: babel   pred: of
# Counter({True: 303, False: 38})
# 5505
# actual: shem   pred: the
# Counter({True: 305, False: 39})
# 5506
# actual: shem   pred: the
# Counter({True: 305, False: 40})
# 5520
# actual: shem   pred: the
# Counter({True: 306, False: 41})
# 6177
# actual: egyptians   pred: egypt
# Counter({True: 398, False: 42, 'multiple words': 1})
# 6705
# actual: goiim   pred: of
# Counter({True: 457, False: 43, 'multiple words': 2})
# 6719
# actual: admah   pred: zeboiim
# Counter({True: 461, False: 44, 'multiple words': 2, 'no prediction': 1})
# 6721
# actual: shemeber   pred: zeboiim
# Counter({True: 461, False: 45, 'multiple words': 2, 'no prediction': 1})
# 6774
# actual: zuzites   pred: karnaim
# Counter({True: 468, False: 46, 'multiple words': 2, 'no prediction': 1})
# 6776
# actual: ham   pred: out
# Counter({True: 468, False: 47, 'multiple words': 2, 'no prediction': 1})
# 6834
# actual: admah   pred: zeboiim
# Counter({True: 478, False: 48, 'multiple words': 2, 'no prediction': 1})
# 6859
# actual: goiim   pred: of
# Counter({True: 485, False: 49, 'multiple words': 2, 'no prediction': 1})
# 6943
# actual: trees   pred: mamre
# Counter({True: 499, False: 50, 'multiple words': 2, 'no prediction': 1})
# 6997
# actual: hobah   pred: as
# Counter({True: 506, False: 51, 'multiple words': 2, 'no prediction': 1})
# 7131
# actual: god   pred: to
# Counter({True: 520, False: 52, 'multiple words': 2, 'no prediction': 1})
# 7211
# actual: lord   pred: sovereign
# Counter({True: 528, False: 53, 'multiple words': 2, 'no prediction': 1})
# 7213
# actual: sovereign   pred: lord
# Counter({True: 528, False: 54, 'multiple words': 2, 'no prediction': 1})
# 7337
# actual: lord   pred: sovereign
# Counter({True: 536, False: 55, 'multiple words': 2, 'no prediction': 1})
# 7339
# actual: sovereign   pred: lord
# Counter({True: 536, False: 56, 'multiple words': 2, 'no prediction': 1})
# 7552
# actual: kenizzites   pred: kenites
# Counter({True: 546, False: 57, 'multiple words': 2, 'no prediction': 1})
# 7863
# actual: god   pred: to
# Counter({True: 582, False: 58, 'multiple words': 2, 'no prediction': 1})
# 7939
# actual: god   pred: to
# Counter({True: 593, False: 59, 'multiple words': 2, 'no prediction': 1})
# 9182
# actual: them   pred: sodom
# Counter({True: 664, False: 60, 'multiple words': 3, 'no prediction': 1})
# 9318
# actual: friends   pred: my
# Counter({True: 667, False: 61, 'multiple words': 3, 'no prediction': 1})
# 10066
# actual: moabites   pred: moab
# Counter({True: 695, False: 62, 'multiple words': 3, 'no prediction': 1})
# 11692
# actual: kesed   pred: hazo
# Counter({True: 818, False: 63, 'multiple words': 3, 'no prediction': 1})
# 11695
# actual: hazo   pred: pildash
# Counter({True: 818, False: 64, 'multiple words': 3, 'no prediction': 1})
# 11698
# actual: pildash   pred: jidlaph
# Counter({True: 818, False: 65, 'multiple words': 3, 'no prediction': 1})
# 11701
# actual: jidlaph   pred: bethuel
# Counter({True: 818, False: 66, 'multiple words': 3, 'no prediction': 1})
# 11733
# actual: gaham   pred: tebah
# Counter({True: 825, False: 67, 'multiple words': 3, 'no prediction': 2})
# 11937
# actual: hittite   pred: hittites
# Counter({True: 842, False: 68, 'multiple words': 3, 'no prediction': 2})
# 13732
# actual: hanoch   pred: abida
# Counter({True: 950, False: 69, 'multiple words': 3, 'no prediction': 2})
# 13734
# actual: abida   pred: eldaah
# Counter({True: 950, False: 70, 'multiple words': 3, 'no prediction': 2})
# 13899
# actual: nebaioth   pred: birth
# Counter({True: 978, False: 71, 'multiple words': 3, 'no prediction': 2})
# 13903
# actual: adbeel   pred: kedar
# Counter({True: 979, False: 72, 'multiple words': 3, 'no prediction': 2})
# 14980
# actual: shibah   pred: שִׁבְעָ֑ה
# Counter({True: 1085, False: 73, 'multiple words': 4, 'no prediction': 3})
# 15003
# actual: judith   pred: beeri
# Counter({True: 1087, False: 74, 'multiple words': 4, 'no prediction': 3})
# 16118
# actual: god   pred: you
# Counter({True: 1158, False: 75, 'multiple words': 5, 'no prediction': 3})
# 16257
# actual: mahalath   pred: nebaioth
# Counter({True: 1178, False: 76, 'multiple words': 8, 'no prediction': 3})
# 17520
# actual: asher   pred: the
# Counter({True: 1282, False: 77, 'multiple words': 9, 'no prediction': 3})
# 21516
# actual: god   pred: to
# Counter({True: 1510, False: 78, 'multiple words': 13, 'no prediction': 4})
# 21776
# actual: asher   pred: the
# Counter({True: 1546, False: 79, 'multiple words': 13, 'no prediction': 4})
# 22013
# actual: omar   pred: teman
# Counter({True: 1599, False: 80, 'multiple words': 14, 'no prediction': 4})
# 22088
# actual: omar   pred: teman
# Counter({True: 1625, False: 81, 'multiple words': 14, 'no prediction': 4})
# 22169
# actual: lotan   pred: horite
# Counter({True: 1653, False: 82, 'multiple words': 14, 'no prediction': 4})
# 22177
# actual: dishon   pred: ezer
# Counter({True: 1656, False: 83, 'multiple words': 14, 'no prediction': 4})
# 22255
# actual: hemdan   pred: dishon
# Counter({True: 1682, False: 84, 'multiple words': 14, 'no prediction': 4})
# 22257
# actual: eshban   pred: hemdan
# Counter({True: 1682, False: 85, 'multiple words': 14, 'no prediction': 4})
# 22281
# actual: lotan   pred: horite
# Counter({True: 1692, False: 86, 'multiple words': 14, 'no prediction': 4})
# 22319
# actual: israelite   pred: the
# Counter({True: 1701, False: 87, 'multiple words': 14, 'no prediction': 4})
# 22351
# actual: husham   pred: temanites
# Counter({True: 1710, False: 88, 'multiple words': 14, 'no prediction': 4})
# 22365
# actual: bedad   pred: midian
# Counter({True: 1713, False: 89, 'multiple words': 14, 'no prediction': 4})
# 22387
# actual: masrekah   pred: as
# Counter({True: 1718, False: 90, 'multiple words': 14, 'no prediction': 4})
# 22397
# actual: rehoboth   pred: river
# Counter({True: 1720, False: 91, 'multiple words': 14, 'no prediction': 4})
# 22421
# actual: hadad   pred: הֲדַ֖ר
# Counter({True: 1724, False: 92, 'multiple words': 14, 'no prediction': 4})
# 22426
# actual: pau   pred:
# Counter({True: 1724, False: 92, 'multiple words': 14, 'no prediction': 5})
# 22431
# actual: mehetabel   pred: matred
# Counter({True: 1724, False: 93, 'multiple words': 14, 'no prediction': 5})
# 22470
# actual: magdiel   pred: iram
# Counter({True: 1735, False: 94, 'multiple words': 14, 'no prediction': 5})
# 22486
# actual: edomites   pred: edom
# Counter({True: 1738, False: 95, 'multiple words': 14, 'no prediction': 5})
# 23305
# actual: adullam   pred: hirah
# Counter({True: 1776, False: 96, 'multiple words': 14, 'no prediction': 5})
# 23517
# actual: adullamite   pred: hirah
# Counter({True: 1803, False: 97, 'multiple words': 14, 'no prediction': 5})
# 25074
# actual: riverbank   pred: nile
# Counter({True: 1876, False: 98, 'multiple words': 14, 'no prediction': 5})
# 25911
# actual: on   pred: potiphera
# Counter({True: 1928, False: 99, 'multiple words': 14, 'no prediction': 5})
# 26025
# actual: on   pred: potiphera
# Counter({True: 1940, False: 100, 'multiple words': 14, 'no prediction': 5})
# 26119
# actual: egyptians   pred: egypt
# Counter({True: 1949, False: 101, 'multiple words': 14, 'no prediction': 5})
# 26148
# actual: egyptians   pred: egypt
# Counter({True: 1951, False: 102, 'multiple words': 14, 'no prediction': 5})
# 27296
# actual: god   pred: you
# Counter({True: 1992, False: 103, 'multiple words': 14, 'no prediction': 5})
# 29385
# actual: ohad   pred: jakin
# Counter({True: 2095, False: 104, 'multiple words': 14, 'no prediction': 5})
# 29478
# actual: shuni   pred: haggi
# Counter({True: 2130, False: 105, 'multiple words': 15, 'no prediction': 5})
# 29480
# actual: ezbon   pred: shuni
# Counter({True: 2130, False: 106, 'multiple words': 15, 'no prediction': 5})
# 29481
# actual: eri   pred: of
# Counter({True: 2130, False: 107, 'multiple words': 15, 'no prediction': 5})
# 29488
# actual: asher   pred: the
# Counter({True: 2132, False: 108, 'multiple words': 15, 'no prediction': 5})
# 29548
# actual: on   pred: potiphera
# Counter({True: 2151, False: 109, 'multiple words': 15, 'no prediction': 5})
# 29565
# actual: ehi   pred: sons
# Counter({True: 2159, False: 110, 'multiple words': 15, 'no prediction': 5})
# 29567
# actual: rosh   pred: the
# Counter({True: 2159, False: 111, 'multiple words': 15, 'no prediction': 5})
# 29591
# actual: jahziel   pred: naphtali
# Counter({True: 2167, False: 112, 'multiple words': 15, 'no prediction': 5})
# 30363
# actual: egyptians   pred: egypt
# Counter({True: 2238, False: 113, 'multiple words': 15, 'no prediction': 5})
# 30717
# actual: god   pred: to
# Counter({True: 2268, False: 114, 'multiple words': 15, 'no prediction': 5})
# 31396
# actual: it   pred: belongs
# Counter({True: 2326, False: 115, 'multiple words': 15, 'no prediction': 5})
# 31439
# actual: seashore   pred: the
# Counter({True: 2327, False: 116, 'multiple words': 15, 'no prediction': 5})
# 31519
# actual: asher   pred: he
# Counter({True: 2334, False: 117, 'multiple words': 15, 'no prediction': 5})
# 32387
# actual: asher   pred: and
# Counter({True: 2417, False: 118, 'multiple words': 18, 'no prediction': 5})
# 32506
# actual: pithom   pred: store
# Counter({True: 2426, False: 119, 'multiple words': 18, 'no prediction': 5})
# 32591
# actual: hebrew   pred: childbirth
# Counter({True: 2432, False: 120, 'multiple words': 18, 'no prediction': 5})
# 32743
# actual: levite   pred: levi
# Counter({True: 2440, False: 121, 'multiple words': 18, 'no prediction': 5})
# 32829
# actual: river   pred: nile
# Counter({True: 2443, False: 122, 'multiple words': 18, 'no prediction': 5})
# 32868
# actual: hebrew   pred: babies
# Counter({True: 2443, False: 123, 'multiple words': 18, 'no prediction': 5})
# 34121
# actual: river   pred: nile
# Counter({True: 2548, False: 124, 'multiple words': 18, 'no prediction': 6})
# 34323
# actual: jethro   pred: of
# Counter({True: 2559, False: 125, 'multiple words': 18, 'no prediction': 6})
# 34917
# actual: israelite   pred: the
# Counter({True: 2608, False: 126, 'multiple words': 18, 'no prediction': 6})
# 34945
# actual: israelite   pred: the
# Counter({True: 2609, False: 127, 'multiple words': 18, 'no prediction': 6})
# 35011
# actual: israelite   pred: the
# Counter({True: 2611, False: 128, 'multiple words': 18, 'no prediction': 6})
# 35170
# actual: god   pred: to
# Counter({True: 2628, False: 129, 'multiple words': 18, 'no prediction': 6})
# 35432
# actual: ohad   pred: jakin
# Counter({True: 2670, False: 130, 'multiple words': 18, 'no prediction': 6})
# 35513
# actual: jochebed   pred: amram
# Counter({True: 2694, False: 131, 'multiple words': 18, 'no prediction': 6})
# 35618
# actual: levite   pred: were
# Counter({True: 2722, False: 132, 'multiple words': 18, 'no prediction': 6})
# 35796
# actual: egyptians   pred: egypt
# Counter({True: 2753, False: 133, 'multiple words': 18, 'no prediction': 6})
# 36080
# actual: river   pred: nile
# Counter({True: 2788, False: 134, 'multiple words': 18, 'no prediction': 6})
# 36196
# actual: river   pred: nile
# Counter({True: 2798, False: 135, 'multiple words': 18, 'no prediction': 6})
# 36200
# actual: egyptians   pred: egypt
# Counter({True: 2798, False: 136, 'multiple words': 18, 'no prediction': 6})
# 36270
# actual: river   pred: nile
# Counter({True: 2804, False: 137, 'multiple words': 18, 'no prediction': 6})
# 37147
# actual: israelites   pred: israel
# Counter({True: 2885, False: 138, 'multiple words': 18, 'no prediction': 6})
# 38420
# actual: sea   pred: west
# Counter({True: 2984, False: 139, 'multiple words': 18, 'no prediction': 6})
# 38694
# actual: egyptians   pred: egypt
# Counter({True: 3010, False: 140, 'multiple words': 18, 'no prediction': 6})
# 38777
# actual: israelites   pred: israel
# Counter({True: 3019, False: 141, 'multiple words': 18, 'no prediction': 6})
# 39564
# actual: egyptians   pred: egypt
# Counter({True: 3056, False: 142, 'multiple words': 18, 'no prediction': 6})
# 39638
# actual: egyptians   pred: egypt
# Counter({True: 3064, False: 143, 'multiple words': 18, 'no prediction': 6})
# 39836
# actual: israelite   pred: the
# Counter({True: 3081, False: 144, 'multiple words': 18, 'no prediction': 6})
# 40821
# actual: egyptians   pred: egypt
# Counter({True: 3171, False: 145, 'multiple words': 18, 'no prediction': 6})
# 40828
# actual: egyptians   pred: egypt
# Counter({True: 3171, False: 146, 'multiple words': 18, 'no prediction': 6})
# 41138
# actual: egyptians   pred: egypt
# Counter({True: 3194, False: 147, 'multiple words': 18, 'no prediction': 6})
# 41349
# actual: lord   pred: praise
# Counter({True: 3219, False: 148, 'multiple words': 18, 'no prediction': 6})
# 41819
# actual: israelite   pred: the
# Counter({True: 3255, False: 149, 'multiple words': 18, 'no prediction': 6})
# 42057
# actual: israelite   pred: the
# Counter({True: 3275, False: 150, 'multiple words': 18, 'no prediction': 6})
# 42076
# actual: israelite   pred: the
# Counter({True: 3277, False: 151, 'multiple words': 18, 'no prediction': 6})
# 42655
# actual: israelite   pred: the
# Counter({True: 3311, False: 152, 'multiple words': 18, 'no prediction': 6})
# 42658
# actual: sin   pred: traveling
# Counter({True: 3311, False: 153, 'multiple words': 18, 'no prediction': 6})
# 42979
# actual: amalekite   pred: overcame
# Counter({True: 3350, False: 154, 'multiple words': 18, 'no prediction': 6})
# 43030
# actual: lord   pred: the
# Counter({True: 3356, False: 155, 'multiple words': 18, 'no prediction': 6})
# 46670
# actual: israelite   pred: the
# Counter({True: 3502, False: 156, 'multiple words': 18, 'no prediction': 6})
# 52359
# actual: sound   pred: moses
# Counter({True: 3681, False: 157, 'multiple words': 18, 'no prediction': 6})
# 54164
# actual: israelite   pred: the
# Counter({True: 3784, False: 158, 'multiple words': 18, 'no prediction': 6})
# 54222
# actual: israelite   pred: the
# Counter({True: 3787, False: 159, 'multiple words': 18, 'no prediction': 6})
# 54509
# actual: israelite   pred: the
# Counter({True: 3792, False: 160, 'multiple words': 18, 'no prediction': 6})
# 54736
# actual: israelite   pred: the
# Counter({True: 3798, False: 161, 'multiple words': 18, 'no prediction': 6})
# 59864
# actual: israelite   pred: the
# Counter({True: 3952, False: 162, 'multiple words': 18, 'no prediction': 6})
# 69062
# actual: israelite   pred: the
# Counter({True: 4200, False: 163, 'multiple words': 18, 'no prediction': 6})
# 69886
# actual: israelite   pred: the
# Counter({True: 4228, False: 164, 'multiple words': 18, 'no prediction': 6})
# 70166
# actual: israelite   pred: the
# Counter({True: 4239, False: 165, 'multiple words': 18, 'no prediction': 6})
# 71444
# actual: israelites   pred: israel
# Counter({True: 4279, False: 166, 'multiple words': 18, 'no prediction': 6})
# 71450
# actual: israelite   pred: israel
# Counter({True: 4279, False: 167, 'multiple words': 18, 'no prediction': 6})
# 71575
# actual: molech   pred: in
# Counter({True: 4280, False: 168, 'multiple words': 18, 'no prediction': 6})
# 72905
# actual: israelites   pred: israel
# Counter({True: 4317, False: 169, 'multiple words': 18, 'no prediction': 6})
# 72914
# actual: israelite   pred: israel
# Counter({True: 4317, False: 170, 'multiple words': 18, 'no prediction': 6})
# 74294
# actual: israelite   pred: blasphemed
# Counter({True: 4395, False: 171, 'multiple words': 18, 'no prediction': 7})
# 74312
# actual: dibri   pred: of
# Counter({True: 4397, False: 172, 'multiple words': 18, 'no prediction': 7})
# 75183
# actual: levitical   pred: levites
# Counter({True: 4416, False: 173, 'multiple words': 18, 'no prediction': 7})
# 77407
# actual: israelite   pred: the
# Counter({True: 4467, False: 174, 'multiple words': 18, 'no prediction': 8})
# 77518
# actual: asher   pred: of
# Counter({True: 4497, False: 175, 'multiple words': 18, 'no prediction': 8})
# 77994
# actual: asher   pred: the
# Counter({True: 4533, False: 176, 'multiple words': 18, 'no prediction': 8})
# 78021
# actual: asher   pred: the
# Counter({True: 4533, False: 177, 'multiple words': 18, 'no prediction': 8})
# 78091
# actual: israelites   pred: israel
# Counter({True: 4538, False: 178, 'multiple words': 18, 'no prediction': 8})
# 78126
# actual: levi   pred: were
# Counter({True: 4539, False: 179, 'multiple words': 18, 'no prediction': 8})
# 78258
# actual: israelite   pred: the
# Counter({True: 4548, False: 180, 'multiple words': 18, 'no prediction': 8})
# 78679
# actual: asher   pred: the
# Counter({True: 4600, False: 181, 'multiple words': 18, 'no prediction': 8})
# 78684
# actual: asher   pred: the
# Counter({True: 4600, False: 182, 'multiple words': 18, 'no prediction': 8})
# 79020
# actual: israelite   pred: israelites
# Counter({True: 4646, False: 183, 'multiple words': 18, 'no prediction': 8})
# 79157
# actual: libnites   pred: gershon
# Counter({True: 4673, False: 184, 'multiple words': 18, 'no prediction': 8})
# 79370
# actual: merarite   pred: merari
# Counter({True: 4695, False: 185, 'multiple words': 18, 'no prediction': 8})
# 79517
# actual: israelite   pred: the
# Counter({True: 4709, False: 186, 'multiple words': 18, 'no prediction': 8})
# 83184
# actual: asher   pred: the
# Counter({True: 4892, False: 187, 'multiple words': 18, 'no prediction': 8})
# 83358
# actual: israelite   pred: the
# Counter({True: 4901, False: 188, 'multiple words': 18, 'no prediction': 8})
# 83664
# actual: israelite   pred: the
# Counter({True: 4915, False: 189, 'multiple words': 18, 'no prediction': 8})
# 83806
# actual: israelite   pred: israelites
# Counter({True: 4934, False: 190, 'multiple words': 18, 'no prediction': 8})
# 83907
# actual: israelite   pred: the
# Counter({True: 4945, False: 191, 'multiple words': 18, 'no prediction': 8})
# 84871
# actual: helon   pred: zebulun
# Counter({True: 5008, False: 192, 'multiple words': 18, 'no prediction': 8})
# 84923
# actual: kohathites   pred: carrying
# Counter({True: 5018, False: 193, 'multiple words': 18, 'no prediction': 8})
# 84969
# actual: gideoni   pred: benjamin
# Counter({True: 5025, False: 194, 'multiple words': 18, 'no prediction': 8})
# 84996
# actual: asher   pred: the
# Counter({True: 5028, False: 195, 'multiple words': 18, 'no prediction': 8})
# 85012
# actual: israelite   pred: the
# Counter({True: 5033, False: 196, 'multiple words': 18, 'no prediction': 8})
# 85026
# actual: midianite   pred: fatherinlaw
# Counter({True: 5036, False: 197, 'multiple words': 18, 'no prediction': 8})
# 85873
# actual: medad   pred: prophesying
# Counter({True: 5078, False: 198, 'multiple words': 18, 'no prediction': 9})
# 86467
# actual: asher   pred: the
# Counter({True: 5158, False: 199, 'multiple words': 18, 'no prediction': 9})
# 86724
# actual: israelite   pred: the
# Counter({True: 5188, False: 200, 'multiple words': 19, 'no prediction': 9})
# 87038
# actual: israelite   pred: the
# Counter({True: 5214, False: 201, 'multiple words': 19, 'no prediction': 9})
# 87062
# actual: israelite   pred: the
# Counter({True: 5218, False: 202, 'multiple words': 19, 'no prediction': 9})
# 88365
# actual: israelite   pred: the
# Counter({True: 5293, False: 203, 'multiple words': 19, 'no prediction': 9})
# 88397
# actual: israelite   pred: the
# Counter({True: 5294, False: 204, 'multiple words': 19, 'no prediction': 9})
# 88457
# actual: israelite   pred: the
# Counter({True: 5295, False: 205, 'multiple words': 19, 'no prediction': 9})
# 88743
# actual: abiram   pred: dathan
# Counter({True: 5316, False: 206, 'multiple words': 19, 'no prediction': 9})
# 88747
# actual: on   pred: peleth
# Counter({True: 5317, False: 207, 'multiple words': 19, 'no prediction': 9})
# 88761
# actual: israelite   pred: the
# Counter({True: 5320, False: 208, 'multiple words': 19, 'no prediction': 9})
# 88908
# actual: israelite   pred: israel
# Counter({True: 5335, False: 209, 'multiple words': 19, 'no prediction': 9})
# 88976
# actual: abiram   pred: dathan
# Counter({True: 5340, False: 210, 'multiple words': 19, 'no prediction': 9})
# 89222
# actual: abiram   pred: dathan
# Counter({True: 5360, False: 211, 'multiple words': 19, 'no prediction': 9})
# 89231
# actual: abiram   pred: dathan
# Counter({True: 5362, False: 212, 'multiple words': 19, 'no prediction': 9})
# 89278
# actual: abiram   pred: dathan
# Counter({True: 5365, False: 213, 'multiple words': 19, 'no prediction': 9})
# 89284
# actual: abiram   pred: dathan
# Counter({True: 5366, False: 214, 'multiple words': 19, 'no prediction': 9})
# 89616
# actual: israelite   pred: the
# Counter({True: 5386, False: 215, 'multiple words': 19, 'no prediction': 9})
# 91087
# actual: israelite   pred: the
# Counter({True: 5477, False: 216, 'multiple words': 19, 'no prediction': 9})
# 91453
# actual: israelite   pred: the
# Counter({True: 5481, False: 217, 'multiple words': 19, 'no prediction': 9})
# 91792
# actual: egyptians   pred: egypt
# Counter({True: 5512, False: 218, 'multiple words': 19, 'no prediction': 9})
# 91942
# actual: israelite   pred: the
# Counter({True: 5521, False: 219, 'multiple words': 19, 'no prediction': 9})
# 91946
# actual: hor   pred: mount
# Counter({True: 5521, False: 220, 'multiple words': 19, 'no prediction': 9})
# 91958
# actual: hor   pred: mount
# Counter({True: 5524, False: 221, 'multiple words': 19, 'no prediction': 9})
# 92004
# actual: hor   pred: mount
# Counter({True: 5529, False: 222, 'multiple words': 19, 'no prediction': 9})
# 92037
# actual: hor   pred: mount
# Counter({True: 5534, False: 223, 'multiple words': 19, 'no prediction': 9})
# 92112
# actual: israelites   pred: israel
# Counter({True: 5547, False: 224, 'multiple words': 19, 'no prediction': 9})
# 92170
# actual: hor   pred: mount
# Counter({True: 5553, False: 225, 'multiple words': 19, 'no prediction': 9})
# 92174
# actual: red sea   pred: mount
# Counter({True: 5553, False: 225, 'multiple words': 20, 'no prediction': 9})
# 92385
# actual: amorite   pred: amorites
# Counter({True: 5571, False: 226, 'multiple words': 20, 'no prediction': 9})
# 92406
# actual: suphah   pred: waheb
# Counter({True: 5577, False: 227, 'multiple words': 20, 'no prediction': 10})
# 92429
# actual: beer   pred: well
# Counter({True: 5580, False: 228, 'multiple words': 20, 'no prediction': 10})
# 92873
# actual: moabites   pred: moab
# Counter({True: 5649, False: 229, 'multiple words': 20, 'no prediction': 10})
# 94940
# actual: israelite   pred: israel
# Counter({True: 5829, False: 230, 'multiple words': 20, 'no prediction': 11})
# 94991
# actual: israelite   pred: israelites
# Counter({True: 5835, False: 231, 'multiple words': 20, 'no prediction': 11})
# 95002
# actual: israelite   pred: israelites
# Counter({True: 5835, False: 232, 'multiple words': 20, 'no prediction': 11})
# 95108
# actual: israelite   pred: the
# Counter({True: 5843, False: 233, 'multiple words': 20, 'no prediction': 11})
# 95216
# actual: israelite   pred: israel
# Counter({True: 5861, False: 234, 'multiple words': 20, 'no prediction': 11})
# 95294
# actual: carmite   pred: carmi
# Counter({True: 5880, False: 235, 'multiple words': 20, 'no prediction': 11})
# 95298
# actual: reuben   pred: the
# Counter({True: 5880, False: 236, 'multiple words': 20, 'no prediction': 11})
# 95323
# actual: abiram   pred: dathan
# Counter({True: 5885, False: 237, 'multiple words': 20, 'no prediction': 11})
# 95327
# actual: abiram   pred: dathan
# Counter({True: 5886, False: 238, 'multiple words': 20, 'no prediction': 11})
# 95415
# actual: simeon   pred: clans
# Counter({True: 5903, False: 239, 'multiple words': 20, 'no prediction': 11})
# 95436
# actual: haggite   pred: haggi
# Counter({True: 5907, False: 240, 'multiple words': 20, 'no prediction': 11})
# 95438
# actual: shuni   pred: haggi
# Counter({True: 5907, False: 241, 'multiple words': 20, 'no prediction': 11})
# 95441
# actual: shunite   pred: haggi
# Counter({True: 5907, False: 242, 'multiple words': 20, 'no prediction': 11})
# 95443
# actual: ozni   pred: oznite
# Counter({True: 5907, False: 243, 'multiple words': 20, 'no prediction': 11})
# 95448
# actual: eri   pred: the
# Counter({True: 5908, False: 244, 'multiple words': 20, 'no prediction': 11})
# 95451
# actual: erite   pred: the
# Counter({True: 5908, False: 245, 'multiple words': 20, 'no prediction': 11})
# 95456
# actual: arodite   pred: arodi
# Counter({True: 5909, False: 246, 'multiple words': 20, 'no prediction': 11})
# 95461
# actual: arelite   pred: areli
# Counter({True: 5910, False: 247, 'multiple words': 20, 'no prediction': 11})
# 95680
# actual: noah   pred: mahlah
# Counter({True: 5971, False: 248, 'multiple words': 20, 'no prediction': 12})
# 95841
# actual: asher   pred: the
# Counter({True: 6010, False: 249, 'multiple words': 20, 'no prediction': 12})
# 95849
# actual: imnite   pred: imnah
# Counter({True: 6011, False: 250, 'multiple words': 20, 'no prediction': 12})
# 95854
# actual: ishvite   pred: ishvi
# Counter({True: 6012, False: 251, 'multiple words': 20, 'no prediction': 12})
# 95876
# actual: asher   pred: had
# Counter({True: 6019, False: 252, 'multiple words': 20, 'no prediction': 12})
# 95881
# actual: asher   pred: the
# Counter({True: 6020, False: 253, 'multiple words': 20, 'no prediction': 12})
# 95906
# actual: gunite   pred: guni
# Counter({True: 6024, False: 254, 'multiple words': 20, 'no prediction': 12})
# 96027
# actual: merarite   pred: merari
# Counter({True: 6036, False: 255, 'multiple words': 20, 'no prediction': 12})
# 96039
# actual: hebronite   pred: clan
# Counter({True: 6039, False: 256, 'multiple words': 20, 'no prediction': 12})
# 96058
# actual: jochebed   pred: amram
# Counter({True: 6045, False: 257, 'multiple words': 20, 'no prediction': 12})
# 96060
# actual: levites   pred: levi
# Counter({True: 6045, False: 258, 'multiple words': 20, 'no prediction': 12})
# 96230
# actual: noah   pred: mahlah
# Counter({True: 6083, False: 259, 'multiple words': 20, 'no prediction': 12})
# 96513
# actual: kadesh   pred: holy
# Counter({True: 6104, False: 260, 'multiple words': 20, 'no prediction': 12})
# 96625
# actual: israelite   pred: the
# Counter({True: 6114, False: 261, 'multiple words': 20, 'no prediction': 12})
# 98641
# actual: israelite   pred: the
# Counter({True: 6184, False: 262, 'multiple words': 20, 'no prediction': 13})
# 99511
# actual: elealeh   pred: sebam
# Counter({True: 6243, False: 263, 'multiple words': 20, 'no prediction': 13})
# 99513
# actual: sebam   pred: nebo
# Counter({True: 6243, False: 264, 'multiple words': 20, 'no prediction': 13})
# 100038
# actual: israelite   pred: the
# Counter({True: 6292, False: 265, 'multiple words': 20, 'no prediction': 13})
# 100270
# actual: makirites   pred: descendants
# Counter({True: 6328, False: 266, 'multiple words': 20, 'no prediction': 13})
# 100742
# actual: hor   pred: mount
# Counter({True: 6398, False: 267, 'multiple words': 21, 'no prediction': 13})
# 100755
# actual: hor   pred: mount
# Counter({True: 6400, False: 268, 'multiple words': 21, 'no prediction': 13})
# 100798
# actual: hor   pred: mount
# Counter({True: 6404, False: 269, 'multiple words': 21, 'no prediction': 13})
# 100823
# actual: hor   pred: mount
# Counter({True: 6408, False: 270, 'multiple words': 21, 'no prediction': 13})
# 101228
# actual: northern   pred: the
# Counter({True: 6451, False: 271, 'multiple words': 21, 'no prediction': 13})
# 101237
# actual: hor   pred: mount
# Counter({True: 6452, False: 272, 'multiple words': 21, 'no prediction': 13})
# 101241
# actual: hor   pred: mount
# Counter({True: 6452, False: 273, 'multiple words': 21, 'no prediction': 13})
# 101368
# actual: reuben   pred: the
# Counter({True: 6467, False: 274, 'multiple words': 21, 'no prediction': 13})
# 101377
# actual: gad   pred: גָּדִ֔י
# Counter({True: 6467, False: 275, 'multiple words': 21, 'no prediction': 13})
# 101468
# actual: elidad   pred: kislon
# Counter({True: 6481, False: 276, 'multiple words': 21, 'no prediction': 14})
# 101470
# actual: kislon   pred: benjamin
# Counter({True: 6481, False: 277, 'multiple words': 21, 'no prediction': 14})
# 101479
# actual: jogli   pred: dan
# Counter({True: 6483, False: 278, 'multiple words': 21, 'no prediction': 14})
# 101499
# actual: shiphtan   pred: joseph
# Counter({True: 6489, False: 279, 'multiple words': 21, 'no prediction': 14})
# 101508
# actual: parnach   pred: zebulun
# Counter({True: 6491, False: 280, 'multiple words': 21, 'no prediction': 14})
# 101517
# actual: azzan   pred: issachar
# Counter({True: 6493, False: 281, 'multiple words': 21, 'no prediction': 14})
# 101522
# actual: asher   pred: the
# Counter({True: 6493, False: 282, 'multiple words': 21, 'no prediction': 14})
# 101524
# actual: ahihud   pred: tribe
# Counter({True: 6493, False: 283, 'multiple words': 21, 'no prediction': 14})
# 101526
# actual: shelomi   pred: asher
# Counter({True: 6493, False: 284, 'multiple words': 21, 'no prediction': 14})
# 102345
# actual: israelite   pred: the
# Counter({True: 6521, False: 285, 'multiple words': 21, 'no prediction': 15})
# 102389
# actual: israelite   pred: the
# Counter({True: 6524, False: 286, 'multiple words': 21, 'no prediction': 15})
# 102510
# actual: israelite   pred: israel
# Counter({True: 6532, False: 287, 'multiple words': 21, 'no prediction': 15})
# 102519
# actual: israelite   pred: the
# Counter({True: 6532, False: 288, 'multiple words': 21, 'no prediction': 15})
# 102533
# actual: israelite   pred: the
# Counter({True: 6532, False: 289, 'multiple words': 21, 'no prediction': 15})
# 102555
# actual: israelite   pred: the
# Counter({True: 6532, False: 290, 'multiple words': 21, 'no prediction': 15})
# 102575
# actual: noah   pred: mahlah
# Counter({True: 6539, False: 291, 'multiple words': 21, 'no prediction': 15})
# 102643
# actual: suph   pred: the
# Counter({True: 6551, False: 292, 'multiple words': 21, 'no prediction': 15})
# 102648
# actual: tophel   pred: suph
# Counter({True: 6552, False: 293, 'multiple words': 21, 'no prediction': 15})
# 102716
# actual: ashtaroth   pred: reigned
# Counter({True: 6564, False: 294, 'multiple words': 21, 'no prediction': 15})
# 105130
# actual: lord   pred: sovereign
# Counter({True: 6758, False: 295, 'multiple words': 21, 'no prediction': 19})
# 105132
# actual: sovereign   pred: lord
# Counter({True: 6758, False: 296, 'multiple words': 21, 'no prediction': 19})
# 109789
# actual: lord   pred: sovereign
# Counter({True: 6981, False: 297, 'multiple words': 21, 'no prediction': 19})
# 109791
# actual: sovereign   pred: lord
# Counter({True: 6981, False: 298, 'multiple words': 21, 'no prediction': 19})
# 110516
# actual: egyptian   pred: brought
# Counter({True: 7021, False: 299, 'multiple words': 21, 'no prediction': 19})
# 110570
# actual: abiram   pred: dathan
# Counter({True: 7024, False: 300, 'multiple words': 21, 'no prediction': 19})
# 111212
# actual: moreh   pred: vicinity
# Counter({True: 7052, False: 301, 'multiple words': 22, 'no prediction': 19})
# 117426
# actual: israelite   pred: the
# Counter({True: 7229, False: 302, 'multiple words': 22, 'no prediction': 19})
# 117809
# actual: pethor   pred: naharaim
# Counter({True: 7238, False: 303, 'multiple words': 22, 'no prediction': 19})
# 120047
# actual: asher   pred: to
# Counter({True: 7329, False: 304, 'multiple words': 22, 'no prediction': 19})
# 122480
# actual: admah   pred: zeboiim
# Counter({True: 7409, False: 305, 'multiple words': 22, 'no prediction': 20})
# 124804
# actual: joshua   pred: of
# Counter({True: 7497, False: 306, 'multiple words': 22, 'no prediction': 20})
# 124954
# actual: hor   pred: mountain
# Counter({True: 7510, False: 307, 'multiple words': 22, 'no prediction': 20})
# 125418
# actual: lake   pred: the
# Counter({True: 7554, False: 308, 'multiple words': 22, 'no prediction': 20})
# 125425
# actual: asher   pred: of
# Counter({True: 7554, False: 309, 'multiple words': 22, 'no prediction': 20})
# 125430
# actual: asher   pred: of
# Counter({True: 7554, False: 310, 'multiple words': 22, 'no prediction': 20})
# 127369
# actual: completely   pred: salt
# Counter({True: 7692, False: 311, 'multiple words': 23, 'no prediction': 21})
# 127838
# actual: set   pred: jordan
# Counter({True: 7737, False: 312, 'multiple words': 23, 'no prediction': 21})
# 128022
# actual: coast   pred: west
# Counter({True: 7753, False: 313, 'multiple words': 23, 'no prediction': 21})
# 129214
# actual: israelites   pred: israel
# Counter({True: 7820, False: 314, 'multiple words': 23, 'no prediction': 21})
# 129405
# actual: lord   pred: sovereign
# Counter({True: 7838, False: 315, 'multiple words': 24, 'no prediction': 21})
# 129407
# actual: sovereign   pred: lord
# Counter({True: 7838, False: 316, 'multiple words': 24, 'no prediction': 21})
# 129790
# actual: a   pred: from
# Counter({True: 7876, False: 317, 'multiple words': 24, 'no prediction': 21})
# 130636
# actual: israelites   pred: israel
# Counter({True: 7925, False: 318, 'multiple words': 25, 'no prediction': 21})
# 130708
# actual: israelites   pred: israel
# Counter({True: 7929, False: 319, 'multiple words': 25, 'no prediction': 21})
# 131173
# actual: perhaps   pred: hivites
# Counter({True: 7979, False: 320, 'multiple words': 25, 'no prediction': 21})
# 131437
# actual: israelites   pred: israel
# Counter({True: 7996, False: 321, 'multiple words': 25, 'no prediction': 21})
# 132017
# actual: israelites   pred: israel
# Counter({True: 8051, False: 322, 'multiple words': 25, 'no prediction': 21})
# 132755
# actual: debir   pred: all
# Counter({True: 8121, False: 323, 'multiple words': 25, 'no prediction': 21})
# 132798
# actual: debir   pred: the
# Counter({True: 8122, False: 324, 'multiple words': 25, 'no prediction': 21})
# 132933
# actual: northern   pred: on
# Counter({True: 8144, False: 325, 'multiple words': 27, 'no prediction': 21})
# 133465
# actual: debir   pred: the
# Counter({True: 8205, False: 326, 'multiple words': 28, 'no prediction': 21})
# 133664
# actual: maacah   pred: geshur
# Counter({True: 8243, False: 327, 'multiple words': 29, 'no prediction': 21})
# 133711
# actual: israelites   pred: israel
# Counter({True: 8253, False: 328, 'multiple words': 29, 'no prediction': 21})
# 133814
# actual: debir   pred: the
# Counter({True: 8272, False: 329, 'multiple words': 29, 'no prediction': 21})
# 133887
# actual: goyim   pred: the
# Counter({True: 8291, False: 330, 'multiple words': 29, 'no prediction': 21})
# 133965
# actual: ashkelon   pred: gaza
# Counter({True: 8301, False: 331, 'multiple words': 30, 'no prediction': 23})
# 133967
# actual: gath   pred:
# Counter({True: 8301, False: 331, 'multiple words': 30, 'no prediction': 24})
# 134032
# actual: israelites   pred: israel
# Counter({True: 8312, False: 332, 'multiple words': 30, 'no prediction': 24})
# 134139
# actual: maacah   pred: geshur
# Counter({True: 8329, False: 333, 'multiple words': 31, 'no prediction': 24})
# 134187
# actual: maacah   pred: geshur
# Counter({True: 8337, False: 334, 'multiple words': 32, 'no prediction': 24})
# 134446
# actual: zaphon   pred: the
# Counter({True: 8385, False: 335, 'multiple words': 32, 'no prediction': 25})
# 134584
# actual: israelites   pred: israel
# Counter({True: 8414, False: 336, 'multiple words': 32, 'no prediction': 25})
# 135077
# actual: azmon   pred: passed
# Counter({True: 8471, False: 337, 'multiple words': 32, 'no prediction': 25})
# 135146
# actual: debir   pred: the
# Counter({True: 8481, False: 338, 'multiple words': 32, 'no prediction': 25})
# 135219
# actual: northern   pred: the
# Counter({True: 8489, False: 339, 'multiple words': 33, 'no prediction': 25})
# 135357
# actual: anakites   pred: anak
# Counter({True: 8513, False: 340, 'multiple words': 33, 'no prediction': 25})
# 135375
# actual: debir   pred: the
# Counter({True: 8517, False: 341, 'multiple words': 33, 'no prediction': 25})
# 135577
# actual: shilhim   pred: ain
# Counter({True: 8559, False: 342, 'multiple words': 33, 'no prediction': 25})
# 135614
# actual: shaaraim   pred: adithaim
# Counter({True: 8569, False: 343, 'multiple words': 33, 'no prediction': 25})
# 135616
# actual: adithaim   pred: gederah
# Counter({True: 8569, False: 344, 'multiple words': 33, 'no prediction': 25})
# 135682
# actual: mareshah   pred: nine
# Counter({True: 8591, False: 345, 'multiple words': 33, 'no prediction': 25})
# 135736
# actual: jattir   pred: shamir
# Counter({True: 8600, False: 346, 'multiple words': 33, 'no prediction': 25})
# 135745
# actual: debir   pred: is
# Counter({True: 8602, False: 347, 'multiple words': 33, 'no prediction': 25})
# 135757
# actual: giloh   pred: eleven
# Counter({True: 8607, False: 348, 'multiple words': 33, 'no prediction': 25})
# 135823
# actual: eltekon   pred: six
# Counter({True: 8625, False: 349, 'multiple words': 33, 'no prediction': 25})
# 135847
# actual: middin   pred: arabah
# Counter({True: 8626, False: 350, 'multiple words': 33, 'no prediction': 25})
# 135933
# actual: westward   pred: sea
# Counter({True: 8640, False: 351, 'multiple words': 33, 'no prediction': 25})
# 136039
# actual: sea   pred: west
# Counter({True: 8657, False: 352, 'multiple words': 33, 'no prediction': 25})
# 136061
# actual: manassites   pred: were
# Counter({True: 8659, False: 353, 'multiple words': 33, 'no prediction': 25})
# 136112
# actual: gileadites   pred: gilead
# Counter({True: 8666, False: 354, 'multiple words': 34, 'no prediction': 25})
# 136143
# actual: helek   pred: allotment
# Counter({True: 8670, False: 355, 'multiple words': 34, 'no prediction': 25})
# 136196
# actual: noah   pred: mahlah
# Counter({True: 8682, False: 356, 'multiple words': 34, 'no prediction': 25})
# 136291
# actual: asher   pred: the
# Counter({True: 8698, False: 357, 'multiple words': 34, 'no prediction': 25})
# 136374
# actual: asher   pred: the
# Counter({True: 8716, False: 358, 'multiple words': 35, 'no prediction': 25})
# 136392
# actual: asher   pred: the
# Counter({True: 8720, False: 359, 'multiple words': 35, 'no prediction': 25})
# 136436
# actual: manassites   pred: were
# Counter({True: 8724, False: 360, 'multiple words': 35, 'no prediction': 25})
# 136942
# actual: northern   pred: north
# Counter({True: 8771, False: 361, 'multiple words': 35, 'no prediction': 25})
# 137093
# actual: geliloth   pred: adummim
# Counter({True: 8782, False: 362, 'multiple words': 36, 'no prediction': 25})
# 137137
# actual: northern   pred: salt
# Counter({True: 8786, False: 363, 'multiple words': 36, 'no prediction': 25})
# 137143
# actual: south   pred: jordan
# Counter({True: 8786, False: 364, 'multiple words': 36, 'no prediction': 25})
# 137211
# actual: towns   pred: geba
# Counter({True: 8794, False: 365, 'multiple words': 36, 'no prediction': 25})
# 137296
# actual: sheba   pred: beersheba
# Counter({True: 8808, False: 366, 'multiple words': 37, 'no prediction': 25})
# 137490
# actual: nahalal   pred: kattath
# Counter({True: 8837, False: 367, 'multiple words': 38, 'no prediction': 25})
# 137584
# actual: towns   pred: jordan
# Counter({True: 8852, False: 368, 'multiple words': 38, 'no prediction': 25})
# 137613
# actual: asher   pred: the
# Counter({True: 8853, False: 369, 'multiple words': 38, 'no prediction': 25})
# 137629
# actual: allammelech   pred: amad
# Counter({True: 8857, False: 370, 'multiple words': 38, 'no prediction': 25})
# 137678
# actual: hammon   pred: kanah
# Counter({True: 8865, False: 371, 'multiple words': 38, 'no prediction': 25})
# 137728
# actual: asher   pred: the
# Counter({True: 8872, False: 372, 'multiple words': 38, 'no prediction': 25})
# 137798
# actual: asher   pred: the
# Counter({True: 8881, False: 373, 'multiple words': 38, 'no prediction': 25})
# 137814
# actual: ziddim   pred: were
# Counter({True: 8882, False: 374, 'multiple words': 38, 'no prediction': 25})
# 137815
# actual: zer   pred: the
# Counter({True: 8882, False: 375, 'multiple words': 38, 'no prediction': 25})
# 137836
# actual: iron   pred: el
# Counter({True: 8890, False: 376, 'multiple words': 38, 'no prediction': 25})
# 137931
# actual: danites   pred: dan
# Counter({True: 8907, False: 377, 'multiple words': 38, 'no prediction': 25})
# 138500
# actual: asher   pred: the
# Counter({True: 8962, False: 378, 'multiple words': 38, 'no prediction': 26})
# 138615
# actual: anak   pred: pastureland
# Counter({True: 8975, False: 379, 'multiple words': 38, 'no prediction': 26})
# 138706
# actual: juttah   pred: shemesh
# Counter({True: 8987, False: 380, 'multiple words': 38, 'no prediction': 26})
# 138837
# actual: eltekeh   pred: tribe
# Counter({True: 9000, False: 381, 'multiple words': 38, 'no prediction': 27})
# 138903
# actual: levite   pred: were
# Counter({True: 9006, False: 382, 'multiple words': 38, 'no prediction': 27})
# 138965
# actual: asher   pred: the
# Counter({True: 9012, False: 383, 'multiple words': 39, 'no prediction': 27})
# 139061
# actual: kartah   pred: jokneam
# Counter({True: 9024, False: 384, 'multiple words': 39, 'no prediction': 27})
# 139073
# actual: nahalal   pred: נַֽהֲלָל֙
# Counter({True: 9025, False: 385, 'multiple words': 39, 'no prediction': 27})
# 139476
# actual: west   pred: jordan
# Counter({True: 9061, False: 386, 'multiple words': 39, 'no prediction': 27})
# 139639
# actual: israelite   pred: israelites
# Counter({True: 9080, False: 387, 'multiple words': 39, 'no prediction': 27})
# 139709
# actual: israelite   pred: israel
# Counter({True: 9090, False: 388, 'multiple words': 39, 'no prediction': 27})
# 141000
# actual: egyptians   pred: egypt
# Counter({True: 9205, False: 389, 'multiple words': 39, 'no prediction': 27})
# 142459
# actual: asher   pred: in
# Counter({True: 9362, False: 390, 'multiple words': 40, 'no prediction': 28})
# 142464
# actual: acco   pred:
# Counter({True: 9362, False: 390, 'multiple words': 40, 'no prediction': 29})
# 142471
# actual: ahlab   pred: or
# Counter({True: 9363, False: 391, 'multiple words': 40, 'no prediction': 29})
# 142480
# actual: aphek   pred: helbah
# Counter({True: 9365, False: 392, 'multiple words': 40, 'no prediction': 29})
# 143327
# actual: israelites   pred: israel
# Counter({True: 9445, False: 393, 'multiple words': 41, 'no prediction': 29})
# 143406
# actual: israelites   pred: israel
# Counter({True: 9455, False: 394, 'multiple words': 41, 'no prediction': 29})
# 144137
# actual: kenite   pred: kenites
# Counter({True: 9536, False: 395, 'multiple words': 41, 'no prediction': 29})
# 144315
# actual: jael   pred: went
# Counter({True: 9566, False: 396, 'multiple words': 41, 'no prediction': 29})
# 144396
# actual: jael   pred: went
# Counter({True: 9567, False: 397, 'multiple words': 41, 'no prediction': 29})
# 144446
# actual: jael   pred: went
# Counter({True: 9570, False: 398, 'multiple words': 41, 'no prediction': 29})
# 144778
# actual: asher   pred: the
# Counter({True: 9622, False: 399, 'multiple words': 41, 'no prediction': 29})
# 145571
# actual: lord   pred: sovereign
# Counter({True: 9689, False: 400, 'multiple words': 41, 'no prediction': 29})
# 145573
# actual: sovereign   pred: lord
# Counter({True: 9689, False: 401, 'multiple words': 41, 'no prediction': 29})
# 145868
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9706, False: 402, 'multiple words': 41, 'no prediction': 29})
# 145930
# actual: asher   pred: that
# Counter({True: 9714, False: 403, 'multiple words': 41, 'no prediction': 29})
# 146087
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9720, False: 404, 'multiple words': 41, 'no prediction': 29})
# 146530
# actual: israelite   pred: the
# Counter({True: 9748, False: 405, 'multiple words': 41, 'no prediction': 29})
# 146792
# actual: asher   pred: the
# Counter({True: 9763, False: 406, 'multiple words': 41, 'no prediction': 29})
# 146850
# actual: midianite   pred: midianites
# Counter({True: 9771, False: 407, 'multiple words': 41, 'no prediction': 29})
# 146973
# actual: jordan   pred: exhausted
# Counter({True: 9789, False: 408, 'multiple words': 41, 'no prediction': 29})
# 147013
# actual: zalmunna   pred: zebah
# Counter({True: 9791, False: 409, 'multiple words': 41, 'no prediction': 29})
# 147024
# actual: zalmunna   pred: zebah
# Counter({True: 9794, False: 410, 'multiple words': 41, 'no prediction': 29})
# 147047
# actual: zalmunna   pred: zebah
# Counter({True: 9796, False: 411, 'multiple words': 41, 'no prediction': 29})
# 147108
# actual: zalmunna   pred: zebah
# Counter({True: 9800, False: 412, 'multiple words': 41, 'no prediction': 29})
# 147167
# actual: zalmunna   pred: zebah
# Counter({True: 9804, False: 413, 'multiple words': 41, 'no prediction': 29})
# 147235
# actual: zalmunna   pred: zebah
# Counter({True: 9811, False: 414, 'multiple words': 41, 'no prediction': 29})
# 147246
# actual: zalmunna   pred: zebah
# Counter({True: 9812, False: 415, 'multiple words': 41, 'no prediction': 29})
# 147298
# actual: zalmunna   pred: zebah
# Counter({True: 9815, False: 416, 'multiple words': 41, 'no prediction': 29})
# 147362
# actual: zalmunna   pred: zebah
# Counter({True: 9819, False: 417, 'multiple words': 41, 'no prediction': 29})
# 147580
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9834, False: 418, 'multiple words': 41, 'no prediction': 29})
# 147689
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9845, False: 419, 'multiple words': 41, 'no prediction': 29})
# 147703
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9847, False: 420, 'multiple words': 41, 'no prediction': 29})
# 147743
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9849, False: 421, 'multiple words': 41, 'no prediction': 29})
# 147824
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9853, False: 422, 'multiple words': 41, 'no prediction': 29})
# 147834
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9854, False: 423, 'multiple words': 41, 'no prediction': 29})
# 148076
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9862, False: 424, 'multiple words': 41, 'no prediction': 29})
# 148152
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9865, False: 425, 'multiple words': 41, 'no prediction': 29})
# 148246
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9878, False: 426, 'multiple words': 41, 'no prediction': 29})
# 148304
# actual: ebed   pred: his
# Counter({True: 9883, False: 427, 'multiple words': 41, 'no prediction': 29})
# 148349
# actual: ebed   pred: serve
# Counter({True: 9886, False: 428, 'multiple words': 41, 'no prediction': 29})
# 148361
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9888, False: 429, 'multiple words': 41, 'no prediction': 29})
# 148412
# actual: ebed   pred: he
# Counter({True: 9894, False: 430, 'multiple words': 41, 'no prediction': 29})
# 148429
# actual: ebed   pred: he
# Counter({True: 9896, False: 431, 'multiple words': 41, 'no prediction': 30})
# 148518
# actual: ebed   pred: as
# Counter({True: 9900, False: 432, 'multiple words': 41, 'no prediction': 30})
# 148581
# actual: centre   pred: center
# Counter({True: 9905, False: 433, 'multiple words': 41, 'no prediction': 30})
# 149052
# actual: jerub-baal   pred: jerubbaal
# Counter({True: 9930, False: 434, 'multiple words': 41, 'no prediction': 30})
# 149096
# actual: gilead   pred: jair
# Counter({True: 9940, False: 435, 'multiple words': 41, 'no prediction': 31})
# 149513
# actual: tob   pred: the
# Counter({True: 9991, False: 436, 'multiple words': 41, 'no prediction': 31})
# 149553
# actual: tob   pred: the
# Counter({True: 9995, False: 437, 'multiple words': 41, 'no prediction': 31})
# 150240
# actual: minnith   pred: vicinity
# Counter({True: 10090, False: 438, 'multiple words': 41, 'no prediction': 31})
# 150446
# actual: israelite   pred: the
# Counter({True: 10098, False: 439, 'multiple words': 41, 'no prediction': 31})
# 150472
# actual: zaphon   pred: the
# Counter({True: 10102, False: 440, 'multiple words': 41, 'no prediction': 31})
# 150585
# actual: gileadites   pred: gilead
# Counter({True: 10111, False: 441, 'multiple words': 41, 'no prediction': 31})
# 150590
# actual: gileadites   pred: gilead
# ...
# Counter({True: 26455, False: 1301, 'no prediction': 308, 'multiple words': 152})
# 387324
# actual: son   pred: manasseh
# Counter({True: 26480, False: 1302, 'no prediction': 308, 'multiple words': 152})
# 387326
# actual: king   pred: hezekiah
# Counter({True: 26480, False: 1303, 'no prediction': 308, 'multiple words': 152})
# 388159
# actual: lord   pred: declares
# Counter({True: 26502, False: 1304, 'no prediction': 308, 'multiple words': 152})
# 389876
# actual: immer   pred: of
# Counter({True: 26566, False: 1305, 'no prediction': 308, 'multiple words': 153})
# 392976
# actual: jeremiah   pred: prophesied
# Counter({True: 26754, False: 1306, 'no prediction': 309, 'multiple words': 153})
# 394227
# actual: josiah   pred: zedekiah
# Counter({True: 26849, False: 1307, 'no prediction': 310, 'multiple words': 153})
# 394877
# actual: year   pred: in
# Counter({True: 26906, False: 1308, 'no prediction': 310, 'multiple words': 153})
# 394890
# actual: azzur   pred: hananiah
# Counter({True: 26906, False: 1309, 'no prediction': 310, 'multiple words': 153})
# 394892
# actual: prophet   pred: azzur
# Counter({True: 26906, False: 1310, 'no prediction': 310, 'multiple words': 153})
# 394897
# actual: house   pred: gibeon
# Counter({True: 26906, False: 1311, 'no prediction': 310, 'multiple words': 153})
# 394898
# actual: lord   pred: in
# Counter({True: 26906, False: 1312, 'no prediction': 310, 'multiple words': 153})
# 395904
# actual: lord   pred: declares
# Counter({True: 27002, False: 1313, 'no prediction': 312, 'multiple words': 154})
# 395990
# actual: anathoth   pred: poses
# Counter({True: 27013, False: 1314, 'no prediction': 312, 'multiple words': 154})
# 396493
# actual: jacob   pred: fortunes
# Counter({True: 27049, False: 1315, 'no prediction': 312, 'multiple words': 154})
# 397532
# actual: lord   pred: to
# Counter({True: 27116, False: 1316, 'no prediction': 312, 'multiple words': 154})
# 397555
# actual: zedekiah   pred: tenth
# Counter({True: 27118, False: 1317, 'no prediction': 312, 'multiple words': 154})
# 399368
# actual: jacob   pred: fortunes
# Counter({True: 27242, False: 1318, 'no prediction': 312, 'multiple words': 156})
# 401574
# actual: jehucal   pred: shelemiah
# Counter({True: 27452, False: 1319, 'no prediction': 314, 'multiple words': 156})
# 401794
# actual: irijah   pred: arrested
# Counter({True: 27480, False: 1320, 'no prediction': 314, 'multiple words': 156})
# 401829
# actual: irijah   pred: arrested
# Counter({True: 27485, False: 1321, 'no prediction': 314, 'multiple words': 156})
# 403428
# actual: lord   pred: the
# Counter({True: 27616, False: 1322, 'no prediction': 316, 'multiple words': 156})
# 403886
# actual: jews   pred: judah
# Counter({True: 27676, False: 1323, 'no prediction': 316, 'multiple words': 156})
# 404401
# actual: geruth   pred: stopping
# Counter({True: 27750, False: 1324, 'no prediction': 316, 'multiple words': 156})
# 406245
# actual: jews   pred: judah
# Counter({True: 27893, False: 1325, 'no prediction': 316, 'multiple words': 157})
# 406296
# actual: jews   pred: and
# Counter({True: 27897, False: 1326, 'no prediction': 316, 'multiple words': 157})
# 406688
# actual: put   pred: lydia
# Counter({True: 27944, False: 1327, 'no prediction': 316, 'multiple words': 157})
# 406818
# actual: warriors   pred: low
# Counter({True: 27962, False: 1328, 'no prediction': 317, 'multiple words': 158})
# 406993
# actual: thebes   pred: to
# Counter({True: 27978, False: 1329, 'no prediction': 317, 'multiple words': 158})
# 407262
# actual: coast   pred: the
# Counter({True: 28006, False: 1330, 'no prediction': 318, 'multiple words': 158})
# 407334
# actual: horonaim   pred: anguished
# Counter({True: 28016, False: 1331, 'no prediction': 318, 'multiple words': 158})
# 407616
# actual: holon   pred: plateau
# Counter({True: 28032, False: 1332, 'no prediction': 318, 'multiple words': 159})
# 407827
# actual: elealeh   pred: rises
# Counter({True: 28056, False: 1333, 'no prediction': 318, 'multiple words': 159})
# 407829
# actual: jahaz   pred: elealeh
# Counter({True: 28056, False: 1334, 'no prediction': 318, 'multiple words': 159})
# 408023
# actual: year   pred: moab
# Counter({True: 28075, False: 1335, 'no prediction': 318, 'multiple words': 159})
# 408027
# actual: lord   pred: declares
# Counter({True: 28075, False: 1336, 'no prediction': 318, 'multiple words': 159})
# 408169
# actual: molech   pred: o
# Counter({True: 28095, False: 1337, 'no prediction': 318, 'multiple words': 159})
# 408965
# actual: marduk   pred: terror
# Counter({True: 28158, False: 1338, 'no prediction': 318, 'multiple words': 160})
# 410263
# actual: jacob   pred: is
# Counter({True: 28254, False: 1339, 'no prediction': 318, 'multiple words': 161})
# 410446
# actual: minni   pred: the
# Counter({True: 28262, False: 1340, 'no prediction': 318, 'multiple words': 161})
# 416081
# actual: 40   pred: judah
# Counter({True: 28513, False: 1341, 'no prediction': 318, 'multiple words': 163})
# 417921
# actual: doing   pred: israel
# Counter({True: 28561, False: 1342, 'no prediction': 319, 'multiple words': 163})
# 419933
# actual: babylonia   pred: to
# Counter({True: 28638, False: 1343, 'no prediction': 321, 'multiple words': 163})
# 419936
# actual: chaldeans   pred: babylonia
# Counter({True: 28638, False: 1344, 'no prediction': 321, 'multiple words': 163})
# 420868
# actual: israelite   pred: the
# Counter({True: 28688, False: 1345, 'no prediction': 321, 'multiple words': 163})
# 420950
# actual: israelite   pred: israel
# Counter({True: 28691, False: 1346, 'no prediction': 321, 'multiple words': 163})
# 422194
# actual: babylonia   pred: merchants
# Counter({True: 28745, False: 1347, 'no prediction': 321, 'multiple words': 163})
# 425740
# actual: southland   pred: south
# Counter({True: 28875, False: 1348, 'no prediction': 321, 'multiple words': 163})
# 425746
# actual: southern   pred: south
# Counter({True: 28875, False: 1349, 'no prediction': 321, 'multiple words': 163})
# 427344
# actual: babylonian   pred: of
# Counter({True: 28949, False: 1350, 'no prediction': 321, 'multiple words': 163})
# 427345
# actual: chaldea   pred: babylonian
# Counter({True: 28949, False: 1351, 'no prediction': 321, 'multiple words': 163})
# 427370
# actual: babylonians   pred: to
# Counter({True: 28949, False: 1352, 'no prediction': 321, 'multiple words': 163})
# 427495
# actual: babylonians   pred: of
# Counter({True: 28953, False: 1353, 'no prediction': 321, 'multiple words': 163})
# 427498
# actual: chaldeans   pred: babylonians
# Counter({True: 28953, False: 1354, 'no prediction': 321, 'multiple words': 163})
# 429066
# actual: coast   pred: the
# Counter({True: 29036, False: 1355, 'no prediction': 321, 'multiple words': 163})
# 429610
# actual: merchant   pred: sea
# Counter({True: 29065, False: 1356, 'no prediction': 321, 'multiple words': 163})
# 429619
# actual: lord   pred: sovereign
# Counter({True: 29065, False: 1357, 'no prediction': 321, 'multiple words': 163})
# 429621
# actual: tyre   pred: lord
# Counter({True: 29065, False: 1358, 'no prediction': 321, 'multiple words': 163})
# 429670
# actual: cyprus   pred: coasts
# Counter({True: 29068, False: 1359, 'no prediction': 321, 'multiple words': 163})
# 429740
# actual: put   pred: lydia
# Counter({True: 29076, False: 1360, 'no prediction': 321, 'multiple words': 163})
# 429873
# actual: minnith   pred: wheat
# Counter({True: 29086, False: 1361, 'no prediction': 321, 'multiple words': 165})
# 429904
# actual: greeks   pred: danites
# Counter({True: 29090, False: 1362, 'no prediction': 321, 'multiple words': 165})
# 431072
# actual: egyptians   pred: egypt
# Counter({True: 29149, False: 1363, 'no prediction': 321, 'multiple words': 165})
# 431367
# actual: put   pred: lydia
# Counter({True: 29178, False: 1364, 'no prediction': 321, 'multiple words': 165})
# 431576
# actual: thebes   pred: to
# Counter({True: 29200, False: 1365, 'no prediction': 321, 'multiple words': 166})
# 431589
# actual: thebes   pred: the
# Counter({True: 29202, False: 1366, 'no prediction': 321, 'multiple words': 166})
# 431599
# actual: thebes   pred: to
# Counter({True: 29204, False: 1367, 'no prediction': 321, 'multiple words': 166})
# 435267
# actual: lord   pred: sovereign
# Counter({True: 29364, False: 1368, 'no prediction': 322, 'multiple words': 166})
# 435292
# actual: lord   pred: sovereign
# Counter({True: 29364, False: 1369, 'no prediction': 322, 'multiple words': 166})
# 436180
# actual: israelites   pred: israel
# Counter({True: 29405, False: 1370, 'no prediction': 322, 'multiple words': 166})
# 436260
# actual: israelite   pred: the
# Counter({True: 29412, False: 1371, 'no prediction': 322, 'multiple words': 166})
# 436630
# actual: put   pred: cush
# Counter({True: 29434, False: 1372, 'no prediction': 322, 'multiple words': 166})
# 437490
# actual: hamonah   pred: so
# Counter({True: 29487, False: 1373, 'no prediction': 322, 'multiple words': 167})
# 439673
# actual: northward   pred: north
# Counter({True: 29518, False: 1374, 'no prediction': 323, 'multiple words': 167})
# 439691
# actual: north side   pred: north
# Counter({True: 29518, False: 1374, 'no prediction': 323, 'multiple words': 168})
# 440266
# actual: israelites   pred: israel
# Counter({True: 29528, False: 1375, 'no prediction': 323, 'multiple words': 168})
# 441409
# actual: israelite   pred: of
# Counter({True: 29566, False: 1376, 'no prediction': 323, 'multiple words': 168})
# 443318
# actual: berothah   pred: sibraim
# Counter({True: 29616, False: 1377, 'no prediction': 323, 'multiple words': 169})
# 443345
# actual: northern   pred: north
# Counter({True: 29622, False: 1378, 'no prediction': 323, 'multiple words': 169})
# 443474
# actual: israelites   pred: israel
# Counter({True: 29636, False: 1379, 'no prediction': 324, 'multiple words': 171})
# 443548
# actual: asher   pred: the
# Counter({True: 29646, False: 1380, 'no prediction': 324, 'multiple words': 171})
# 443553
# actual: asher   pred: the
# Counter({True: 29646, False: 1381, 'no prediction': 324, 'multiple words': 171})
# 444267
# actual: asher   pred: the
# Counter({True: 29702, False: 1382, 'no prediction': 324, 'multiple words': 174})
# 444468
# actual: meshach   pred: abednego
# Counter({True: 29725, False: 1383, 'no prediction': 324, 'multiple words': 174})
# 445419
# actual: judah   pred: exiles
# Counter({True: 29765, False: 1384, 'no prediction': 324, 'multiple words': 175})
# 446100
# actual: meshach   pred: abednego
# Counter({True: 29777, False: 1385, 'no prediction': 324, 'multiple words': 175})
# 446414
# actual: meshach   pred: abednego
# Counter({True: 29788, False: 1386, 'no prediction': 325, 'multiple words': 175})
# 446454
# actual: meshach   pred: abednego
# Counter({True: 29790, False: 1387, 'no prediction': 325, 'multiple words': 175})
# 446474
# actual: meshach   pred: abednego
# Counter({True: 29792, False: 1388, 'no prediction': 325, 'multiple words': 175})
# 446558
# actual: meshach   pred: abednego
# Counter({True: 29793, False: 1389, 'no prediction': 325, 'multiple words': 175})
# 446639
# actual: meshach   pred: abednego
# Counter({True: 29796, False: 1390, 'no prediction': 325, 'multiple words': 175})
# 446673
# actual: meshach   pred: abednego
# Counter({True: 29797, False: 1391, 'no prediction': 325, 'multiple words': 175})
# 446733
# actual: meshach   pred: abednego
# Counter({True: 29798, False: 1392, 'no prediction': 325, 'multiple words': 175})
# 446843
# actual: meshach   pred: abednego
# Counter({True: 29801, False: 1393, 'no prediction': 325, 'multiple words': 175})
# 446861
# actual: meshach   pred: abednego
# Counter({True: 29802, False: 1394, 'no prediction': 325, 'multiple words': 175})
# 446922
# actual: meshach   pred: abednego
# Counter({True: 29804, False: 1395, 'no prediction': 325, 'multiple words': 175})
# 446980
# actual: meshach   pred: abednego
# Counter({True: 29805, False: 1396, 'no prediction': 325, 'multiple words': 175})
# 447012
# actual: meshach   pred: abednego
# Counter({True: 29806, False: 1397, 'no prediction': 325, 'multiple words': 175})
# 448481
# actual: judah   pred: exiles
# Counter({True: 29838, False: 1398, 'no prediction': 325, 'multiple words': 176})
# 449337
# actual: judah   pred: exiles
# Counter({True: 29862, False: 1399, 'no prediction': 325, 'multiple words': 176})
# 450376
# actual: days   pred: pronounced
# Counter({True: 29886, False: 1400, 'no prediction': 327, 'multiple words': 176})
# 452322
# actual: persian   pred: persia
# Counter({True: 29950, False: 1401, 'no prediction': 327, 'multiple words': 176})
# 453541
# actual: nubians   pred: libyans
# Counter({True: 29982, False: 1402, 'no prediction': 327, 'multiple words': 176})
# 453892
# actual: joash   pred: jehoash
# Counter({True: 30000, False: 1403, 'no prediction': 327, 'multiple words': 176})
# 455131
# actual: rebels   pred: are
# Counter({True: 30053, False: 1404, 'no prediction': 327, 'multiple words': 176})
# 455182
# actual: israelites   pred: israel
# Counter({True: 30059, False: 1405, 'no prediction': 327, 'multiple words': 176})
# 455474
# actual: adam   pred: the
# Counter({True: 30080, False: 1406, 'no prediction': 327, 'multiple words': 176})
# 456468
# actual: wickedness   pred: hills
# Counter({True: 30138, False: 1407, 'no prediction': 327, 'multiple words': 176})
# 456606
# actual: shalman   pred: arbel
# Counter({True: 30146, False: 1408, 'no prediction': 327, 'multiple words': 176})
# 456759
# actual: admah   pred: zeboiim
# Counter({True: 30154, False: 1409, 'no prediction': 327, 'multiple words': 176})
# 456763
# actual: zeboiim   pred:
# Counter({True: 30154, False: 1409, 'no prediction': 328, 'multiple words': 176})
# 460724
# actual: philistia   pred: gath
# Counter({True: 30410, False: 1410, 'no prediction': 329, 'multiple words': 177})
# 460938
# actual: karnaim   pred: strength
# Counter({True: 30418, False: 1411, 'no prediction': 329, 'multiple words': 177})
# 461461
# actual: egypt   pred: nile
# Counter({True: 30473, False: 1412, 'no prediction': 329, 'multiple words': 178})
# 461768
# actual: river   pred: nile
# Counter({True: 30487, False: 1413, 'no prediction': 330, 'multiple words': 178})
# 461809
# actual: israelites   pred: israel
# Counter({True: 30489, False: 1414, 'no prediction': 331, 'multiple words': 178})
# 462430
# actual: israelite   pred: the
# Counter({True: 30537, False: 1415, 'no prediction': 332, 'multiple words': 178})
# 462432
# actual: canaan   pred:
# Counter({True: 30537, False: 1415, 'no prediction': 333, 'multiple words': 178})
# 463591
# actual: lord   pred: sovereign
# Counter({True: 30614, False: 1416, 'no prediction': 333, 'multiple words': 178})
# 463753
# actual: shaphir   pred: nakedness
# Counter({True: 30625, False: 1417, 'no prediction': 333, 'multiple words': 178})
# 463776
# actual: maroth   pred: waiting
# Counter({True: 30626, False: 1418, 'no prediction': 333, 'multiple words': 178})
# 464776
# actual: israelites   pred: israel
# Counter({True: 30680, False: 1419, 'no prediction': 334, 'multiple words': 178})
# 464842
# actual: assyrian   pred: assyria
# Counter({True: 30685, False: 1420, 'no prediction': 334, 'multiple words': 178})
# 465534
# actual: egypt   pred: the
# Counter({True: 30715, False: 1421, 'no prediction': 334, 'multiple words': 178})
# 465538
# actual: egypt   pred: the
# Counter({True: 30715, False: 1422, 'no prediction': 334, 'multiple words': 178})
# 466318
# actual: river   pred: the
# Counter({True: 30743, False: 1423, 'no prediction': 336, 'multiple words': 178})
# 466320
# actual: waters   pred: the
# Counter({True: 30743, False: 1424, 'no prediction': 336, 'multiple words': 178})
# 466331
# actual: put   pred: cush
# Counter({True: 30745, False: 1425, 'no prediction': 336, 'multiple words': 178})
# 466333
# actual: libya   pred:
# Counter({True: 30745, False: 1425, 'no prediction': 337, 'multiple words': 178})
# 467527
# actual: sovereign   pred: lord
# Counter({True: 30766, False: 1426, 'no prediction': 337, 'multiple words': 178})
# 467528
# actual: lord   pred: sovereign
# Counter({True: 30766, False: 1427, 'no prediction': 337, 'multiple words': 178})
# 469778
# actual: shebat   pred: the
# Counter({True: 30926, False: 1428, 'no prediction': 337, 'multiple words': 178})
# 471152
# actual: babylonia   pred: שִׁנְעָ֑ר
# Counter({True: 30998, False: 1429, 'no prediction': 337, 'multiple words': 178})
# 471344
# actual: tobijah   pred: jedaiah
# Counter({True: 31003, False: 1430, 'no prediction': 337, 'multiple words': 178})
# 471451
# actual: tobijah   pred: jedaiah
# Counter({True: 31012, False: 1431, 'no prediction': 338, 'multiple words': 178})
# 471457
# actual: hen   pred: in
# Counter({True: 31013, False: 1432, 'no prediction': 338, 'multiple words': 178})

# %%
line = 9318

# %%
gold_data.iloc[line-8: line+8, [0, 1, 2, 3, 4, 5, 10,11, 32]]
# Out:
#       index book  chapter  verse  word  subword       text   lemma  \
# 9310   9310  GEN       19      6     6        1     סָגַ֥ר    5462
# 9311   9311  GEN       19      6     7        1   אַחֲרָֽי   310 a
# 9312   9312  GEN       19      6     7        2          ו    None
# 9313   9313  GEN       19      7     1        1         וַ       c
# 9314   9314  GEN       19      7     1        2   יֹּאמַ֑ר     559
# 9315   9315  GEN       19      7     2        1        אַל     408
# 9316   9316  GEN       19      7     3        1       נָ֥א    4994
# 9317   9317  GEN       19      7     5        1  תָּרֵֽעוּ  7489 a
# 9318   9318  GEN       19      7     4        1      אַחַ֖     251
# 9319   9319  GEN       19      7     4        2          י    None
# 9320   9320  GEN       19      8     1        1     הִנֵּה    2009
# 9321   9321  GEN       19      8     2        1       נָ֨א    4994
# 9322   9322  GEN       19      8     3        1        לִ֜       l
# 9323   9323  GEN       19      8     3        2          י    None
# 9324   9324  GEN       19      8     4        1   שְׁתֵּ֣י    8147
# 9325   9325  GEN       19      8     5        1    בָנ֗וֹת    1323
#
#                      NIV84
# 9310                  shut
# 9311                  None
# 9312                  None
# 9313                  None
# 9314                  said
# 9315                   Don
# 9316                  None
# 9317  do this wicked thing
# 9318               friends
# 9319               friends
# 9320                  None
# 9321                  None
# 9322                  None
# 9323                  None
# 9324                   two
# 9325             daughters

# %%
word = bible_df.loc[line, ['text']].values[0][0]
hebrew_source_normalized = normalize_word(word)
book = bible_df.loc[line, ['book']].values[0][0]
chapter = bible_df.loc[line, ['chapter']].values[0][0]
verse = bible_df.loc[line, ['verse']].values[0][0]
ref = f'{book} {chapter}:{verse}\n'
vref_index = vref_data.index(ref)

def normalize_word(word):
    return re.sub("[^\w\s]", "", word.lower()) if word else ''

candidate_words = set(NIV84_df.loc[vref_index, 'words']) if vref_index in NIV84_df.index else set([])
candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
candidate_words
# Out:
# ['',
#  'this',
#  'said',
#  'my',
#  'and',
#  'friends',
#  'don',
#  'thing',
#  'wicked',
#  'no',
#  'do']

# %%
candidate_df = df[(df['normalized_target'] == hebrew_source_normalized) | (df['normalized_source'] == hebrew_source_normalized)]
candidate_df
# Out:
#         Unnamed: 0     source     target  align_count  word score  \
# 668            668          a       אָֽח            2    0.120882
# 5550          5550         an       אָ֗ח            1    0.137852
# 16505        16505    brother       אָ֖ח            2    0.516493
# 16506        16506    brother       אָ֗ח            2    0.370858
# 16507        16507    brother       אָ֣ח            3    0.591563
# 16508        16508    brother       אָ֥ח            3    0.532790
# 16509        16509    brother       אָֽח            3    0.578469
# 16510        16510    brother       אָחִ            3    0.599111
# 16511        16511    brother      אָחִ֑            3    0.477107
# 16514        16514    brother      אָחִ֕            1    0.338540
# 16515        16515    brother      אָחִ֖            6    0.519708
# 16517        16517    brother      אָחִ֗            2    0.751299
# 16520        16520    brother      אָחִ֣            2    0.493880
# 16522        16522    brother      אָחִ֥            2    0.633550
# 16525        16525    brother      אָחִֽ            2    0.355504
# 16541        16541   brothers      אֶחָ֑            4    0.512580
# 16549        16549   brothers      אַ֭חַ            1    0.483506
# 16558        16558   brothers       אַחַ            2    0.803529
# 16559        16559   brothers      אַחַ֖            2    0.251688
# 16560        16560   brothers      אַחַ֣            5    0.469857
# 16569        16569  brotherʼs      אָחִ֖            1    0.050540
# 17359        17359        but      אַ֭חַ            1    0.174900
# 26120        26120   deceiver       אָח֙            1    0.114857
# 29984        29984      donʼt      אַחַ֖            1    0.010027
# 37557        37557    firepot       אָ֖ח            1    0.191823
# 37876        37876      flash       אָ֛ח            1    0.069799
# 47250        47250       have       אָ֭ח            1    0.452164
# 56051        56051         is       אָ֥ח            1    0.210589
# 71220        71220         my      אַחַ֣            4    0.382741
# 75939        75939   offended       אָ֗ח            1    0.203366
# 76420        76420         oh      אָחִֽ            1    0.131919
# 81875        81875     plenty      אָחִ֕            1    0.339108
# 87557        87557   relative      אָחִ֣            1    0.185404
# 110511      110511       this      אַחַ֖            1    0.095848
# 134600      134600      אֶחָ֑   brothers            4    0.512580
# 134601      134601      אֶחָ֑   stranger            1    0.083160
# 135856      135856      אַ֭חַ   brothers            2    0.483506
# 135857      135857      אַ֭חַ        but            1    0.174900
# 135858      135858      אַ֭חַ          “            1    0.025329
# 136644      136644       אַחַ   brothers            2    0.803529
# 136651      136651      אַחַ֖   brothers            2    0.251688
# 136652      136652      אַחַ֖        iʼm            1    0.065840
# 136653      136653      אַחַ֖      thing            1    0.095583
# 136654      136654      אַחַ֖       this            1    0.095848
# 136655      136655      אַחַ֖     wicked            1    0.093528
# 136689      136689      אַחַ֣   brothers            5    0.469857
# 136690      136690      אַחַ֣         my            5    0.382741
# 136708      136708      אַחַ֥     gideon            1    0.587840
# 138134      138134       אָ֖ח    brother            2    0.516493
# 138135      138135       אָ֖ח    firepot            1    0.191823
# 138152      138152       אָ֗ח         an            1    0.137852
# 138153      138153       אָ֗ח    brother            2    0.370858
# 138154      138154       אָ֗ח   offended            1    0.139776
# 138270      138270       אָ֣ח    brother            3    0.591563
# 138271      138271       אָ֣ח     friend            1    0.133687
# 138337      138337       אָ֥ח    brother            3    0.532790
# 138338      138338       אָ֥ח         is            1    0.210589
# 138434      138434       אָ֭ח       have            1    0.452164
# 138507      138507       אָֽח          a            1    0.120882
# 138508      138508       אָֽח    brother            3    0.578469
# 139125      139125       אָחִ    brother            3    0.599111
# 139126      139126       אָחִ      hairy            1    0.150228
# 139127      139127      אָחִ֑    brother            3    0.477107
# 139128      139128      אָחִ֑          ”            4    0.302489
# 139138      139138      אָחִ֕    brother            1    0.338540
# 139139      139139      אָחִ֕     plenty            1    0.339108
# 139140      139140      אָחִ֖    brother            6    0.519708
# 139141      139141      אָחִ֖  brotherʼs            1    0.050540
# 139147      139147      אָחִ֗    brother            2    0.751299
# 139152      139152      אָחִ֣    brother            2    0.493880
# 139153      139153      אָחִ֣   relative            1    0.185404
# 139160      139160      אָחִ֥    brother            2    0.633550
# 139167      139167      אָחִֽ    brother            2    0.355504
# 139168      139168      אָחִֽ         oh            1    0.131919
# 139169      139169      אָחִֽ          ”            2    0.217844
# 243595      243595          “      אַ֭חַ            1    0.025329
# 244214      244214          ”      אָחִ֑            3    0.302489
# 244215      244215          ”      אָחִֽ            2    0.217844
#
#         verse score normalized_source normalized_target   jac_sim  \
# 668        0.207583                 a                אח -1.000000
# 5550       0.223522                an                אח -1.000000
# 16505      0.202810           brother                אח  0.172996
# 16506      0.166233           brother                אח  0.172996
# 16507      0.198404           brother                אח  0.172996
# 16508      0.223882           brother                אח  0.172996
# 16509      0.233705           brother                אח  0.172996
# 16510      0.256289           brother                אח  0.172996
# 16511      0.275923           brother                אח  0.172996
# 16514      0.222177           brother                אח  0.172996
# 16515      0.246001           brother                אח  0.172996
# 16517      0.214419           brother                אח  0.172996
# 16520      0.189933           brother                אח  0.172996
# 16522      0.196764           brother                אח  0.172996
# 16525      0.267555           brother                אח  0.172996
# 16541      0.262936          brothers                אח  0.092437
# 16549      0.394023          brothers                אח  0.092437
# 16558      0.250212          brothers                אח  0.092437
# 16559      0.247064          brothers                אח  0.092437
# 16560      0.236206          brothers                אח  0.092437
# 16569      0.226120         brotherʼs                אח  0.022727
# 17359      0.394023               but                אח -1.000000
# 26120      0.193086          deceiver                אח  0.013514
# 29984      0.165986             donʼt                אח  0.023256
# 37557      0.260186           firepot                אח  0.027027
# 37876      0.243677             flash                אח  0.012821
# 47250      0.227233              have                אח -1.000000
# 56051      0.216643                is                אח -1.000000
# 71220      0.228364                my                אח  0.018008
# 75939      0.223522          offended                אח  0.013699
# 76420      0.290974                oh                אח  0.019231
# 81875      0.222177            plenty                אח  0.011905
# 87557      0.203276          relative                אח  0.011111
# 110511     0.211885              this                אח -1.000000
# 134600     0.232889                אח          brothers -1.000000
# 134601     0.245245                אח          stranger -1.000000
# 135856     0.298360                אח          brothers -1.000000
# 135857     0.291776                אח               but -1.000000
# 135858     0.304943                אח               NaN -1.000000
# 136644     0.202521                אח          brothers -1.000000
# 136651     0.209538                אח          brothers -1.000000
# 136652     0.190729                אח               iʼm -1.000000
# 136653     0.179815                אח             thing -1.000000
# 136654     0.179815                אח              this -1.000000
# 136655     0.179815                אח            wicked -1.000000
# 136689     0.218375                אח          brothers -1.000000
# 136690     0.214986                אח                my -1.000000
# 136708     0.246679                אח            gideon -1.000000
# 138134     0.191594                אח           brother -1.000000
# 138135     0.222838                אח           firepot -1.000000
# 138152     0.204781                אח                an -1.000000
# 138153     0.171592                אח           brother -1.000000
# 138154     0.204781                אח          offended -1.000000
# 138270     0.202052                אח           brother -1.000000
# 138271     0.260563                אח            friend -1.000000
# 138337     0.246422                אח           brother -1.000000
# 138338     0.214905                אח                is -1.000000
# 138434     0.253928                אח              have -1.000000
# 138507     0.234798                אח                 a -1.000000
# 138508     0.205007                אח           brother -1.000000
# 139125     0.251788                אח           brother -1.000000
# 139126     0.283943                אח             hairy -1.000000
# 139127     0.264033                אח           brother -1.000000
# 139128     0.238332                אח               NaN -1.000000
# 139138     0.160603                אח           brother -1.000000
# 139139     0.160603                אח            plenty -1.000000
# 139140     0.226268                אח           brother -1.000000
# 139141     0.233094                אח         brotherʼs -1.000000
# 139147     0.184701                אח           brother -1.000000
# 139152     0.207312                אח           brother -1.000000
# 139153     0.228088                אח          relative -1.000000
# 139160     0.187423                אח           brother -1.000000
# 139167     0.212594                אח           brother -1.000000
# 139168     0.225446                אח                oh -1.000000
# 139169     0.212594                אח               NaN -1.000000
# 243595     0.301606               NaN                אח -1.000000
# 244214     0.239580               NaN                אח -1.000000
# 244215     0.267555               NaN                אח -1.000000
#
#         match_counts  total_score
# 668                0    -0.120882
# 5550               0    -0.137852
# 16505             41     0.089351
# 16506             41     0.064157
# 16507             41     0.102338
# 16508             41     0.092170
# 16509             41     0.100073
# 16510             41     0.103644
# 16511             41     0.082537
# 16514             41     0.058566
# 16515             41     0.089907
# 16517             41     0.129971
# 16520             41     0.085439
# 16522             41     0.109602
# 16525             41     0.061501
# 16541             22     0.047381
# 16549             22     0.044694
# 16558             22     0.074276
# 16559             22     0.023265
# 16560             22     0.043432
# 16569              2     0.001149
# 17359              0    -0.174900
# 26120              1     0.001552
# 29984              4     0.000233
# 37557              2     0.005184
# 37876              1     0.000895
# 47250              0    -0.452164
# 56051              0    -0.210589
# 71220             49     0.006892
# 75939              1     0.002786
# 76420              2     0.002537
# 81875              1     0.004037
# 87557              1     0.002060
# 110511             0    -0.095848
# 134600             0    -0.512580
# 134601             0    -0.083160
# 135856             0    -0.483506
# 135857             0    -0.174900
# 135858             0    -0.025329
# 136644             0    -0.803529
# 136651             0    -0.251688
# 136652             0    -0.065840
# 136653             0    -0.095583
# 136654             0    -0.095848
# 136655             0    -0.093528
# 136689             0    -0.469857
# 136690             0    -0.382741
# 136708             0    -0.587840
# 138134             0    -0.516493
# 138135             0    -0.191823
# 138152             0    -0.137852
# 138153             0    -0.370858
# 138154             0    -0.139776
# 138270             0    -0.591563
# 138271             0    -0.133687
# 138337             0    -0.532790
# 138338             0    -0.210589
# 138434             0    -0.452164
# 138507             0    -0.120882
# 138508             0    -0.578469
# 139125             0    -0.599111
# 139126             0    -0.150228
# 139127             0    -0.477107
# 139128             0    -0.302489
# 139138             0    -0.338540
# 139139             0    -0.339108
# 139140             0    -0.519708
# 139141             0    -0.050540
# 139147             0    -0.751299
# 139152             0    -0.493880
# 139153             0    -0.185404
# 139160             0    -0.633550
# 139167             0    -0.355504
# 139168             0    -0.131919
# 139169             0    -0.217844
# 243595             0    -0.025329
# 244214             0    -0.302489
# 244215             0    -0.217844

# %%
candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words) or x['normalized_target'] in list(candidate_words), axis=1)].sort_values('total_score', ascending=False)
# Out:
#         Unnamed: 0 source  target  align_count  word score  verse score  \
# 71220        71220     my   אַחַ֣            4    0.382741     0.228364
# 136655      136655  אַחַ֖  wicked            1    0.093528     0.179815
# 136653      136653  אַחַ֖   thing            1    0.095583     0.179815
# 110511      110511   this   אַחַ֖            1    0.095848     0.211885
# 136654      136654  אַחַ֖    this            1    0.095848     0.179815
# 136690      136690  אַחַ֣      my            5    0.382741     0.214986
#
#        normalized_source normalized_target   jac_sim  match_counts  \
# 71220                 my                אח  0.018008            49
# 136655                אח            wicked -1.000000             0
# 136653                אח             thing -1.000000             0
# 110511              this                אח -1.000000             0
# 136654                אח              this -1.000000             0
# 136690                אח                my -1.000000             0
#
#         total_score
# 71220      0.006892
# 136655    -0.093528
# 136653    -0.095583
# 110511    -0.095848
# 136654    -0.095848
# 136690    -0.382741

# %% [markdown]
# Total number of names:

# %%
word
# Out:
# 'שֶׁמְאֵ֨בֶר֙'

# %%
df[df['source'] == 'shemeber']
# Out:
#        Unnamed: 0    source    target  align_count  word score  verse score  \
# 80989       80989  shemeber  אַדְמָ֗ה            1     0.78108     0.330563
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 80989          shemeber              אדמה     -1.0             0     -0.78108

# %% [markdown]
# Number of matched names:

# %%
vref_index
# Out:
# 464

# %%
df[df['target'] == 'עֵ֖דֶן']
# Out:
#        Unnamed: 0 source  target  align_count  word score  verse score  \
# 26110       26110   eden  עֵ֖דֶן            2    0.799089     0.322273
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 26110              eden               עדן  0.818182            18      3.79264

# %%
matched_names['predicted'] = matched_names['text'].progress_apply(lambda x: df.loc[df[df['target'] == x]['total_score'].idxmax()]['source'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32282/32282 [06:18<00:00, 85.21it/s]

# %%
matched_names
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [32282 rows x 15 columns]

# %%
def is_word_correct(row):
    word = row['english'].split("’")[0] if row['english'] is not None else ''
    return word == row['predicted']

# %%
matched_names[matched_names.apply(is_word_correct, axis=1)]
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [29972 rows x 15 columns]

# %%
matched_names[~matched_names.apply(is_word_correct, axis=1)].head(100)
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 1591   GEN        3     17     1        3  o010030170013  00100301700006
# 1682   GEN        3     21     4        2  o010030210042  00100302100012
# 1809   GEN        4      2    11        2  o010040020112  00100400200030
# 1845   GEN        4      4    11        1  o010040040111  00100400400032
# 1927   GEN        4      8    12        1  o010040080121  00100400800036
# 2114   GEN        4     18     2        2  o010040180022  00100401800008
# 2198   GEN        4     23     4        1  o010040230041  00100402300012
# 2231   GEN        4     25     2        1  o010040250021  00100402500006
# 2270   GEN        4     26     9        1  o010040260091  00100402600024
# 2281   GEN        5      1     4        1  o010050010041  00100500100008
# 2314   GEN        5      3     2        1  o010050030021  00100500300006
# 2336   GEN        5      4     3        1  o010050040031  00100500400008
# 2354   GEN        5      5     4        1  o010050050041  00100500500010
# 2412   GEN        5      9     2        1  o010050090021  00100500900006
# 2777   GEN        5     32    10        1  o010050320101  00100503200024
# 2980   GEN        6     10     6        1  o010060100061  00100601000014
# 3519   GEN        7     13     6        2  o010070130062  00100701300020
# 4687   GEN        9     18     7        1  o010090180071  00100901800020
# 4750   GEN        9     23     2        1  o010090230021  00100902300006
# 4813   GEN        9     26     5        1  o010090260051  00100902600012
# 4816   GEN        9     26     7        1  o010090260071  00100902600018
# 4828   GEN        9     27     6        1  o010090270061  00100902700018
# 4831   GEN        9     27     8        1  o010090270081  00100902700024
# 4865   GEN       10      1     5        1  o010100010051  00101000100012
# 4879   GEN       10      2     3        1  o010100020031  00101000200006
# 4883   GEN       10      2     5        2  o010100020052  00101000200014
# 4902   GEN       10      4     2        1  o010100040021  00101000400006
# 4933   GEN       10      6     4        2  o010100060042  00101000600012
# 4935   GEN       10      6     5        2  o010100060052  00101000600016
# 4991   GEN       10     10     4        1  o010100100041  00101001000010
# 4993   GEN       10     10     5        2  o010100100052  00101001000014
# 5042   GEN       10     13     8        1  o010100130081  00101001300022
# 5073   GEN       10     16     2        2  o010100160022  00101001600008
# 5081   GEN       10     16     6        2  o010100160062  00101001600024
# 5085   GEN       10     17     2        2  o010100170022  00101001700008
# 5089   GEN       10     17     4        2  o010100170042  00101001700016
# 5093   GEN       10     17     6        2  o010100170062  00101001700024
# 5097   GEN       10     18     2        2  o010100180022  00101001800008
# 5101   GEN       10     18     4        2  o010100180042  00101001800016
# 5111   GEN       10     18    10        2  o010100180102  00101001800036
# 5154   GEN       10     21     1        3  o010100210013  00101002100006
# 5167   GEN       10     22     2        1  o010100220021  00101002200004
# 5170   GEN       10     22     4        2  o010100220042  00101002200010
# 5193   GEN       10     24     5        2  o010100240052  00101002400014
# 5226   GEN       10     26     6        1  o010100260061  00101002600016
# 5229   GEN       10     26     8        1  o010100260081  00101002600022
# 5256   GEN       10     29     4        1  o010100290041  00101002900012
# 5279   GEN       10     31     3        1  o010100310031  00101003100006
# 5483   GEN       11      9     5        1  o010110090051  00101100900010
# 5505   GEN       11     10     3        1  o010110100031  00101101000006
# 5535   GEN       11     12     1        2  o010110120012  00101101200004
# 5624   GEN       11     18     2        1  o010110180021  00101101800006
# 5704   GEN       11     24     2        1  o010110240021  00101102400006
# 5939   GEN       12      4     9        1  o010120040091  00101200400024
# 5955   GEN       12      5     2        1  o010120050021  00101200500006
# 6348   GEN       13      3     3        2  o010130030032  00101300300012
# 6434   GEN       13      7    10        1  o010130070101  00101300700024
# 6440   GEN       13      7    12        3  o010130070123  00101300700036
# 6604   GEN       13     14    19        2  o010130140192  00101301400048
# 6705   GEN       14      1    14        1  o010140010141  00101400100034
# 6782   GEN       14      5    19        2  o010140050192  00101400500060
# 6859   GEN       14      9     7        1  o010140090071  00101400900016
# 6943   GEN       14     13     8        2  o010140130082  00101401300030
# 6946   GEN       14     13    10        2  o010140130102  00101401300036
# 7031   GEN       14     17     3        1  o010140170031  00101401700008
# 7339   GEN       15      8     3        1  o010150080031  00101500800008
# 7548   GEN       15     19     2        2  o010150190022  00101501900006
# 7552   GEN       15     19     4        2  o010150190042  00101501900014
# 7556   GEN       15     19     6        2  o010150190062  00101501900022
# 7560   GEN       15     20     2        2  o010150200022  00101502000008
# 7564   GEN       15     20     4        2  o010150200042  00101502000016
# 7580   GEN       15     21     6        2  o010150210062  00101502100024
# 7584   GEN       15     21     8        2  o010150210082  00101502100032
# 7597   GEN       16      1     9        1  o010160010091  00101600100022
# 7637   GEN       16      3     7        2  o010160030072  00101600300018
# 8225   GEN       17     15    11        1  o010170150111  00101701500024
# 10066  GEN       19     37     9        1  o010190370091  00101903700024
# 10098  GEN       20      1     5        2  o010200010052  00102000100016
# 10777  GEN       21     14    20        1  o010210140201  00102101400064
# 11122  GEN       21     31     6        1  o010210310061  00102103100018
# 11276  GEN       22      4     4        1  o010220040041  00102200400016
# 11645  GEN       22     19     9        1  o010220190091  00102201900024
# 11651  GEN       22     19    13        2  o010220190132  00102201900036
# 12055  GEN       23     16     2        1  o010230160021  00102301600006
# 12083  GEN       23     17     3        1  o010230170031  00102301700008
# 12968  GEN       24     36     2        1  o010240360021  00102403600006
# 13241  GEN       24     47    11        1  o010240470111  00102404700028
# 13568  GEN       24     62    10        2  o010240620102  00102406200028
# 13724  GEN       25      3    12        2  o010250030122  00102500300034
# 13901  GEN       25     13    10        2  o010250130102  00102501300028
# 13974  GEN       25     18    10        1  o010250180101  00102501800024
# 14008  GEN       25     20    12        2  o010250200122  00102502000032
# 14305  GEN       26      1    14        1  o010260010141  00102600100046
# 14753  GEN       26     22    11        1  o010260220111  00102602200032
# 14771  GEN       26     23     3        1  o010260230031  00102602300010
# 14837  GEN       26     26     5        2  o010260260052  00102602600016
# 14980  GEN       26     33     3        1  o010260330031  00102603300008
# 14986  GEN       26     33     8        1  o010260330081  00102603300020
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
# 16052  GEN       27     46     9        1  o010270460091  00102704600024
#
#       ot-nt          unicode            text   lemma normalized      english  \
# 1591     OT           אָדָ֣ם          אָדָ֣ם     121       None         adam
# 1682     OT           אָדָ֧ם          אָדָ֧ם     120       None         adam
# 1809     OT           קַ֕יִן          קַ֕יִן  7014 b       None         cain
# 1845     OT           הֶ֖בֶל          הֶ֖בֶל    1893       None         abel
# 1927     OT           הֶ֥בֶל          הֶ֥בֶל    1893       None         abel
# 2114     OT         חֲנוֹךְ֙        חֲנוֹךְ֙    2585       None        enoch
# 2198     OT           עָדָ֤ה          עָדָ֤ה    5711       None         adah
# 2231     OT           אָדָ֥ם          אָדָ֥ם     121       None         adam
# 2270     OT         אֱנ֑וֹשׁ        אֱנ֑וֹשׁ     583       None        enosh
# 2281     OT           אָדָ֑ם          אָדָ֑ם     121       None         adam
# 2314     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2336     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2354     OT           אָדָם֙          אָדָם֙     121       None         adam
# 2412     OT         אֱנ֖וֹשׁ        אֱנ֖וֹשׁ     583       None        enosh
# 2777     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 2980     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 3519     OT            שֵׁם־            שֵׁם    8035       None         shem
# 4687     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4750     OT            שֵׁ֨ם           שֵׁ֨ם    8035       None         shem
# 4813     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4816     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4828     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4831     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4865     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4879     OT          גֹּ֣מֶר         גֹּ֣מֶר    1586       None        gomer
# 4883     OT           מָדַ֖י          מָדַ֖י    4074       None        madai
# 4902     OT           יָוָ֖ן          יָוָ֖ן    3120       None        javan
# 4933     OT       מִצְרַ֖יִם      מִצְרַ֖יִם    4714       None      mizraim
# 4935     OT            פ֥וּט           פ֥וּט    6316       None          put
# 4991     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 4993     OT          אֶ֖רֶךְ         אֶ֖רֶךְ     751       None        erech
# 5042     OT        לְהָבִ֖ים       לְהָבִ֖ים    3853       None      lehabim
# 5073     OT        יְבוּסִי֙       יְבוּסִי֙    2983       None    jebusites
# 5081     OT    גִּרְגָּשִֽׁי   גִּרְגָּשִֽׁי    1622       None  girgashites
# 5085     OT          חִוִּ֥י         חִוִּ֥י    2340       None      hivites
# 5089     OT         עַרְקִ֖י        עַרְקִ֖י    6208       None      arkites
# 5093     OT         סִּינִֽי        סִּינִֽי    5513       None      sinites
# 5097     OT       אַרְוָדִ֥י      אַרְוָדִ֥י     721       None    arvadites
# 5101     OT        צְּמָרִ֖י       צְּמָרִ֖י    6786       None    zemarites
# 5111     OT      כְּנַעֲנִֽי     כְּנַעֲנִֽי  3669 a       None    canaanite
# 5154     OT            שֵׁ֥ם           שֵׁ֥ם    8035       None         shem
# 5167     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 5170     OT        אַשּׁ֑וּר       אַשּׁ֑וּר     804       None       asshur
# 5193     OT          שֶׁ֖לַח         שֶׁ֖לַח    7974       None       shelah
# 5226     OT          שָׁ֑לֶף         שָׁ֑לֶף    8026       None      sheleph
# 5229     OT     חֲצַרְמָ֖וֶת    חֲצַרְמָ֖וֶת    2700       None  hazarmaveth
# 5256     OT        חֲוִילָ֖ה       חֲוִילָ֖ה    2341       None      havilah
# 5279     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5483     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 5505     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5535     OT   אַרְפַּכְשַׁ֣ד  אַרְפַּכְשַׁ֣ד     775       None   arpachshad
# 5624     OT           פֶ֖לֶג          פֶ֖לֶג    6389       None        peleg
# 5704     OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 5939     OT            ל֑וֹט           ל֑וֹט    3876       None          lot
# 5955     OT         אַבְרָם֩        אַבְרָם֩      87       None        abram
# 6348     OT          נֶּ֖גֶב         נֶּ֖גֶב    5045       None        negev
# 6434     OT            ל֑וֹט           ל֑וֹט    3876       None        lot’s
# 6440     OT       פְּרִזִּ֔י      פְּרִזִּ֔י    6522       None   perizzites
# 6604     OT          נֶ֖גְבּ        נֶ֖גְבָּ    5045       None        south
# 6705     OT         גּוֹיִֽם        גּוֹיִֽם  1471 b       None        goiim
# 6782     OT          שָׁוֵ֖ה         שָׁוֵ֖ה    7740       None       shaveh
# 6859     OT         גּוֹיִ֔ם        גּוֹיִ֔ם  1471 b       None        goiim
# 6943     OT        אֵֽלֹנֵ֜י       אֵֽלֹנֵ֜י     436       None         oaks
# 6946     OT         אֱמֹרִ֗י        אֱמֹרִ֗י     567       None      amorite
# 7031     OT           סְדֹם֮          סְדֹם֮    5467       None        sodom
# 7339     OT          יֱהוִ֔ה         יֱהוִ֔ה    3069       None          god
# 7548     OT         קֵּינִי֙        קֵּינִי֙    7017       None      kenites
# 7552     OT       קְּנִזִּ֔י      קְּנִזִּ֔י    7074       None   kenizzites
# 7556     OT      קַּדְמֹנִֽי     קַּדְמֹנִֽי    6935       None   kadmonites
# 7560     OT          חִתִּ֥י         חִתִּ֥י    2850       None     hittites
# 7564     OT       פְּרִזִּ֖י      פְּרִזִּ֖י    6522       None   perizzites
# 7580     OT    גִּרְגָּשִׁ֖י   גִּרְגָּשִׁ֖י    1622       None  girgashites
# 7584     OT        יְבוּסִֽי       יְבוּסִֽי    2983       None    jebusites
# 7597     OT        מִצְרִ֖ית       מִצְרִ֖ית    4713       None     egyptian
# 7637     OT       מִּצְרִית֙      מִּצְרִית֙    4713       None     egyptian
# 8225     OT          שָׂרָ֑י         שָׂרָ֑י    8297       None        sarai
# 10066    OT          מוֹאָ֖ב         מוֹאָ֖ב    4124       None     moabites
# 10098    OT          נֶּ֔גֶב         נֶּ֔גֶב    5045       None        negev
# 10777    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 11122    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11276    OT       אַבְרָהָ֧ם      אַבְרָהָ֧ם      85       None      abraham
# 11645    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11651    OT   בְאֵ֥ר שָֽׁבַע          בְאֵ֥ר    884+       None         None
# 12055    OT       אַבְרָהָם֮      אַבְרָהָם֮      85       None      abraham
# 12083    OT        עֶפְר֗וֹן       עֶפְר֗וֹן    6085       None     ephron’s
# 12968    OT          שָׂרָה֩         שָׂרָה֩    8283       None        sarah
# 13241    OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 13568    OT          נֶּֽגֶב         נֶּֽגֶב    5045       None        negev
# 13724    OT       לְאֻמִּֽים      לְאֻמִּֽים    3817       None      leummim
# 13901    OT           קֵדָ֥ר          קֵדָ֥ר    6938       None        kedar
# 13974    OT        אַשּׁ֑וּר      אַשּׁ֑וּרָ     804       None       asshur
# 14008    OT  פַּדַּ֖נ אֲרָ֑ם        פַּדַּ֖ן   6307+       None         None
# 14305    OT    אֲבִימֶּ֥לֶךְ   אֲבִימֶּ֥לֶךְ      40       None    abimelech
# 14753    OT        רְחֹב֔וֹת       רְחֹב֔וֹת    7344       None     rehoboth
# 14771    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 14837    OT        אֲחֻזַּת֙       אֲחֻזַּת֙     276       None     ahuzzath
# 14980    OT        שִׁבְעָ֑ה       שִׁבְעָ֑ה    7656       None       shibah
# 14986    OT  בְּאֵ֣ר שֶׁ֔בַע         בְּאֵ֣ר    884+       None         None
# 15003    OT       יְהוּדִ֔ית      יְהוּדִ֔ית    3067       None       judith
# 16052    OT             חֵ֑ת            חֵ֑ת    2845       None      hittite
#
#               greek         predicted
# 1591           αδαμ               man
# 1682           αδαμ                of
# 1809           καιν            tiller
# 1845           αβελ            vanity
# 1927           αβελ          futility
# 2114           ενωξ            hanoch
# 2198            αδα            zillah
# 2231           αδαμ               man
# 2270           ενως               man
# 2281       ἀνθρώπων               man
# 2314           αδαμ               man
# 2336           αδαμ               man
# 2354           αδαμ               man
# 2412           ενως            mortal
# 2777            σημ              name
# 2980            σημ              name
# 3519            σημ              name
# 4687            σημ              name
# 4750            σημ              name
# 4813            σημ              name
# 4816         ξανααν              shem
# 4828            σημ              name
# 4831         ξανααν              shem
# 4865            σημ              name
# 4879          γαμερ           japheth
# 4883          μαδαι             gomer
# 4902          ιωυαν            greece
# 4933        μεσραιμ             egypt
# 4935           φουδ           mizraim
# 4991        βαβυλὼν           babylon
# 4993           ορεξ              slow
# 5042           None              anam
# 5073     ιεβουσαῖον          jebusite
# 5081     γεργεσαῖον        girgashite
# 5085         ευαῖον            hivite
# 5089      αρουκαῖον            arkite
# 5093      ασενναῖον            sinite
# 5097        ἀράδιον          arvadite
# 5101      σαμαραῖον         hamathite
# 5111      ξαναναίων         tradesmen
# 5154            σημ              name
# 5167            σημ              name
# 5170         ασσουρ           assyria
# 5193           σαλα            became
# 5226           None           almodad
# 5229        ασαρμωθ           sheleph
# 5256          ευιλα             jobab
# 5279            σημ              name
# 5483       σύγξυσις           babylon
# 5505            σημ              name
# 5535         ἔζησεν        thirtyfive
# 5624          φαλεκ            thirty
# 5704          ναξωρ        twentynine
# 5939            λωτ             lot’s
# 5955          αβραμ             sarai
# 6348           None             south
# 6434            λωτ             lot’s
# 6440      φερεζαῖοι         perizzite
# 6604           None         southward
# 6705          ἐθνῶν           nations
# 6782           σαυη  shavehkiriathaim
# 6859          ἐθνῶν           nations
# 6943           δρυὶ             mamre
# 6946         αμορις          amorites
# 7031        σοδομων            defeat
# 7339           None               may
# 7548      καιναίους            kenite
# 7552     κενεζαίους         kenizzite
# 7556    κεδμωναίους         kadmonite
# 7560      ξετταίους           hittite
# 7564     φερεζαίους         perizzite
# 7580    γεργεσαίους        girgashite
# 7584    ιεβουσαίους          jebusite
# 7597       αἰγυπτία              maid
# 7637      αἰγυπτίαν           abram’s
# 8225           σαρα           princes
# 10066      μωαβιτῶν              moab
# 10098          λίβα             south
# 10777          None         beersheba
# 11122          None         beersheba
# 11276        αβρααμ            raised
# 11645          None         beersheba
# 11651          None         beersheba
# 12055        αβρααμ            ephron
# 12083         εφρων          ephron’s
# 12968         σαρρα          master’s
# 13241         ναξωρ        twentynine
# 13568          None             south
# 13724        λοωμιμ           peoples
# 13901         κηδαρ          nebaioth
# 13974          πρὸς           assyria
# 14008  μεσοποταμίας           aramean
# 14305      αβιμελεξ             gerar
# 14753     εὐρυξωρία           squares
# 14771          None         beersheba
# 14837        οξοζαθ           adviser
# 14980         ὅρκος             seven
# 14986          None         beersheba
# 15003        ιουδιν            judean
# 16052           ξετ              heth

# %%
hebrew_names = set(hebrew_names)
hebrew_matched_names = set(hebrew_matched_names)
list(hebrew_names - hebrew_matched_names)
# Out:
# ['מָכִֽי',
#  'יְה֗וּד',
#  'מִיכָיָ֜ה',
#  'זִ֥יעַ',
#  'נָב֗וֹת',
#  'נְבַלָּֽט',
#  'כִּנֶּ֔רֶת',
#  'נְבֽוּכַדְרֶאצַּ֥ר',
#  'זְבֻל֑וּן',
#  'רֶ֧גֶם',
#  'מּוֹאֲבִיָּ֜ה',
#  'הֶ֨בֶל֙',
#  'עֵ֠ילָם',
#  'מֵידָ֔ד',
#  'יִּשְׂרְאֵלִֽי',
#  'אֱלִישָׁ֖ה',
#  'הוֹמָ֑ם',
#  'בְאֵרָֽא',
#  'אַשְׁבֵּלִ֑י',
#  'אֲגַ֥ג',
#  'רֽאוּבֵנִ֗י',
#  'תַפֻּ֖חַ',
#  'אָצַל֒',
#  'כִּסְלֵיו֙',
#  'רְפָיָ֧ה',
#  'מִיכָיָ֧ה',
#  'בִּתִּ֞',
#  'שִׁמְעָתִ֖ים',
#  'תַּ֠תְּנַי',
#  'יִצְחָ֨ק',
#  'אֲשִׁימָֽא',
#  'יֵשׁ֛וּעַ',
#  'אֲחַזְיָ֤ה',
#  'אֲרִיאֵ֡ל',
#  'גִּבְעָ֨תָ',
#  'דָּ֣ן',
#  'שְׁבָ֔ט',
#  'בָּשָׁ֞ן',
#  'יִבְלְעָ֨ם',
#  'עִיּ֡וֹן',
#  'תֻּבַ֣ל',
#  'בִּנְיָמִ֣ין',
#  'צָפ֥וֹן',
#  'חֶלְקָֽי',
#  'שָׁמָע֙',
#  'מֹּ֣רַשְׁתִּ֔י',
#  'כְּנַעֲנִ֨י',
#  'אֲחִיה֖וּד',
#  'פַּלְטִ֔י',
#  'קְעִלָ֔ה',
#  'צוֹפִ֖ים',
#  'אַבְרָ֫הָ֥ם',
#  'שִׁרְטַ֖י',
#  'בַקְבֻּֽקְיָ֛ה',
#  'מֹּצָֽה',
#  'כְנָ֑נִי',
#  'יַּעֲקֹ֑ב',
#  'יְהוּדִי֙',
#  'נַעֲמָֽן',
#  'מָע֖וֹךְ',
#  'פְּרָ֔ת',
#  'שַׁלְמַ֖י',
#  'שִׁמְשַׁ֥י',
#  'חֲשֻׂפָ֖א',
#  'שִׁפְעִ֧י',
#  'אַמְנֹ֗ן',
#  'יַֽאֲזַנְיָ֨הוּ֙',
#  'בּוּנִּֽי',
#  'עֵיבָ֖ל',
#  'ירִימ֤וֹת',
#  'אֵ֔צֶר',
#  'אֲשַׂרְאֵ֖לָה',
#  'עֶקְרוֹן֮',
#  'מּוֹרָֽא',
#  'שִּׁטִּים֙',
#  'צְֽרֵרָ֔תָ',
#  'יְדוּת֑וּן',
#  'נֽוֹעַדְיָ֥ה',
#  'זְבֻ֣ל',
#  'דַּמֶּ֤שֶׂק',
#  'נֹ֑ף',
#  'גָדִ֜י',
#  'יִשָּׂשכָ֣ר',
#  'יִתְמָ֖ה',
#  'עָמְרִ֨י',
#  'שֵׁשַׁ֥י',
#  'בְּאֵ֣רֹתִ֔י',
#  'לֶ֗מֶךְ',
#  'שֵׁלָ֗ה',
#  'שָׁ֠אוּל',
#  'פַרְעֹ֖שׁ',
#  'מְשִׁלֵּמ֔וֹת',
#  'גִּלְעָדִֽי',
#  'אַבְנֵר֩',
#  'אֶסְתֵּֽר',
#  'אֲרִדַ֖י',
#  'אַרְבִּֽי',
#  'פַרְעֹה֒',
#  'עַבְדִּיאֵ֣ל',
#  'נָבָ֡ל',
#  'יְקַמְיָ֥ה',
#  'טֶ֣בַח',
#  'ס֧וּחַ',
#  'בֵּ֣לְטְשַׁאצַּ֗ר',
#  'נְתַנְיָ֥ה',
#  'יִֽזְרַחְיָ֖ה',
#  'עֵיטָם֒',
#  'קְוֵ֕א',
#  'מִכְמָ֔ס',
#  'נְבֽוּכַדְרֶאצַּר֒',
#  'יַעֲקֹב֮',
#  'יִגְאָל',
#  'גַעְתָּ֔ם',
#  'שִׁמְשׁ֥וֹן',
#  'בִּנְיָמִן֒',
#  'כַרְכַּ֔ס',
#  'חִלְקִיָּ֛הוּ',
#  'מֵּרֹ֣נֹתִ֔י',
#  'פִּרְעָתוֹנִ֑י',
#  'פַרְעֹה֮',
#  'גְדֵרֹתָ֑יִם',
#  'עֲשְׁתְּרָתִ֑י',
#  'מָֽרֵשָׁ֑ה',
#  'זַכַּ֖י',
#  'אַהֲרֹן֮',
#  'חֵ֨לֶף',
#  'נְבָ֗ט',
#  'אַרְנ֑וֹן',
#  'דָּוִ֡ד',
#  'ירִיחוֹ֮',
#  'אֶלְעָלֵ֔ה',
#  'נְּמ֣וּאֵלִ֔י',
#  'זָ֑רֶד',
#  'מֵישַׁךְ֙',
#  'שֵׁשַׁ֖ךְ',
#  'אֲדֹמִי֮',
#  'הוֹדַוְיָ֡הוּ',
#  'דּוּרָ֔א',
#  'אֹ֛רֶן',
#  'כּ֗וּשׁ',
#  'הָמָ֡ן',
#  'חָגָ֥ב',
#  'עֲתַלְיָ֑ה',
#  'אֱלִיאָ֣ב',
#  'אֲחִֽינָדָ֥ב',
#  'חָֽרֶת',
#  'יֽוֹצָדָ֔ק',
#  'זְרַֽחְיָ֑ה',
#  'אֲדוֹמִ֔ים',
#  'אֱלִיפַ֣ז',
#  'בְּנָיָֽה',
#  'צִיד֜וֹן',
#  'נְבֽוּכַדְנֶאצַּ֔ר',
#  'חֹרֵֽבָ',
#  'אַשּׁוּר֮',
#  'נָ֭הָר',
#  'חֲזָיָ֨ה',
#  'יְהוּכַ֣ל',
#  'בֵּבָ֑י',
#  'שָׂרָ֗ה',
#  'אֲבִיגַ֗יִל',
#  'נְתַנְיָ֔ה',
#  'יהוּדָ֧ה',
#  'אֲחַסְבַּ֖י',
#  'דָנִיֵּ֡אל',
#  'עֹג֙',
#  'בָלָ֜ק',
#  'שֹֽׁמְר֗וֹן',
#  'צְבֹעִ֖ים',
#  'נְבֻכַדְנֶאצַּ֨ר',
#  'מַלְכִּיָּ֔ה',
#  'עוּתַ֨י',
#  'שְׁבַנְיָ֡הוּ',
#  'הָמָ֥ן',
#  'הָגָ֑ר',
#  'אֲחוֹחִי֙',
#  'יְ֠הוֹחָנָן',
#  'אֲחַשְׁוֵר֜וֹשׁ',
#  'לֵּוִ֜י',
#  'דִינָה֙',
#  'בָשָׁן֙',
#  'אַבְרָם֮',
#  'יְהֽוֹעַדָּ֖ן',
#  'יוֹיָרִ֥יב',
#  'עַכְבּ֨וֹר',
#  'צֹּרִ֔ים',
#  'שְׂר֔וּג',
#  'שָׂרָ֔י',
#  'אַשְׁדּוֹדִ֔ית',
#  'זֶ֨רֶשׁ',
#  'כִּנְר֔וֹת',
#  'לוּדִ֕ים',
#  'עֶזְרָ֨א',
#  'פִּלְדָּ֖שׁ',
#  'שְׁכַנְיָ֖הוּ',
#  'כָּב֖וּל',
#  'קִדְר֜וֹן',
#  'טַבָּעֽוֹת',
#  'אִדּ֨וֹ',
#  'צְבוֹיִ֔ים',
#  'יְהוֹעַדָּ֖ן',
#  'סְכָכָֽה',
#  'מַֽעַזְיָ֖הוּ',
#  'פֻוָּ֖ה',
#  'מִֽיכָאֵ֗ל',
#  'בָלָ֗ק',
#  'בְּאֵֽרֹתִ֖י',
#  'נְעַרְיָה',
#  'אוּלָ֖ם',
#  'יִמְנָ֖ע',
#  'דָֽנִיֵּ֑אל',
#  'תַּרְשִׁישׁ֙',
#  'חָ֕ם',
#  'דְבִ֨רָ',
#  'מַלּוּךְ֙',
#  'חֲשַׁבְיָ֨ה',
#  'יְשַֽׁעְיָ֖ה',
#  'יִדְבָּ֑שׁ',
#  'גְּמַרְיָהוּ֩',
#  'אֶתְנִ֥י',
#  'גָד֩',
#  'אָסָף֩',
#  'דְלָיָ֨הוּ֙',
#  'אֶ֠לְקָנָה',
#  'יוֹזָבָ֔ד',
#  'שַׁלְתִּיאֵל֙',
#  'עָ֤ר',
#  'יֵ֥שֶׁר',
#  'כְּרֵתִ֛י',
#  'צַֽאֲנָ֔ן',
#  'פְּלִשְׁתִּים֒',
#  'שְׁמַעְיָ֔הוּ',
#  'נִמְשִׁ֖י',
#  'צָפֹ֛נָ',
#  'עָמְרִ֤י',
#  'גִבְע֨וֹן',
#  'שְׁמַעְיָ֧ה',
#  'יָ֣מָּ',
#  'לְּבָנ֞וֹן',
#  'מִּצְפָּה֒',
#  'קְצִיעָ֑ה',
#  'תְּקוֹעִ֑י',
#  'מִצְרַ֤יִם',
#  'נְ֠תַנְיָהוּ',
#  'קַבְצְאֵ֑ל',
#  'מַעֲכָה֙',
#  'עֲתַלְיָ֔ה',
#  'חֶצְר֗וֹן',
#  'דָּרְיָ֔וֶשׁ',
#  'רֶ֧שֶׁף',
#  'פּוּנִֽי',
#  'ירוּשְׁלֶ֛ם',
#  'חִלְקִיָּהוּ֩',
#  'בֵלְטְשַׁאצַּר֙',
#  'אֲמַצְיָ֣ה',
#  'ראוּבֵנִ֤י',
#  'זִיזָ֨א',
#  'עָלָ֑מֶת',
#  'לָכִ֛ישׁ',
#  'צִ֫יּ֥וֹן',
#  'אָ֣שֵׁרִ֔י',
#  'קַרְתָּ֖ן',
#  'נְ֠חֶמְיָה',
#  'נְּתִינִים֙',
#  'גִבְע֔וֹן',
#  'יְרִיח֥וֹ',
#  'זְאֵ֑ב',
#  'עַמִּיזָבָ֖ד',
#  'תְק֨וֹעַ֙',
#  'צִדְקִיָּ֤ה',
#  'שֵׁ֑ת',
#  'סַּרְדִּ֔י',
#  'צְּרֵדָ֗ה',
#  'פּוּעָֽה',
#  'יוֹיָכִֽין',
#  'פִרְעָתוֹן֙',
#  'מֵּרֹנֹתִֽי',
#  'גַ֨עַל',
#  'אַחְאָב֒',
#  'בְרִעָ֣ה',
#  'אַרְדִּ֔י',
#  'עַלְיָ֧ן',
#  'גִּרְגָּשִׁ֨י',
#  'מַקֵּדָ֔ה',
#  'אֶשְׁתָּאֹ֗ל',
#  'שְׁבָ֑א',
#  'עַמּ֧וֹן',
#  'קַּדְמֹנִֽי',
#  'יִבְנִיָּֽה',
#  'בֶּ֚לַע',
#  'גִּבְלִ֑ים',
#  'רְעוּאֵ֣ל',
#  'יְשַֽׁעְיָ֖הוּ',
#  'גִּבְעָ֜ה',
#  'יְשֻׁרוּן֙',
#  'אדֹנָ֔',
#  'אֶלְחָנָן֩',
#  'שִׁישַׁ֣ק',
#  'יְהוּדִ֔י',
#  'נָבָל֒',
#  'לֶּ֗חִי',
#  'חֵלֽוֹן',
#  'שּׁוּנַמִּ֖ית',
#  'חִזְקִיָּהוּ֒',
#  'מֶ֤שֶׁךְ',
#  'שִׁפְרָ֔ה',
#  'מִּצְפָּ֛ה',
#  'חָנֵ֥ס',
#  'גִיח֨וֹן',
#  'רוּמָ֖ה',
#  'נַחֲמָ֜נִי',
#  'יְהוּדָיֵ',
#  'וַיְזָֽתָא',
#  'גֹּ֖שֶׁן',
#  'יְהוֹאָחָ֤ז',
#  'בְּאֵרֹתִ֖ים',
#  'אֶלְתְּקֵ֥ה',
#  'בֵּלְטְשַׁאצַּ֗ר',
#  'יְהֻדִיָּ֗ה',
#  'חִירָ֜ם',
#  'זְכַרְיָ֡הוּ',
#  'אוּפָ֔ז',
#  'לְוִיִּ֨ם',
#  'יָרִ֖יב',
#  'רֵכָ֨ב',
#  'גֵֽי',
#  'שֶֽׁלֶמְיָ֥ה',
#  'בְנָיָ֖הוּ',
#  'מִּדְיָנִ֖ית',
#  'צְבֹאיִ֑ם',
#  'יִּזְרָ֑ח',
#  'שַׁלּ֣וּן',
#  'קֵדָ֛ר',
#  'תָּמָ֔ר',
#  'יוֹסֵ֨ף',
#  'זָנוֹחַ֒',
#  'יֹאושִׁיָּ֖הוּ',
#  'יְאֹר֒',
#  'דֶּ֛קֶר',
#  'רְפִידִ֔ם',
#  'גִּבְעוֹנִ֛י',
#  'יִּזְרְעֵאלִ֖י',
#  'יְאֹר֮',
#  'גַּרְמִ֑י',
#  'בֶרֶכְיָ֤ה',
#  'יְ֠רוּשָׁלִַם',
#  'חֲשַׁבְנְיָ֜ה',
#  'נָח֛וֹר',
#  'אֲחִֽיסָמָךְ֙',
#  'לוּבִ֥ים',
#  'סִ֛ין',
#  'אֲרָמִ֖ית',
#  'יָּ֑מָּ',
#  'ידִֽיעֲאֵל֙',
#  'בְּרִיעִֽי',
#  'מְלַטְיָ֣ה',
#  'גָ֑ד',
#  'בֶּ֣לַע',
#  'טוֹבִיָּ֑ה',
#  'לְבָנ֗וֹנָ',
#  'סֻכִּיִּ֖ים',
#  'גֵ֣י',
#  'תֶ֜רֶשׁ',
#  'עֶפְרוֹן֒',
#  'שָׁגֵ֖ה',
#  'תֵּימָ֔ן',
#  'יְה֣וֹנָדָ֔ב',
#  'בַּעַל',
#  'צֹ֔חַר',
#  'עִדּ֑וֹא',
#  'קָּרְחִ֑י',
#  'אַרְכִּ֔י',
#  'אֲחִימַ֗עַץ',
#  'יְהוָ֘ה',
#  'חֲמָ֛ת',
#  'אַחְיָ֣ן',
#  'יִרְמְיָ֨ה',
#  'אוּרִיָּה֙',
#  'אֲרָמִֽית',
#  'צְמָרַ֔יִם',
#  'שְׁכֶ֜ם',
#  'יַּרְדֵּן',
#  'אֱד֞וֹם',
#  'מַעֲשֵׂיָ֖ה',
#  'יְהוּדִ֜י',
#  'נֹּ֔א',
#  'אֶבְיָתָ֗ר',
#  'אֲמָ֥ם',
#  'יִּשְׂרָאֵ֛ל',
#  'מוֹאֲבִיּֽוֹת',
#  'פָּ֑עוּ',
#  'גִּבְע֑וֹן',
#  'חֲשַׁבְיָ֛ה',
#  'כְּלֽוּב',
#  'אֵימִ֔ים',
#  'יְרֵח֥וֹ',
#  'גָּ֑בַע',
#  'שְׁמוּאֵ֞ל',
#  'שִּׁילֹנִ֨י',
#  'חִוִּ֧י',
#  'אֱלִיעֶ֔זֶר',
#  'דַרְדַּ֖ע',
#  'נְתַנְיָ֑ה',
#  'הָרָא֙',
#  'יָבִ֔ין',
#  'יְע֛וּשׁ',
#  'רִצְיָֽא',
#  'בַרְזִלַּ֗י',
#  'אוּלָ֑י',
#  'אֶלְתְּקֵ֖א',
#  'לָֽשַׁע',
#  'צָּרְעָ֣ה',
#  'חֶפְצִי',
#  'אָשֵׁ֤ר',
#  'אֲבִינֹ֖עַם',
#  'צִֽקְלַ֖ג',
#  'בָבְלָיֵ',
#  'תָמָר֙',
#  'הֹרָם֙',
#  'יְהֹוָה֙',
#  'שַֽׁעֲלַבִּ֥ין',
#  'לְמוּאֵ֣ל',
#  'יהוֹשֻׁ֔עַ',
#  'חִילֵז֙',
#  'יְרֹחָ֧ם',
#  'ישַׁעְיָהוּ',
#  'קָֽיִן',
#  'יִּשְׂרָאֵל֒',
#  'פְּלִשְׁתִּ֤ים',
#  'חֲנֹ֔ךְ',
#  'אֵל֛וֹת',
#  'מַלְכִּיָּ֖ה',
#  'עֲדִינָ֨א',
#  'סְבָ֗א',
#  'אֲבִישׁ֗וּעַ',
#  'שִׁיאֹ֖ן',
#  'אִיזֶ֥בֶל',
#  'כַשְׂדָּֽי',
#  'אֲזַנְיָ֔ה',
#  'רַבָּה֒',
#  'יַעְכָּ֛ן',
#  'יְרוּשָׁלְַ֗מָ',
#  'אַשְׁפְּנַ֖ז',
#  'אָמוֹץ֙',
#  'אֲחִיָּ֣הוּ',
#  'צָפ֥וֹנָ',
#  'מֵּשָׁ֑א',
#  'מֹ֣ף',
#  'נֵ֜ר',
#  'זִפְרֹ֔נָ',
#  'יהוֹנָתָ֜ן',
#  'אֱלִיאָב֮',
#  'בִּזְּתָ֨א',
#  'זַמְזֻמִּֽים',
#  'דִֽימוֹנָ֖ה',
#  'יֽוֹשָׁפָ֡ט',
#  'שִׁמְשׁוֹן֮',
#  'אֶפְרַיִם֒',
#  'מִּצְרַיִם֒',
#  'פַשְׁחוּר֙',
#  'בְעֹֽן',
#  'פְּלַטְיָ֥הוּ',
#  'דָּוִיד֩',
#  'כְּבָ֔ר',
#  'שִׁיל֑וֹ',
#  'אֵלֹנִ֑י',
#  'יְהֹוָ֔ה',
#  'בִּדְקַר֙',
#  'יוֹשָׁ֖ה',
#  'יָרְקֳעָ֑ם',
#  'חֻבָּ֥ה',
#  'בָבֶ֛ל',
#  'יֹאשִׁיָּ֤הוּ',
#  'יְרִיח֑וֹ',
#  'תֵּימָ֤ן',
#  'גִדְע֥וֹן',
#  'גִּ֣זוֹנִ֔י',
#  'עֲמָלֵק֙',
#  'בַּעֲנָ֣ה',
#  'הַגְרִֽי',
#  'שְׁכֶ֧ם',
#  'אֲדוֹנָ֔',
#  'זְבַדְיָ֖ה',
#  'יִסְכָּֽה',
#  'דָ֠וִד',
#  'חֵ֤פֶר',
#  'בַּרְזִלַּ֤י',
#  'גֶּ֣בַע',
#  'צּוֹבָ֔ה',
#  'שֻּׁנַמִּית֙',
#  'שִּֽׁילוֹנִ֗י',
#  'גָּזֵֽז',
#  'מַעֲשֵׂיָ֧הוּ',
#  'יְהוֹשֻׁעַ֒',
#  'עֲרָבִ֔י',
#  'ל֑וֹט',
#  'נְח֣וּם',
#  'פְרִידָֽא',
#  'יַּחְלְאֵלִֽי',
#  'שֶׁבַע',
#  'נְבֽוּכַדְנֶצַּ֜ר',
#  'יֵ֠הוּא',
#  'פְּנוּאֵ֖ל',
#  'דְּבֹרָ֔ה',
#  'שִּׁל֤וֹ',
#  'דָוִ֜יד',
#  'אֲדֹ֣מִיֹּ֔ת',
#  'יְהֽוֹיָקִ֜ים',
#  'יִתְר֛וֹ',
#  'עַמֹּנִ֜ים',
#  'יְרֵחוֹ֒',
#  'חֲשַׁבְיָ֨הוּ',
#  'יֵהוּא֮',
#  'יָעֵל֙',
#  'אֱלִיעֶ֡זֶר',
#  'יְהֹוָ֧ה',
#  'לֵוָיֵ֜',
#  'אָמוֹן֩',
#  'גֹּעָֽתָ',
#  'חֲנַמְאֵ֨ל',
#  'מְּנַשֶּׁ֡ה',
#  'שַׁמְה֣וּת',
#  'פֶּ֧רֶץ',
#  'ישׁוֹחָיָה',
#  'יִתְר֖וֹ',
#  'שַׁלֻּם֙',
#  'מִרְיָ֛ם',
#  'אַבְשָׁלֹ֛ם',
#  'יַעְנַ֥י',
#  'מֵישַׁ֧ךְ',
#  'בַעֲנָ֔ה',
#  'יהֽוֹנָתָ֥ן',
#  'בָּבֶ֔לָ',
#  'יהוֹיָדָ֜ע',
#  'גָּ֞ד',
#  'אָזְנִ֕י',
#  'נֵיבָֽי',
#  'אֲבִישַׁ֨י',
#  'יָרָבְעָ֨ם',
#  'יהוֹיָקִ֨ים',
#  'אֶפְרַיִם֮',
#  'יהוֹשֻׁ֗עַ',
#  'דָּרְיָ֖וֶשׁ',
#  'קְּנִזִּי֙',
#  'בֶּֽרֶכְיָ֑הוּ',
#  'נַּחֲלִיאֵ֖ל',
#  'יְהוֹרָ֡ם',
#  'יַדּ֔וּעַ',
#  'גִּבְעָה֮',
#  'אוּרִיָּ֨ה',
#  'אֲחַזְיָ֛הוּ',
#  'תָֽמַח',
#  'נְצִ֖יחַ',
#  'עֲקָֽן',
#  'פוּאָ֛ה',
#  'בָלָ֧ק',
#  'סְפַרְוַ֔יִם',
#  'עֲנָקִים֙',
#  'אַבְשָׁל֧וֹם',
#  'אַרְדּֽוֹן',
#  'אֲבִימֶ֧לֶךְ',
#  'קַדְמִיאֵ֥ל',
#  'תַעְנַךְ֙',
#  'עַֽלְוָ֖ה',
#  'מַֽעֲכָת֙',
#  'יֽוֹצָדָ֜ק',
#  'בָּרָק֙',
#  'חַשּׁ֛וּב',
#  'אֶלְנָתָ֧ן',
#  'יִרְמְיָ֑ה',
#  'נְבוּכַדְרֶאצַּ֨ר',
#  'עֲשָׂהאֵ֛ל',
#  'כַלְכֹּ֥ל',
#  'פִּרְעָתוֹנִֽי',
#  'אֱמֹרִ֤י',
#  'מְהֵֽיטַבְאֵל֙',
#  'יוֹקִ֞ים',
#  'בַעְשָׁ֛א',
#  'הַגְרִֽים',
#  'יהוֹנָתָן',
#  'שָּׁא֖וּל',
#  'עֲנָ֔ב',
#  'חֲנַנְיָה',
#  'מִיכַל֒',
#  'יֶ֨רֶד',
#  'עַכּ֔וֹ',
#  'אֱלִיחֹ֧רֶף',
#  'דָויִ֔ד',
#  'כַשְׂדָּאָֽ',
#  'יְהֽוֹחָנָן֙',
#  'יִגְדַּלְיָ֖הוּ',
#  'גִּבְעָ֔תָ',
#  'ירֽוּשְׁלֶ֑ם',
#  'כְּנַעַן֒',
#  'שׁ֖וּרָ',
#  'דְּבִ֑יר',
#  'יְכָלְיָ֖הוּ',
#  'בַּעֲשֵׂיָ֖ה',
#  'עֲשָׂהאֵ֜ל',
#  'מִגְדּ֔וֹל',
#  'עֵינַ֔יִם',
#  'נָתָ֧ן',
#  'חֶלְקִֽי',
#  'בַּ֨עַל֙',
#  'צְרוּיָ֑ה',
#  'נְ֠תַנְיָה',
#  'יִתְנָֽן',
#  'עִירִ֜י',
#  'נְתַנְאֵ֡ל',
#  'עַקּֽוּב',
#  'חִירָ֛ה',
#  'פָדֽוֹן',
#  'נְתַנְיָ֤ה',
#  'ירֽוּשָׁלִַ֔ם',
#  'עֲרוֹעֵ֗ר',
#  'חֳרֵ֥ם',
#  'חֲנַנְיָה֙',
#  'גַזָּֽם',
#  'יהוּדָ֤ה',
#  'נ֟וּן',
#  'עֲרוֹעֵ֖ר',
#  'בָּשָׁן֒',
#  'צֵלַ֡ע',
#  'מְעוּנִ֖ים',
#  'אֲדֹנִיָּ֨הוּ֙',
#  'צְרֵדָֽתָ',
#  'דִּימ֖וֹן',
#  'גִּֽילֹנִ֜י',
#  'שַׁלֻּ֖ם',
#  'מִּצְפָּ֔תָ',
#  'תּוֹלָעִ֑י',
#  'נְבֽוּכַדְנֶצַּר֙',
#  'אֲמָנָ֗ה',
#  'לֶ֜שֶׁם',
#  'אֱלִיעֶ֧זֶר',
#  'אֲחִיָּ֗הוּ',
#  'מָכִ֤יר',
#  'טַבּ֣וּר',
#  'בַקְבּ֥וּק',
#  'יַֽעֲק֔וֹב',
#  'יֹ֣אשִׁיָּ֔הוּ',
#  'אֽוּרִיָּ֗ה',
#  'אַדְמָ֣תָא',
#  'חַרְחֽוּר',
#  'אַיָּל֜וֹן',
#  'רָפֽוּא',
#  'מַתַּנְיָה֙',
#  'חֲכִילָ֗ה',
#  'קֵֽלָיָה֙',
#  'בְּנְיָמִ֥ן',
#  'אֶלְיָשִׁ֜יב',
#  'אִֽיתִיאֵ֑ל',
#  'יהוֹשֻׁ֪עַ',
#  'פְנוּאֵ֔ל',
#  'מַֽשׁ',
#  'בָּ֠בֶל',
#  'אַדָּ֖ן',
#  'יְּהוּדִ֗י',
#  'שַׁבְּתַ֥י',
#  'חֶשְׁבּ֧וֹן',
#  'מָרָ֔תָ',
#  'עֲזַרְיָ֔הוּ',
#  'יִּשְׂרָאֵ֜ל',
#  'גָמ֖וּל',
#  'עֲזַרְיָ֨הוּ',
#  'אֲחִימֶ֜לֶךְ',
#  'פְּלִשְׁתִּים',
#  'רָ֣אמַת',
#  'גַ֖חַר',
#  'אֱלִ֨ישָׁמָ֜ע',
#  'צְרִ֡י',
#  'תִּרְשָׁ֜תָא',
#  'שְֽׁמַֽעְיָה֩',
#  'יְ֠הוֹיָקִים',
#  'אֲגַ֖ג',
#  'וָפְסִֽי',
#  'לוּד֙',
#  'גֶּ֥בֶר',
#  'אֲחִיָּ֜הוּ',
#  'זְאֵב֙',
#  'טָֽבְאֵל֙',
#  'ט֣וֹבִיָּ֔ה',
#  'דַבָּ֑שֶׁת',
#  'אֶבְיָתָ֨ר',
#  'נְבוּכַדְנֶצַּ֑ר',
#  'שִֽׁמְעִ֨י',
#  'צָּפ֛וֹן',
#  'גָּלִ֔ילָ',
#  'אַסְפָּֽתָא',
#  'עֶזְרָ֡א',
#  'צִפּ֔וֹר',
#  'ירוּשְׁלֶם֙',
#  'אֹ֖ן',
#  'שִּׁטִּ֗ים',
#  'בְרִיעָה֙',
#  'כְּלוּבָֽי',
#  'צְפַנְיָ֔ה',
#  'שֶּׂ֔כוּ',
#  'פֶּ֥קַח',
#  'ע֨וֹג',
#  'אַרְפַּכְשָׁ֔ד',
#  'רַעַמְסֵֽס',
#  'מַלְאָכִֽי',
#  'עֻזִּיאֵ֤ל',
#  'תּֽוֹגַרְמָ֔ה',
#  'צִיּ֞וֹן',
#  'עַזָּֽן',
#  'מִדְיָנִ֜ים',
#  'מַֽעַזְיָ֥ה',
#  'סְפָרַ֑ד',
#  'שַׂלְמָ֖א',
#  'נָ֣פַת',
#  'אַרְתַּחְשַׁ֖שְׂתְּ',
#  'פִּלְחָ֖א',
#  'יהֻ֥ד',
#  'דַנָּ֥ה',
#  'תִּרְשָׁ֡תָא',
#  'עֵלְמָיֵֽ',
#  'פּ֥וּל',
#  'דָּרְיָ֧וֶשׁ',
#  'קְלִיטָ֔א',
#  'יְהוִ֡ה',
#  'עֶקְרֹנִ֜ים',
#  'יָּ֧ם',
#  'פְּלֵתִ֖י',
#  'עֲנַמֶּ֖לֶךְ',
#  'יהוּדָה֒',
#  'נָב֨וֹת',
#  'וַשְׁתִּי֙',
#  'שִׁלוֹ֙',
#  'אֲרַ֥ב',
#  'כּוּשׁ֮',
#  'פְלִשְׁתִּיִּ֥ים',
#  'עֲנָ֖נִי',
#  'תְחַפְנְחֵס֙',
#  'יְר֣וּשְׁלֶ֔ם',
#  'שִּׁלֹ֗ה',
#  'שָּׁאוּלִֽי',
#  'אֲבִיגַ֣ל',
#  'נְבוּכַדנֶאצַּ֤ר',
#  'צִדְקִיָּ֡הוּ',
#  'רְחֻ֖ם',
#  'יְבוּסִ֥י',
#  'עַשְׁתָּרֹ֑ת',
#  'יְדוּתוּן֙',
#  'קִבְצַ֨יִם֙',
#  'יָ֥הּ',
#  'יֽוֹנָתָן֙',
#  'רְמַלְיָ֤הוּ',
#  'חֵ֤ת',
#  'יַבְנֵ֔ה',
#  'גַּדִּ֖י',
#  'ידַֽעְיָ֔ה',
#  'נְב֑וֹ',
#  'מֹּלֶךְ֒',
#  'אֲבִיגַ֡יִל',
#  'נְבוּכַדְנֶצַּר֒',
#  'מִּצְפָּה֮',
#  'תְּקוֹעִ֑ים',
#  'מִתְרְדָ֣ת',
#  'אֵלִיָּ֛הוּ',
#  'יְּהוּדִ֑ים',
#  'בִנּ֖וּי',
#  'לַ֥יִשׁ',
#  'אֽוּרִיאֵ֤ל',
#  'מָנ֜וֹחַ',
#  'יִשְׁמָעֵ֥אל',
#  'שָׁאוּל֒',
#  'אִבְצָ֖ן',
#  'יוֹזָבָד֙',
#  'אֲמַצְיָ֔ה',
#  'בִּלְהָ֔ה',
#  'תַחְפְּנֵ֔ס',
#  'יוֹרָ֤ם',
#  'כָּנְיָ֔הוּ',
#  'פְּתוּאֵֽל',
#  'שְׁכַנְיָ֔ה',
#  'שְׁלוֹמִ֖ית',
#  'גִלְעָ֛ד',
#  'מוֹאָ֧ב',
#  'הָרָרִ֑י',
#  'נִבְחַ֖ז',
#  'דָוִ֞יד',
#  'דַרְק֖וֹן',
#  'גִּדְעוֹנִֽי',
#  'דָּֽנִיֵּ֜אל',
#  'אֲחִיקָ֑ם',
#  'מַכְבֵּנָ֖ה',
#  'נְחֶמְיָ֧ה',
#  'אֲבִיה֛וּא',
#  'דִשׁ֥וֹן',
#  'צִלָּה֙',
#  'כַבּ֥וֹן',
#  'יְחִיאֵ֑ל',
#  'יָגְלִֽי',
#  'שֻּׁ֣תַלְחִ֔י',
#  'עֲמֹרָה֙',
#  'מִיכָ֣יְהוּ',
#  'יְרִיח֜וֹ',
#  'יִשָּׂשכָ֤ר',
#  'אַרְכְּוָיֵ֤',
#  'בְּנָיָ֣הוּ',
#  'שַׂלְמָֽה',
#  'עֻזִיָּ֖א',
#  'פ֔וּל',
#  'אַבְרָהָם֩',
#  'צִקְלַ֖ג',
#  'רֶ֔סֶן',
#  'מְרָרִי֒',
#  'עֻזִּיאֵל',
#  'צִידֹנִ֗ים',
#  'יְה֖וּד',
#  'עַיָּ֖ה',
#  'נַחֲלִיאֵ֑ל',
#  'יְבֻסִ֖י',
#  'בִּנְיָמִ֑ין',
#  'גַּ֣ת',
#  'שָׁ֑מֶד',
#  'אַמְצִ֣י',
#  'בָלָ֤ק',
#  'חוּקֹ֑קָ',
#  'מְּכֵ֣רָתִ֔י',
#  'עֲשִׂיאֵֽל',
#  'בִּנּ֖וּי',
#  'יְּהוּדִ֨ים',
#  'שְׁחַרְיָ֖ה',
#  'אֲחִיָּה֙',
#  'נְחֶמְיָ֗ה',
#  'אֲדֹנִיקָם֮',
#  'נְצִֽיב',
#  'אֱלִיָּ֔תָה',
#  'יְחִזְקִיָּ֡הוּ',
#  'נָּהָ֣ר',
#  'יְּהוּדִים֩',
#  'בְנָיָ֡הוּ',
#  'סַלּוּא֙',
#  'י֠וֹסֵף',
#  'אַשְׁקְל֗וֹן',
#  'זּוּזִ֖ים',
#  'כִּסְלֽוֹן',
#  'מָנ֤וֹחַ',
#  'זִ֗ו',
#  'צָפֹ֣נָ',
#  'מַּכְפֵּלָה֙',
#  'פִינְחָס',
#  'אָשֵׁ֜ר',
#  'תַּרְתָּ֑ק',
#  'צְלָפְחָד֮',
#  'יָבִ֗ין',
#  'יְהוִה֮',
#  'עָנִֽים',
#  'אֱלִיה֛וּא',
#  'תִּרְצָ֔ה',
#  'יְרֽוּשָׁלִַם֮',
#  'יָל֑וֹן',
#  'חֲתַֽת',
#  'שִּׁלֹנִֽי',
#  'זִיזָ֖ה',
#  'מְּדָנִ֔ים',
#  'פָֽרַס',
#  'מִֽיכָאֵ֜ל',
#  'שַׁלֻּ֔ם',
#  'שׁוּשָׁ֖ן',
#  'נְבֻכַדְנֶאצַּ֣ר',
#  'צִיעֹ֑ר',
#  'אֲחַזְיָ֜הוּ',
#  'מְהוּמָן',
#  'אֶלְיוֹעֵינַ֗י',
#  'מַכְנַדְבַ֥י',
#  'יְרַחְמְאֵ֑ל',
#  'יוֹרָם֩',
#  'מָכִיר֩',
#  'בָּלָ֥ק',
#  'תֵּמָ֑א',
#  'אַׄהֲׄרֹ֛ׄןׄ',
#  'מִֽיכָאֵ֑ל',
#  'אֲחִיט֜וּב',
#  'עַתְלָֽי',
#  'עֲזַרְיָהוּ֩',
#  'סְדֹ֜ם',
#  'שְׁמַעְיָה',
#  'הֵגַ֖י',
#  'בֵסַ֥י',
#  'סִֽיסְרָא֩',
#  'תֵּֽימָנִ֗י',
#  'צֹ֜ר',
#  'זְבוּב֮',
#  'חָצֹ֥ר',
#  'שָּׂטָן֙',
#  'יְדִידָ֥ה',
#  'לָכִ֨ישָׁ',
#  'נְבָ֨ט',
#  'הֵשִׁ֨יב',
#  'מְעוֹנֹתַ֖י',
#  'טְּלָאִ֔ים',
#  'עַ֗יִשׁ',
#  'אֲדֹ֨נִיָּ֧הוּ',
#  'שָׁוֵ֔ה',
#  'בִזְיוֹתְיָֽה',
#  'אֲחִיָּ֗ה',
#  'מִכָ֔יְהוּ',
#  'גָּדִ֖י',
#  'סֶ֣לֶד',
#  'גִּבְעֹנִ֞ים',
#  'צִידֹ֥ן',
#  'יְהוִ֤הּ',
#  'הוֹשָׁמָ֖ע',
#  'הָ֑ם',
#  'אַיָּ֑ה',
#  'עַמּוֹנִ֛ים',
#  'בִּנְיָמִין֒',
#  'קַּדְמוֹנִ֔י',
#  'כִּנֶּ֗רֶת',
#  'שְׁמוּאֵל֒',
#  'גֶ֨שֶׁם',
#  'אֲבִיהוּא֙',
#  'יוֹאָחָ֣ז',
#  'נְטָעִ֖ים',
#  'עֶקְרוֹן֒',
#  'פָּ֑עִי',
#  'בְּעֶשְׁתְּרָ֖ה',
#  'שָׁרָ֖ר',
#  'בְרִיעָ֑ה',
#  'עַשְׁתֹּרֶת֮',
#  'מְ֠נַחֵם',
#  'מַתִּתְיָ֜הוּ',
#  'יַעֲקוֹב֩',
#  'רֵ֠כָב',
#  'עֵרִֽי',
#  'יִ֠שְׁמָעֵאל',
#  'אָבִֽיב',
#  'יִשְׁפָּ֥ן',
#  'גָֽחַר',
#  'עֶפְרֹ֔ן',
#  'עֲמָשַׂ֞י',
#  'עַדְנָ֣ה',
#  'יִדְאֲלָ֖ה',
#  'גֵּבִ֖ים',
#  'סֶֽנֶּה',
#  'חֲנַמְאֵ֣ל',
#  'אֲחַשְׁוֵרֹ֔שׁ',
#  'קִישִׁ֔י',
#  'אֲחִימֶ֑לֶךְ',
#  'מַרְסְנָ֖א',
#  'שִׁמְרָ֖ת',
#  'חוּקֹק֙',
#  'אֶלְקָנָ֨ה',
#  'יֽוֹרָם',
#  'עֲנָת֑וֹת',
#  'בְנָיָהוּ֩',
#  'יְכָנְיָ֣הוּ',
#  'עַזּ֨וּר',
#  'לַעְדָּ֖ה',
#  'יַעֲק֗וֹב',
#  'צָּפוֹן֮',
#  'יְהוֹאָ֤שׁ',
#  'עֶפְרַ֖יִן',
#  'סַלּ֣וּ',
#  'חֹרֵב֙',
#  'דָנִיֵּ֤אל',
#  'יְהוּדָיֵ֔',
#  'סֶ֖לֶד',
#  'יִזִּיָּ֤ה',
#  'מוּשִׁ֗י',
#  'מְשֻׁלֶּ֥מֶת',
#  'כּוּשִׁ֑י',
#  'בֵּֽרֹתַ֖י',
#  'נַעֲמָ֣ן',
#  'יְהֹוִ֔ה',
#  'יֹֽ֠אשִׁיָּהוּ',
#  'יָבֵ֔שָׁ',
#  'זָבָ֣ד',
#  'זְבִינָ֔א',
#  'עַי֮',
#  'שָׂטָ֖ן',
#  'יְהוֹשׁ֔וּעַ',
#  'יְהוֹנָתָ֧ן',
#  'חַגִּ֑י',
#  'עֲטָר֣וֹת',
#  'נְטֹפָ֖ה',
#  'דְּלִילָה֩',
#  'יֽוֹאָחָז֙',
#  'גִלְעָ֑ד',
#  'חַלְח֥וּל',
#  'צ֕וֹר',
#  'עֻזִּיָּ֗הוּ',
#  'חִלְקִיָּ֖הוּ',
#  'יְהוֹצָדָק֙',
#  'גִלְעָדִ֑ים',
#  'בִּכְרִי֙',
#  'בְּעָלִ֑ים',
#  'אֱד֨וֹם',
#  'הַרְמ֖וֹנָ',
#  'פּ֣וּל',
#  'רִמּוֹן֩',
#  'עַמּוֹנִ֑י',
#  'עַזְרִיאֵ֗ל',
#  'בִנְיָמִ֧ן',
#  'יִּזְרְעֶ֗אל',
#  'יְרוּשְׁלֶֽם',
#  ...]

# %%
df[df['source'] == 'judith']
# Out:
#        Unnamed: 0  source    target  align_count  word score  verse score  \
# 48917       48917  judith  אִשָּׁה֙            1    0.333115     0.380322
# 48918       48918  judith  יִּקַּ֤ח            1    0.332959     0.380322
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 48917            judith               אשה     -1.0             0         -0.0
# 48918            judith               יקח     -1.0             0         -0.0

# %%
bible_df[bible_df['text'] == 'יְהוּדִ֔ית']
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 15003   GEN       26     34     9        1  o010260340091  00102603400022
# 231296  2KI       18     26    21        1  o120180260211  01201802600048
# 366489  ISA       36     11    19        1  o230360110191  02303601100044
#
#        ot-nt     unicode        text lemma normalized            english  \
# 15003     OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None             Judith
# 231296    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None          in Hebrew
# 366489    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None  language of Judah
#
#             greek      hebrew mandarin domain_codes               domains  \
# 15003      ιουδιν  יְהוּדִ֔ית       犹滴  [003001007]     [Names of People]
# 231296  ιουδαϊστί  יְהוּדִ֔ית    用希伯来语  [003001009]  [Names of Languages]
# 366489  ιουδαϊστί  יְהוּדִ֔ית      犹大语  [003001009]  [Names of Languages]
#
#                sdbh_codes top_domains
# 15003   [002822001001000]    [003001]
# 231296  [002820001001000]    [003001]
# 366489  [002820001001000]    [003001]

# %%
df[df['normalized_target'] == 'יהודית']
# Out:
#        Unnamed: 0  source      target  align_count  word score  verse score  \
# 10354       10354   beeri  יְהוּדִ֔ית            1    0.195174     0.380322
# 48762       48762  judean  יְהוּדִ֑ית            2    0.570450     0.319680
# 48763       48763  judean  יְהוּדִ֔ית            2    0.523498     0.333000
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 10354             beeri            יהודית  0.125000             1     0.009279
# 48762            judean            יהודית  0.571429             4     0.416827
# 48763            judean            יהודית  0.571429             4     0.398457

# %%
bible_df[bible_df['english'] == 'Judith']
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
#
#       ot-nt     unicode        text lemma normalized english   greek  \
# 15003    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None  Judith  ιουδιν
#
#            hebrew mandarin domain_codes            domains         sdbh_codes  \
# 15003  יְהוּדִ֔ית       犹滴  [003001007]  [Names of People]  [002822001001000]
#
#       top_domains
# 15003    [003001]

# %%
normalize_word('יְהוּדִ֔ית')
# Out:
# 'יהודית'

# %%
old_matched_names = matched_names
