# %%
from pathlib import Path
from combined import run_fa, run_match_words, combine_df
import os
from match import normalize_word
import pandas as pd
from tqdm import tqdm
from machine.tokenization import LatinWordTokenizer
from typing import Iterable, Tuple, List
import re
tqdm.pandas()
from collections import Counter

pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('pfs/out/en-NIV84_combined.csv')
bible_df = pd.read_parquet('../../../../new2old/data/bible_words.parquet')

# %%
vref_file = 'pfs/ref_data/vref.txt'
with open(vref_file) as f:
    vref_data = f.readlines()
vref_data
# Out:
# ['GEN 1:1\n',
#  'GEN 1:2\n',
#  'GEN 1:3\n',
#  'GEN 1:4\n',
#  'GEN 1:5\n',
#  'GEN 1:6\n',
#  'GEN 1:7\n',
#  'GEN 1:8\n',
#  'GEN 1:9\n',
#  'GEN 1:10\n',
#  'GEN 1:11\n',
#  'GEN 1:12\n',
#  'GEN 1:13\n',
#  'GEN 1:14\n',
#  'GEN 1:15\n',
#  'GEN 1:16\n',
#  'GEN 1:17\n',
#  'GEN 1:18\n',
#  'GEN 1:19\n',
#  'GEN 1:20\n',
#  'GEN 1:21\n',
#  'GEN 1:22\n',
#  'GEN 1:23\n',
#  'GEN 1:24\n',
#  'GEN 1:25\n',
#  'GEN 1:26\n',
#  'GEN 1:27\n',
#  'GEN 1:28\n',
#  'GEN 1:29\n',
#  'GEN 1:30\n',
#  'GEN 1:31\n',
#  'GEN 2:1\n',
#  'GEN 2:2\n',
#  'GEN 2:3\n',
#  'GEN 2:4\n',
#  'GEN 2:5\n',
#  'GEN 2:6\n',
#  'GEN 2:7\n',
#  'GEN 2:8\n',
#  'GEN 2:9\n',
#  'GEN 2:10\n',
#  'GEN 2:11\n',
#  'GEN 2:12\n',
#  'GEN 2:13\n',
#  'GEN 2:14\n',
#  'GEN 2:15\n',
#  'GEN 2:16\n',
#  'GEN 2:17\n',
#  'GEN 2:18\n',
#  'GEN 2:19\n',
#  'GEN 2:20\n',
#  'GEN 2:21\n',
#  'GEN 2:22\n',
#  'GEN 2:23\n',
#  'GEN 2:24\n',
#  'GEN 2:25\n',
#  'GEN 3:1\n',
#  'GEN 3:2\n',
#  'GEN 3:3\n',
#  'GEN 3:4\n',
#  'GEN 3:5\n',
#  'GEN 3:6\n',
#  'GEN 3:7\n',
#  'GEN 3:8\n',
#  'GEN 3:9\n',
#  'GEN 3:10\n',
#  'GEN 3:11\n',
#  'GEN 3:12\n',
#  'GEN 3:13\n',
#  'GEN 3:14\n',
#  'GEN 3:15\n',
#  'GEN 3:16\n',
#  'GEN 3:17\n',
#  'GEN 3:18\n',
#  'GEN 3:19\n',
#  'GEN 3:20\n',
#  'GEN 3:21\n',
#  'GEN 3:22\n',
#  'GEN 3:23\n',
#  'GEN 3:24\n',
#  'GEN 4:1\n',
#  'GEN 4:2\n',
#  'GEN 4:3\n',
#  'GEN 4:4\n',
#  'GEN 4:5\n',
#  'GEN 4:6\n',
#  'GEN 4:7\n',
#  'GEN 4:8\n',
#  'GEN 4:9\n',
#  'GEN 4:10\n',
#  'GEN 4:11\n',
#  'GEN 4:12\n',
#  'GEN 4:13\n',
#  'GEN 4:14\n',
#  'GEN 4:15\n',
#  'GEN 4:16\n',
#  'GEN 4:17\n',
#  'GEN 4:18\n',
#  'GEN 4:19\n',
#  'GEN 4:20\n',
#  'GEN 4:21\n',
#  'GEN 4:22\n',
#  'GEN 4:23\n',
#  'GEN 4:24\n',
#  'GEN 4:25\n',
#  'GEN 4:26\n',
#  'GEN 5:1\n',
#  'GEN 5:2\n',
#  'GEN 5:3\n',
#  'GEN 5:4\n',
#  'GEN 5:5\n',
#  'GEN 5:6\n',
#  'GEN 5:7\n',
#  'GEN 5:8\n',
#  'GEN 5:9\n',
#  'GEN 5:10\n',
#  'GEN 5:11\n',
#  'GEN 5:12\n',
#  'GEN 5:13\n',
#  'GEN 5:14\n',
#  'GEN 5:15\n',
#  'GEN 5:16\n',
#  'GEN 5:17\n',
#  'GEN 5:18\n',
#  'GEN 5:19\n',
#  'GEN 5:20\n',
#  'GEN 5:21\n',
#  'GEN 5:22\n',
#  'GEN 5:23\n',
#  'GEN 5:24\n',
#  'GEN 5:25\n',
#  'GEN 5:26\n',
#  'GEN 5:27\n',
#  'GEN 5:28\n',
#  'GEN 5:29\n',
#  'GEN 5:30\n',
#  'GEN 5:31\n',
#  'GEN 5:32\n',
#  'GEN 6:1\n',
#  'GEN 6:2\n',
#  'GEN 6:3\n',
#  'GEN 6:4\n',
#  'GEN 6:5\n',
#  'GEN 6:6\n',
#  'GEN 6:7\n',
#  'GEN 6:8\n',
#  'GEN 6:9\n',
#  'GEN 6:10\n',
#  'GEN 6:11\n',
#  'GEN 6:12\n',
#  'GEN 6:13\n',
#  'GEN 6:14\n',
#  'GEN 6:15\n',
#  'GEN 6:16\n',
#  'GEN 6:17\n',
#  'GEN 6:18\n',
#  'GEN 6:19\n',
#  'GEN 6:20\n',
#  'GEN 6:21\n',
#  'GEN 6:22\n',
#  'GEN 7:1\n',
#  'GEN 7:2\n',
#  'GEN 7:3\n',
#  'GEN 7:4\n',
#  'GEN 7:5\n',
#  'GEN 7:6\n',
#  'GEN 7:7\n',
#  'GEN 7:8\n',
#  'GEN 7:9\n',
#  'GEN 7:10\n',
#  'GEN 7:11\n',
#  'GEN 7:12\n',
#  'GEN 7:13\n',
#  'GEN 7:14\n',
#  'GEN 7:15\n',
#  'GEN 7:16\n',
#  'GEN 7:17\n',
#  'GEN 7:18\n',
#  'GEN 7:19\n',
#  'GEN 7:20\n',
#  'GEN 7:21\n',
#  'GEN 7:22\n',
#  'GEN 7:23\n',
#  'GEN 7:24\n',
#  'GEN 8:1\n',
#  'GEN 8:2\n',
#  'GEN 8:3\n',
#  'GEN 8:4\n',
#  'GEN 8:5\n',
#  'GEN 8:6\n',
#  'GEN 8:7\n',
#  'GEN 8:8\n',
#  'GEN 8:9\n',
#  'GEN 8:10\n',
#  'GEN 8:11\n',
#  'GEN 8:12\n',
#  'GEN 8:13\n',
#  'GEN 8:14\n',
#  'GEN 8:15\n',
#  'GEN 8:16\n',
#  'GEN 8:17\n',
#  'GEN 8:18\n',
#  'GEN 8:19\n',
#  'GEN 8:20\n',
#  'GEN 8:21\n',
#  'GEN 8:22\n',
#  'GEN 9:1\n',
#  'GEN 9:2\n',
#  'GEN 9:3\n',
#  'GEN 9:4\n',
#  'GEN 9:5\n',
#  'GEN 9:6\n',
#  'GEN 9:7\n',
#  'GEN 9:8\n',
#  'GEN 9:9\n',
#  'GEN 9:10\n',
#  'GEN 9:11\n',
#  'GEN 9:12\n',
#  'GEN 9:13\n',
#  'GEN 9:14\n',
#  'GEN 9:15\n',
#  'GEN 9:16\n',
#  'GEN 9:17\n',
#  'GEN 9:18\n',
#  'GEN 9:19\n',
#  'GEN 9:20\n',
#  'GEN 9:21\n',
#  'GEN 9:22\n',
#  'GEN 9:23\n',
#  'GEN 9:24\n',
#  'GEN 9:25\n',
#  'GEN 9:26\n',
#  'GEN 9:27\n',
#  'GEN 9:28\n',
#  'GEN 9:29\n',
#  'GEN 10:1\n',
#  'GEN 10:2\n',
#  'GEN 10:3\n',
#  'GEN 10:4\n',
#  'GEN 10:5\n',
#  'GEN 10:6\n',
#  'GEN 10:7\n',
#  'GEN 10:8\n',
#  'GEN 10:9\n',
#  'GEN 10:10\n',
#  'GEN 10:11\n',
#  'GEN 10:12\n',
#  'GEN 10:13\n',
#  'GEN 10:14\n',
#  'GEN 10:15\n',
#  'GEN 10:16\n',
#  'GEN 10:17\n',
#  'GEN 10:18\n',
#  'GEN 10:19\n',
#  'GEN 10:20\n',
#  'GEN 10:21\n',
#  'GEN 10:22\n',
#  'GEN 10:23\n',
#  'GEN 10:24\n',
#  'GEN 10:25\n',
#  'GEN 10:26\n',
#  'GEN 10:27\n',
#  'GEN 10:28\n',
#  'GEN 10:29\n',
#  'GEN 10:30\n',
#  'GEN 10:31\n',
#  'GEN 10:32\n',
#  'GEN 11:1\n',
#  'GEN 11:2\n',
#  'GEN 11:3\n',
#  'GEN 11:4\n',
#  'GEN 11:5\n',
#  'GEN 11:6\n',
#  'GEN 11:7\n',
#  'GEN 11:8\n',
#  'GEN 11:9\n',
#  'GEN 11:10\n',
#  'GEN 11:11\n',
#  'GEN 11:12\n',
#  'GEN 11:13\n',
#  'GEN 11:14\n',
#  'GEN 11:15\n',
#  'GEN 11:16\n',
#  'GEN 11:17\n',
#  'GEN 11:18\n',
#  'GEN 11:19\n',
#  'GEN 11:20\n',
#  'GEN 11:21\n',
#  'GEN 11:22\n',
#  'GEN 11:23\n',
#  'GEN 11:24\n',
#  'GEN 11:25\n',
#  'GEN 11:26\n',
#  'GEN 11:27\n',
#  'GEN 11:28\n',
#  'GEN 11:29\n',
#  'GEN 11:30\n',
#  'GEN 11:31\n',
#  'GEN 11:32\n',
#  'GEN 12:1\n',
#  'GEN 12:2\n',
#  'GEN 12:3\n',
#  'GEN 12:4\n',
#  'GEN 12:5\n',
#  'GEN 12:6\n',
#  'GEN 12:7\n',
#  'GEN 12:8\n',
#  'GEN 12:9\n',
#  'GEN 12:10\n',
#  'GEN 12:11\n',
#  'GEN 12:12\n',
#  'GEN 12:13\n',
#  'GEN 12:14\n',
#  'GEN 12:15\n',
#  'GEN 12:16\n',
#  'GEN 12:17\n',
#  'GEN 12:18\n',
#  'GEN 12:19\n',
#  'GEN 12:20\n',
#  'GEN 13:1\n',
#  'GEN 13:2\n',
#  'GEN 13:3\n',
#  'GEN 13:4\n',
#  'GEN 13:5\n',
#  'GEN 13:6\n',
#  'GEN 13:7\n',
#  'GEN 13:8\n',
#  'GEN 13:9\n',
#  'GEN 13:10\n',
#  'GEN 13:11\n',
#  'GEN 13:12\n',
#  'GEN 13:13\n',
#  'GEN 13:14\n',
#  'GEN 13:15\n',
#  'GEN 13:16\n',
#  'GEN 13:17\n',
#  'GEN 13:18\n',
#  'GEN 14:1\n',
#  'GEN 14:2\n',
#  'GEN 14:3\n',
#  'GEN 14:4\n',
#  'GEN 14:5\n',
#  'GEN 14:6\n',
#  'GEN 14:7\n',
#  'GEN 14:8\n',
#  'GEN 14:9\n',
#  'GEN 14:10\n',
#  'GEN 14:11\n',
#  'GEN 14:12\n',
#  'GEN 14:13\n',
#  'GEN 14:14\n',
#  'GEN 14:15\n',
#  'GEN 14:16\n',
#  'GEN 14:17\n',
#  'GEN 14:18\n',
#  'GEN 14:19\n',
#  'GEN 14:20\n',
#  'GEN 14:21\n',
#  'GEN 14:22\n',
#  'GEN 14:23\n',
#  'GEN 14:24\n',
#  'GEN 15:1\n',
#  'GEN 15:2\n',
#  'GEN 15:3\n',
#  'GEN 15:4\n',
#  'GEN 15:5\n',
#  'GEN 15:6\n',
#  'GEN 15:7\n',
#  'GEN 15:8\n',
#  'GEN 15:9\n',
#  'GEN 15:10\n',
#  'GEN 15:11\n',
#  'GEN 15:12\n',
#  'GEN 15:13\n',
#  'GEN 15:14\n',
#  'GEN 15:15\n',
#  'GEN 15:16\n',
#  'GEN 15:17\n',
#  'GEN 15:18\n',
#  'GEN 15:19\n',
#  'GEN 15:20\n',
#  'GEN 15:21\n',
#  'GEN 16:1\n',
#  'GEN 16:2\n',
#  'GEN 16:3\n',
#  'GEN 16:4\n',
#  'GEN 16:5\n',
#  'GEN 16:6\n',
#  'GEN 16:7\n',
#  'GEN 16:8\n',
#  'GEN 16:9\n',
#  'GEN 16:10\n',
#  'GEN 16:11\n',
#  'GEN 16:12\n',
#  'GEN 16:13\n',
#  'GEN 16:14\n',
#  'GEN 16:15\n',
#  'GEN 16:16\n',
#  'GEN 17:1\n',
#  'GEN 17:2\n',
#  'GEN 17:3\n',
#  'GEN 17:4\n',
#  'GEN 17:5\n',
#  'GEN 17:6\n',
#  'GEN 17:7\n',
#  'GEN 17:8\n',
#  'GEN 17:9\n',
#  'GEN 17:10\n',
#  'GEN 17:11\n',
#  'GEN 17:12\n',
#  'GEN 17:13\n',
#  'GEN 17:14\n',
#  'GEN 17:15\n',
#  'GEN 17:16\n',
#  'GEN 17:17\n',
#  'GEN 17:18\n',
#  'GEN 17:19\n',
#  'GEN 17:20\n',
#  'GEN 17:21\n',
#  'GEN 17:22\n',
#  'GEN 17:23\n',
#  'GEN 17:24\n',
#  'GEN 17:25\n',
#  'GEN 17:26\n',
#  'GEN 17:27\n',
#  'GEN 18:1\n',
#  'GEN 18:2\n',
#  'GEN 18:3\n',
#  'GEN 18:4\n',
#  'GEN 18:5\n',
#  'GEN 18:6\n',
#  'GEN 18:7\n',
#  'GEN 18:8\n',
#  'GEN 18:9\n',
#  'GEN 18:10\n',
#  'GEN 18:11\n',
#  'GEN 18:12\n',
#  'GEN 18:13\n',
#  'GEN 18:14\n',
#  'GEN 18:15\n',
#  'GEN 18:16\n',
#  'GEN 18:17\n',
#  'GEN 18:18\n',
#  'GEN 18:19\n',
#  'GEN 18:20\n',
#  'GEN 18:21\n',
#  'GEN 18:22\n',
#  'GEN 18:23\n',
#  'GEN 18:24\n',
#  'GEN 18:25\n',
#  'GEN 18:26\n',
#  'GEN 18:27\n',
#  'GEN 18:28\n',
#  'GEN 18:29\n',
#  'GEN 18:30\n',
#  'GEN 18:31\n',
#  'GEN 18:32\n',
#  'GEN 18:33\n',
#  'GEN 19:1\n',
#  'GEN 19:2\n',
#  'GEN 19:3\n',
#  'GEN 19:4\n',
#  'GEN 19:5\n',
#  'GEN 19:6\n',
#  'GEN 19:7\n',
#  'GEN 19:8\n',
#  'GEN 19:9\n',
#  'GEN 19:10\n',
#  'GEN 19:11\n',
#  'GEN 19:12\n',
#  'GEN 19:13\n',
#  'GEN 19:14\n',
#  'GEN 19:15\n',
#  'GEN 19:16\n',
#  'GEN 19:17\n',
#  'GEN 19:18\n',
#  'GEN 19:19\n',
#  'GEN 19:20\n',
#  'GEN 19:21\n',
#  'GEN 19:22\n',
#  'GEN 19:23\n',
#  'GEN 19:24\n',
#  'GEN 19:25\n',
#  'GEN 19:26\n',
#  'GEN 19:27\n',
#  'GEN 19:28\n',
#  'GEN 19:29\n',
#  'GEN 19:30\n',
#  'GEN 19:31\n',
#  'GEN 19:32\n',
#  'GEN 19:33\n',
#  'GEN 19:34\n',
#  'GEN 19:35\n',
#  'GEN 19:36\n',
#  'GEN 19:37\n',
#  'GEN 19:38\n',
#  'GEN 20:1\n',
#  'GEN 20:2\n',
#  'GEN 20:3\n',
#  'GEN 20:4\n',
#  'GEN 20:5\n',
#  'GEN 20:6\n',
#  'GEN 20:7\n',
#  'GEN 20:8\n',
#  'GEN 20:9\n',
#  'GEN 20:10\n',
#  'GEN 20:11\n',
#  'GEN 20:12\n',
#  'GEN 20:13\n',
#  'GEN 20:14\n',
#  'GEN 20:15\n',
#  'GEN 20:16\n',
#  'GEN 20:17\n',
#  'GEN 20:18\n',
#  'GEN 21:1\n',
#  'GEN 21:2\n',
#  'GEN 21:3\n',
#  'GEN 21:4\n',
#  'GEN 21:5\n',
#  'GEN 21:6\n',
#  'GEN 21:7\n',
#  'GEN 21:8\n',
#  'GEN 21:9\n',
#  'GEN 21:10\n',
#  'GEN 21:11\n',
#  'GEN 21:12\n',
#  'GEN 21:13\n',
#  'GEN 21:14\n',
#  'GEN 21:15\n',
#  'GEN 21:16\n',
#  'GEN 21:17\n',
#  'GEN 21:18\n',
#  'GEN 21:19\n',
#  'GEN 21:20\n',
#  'GEN 21:21\n',
#  'GEN 21:22\n',
#  'GEN 21:23\n',
#  'GEN 21:24\n',
#  'GEN 21:25\n',
#  'GEN 21:26\n',
#  'GEN 21:27\n',
#  'GEN 21:28\n',
#  'GEN 21:29\n',
#  'GEN 21:30\n',
#  'GEN 21:31\n',
#  'GEN 21:32\n',
#  'GEN 21:33\n',
#  'GEN 21:34\n',
#  'GEN 22:1\n',
#  'GEN 22:2\n',
#  'GEN 22:3\n',
#  'GEN 22:4\n',
#  'GEN 22:5\n',
#  'GEN 22:6\n',
#  'GEN 22:7\n',
#  'GEN 22:8\n',
#  'GEN 22:9\n',
#  'GEN 22:10\n',
#  'GEN 22:11\n',
#  'GEN 22:12\n',
#  'GEN 22:13\n',
#  'GEN 22:14\n',
#  'GEN 22:15\n',
#  'GEN 22:16\n',
#  'GEN 22:17\n',
#  'GEN 22:18\n',
#  'GEN 22:19\n',
#  'GEN 22:20\n',
#  'GEN 22:21\n',
#  'GEN 22:22\n',
#  'GEN 22:23\n',
#  'GEN 22:24\n',
#  'GEN 23:1\n',
#  'GEN 23:2\n',
#  'GEN 23:3\n',
#  'GEN 23:4\n',
#  'GEN 23:5\n',
#  'GEN 23:6\n',
#  'GEN 23:7\n',
#  'GEN 23:8\n',
#  'GEN 23:9\n',
#  'GEN 23:10\n',
#  'GEN 23:11\n',
#  'GEN 23:12\n',
#  'GEN 23:13\n',
#  'GEN 23:14\n',
#  'GEN 23:15\n',
#  'GEN 23:16\n',
#  'GEN 23:17\n',
#  'GEN 23:18\n',
#  'GEN 23:19\n',
#  'GEN 23:20\n',
#  'GEN 24:1\n',
#  'GEN 24:2\n',
#  'GEN 24:3\n',
#  'GEN 24:4\n',
#  'GEN 24:5\n',
#  'GEN 24:6\n',
#  'GEN 24:7\n',
#  'GEN 24:8\n',
#  'GEN 24:9\n',
#  'GEN 24:10\n',
#  'GEN 24:11\n',
#  'GEN 24:12\n',
#  'GEN 24:13\n',
#  'GEN 24:14\n',
#  'GEN 24:15\n',
#  'GEN 24:16\n',
#  'GEN 24:17\n',
#  'GEN 24:18\n',
#  'GEN 24:19\n',
#  'GEN 24:20\n',
#  'GEN 24:21\n',
#  'GEN 24:22\n',
#  'GEN 24:23\n',
#  'GEN 24:24\n',
#  'GEN 24:25\n',
#  'GEN 24:26\n',
#  'GEN 24:27\n',
#  'GEN 24:28\n',
#  'GEN 24:29\n',
#  'GEN 24:30\n',
#  'GEN 24:31\n',
#  'GEN 24:32\n',
#  'GEN 24:33\n',
#  'GEN 24:34\n',
#  'GEN 24:35\n',
#  'GEN 24:36\n',
#  'GEN 24:37\n',
#  'GEN 24:38\n',
#  'GEN 24:39\n',
#  'GEN 24:40\n',
#  'GEN 24:41\n',
#  'GEN 24:42\n',
#  'GEN 24:43\n',
#  'GEN 24:44\n',
#  'GEN 24:45\n',
#  'GEN 24:46\n',
#  'GEN 24:47\n',
#  'GEN 24:48\n',
#  'GEN 24:49\n',
#  'GEN 24:50\n',
#  'GEN 24:51\n',
#  'GEN 24:52\n',
#  'GEN 24:53\n',
#  'GEN 24:54\n',
#  'GEN 24:55\n',
#  'GEN 24:56\n',
#  'GEN 24:57\n',
#  'GEN 24:58\n',
#  'GEN 24:59\n',
#  'GEN 24:60\n',
#  'GEN 24:61\n',
#  'GEN 24:62\n',
#  'GEN 24:63\n',
#  'GEN 24:64\n',
#  'GEN 24:65\n',
#  'GEN 24:66\n',
#  'GEN 24:67\n',
#  'GEN 25:1\n',
#  'GEN 25:2\n',
#  'GEN 25:3\n',
#  'GEN 25:4\n',
#  'GEN 25:5\n',
#  'GEN 25:6\n',
#  'GEN 25:7\n',
#  'GEN 25:8\n',
#  'GEN 25:9\n',
#  'GEN 25:10\n',
#  'GEN 25:11\n',
#  'GEN 25:12\n',
#  'GEN 25:13\n',
#  'GEN 25:14\n',
#  'GEN 25:15\n',
#  'GEN 25:16\n',
#  'GEN 25:17\n',
#  'GEN 25:18\n',
#  'GEN 25:19\n',
#  'GEN 25:20\n',
#  'GEN 25:21\n',
#  'GEN 25:22\n',
#  'GEN 25:23\n',
#  'GEN 25:24\n',
#  'GEN 25:25\n',
#  'GEN 25:26\n',
#  'GEN 25:27\n',
#  'GEN 25:28\n',
#  'GEN 25:29\n',
#  'GEN 25:30\n',
#  'GEN 25:31\n',
#  'GEN 25:32\n',
#  'GEN 25:33\n',
#  'GEN 25:34\n',
#  'GEN 26:1\n',
#  'GEN 26:2\n',
#  'GEN 26:3\n',
#  'GEN 26:4\n',
#  'GEN 26:5\n',
#  'GEN 26:6\n',
#  'GEN 26:7\n',
#  'GEN 26:8\n',
#  'GEN 26:9\n',
#  'GEN 26:10\n',
#  'GEN 26:11\n',
#  'GEN 26:12\n',
#  'GEN 26:13\n',
#  'GEN 26:14\n',
#  'GEN 26:15\n',
#  'GEN 26:16\n',
#  'GEN 26:17\n',
#  'GEN 26:18\n',
#  'GEN 26:19\n',
#  'GEN 26:20\n',
#  'GEN 26:21\n',
#  'GEN 26:22\n',
#  'GEN 26:23\n',
#  'GEN 26:24\n',
#  'GEN 26:25\n',
#  'GEN 26:26\n',
#  'GEN 26:27\n',
#  'GEN 26:28\n',
#  'GEN 26:29\n',
#  'GEN 26:30\n',
#  'GEN 26:31\n',
#  'GEN 26:32\n',
#  'GEN 26:33\n',
#  'GEN 26:34\n',
#  'GEN 26:35\n',
#  'GEN 27:1\n',
#  'GEN 27:2\n',
#  'GEN 27:3\n',
#  'GEN 27:4\n',
#  'GEN 27:5\n',
#  'GEN 27:6\n',
#  'GEN 27:7\n',
#  'GEN 27:8\n',
#  'GEN 27:9\n',
#  'GEN 27:10\n',
#  'GEN 27:11\n',
#  'GEN 27:12\n',
#  'GEN 27:13\n',
#  'GEN 27:14\n',
#  'GEN 27:15\n',
#  'GEN 27:16\n',
#  'GEN 27:17\n',
#  'GEN 27:18\n',
#  'GEN 27:19\n',
#  'GEN 27:20\n',
#  'GEN 27:21\n',
#  'GEN 27:22\n',
#  'GEN 27:23\n',
#  'GEN 27:24\n',
#  'GEN 27:25\n',
#  'GEN 27:26\n',
#  'GEN 27:27\n',
#  'GEN 27:28\n',
#  'GEN 27:29\n',
#  'GEN 27:30\n',
#  'GEN 27:31\n',
#  'GEN 27:32\n',
#  'GEN 27:33\n',
#  'GEN 27:34\n',
#  'GEN 27:35\n',
#  'GEN 27:36\n',
#  'GEN 27:37\n',
#  'GEN 27:38\n',
#  'GEN 27:39\n',
#  'GEN 27:40\n',
#  'GEN 27:41\n',
#  'GEN 27:42\n',
#  'GEN 27:43\n',
#  'GEN 27:44\n',
#  'GEN 27:45\n',
#  'GEN 27:46\n',
#  'GEN 28:1\n',
#  'GEN 28:2\n',
#  'GEN 28:3\n',
#  'GEN 28:4\n',
#  'GEN 28:5\n',
#  'GEN 28:6\n',
#  'GEN 28:7\n',
#  'GEN 28:8\n',
#  'GEN 28:9\n',
#  'GEN 28:10\n',
#  'GEN 28:11\n',
#  'GEN 28:12\n',
#  'GEN 28:13\n',
#  'GEN 28:14\n',
#  'GEN 28:15\n',
#  'GEN 28:16\n',
#  'GEN 28:17\n',
#  'GEN 28:18\n',
#  'GEN 28:19\n',
#  'GEN 28:20\n',
#  'GEN 28:21\n',
#  'GEN 28:22\n',
#  'GEN 29:1\n',
#  'GEN 29:2\n',
#  'GEN 29:3\n',
#  'GEN 29:4\n',
#  'GEN 29:5\n',
#  'GEN 29:6\n',
#  'GEN 29:7\n',
#  'GEN 29:8\n',
#  'GEN 29:9\n',
#  'GEN 29:10\n',
#  'GEN 29:11\n',
#  'GEN 29:12\n',
#  'GEN 29:13\n',
#  'GEN 29:14\n',
#  'GEN 29:15\n',
#  'GEN 29:16\n',
#  'GEN 29:17\n',
#  'GEN 29:18\n',
#  'GEN 29:19\n',
#  'GEN 29:20\n',
#  'GEN 29:21\n',
#  'GEN 29:22\n',
#  'GEN 29:23\n',
#  'GEN 29:24\n',
#  'GEN 29:25\n',
#  'GEN 29:26\n',
#  'GEN 29:27\n',
#  'GEN 29:28\n',
#  'GEN 29:29\n',
#  'GEN 29:30\n',
#  'GEN 29:31\n',
#  'GEN 29:32\n',
#  'GEN 29:33\n',
#  'GEN 29:34\n',
#  'GEN 29:35\n',
#  'GEN 30:1\n',
#  'GEN 30:2\n',
#  'GEN 30:3\n',
#  'GEN 30:4\n',
#  'GEN 30:5\n',
#  'GEN 30:6\n',
#  'GEN 30:7\n',
#  'GEN 30:8\n',
#  'GEN 30:9\n',
#  'GEN 30:10\n',
#  'GEN 30:11\n',
#  'GEN 30:12\n',
#  'GEN 30:13\n',
#  'GEN 30:14\n',
#  'GEN 30:15\n',
#  'GEN 30:16\n',
#  'GEN 30:17\n',
#  'GEN 30:18\n',
#  'GEN 30:19\n',
#  'GEN 30:20\n',
#  'GEN 30:21\n',
#  'GEN 30:22\n',
#  'GEN 30:23\n',
#  'GEN 30:24\n',
#  'GEN 30:25\n',
#  'GEN 30:26\n',
#  'GEN 30:27\n',
#  'GEN 30:28\n',
#  'GEN 30:29\n',
#  'GEN 30:30\n',
#  'GEN 30:31\n',
#  'GEN 30:32\n',
#  'GEN 30:33\n',
#  'GEN 30:34\n',
#  'GEN 30:35\n',
#  'GEN 30:36\n',
#  'GEN 30:37\n',
#  'GEN 30:38\n',
#  'GEN 30:39\n',
#  'GEN 30:40\n',
#  'GEN 30:41\n',
#  'GEN 30:42\n',
#  'GEN 30:43\n',
#  'GEN 31:1\n',
#  'GEN 31:2\n',
#  'GEN 31:3\n',
#  'GEN 31:4\n',
#  'GEN 31:5\n',
#  'GEN 31:6\n',
#  'GEN 31:7\n',
#  'GEN 31:8\n',
#  'GEN 31:9\n',
#  'GEN 31:10\n',
#  'GEN 31:11\n',
#  'GEN 31:12\n',
#  'GEN 31:13\n',
#  'GEN 31:14\n',
#  'GEN 31:15\n',
#  'GEN 31:16\n',
#  'GEN 31:17\n',
#  'GEN 31:18\n',
#  'GEN 31:19\n',
#  'GEN 31:20\n',
#  'GEN 31:21\n',
#  'GEN 31:22\n',
#  'GEN 31:23\n',
#  'GEN 31:24\n',
#  'GEN 31:25\n',
#  'GEN 31:26\n',
#  'GEN 31:27\n',
#  'GEN 31:28\n',
#  'GEN 31:29\n',
#  'GEN 31:30\n',
#  'GEN 31:31\n',
#  'GEN 31:32\n',
#  'GEN 31:33\n',
#  'GEN 31:34\n',
#  'GEN 31:35\n',
#  'GEN 31:36\n',
#  'GEN 31:37\n',
#  'GEN 31:38\n',
#  'GEN 31:39\n',
#  'GEN 31:40\n',
#  'GEN 31:41\n',
#  'GEN 31:42\n',
#  'GEN 31:43\n',
#  'GEN 31:44\n',
#  'GEN 31:45\n',
#  'GEN 31:46\n',
#  'GEN 31:47\n',
#  'GEN 31:48\n',
#  'GEN 31:49\n',
#  'GEN 31:50\n',
#  'GEN 31:51\n',
#  'GEN 31:52\n',
#  'GEN 31:53\n',
#  'GEN 31:54\n',
#  'GEN 32:1\n',
#  'GEN 32:2\n',
#  'GEN 32:3\n',
#  'GEN 32:4\n',
#  'GEN 32:5\n',
#  'GEN 32:6\n',
#  'GEN 32:7\n',
#  'GEN 32:8\n',
#  'GEN 32:9\n',
#  'GEN 32:10\n',
#  'GEN 32:11\n',
#  'GEN 32:12\n',
#  'GEN 32:13\n',
#  'GEN 32:14\n',
#  'GEN 32:15\n',
#  'GEN 32:16\n',
#  'GEN 32:17\n',
#  'GEN 32:18\n',
#  'GEN 32:19\n',
#  'GEN 32:20\n',
#  'GEN 32:21\n',
#  'GEN 32:22\n',
#  'GEN 32:23\n',
#  'GEN 32:24\n',
#  'GEN 32:25\n',
#  'GEN 32:26\n',
#  'GEN 32:27\n',
#  'GEN 32:28\n',
#  'GEN 32:29\n',
#  'GEN 32:30\n',
#  'GEN 32:31\n',
#  'GEN 32:32\n',
#  'GEN 32:33\n',
#  'GEN 33:1\n',
#  'GEN 33:2\n',
#  'GEN 33:3\n',
#  'GEN 33:4\n',
#  'GEN 33:5\n',
#  'GEN 33:6\n',
#  'GEN 33:7\n',
#  'GEN 33:8\n',
#  'GEN 33:9\n',
#  'GEN 33:10\n',
#  'GEN 33:11\n',
#  'GEN 33:12\n',
#  'GEN 33:13\n',
#  'GEN 33:14\n',
#  'GEN 33:15\n',
#  'GEN 33:16\n',
#  'GEN 33:17\n',
#  'GEN 33:18\n',
#  'GEN 33:19\n',
#  'GEN 33:20\n',
#  'GEN 34:1\n',
#  'GEN 34:2\n',
#  'GEN 34:3\n',
#  'GEN 34:4\n',
#  'GEN 34:5\n',
#  'GEN 34:6\n',
#  'GEN 34:7\n',
#  'GEN 34:8\n',
#  'GEN 34:9\n',
#  'GEN 34:10\n',
#  'GEN 34:11\n',
#  'GEN 34:12\n',
#  'GEN 34:13\n',
#  'GEN 34:14\n',
#  'GEN 34:15\n',
#  'GEN 34:16\n',
#  'GEN 34:17\n',
#  'GEN 34:18\n',
#  'GEN 34:19\n',
#  ...]

# %%
def text_to_words(text: str) -> List[str]:
    """
    Inputs:
        text:   Normally a sentence, or Bible verse
    Outputs:
        A list of words, where the sentence has had its punctuation removed, and words splits into a list of words
    """
    # word_list = re.sub("[^\w\s]", "", text.lower()).split()
    # word_list = text.lower().replace('.', '').replace(',', '').replace('?', '').replace('!', '').split()
    word_tokenizer = LatinWordTokenizer()
    word_list = [normalize_word(word) for word in word_tokenizer.tokenize(text)]
    return word_list


def vref_to_df(file):
    with open(file, 'r') as f:
        bible_data = f.readlines()
    words = [text_to_words(line) for line in bible_data]
    normalized_words = [[normalize_word(word) if word else '' for word in word_list] if word_list else [] for word_list in words]
    df = pd.DataFrame({'text': bible_data, 'words': words, 'normalized_words': normalized_words})
    df = df[df['text'].apply(lambda x: len(x) > 2)]
    df = df[df['text'] != "b'\n'"]
    return df

# %%
NIV84_df = vref_to_df('pfs/text_data/en-NIV84.txt')

# %%
gold_data = pd.read_parquet('../../../../new2old/data/gold_translation_data.parquet')

# %%
df.loc[:, 'total_score'] = df.apply(lambda row: row['word score'] * row['jac_sim'], axis=1)

# %%
domains = ['003001001', '003001002','003001004','003001006', '003001007','003001008','003001009','003001010', '003001012' ,'003001013' , '003001014', '003001015' , '003001017']
names_df = bible_df[bible_df['domain_codes'].apply(lambda x: len(set(domains).intersection(set(x))) > 0)]
names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)
# print(names)
english_names = names_df['english'].unique()
english_names = [name.lower() for name in english_names if name is not None]
hebrew_names = names_df['text'].unique()
hebrew_names = [name.lower() for name in hebrew_names if name is not None]
# Out:
# /tmp/ipykernel_259064/892064452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   names_df.loc[:, 'english'] = names_df['english'].apply(lambda x: x.lower() if x is not None else x)

# %%
hebrew_matched_names = list(set(hebrew_names).intersection(df[df['jac_sim'] > 0]['target'].unique()))
english_matched_names = list(set(english_names).intersection(df[df['jac_sim'] > 0]['source'].unique()))

# %%
print(len(hebrew_names))
print(len(hebrew_matched_names))
print(len(english_names))
print(len(english_matched_names))
# Out:
# 9744
# 7245
# 2649
# 2155

# %%
names = names_df[names_df['text'].apply(lambda x: x in hebrew_names)]
# print(names_df.iloc[:, :14][names_df['english'].apply(lambda x: x in english_matched_names)])

# %%
names = names[gold_data['NIV84'].apply(lambda x: x is not None)]
# Out:
# /tmp/ipykernel_259064/1840373318.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   names = names[gold_data['NIV84'].apply(lambda x: x is not None)]

# %%
max_rows = -1
counter = Counter()
for index, row in names.iloc[:max_rows, :].iterrows():
    hebrew_source = row['text']
    hebrew_source_normalized = normalize_word(hebrew_source)    
    book = row['book']
    chapter = row['chapter']
    verse = row['verse']
#     word = row['word']
#     subword = row['subword']
    ref = f'{book} {chapter}:{verse}\n'
    vref_index = vref_data.index(ref)
#     print(ref)
#     print(vref_index)
#     candidate_words = set(gold_data[(gold_data['book'] == book) & (gold_data['chapter'] == chapter) & (gold_data['verse'] == verse)]['NIV84'])
#     candidate_words = [word.lower() for word in candidate_words if word is not None]
    candidate_words = set(NIV84_df.loc[vref_index, 'words'])  if vref_index in NIV84_df.index else set([])
    candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]

    candidate_df = df[df['normalized_target'] == hebrew_source_normalized]
#     actual = row['english']
    actual = gold_data.loc[index, ['NIV84']].values[0] if index in gold_data.index else None
    actual = actual.lower() if actual else ''
    if len(actual.split()) > 1:
        counter['multiple words'] += 1
    elif candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].shape[0] > 0:
        pred = candidate_df.loc[candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)]['total_score'].idxmax()]['source']
        correct = pred == actual or pred == actual.split("ʼ")[0] or actual == pred.split("ʼ")[0] 
        counter.update([correct]) 
    else:
        pred = ''
        counter['no prediction'] += 1

    if not correct:
        print(index)
        print(f"actual: {actual}   pred: {pred}")
#         print(candidate_df)
        print(counter)
# Out:
# 920
# actual: pishon   pred: first
# Counter({True: 7, False: 1})
# 1591
# actual: adam   pred: of
# Counter({True: 29, False: 2})
# 1670
# actual: eve   pred: would
# Counter({True: 29, False: 3})
# 1682
# actual: adam   pred: of
# Counter({True: 30, False: 4})
# 2231
# actual: adam   pred: of
# Counter({True: 88, False: 5, 'no prediction': 1})
# 2281
# actual: adam   pred: man
# Counter({True: 94, False: 6, 'no prediction': 1})
# 2314
# actual: adam   pred: in
# Counter({True: 94, False: 7, 'no prediction': 1})
# 2777
# actual: shem   pred: the
# Counter({True: 141, False: 8, 'no prediction': 1})
# 3519
# actual: shem   pred: the
# Counter({True: 168, False: 9, 'no prediction': 1})
# 4687
# actual: shem   pred: the
# Counter({True: 187, False: 10, 'no prediction': 1})
# 4750
# actual: shem   pred: in
# Counter({True: 195, False: 11, 'no prediction': 1})
# 4813
# actual: shem   pred: the
# Counter({True: 199, False: 12, 'no prediction': 1})
# 4828
# actual: shem   pred: in
# Counter({True: 201, False: 13, 'no prediction': 1})
# 4865
# actual: shem   pred: the
# Counter({True: 205, False: 14, 'no prediction': 1})
# 4883
# actual: madai   pred: gomer
# Counter({True: 210, False: 15, 'no prediction': 1})
# 4933
# actual: mizraim   pred: of
# Counter({True: 225, False: 16, 'no prediction': 1})
# 4935
# actual: put   pred: mizraim
# Counter({True: 225, False: 17, 'no prediction': 1})
# 4993
# actual: erech   pred: the
# Counter({True: 239, False: 18, 'no prediction': 1})
# 4995
# actual: akkad   pred: erech
# Counter({True: 239, False: 19, 'no prediction': 1})
# 5033
# actual: mizraim   pred: of
# Counter({True: 247, False: 20, 'no prediction': 1})
# 5036
# actual: ludites   pred: father
# Counter({True: 247, False: 21, 'no prediction': 1})
# 5039
# actual: anamites   pred: ludites
# Counter({True: 247, False: 22, 'no prediction': 1})
# 5042
# actual: lehabites   pred: anamites
# Counter({True: 247, False: 23, 'no prediction': 1})
# 5048
# actual: pathrusites   pred: casluhites
# Counter({True: 248, False: 24, 'no prediction': 1})
# 5101
# actual: zemarites   pred: hamathites
# Counter({True: 261, False: 25, 'no prediction': 1})
# 5116
# actual: canaan   pred: the
# Counter({True: 263, False: 26, 'no prediction': 1})
# 5132
# actual: admah   pred: zeboiim
# Counter({True: 268, False: 27, 'no prediction': 1})
# 5134
# actual: zeboiim   pred: as
# Counter({True: 268, False: 28, 'no prediction': 1})
# 5154
# actual: shem   pred: the
# Counter({True: 270, False: 29, 'no prediction': 1})
# 5167
# actual: shem   pred: the
# Counter({True: 271, False: 30, 'no prediction': 1})
# 5223
# actual: almodad   pred: father
# Counter({True: 287, False: 31, 'no prediction': 1})
# 5226
# actual: sheleph   pred: almodad
# Counter({True: 287, False: 32, 'no prediction': 1})
# 5229
# actual: hazarmaveth   pred: sheleph
# Counter({True: 287, False: 33, 'no prediction': 1})
# 5253
# actual: ophir   pred: havilah
# Counter({True: 294, False: 34, 'no prediction': 1})
# 5272
# actual: sephar   pred: they
# Counter({True: 298, False: 35, 'no prediction': 1})
# 5279
# actual: shem   pred: in
# Counter({True: 298, False: 36, 'no prediction': 1})
# 5483
# actual: babel   pred: of
# Counter({True: 303, False: 37, 'no prediction': 1})
# 5505
# actual: shem   pred: the
# Counter({True: 305, False: 38, 'no prediction': 1})
# 5506
# actual: shem   pred: the
# Counter({True: 305, False: 39, 'no prediction': 1})
# 5520
# actual: shem   pred: the
# Counter({True: 306, False: 40, 'no prediction': 1})
# 6177
# actual: egyptians   pred: egypt
# Counter({True: 398, False: 41, 'no prediction': 1, 'multiple words': 1})
# 6719
# actual: admah   pred: zeboiim
# Counter({True: 462, False: 42, 'no prediction': 2, 'multiple words': 2})
# 6721
# actual: shemeber   pred: zeboiim
# Counter({True: 462, False: 43, 'no prediction': 2, 'multiple words': 2})
# 6774
# actual: zuzites   pred: karnaim
# Counter({True: 469, False: 44, 'no prediction': 2, 'multiple words': 2})
# 6776
# actual: ham   pred: out
# Counter({True: 469, False: 45, 'no prediction': 2, 'multiple words': 2})
# 6834
# actual: admah   pred: zeboiim
# Counter({True: 479, False: 46, 'no prediction': 2, 'multiple words': 2})
# 6997
# actual: hobah   pred: as
# Counter({True: 508, False: 47, 'no prediction': 3, 'multiple words': 2})
# 7131
# actual: god   pred: to
# Counter({True: 522, False: 48, 'no prediction': 3, 'multiple words': 2})
# 7211
# actual: lord   pred: sovereign
# Counter({True: 530, False: 49, 'no prediction': 3, 'multiple words': 2})
# 7213
# actual: sovereign   pred: lord
# Counter({True: 530, False: 50, 'no prediction': 3, 'multiple words': 2})
# 7337
# actual: lord   pred: sovereign
# Counter({True: 538, False: 51, 'no prediction': 3, 'multiple words': 2})
# 7339
# actual: sovereign   pred: lord
# Counter({True: 538, False: 52, 'no prediction': 3, 'multiple words': 2})
# 7552
# actual: kenizzites   pred: kenites
# Counter({True: 548, False: 53, 'no prediction': 3, 'multiple words': 2})
# 7863
# actual: god   pred: to
# Counter({True: 584, False: 54, 'no prediction': 3, 'multiple words': 2})
# 7939
# actual: god   pred: to
# Counter({True: 595, False: 55, 'no prediction': 3, 'multiple words': 2})
# 9182
# actual: them   pred: sodom
# Counter({True: 666, False: 56, 'no prediction': 3, 'multiple words': 3})
# 9318
# actual: friends   pred: my
# Counter({True: 669, False: 57, 'no prediction': 3, 'multiple words': 3})
# 10066
# actual: moabites   pred: moab
# Counter({True: 697, False: 58, 'no prediction': 3, 'multiple words': 3})
# 11692
# actual: kesed   pred: hazo
# Counter({True: 820, False: 59, 'no prediction': 3, 'multiple words': 3})
# 11695
# actual: hazo   pred: pildash
# Counter({True: 820, False: 60, 'no prediction': 3, 'multiple words': 3})
# 11698
# actual: pildash   pred: jidlaph
# Counter({True: 820, False: 61, 'no prediction': 3, 'multiple words': 3})
# 11701
# actual: jidlaph   pred: bethuel
# Counter({True: 820, False: 62, 'no prediction': 3, 'multiple words': 3})
# 11733
# actual: gaham   pred: tebah
# Counter({True: 827, False: 63, 'no prediction': 4, 'multiple words': 3})
# 11937
# actual: hittite   pred: hittites
# Counter({True: 844, False: 64, 'no prediction': 4, 'multiple words': 3})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [572], line 26
#      24 if len(actual.split()) > 1:
#      25     counter['multiple words'] += 1
# ---> 26 elif candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].shape[0] > 0:
#      27     pred = candidate_df.loc[candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)]['total_score'].idxmax()]['source']
#      28     correct = pred == actual or pred == actual.split("ʼ")[0] or actual == pred.split("ʼ")[0]
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/frame.py:3796, in DataFrame.__getitem__(self, key)
#    3794 # Do we have a (boolean) 1d indexer?
#    3795 if com.is_bool_indexer(key):
# -> 3796     return self._getitem_bool_array(key)
#    3798 # We are left with two options: a single key, and a collection of keys,
#    3799 # We interpret tuples as collections only for non-MultiIndex
#    3800 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~/.local/share/virtualenvs/word_alignment-0dcHeh1K/lib/python3.10/site-packages/pandas/core/frame.py:3851, in DataFrame._getitem_bool_array(self, key)
#    3849 key = check_bool_indexer(self.index, key)
#    3850 indexer = key.nonzero()[0]
# -> 3851 return self._take_with_is_copy(indexer, axis=0)
#
# KeyboardInterrupt:

# %%
line = 9318

# %%
gold_data.iloc[line-8: line+8, [0, 1, 2, 3, 4, 5, 10,11, 32]]
# Out:
#       index book  chapter  verse  word  subword       text   lemma  \
# 9310   9310  GEN       19      6     6        1     סָגַ֥ר    5462
# 9311   9311  GEN       19      6     7        1   אַחֲרָֽי   310 a
# 9312   9312  GEN       19      6     7        2          ו    None
# 9313   9313  GEN       19      7     1        1         וַ       c
# 9314   9314  GEN       19      7     1        2   יֹּאמַ֑ר     559
# 9315   9315  GEN       19      7     2        1        אַל     408
# 9316   9316  GEN       19      7     3        1       נָ֥א    4994
# 9317   9317  GEN       19      7     5        1  תָּרֵֽעוּ  7489 a
# 9318   9318  GEN       19      7     4        1      אַחַ֖     251
# 9319   9319  GEN       19      7     4        2          י    None
# 9320   9320  GEN       19      8     1        1     הִנֵּה    2009
# 9321   9321  GEN       19      8     2        1       נָ֨א    4994
# 9322   9322  GEN       19      8     3        1        לִ֜       l
# 9323   9323  GEN       19      8     3        2          י    None
# 9324   9324  GEN       19      8     4        1   שְׁתֵּ֣י    8147
# 9325   9325  GEN       19      8     5        1    בָנ֗וֹת    1323
#
#                      NIV84
# 9310                  shut
# 9311                  None
# 9312                  None
# 9313                  None
# 9314                  said
# 9315                   Don
# 9316                  None
# 9317  do this wicked thing
# 9318               friends
# 9319               friends
# 9320                  None
# 9321                  None
# 9322                  None
# 9323                  None
# 9324                   two
# 9325             daughters

# %%
word = bible_df.loc[line, ['text']].values[0][0]
hebrew_source_normalized = normalize_word(word)
book = bible_df.loc[line, ['book']].values[0][0]
chapter = bible_df.loc[line, ['chapter']].values[0][0]
verse = bible_df.loc[line, ['verse']].values[0][0]
ref = f'{book} {chapter}:{verse}\n'
vref_index = vref_data.index(ref)

def normalize_word(word):
    return re.sub("[^\w\s]", "", word.lower()) if word else ''

candidate_words = set(NIV84_df.loc[vref_index, 'words']) if vref_index in NIV84_df.index else set([])
candidate_words = [word.lower().split("ʼ")[0] for word in candidate_words if word is not None]
candidate_words
# Out:
# ['',
#  'this',
#  'said',
#  'my',
#  'and',
#  'friends',
#  'don',
#  'thing',
#  'wicked',
#  'no',
#  'do']

# %%
candidate_df = df[df['normalized_target'] == hebrew_source_normalized]
candidate_df
# Out:
#         Unnamed: 0     source target  align_count  word score  verse score  \
# 619            619          a   אָֽח            2    0.120882     0.207583
# 4708          4708         an   אָ֗ח            1    0.137852     0.223522
# 13798        13798    brother   אָ֖ח            2    0.516493     0.202810
# 13799        13799    brother   אָ֗ח            2    0.370858     0.166233
# 13800        13800    brother   אָ֣ח            3    0.591563     0.198404
# 13801        13801    brother   אָ֥ח            3    0.532790     0.223882
# 13802        13802    brother   אָֽח            3    0.578469     0.233705
# 13803        13803    brother   אָחִ            3    0.599111     0.256289
# 13804        13804    brother  אָחִ֑            3    0.477107     0.275923
# 13807        13807    brother  אָחִ֕            1    0.338540     0.222177
# 13808        13808    brother  אָחִ֖            6    0.519708     0.246001
# 13810        13810    brother  אָחִ֗            2    0.751299     0.214419
# 13813        13813    brother  אָחִ֣            2    0.493880     0.189933
# 13815        13815    brother  אָחִ֥            2    0.633550     0.196764
# 13818        13818    brother  אָחִֽ            2    0.355504     0.267555
# 13834        13834   brothers  אֶחָ֑            4    0.512580     0.262936
# 13842        13842   brothers  אַ֭חַ            1    0.483506     0.394023
# 13851        13851   brothers   אַחַ            2    0.803529     0.250212
# 13852        13852   brothers  אַחַ֖            2    0.251688     0.247064
# 13853        13853   brothers  אַחַ֣            5    0.469857     0.236206
# 13859        13859  brotherʼs  אָחִ֖            1    0.050540     0.226120
# 14518        14518        but  אַ֭חַ            1    0.174900     0.394023
# 21930        21930   deceiver   אָח֙            1    0.114857     0.193086
# 31677        31677    firepot   אָ֖ח            1    0.191823     0.260186
# 31946        31946      flash   אָ֛ח            1    0.069799     0.243677
# 39863        39863       have   אָ֭ח            1    0.452164     0.227233
# 47355        47355         is   אָ֥ח            1    0.210589     0.216643
# 60293        60293         my  אַחַ֣            4    0.382741     0.228364
# 64306        64306   offended   אָ֗ח            1    0.203366     0.223522
# 64709        64709         oh  אָחִֽ            1    0.131919     0.290974
# 69300        69300     plenty  אָחִ֕            1    0.339108     0.222177
# 74042        74042   relative  אָחִ֣            1    0.185404     0.203276
# 93619        93619       this  אַחַ֖            1    0.095848     0.211885
# 109708      109708          ”  אָחִ֑            3    0.302489     0.239580
# 109709      109709          ”  אָחִֽ            2    0.217844     0.267555
#
#        normalized_source normalized_target   jac_sim  match_counts  \
# 619                    a                אח -1.000000             0
# 4708                  an                אח -1.000000             0
# 13798            brother                אח  0.172996            41
# 13799            brother                אח  0.172996            41
# 13800            brother                אח  0.172996            41
# 13801            brother                אח  0.172996            41
# 13802            brother                אח  0.172996            41
# 13803            brother                אח  0.172996            41
# 13804            brother                אח  0.172996            41
# 13807            brother                אח  0.172996            41
# 13808            brother                אח  0.172996            41
# 13810            brother                אח  0.172996            41
# 13813            brother                אח  0.172996            41
# 13815            brother                אח  0.172996            41
# 13818            brother                אח  0.172996            41
# 13834           brothers                אח  0.092437            22
# 13842           brothers                אח  0.092437            22
# 13851           brothers                אח  0.092437            22
# 13852           brothers                אח  0.092437            22
# 13853           brothers                אח  0.092437            22
# 13859          brotherʼs                אח  0.022727             2
# 14518                but                אח -1.000000             0
# 21930           deceiver                אח  0.013514             1
# 31677            firepot                אח  0.027027             2
# 31946              flash                אח  0.012821             1
# 39863               have                אח -1.000000             0
# 47355                 is                אח -1.000000             0
# 60293                 my                אח  0.018008            49
# 64306           offended                אח  0.013699             1
# 64709                 oh                אח  0.019231             2
# 69300             plenty                אח  0.011905             1
# 74042           relative                אח  0.011111             1
# 93619               this                אח -1.000000             0
# 109708               NaN                אח -1.000000             0
# 109709               NaN                אח -1.000000             0
#
#         total_score
# 619       -0.120882
# 4708      -0.137852
# 13798      0.089351
# 13799      0.064157
# 13800      0.102338
# 13801      0.092170
# 13802      0.100073
# 13803      0.103644
# 13804      0.082537
# 13807      0.058566
# 13808      0.089907
# 13810      0.129971
# 13813      0.085439
# 13815      0.109602
# 13818      0.061501
# 13834      0.047381
# 13842      0.044694
# 13851      0.074276
# 13852      0.023265
# 13853      0.043432
# 13859      0.001149
# 14518     -0.174900
# 21930      0.001552
# 31677      0.005184
# 31946      0.000895
# 39863     -0.452164
# 47355     -0.210589
# 60293      0.006892
# 64306      0.002786
# 64709      0.002537
# 69300      0.004037
# 74042      0.002060
# 93619     -0.095848
# 109708    -0.302489
# 109709    -0.217844

# %%
candidate_df[candidate_df.apply(lambda x: x['normalized_source'] in list(candidate_words), axis=1)].sort_values('total_score', ascending=False)
# Out:
#        Unnamed: 0 source target  align_count  word score  verse score  \
# 60293       60293     my  אַחַ֣            4    0.382741     0.228364
# 93619       93619   this  אַחַ֖            1    0.095848     0.211885
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 60293                my                אח  0.018008            49     0.006892
# 93619              this                אח -1.000000             0    -0.095848

# %% [markdown]
# Total number of names:

# %%
word
# Out:
# 'שֶׁמְאֵ֨בֶר֙'

# %%
df[df['source'] == 'shemeber']
# Out:
#        Unnamed: 0    source    target  align_count  word score  verse score  \
# 80989       80989  shemeber  אַדְמָ֗ה            1     0.78108     0.330563
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 80989          shemeber              אדמה     -1.0             0     -0.78108

# %% [markdown]
# Number of matched names:

# %%
matched_names.shape[0]
# Out:
# 32282

# %%
df[df['target'] == 'עֵ֖דֶן']
# Out:
#        Unnamed: 0 source  target  align_count  word score  verse score  \
# 26110       26110   eden  עֵ֖דֶן            2    0.799089     0.322273
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 26110              eden               עדן  0.818182            18      3.79264

# %%
matched_names['predicted'] = matched_names['text'].progress_apply(lambda x: df.loc[df[df['target'] == x]['total_score'].idxmax()]['source'])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 32282/32282 [06:18<00:00, 85.21it/s]

# %%
matched_names
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [32282 rows x 15 columns]

# %%
def is_word_correct(row):
    word = row['english'].split("’")[0] if row['english'] is not None else ''
    return word == row['predicted']

# %%
matched_names[matched_names.apply(is_word_correct, axis=1)]
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 774     GEN        2      4     8        1  o010020040081  00100200400026
# 799     GEN        2      5    15        1  o010020050151  00100200500042
# 827     GEN        2      7     2        1  o010020070021  00100200700006
# 852     GEN        2      8     2        1  o010020080021  00100200800006
# 856     GEN        2      8     5        2  o010020080052  00100200800014
# ...     ...      ...    ...   ...      ...            ...             ...
# 475752  MAL        3     21    14        1  o390030210141  03900302100034
# 475756  MAL        3     22     3        1  o390030220031  03900302200006
# 475767  MAL        3     22    11        1  o390030220111  03900302200024
# 475777  MAL        3     23     6        1  o390030230061  03900302300012
# 475784  MAL        3     23    11        1  o390030230111  03900302300026
#
#        ot-nt      unicode         text   lemma normalized english   greek  \
# 774       OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord    None
# 799       OT      יְהוָ֤ה      יְהוָ֤ה    3068       None    lord    None
# 827       OT      יְהוָ֨ה      יְהוָ֨ה    3068       None    lord    None
# 852       OT      יְהוָ֧ה      יְהוָ֧ה    3068       None    lord  κύριος
# 856       OT       עֵ֖דֶן       עֵ֖דֶן  5731 b       None    eden    εδεμ
# ...      ...          ...          ...     ...        ...     ...     ...
# 475752    OT      יְהוָ֥ה      יְהוָ֥ה    3068       None    lord  κύριος
# 475756    OT      מֹשֶׁ֣ה      מֹשֶׁ֣ה    4872       None   moses   μωυσῆ
# 475767    OT  יִשְׂרָאֵ֔ל  יִשְׂרָאֵ֔ל    3478       None  israel  ισραηλ
# 475777    OT    אֵלִיָּ֣ה    אֵלִיָּ֣ה     452       None  elijah   ηλιαν
# 475784    OT      יְהוָ֔ה      יְהוָ֔ה    3068       None    lord  κυρίου
#
#        predicted
# 774         lord
# 799         lord
# 827         lord
# 852         lord
# 856         eden
# ...          ...
# 475752      lord
# 475756     moses
# 475767    israel
# 475777    elijah
# 475784      lord
#
# [29972 rows x 15 columns]

# %%
matched_names[~matched_names.apply(is_word_correct, axis=1)].head(100)
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 1591   GEN        3     17     1        3  o010030170013  00100301700006
# 1682   GEN        3     21     4        2  o010030210042  00100302100012
# 1809   GEN        4      2    11        2  o010040020112  00100400200030
# 1845   GEN        4      4    11        1  o010040040111  00100400400032
# 1927   GEN        4      8    12        1  o010040080121  00100400800036
# 2114   GEN        4     18     2        2  o010040180022  00100401800008
# 2198   GEN        4     23     4        1  o010040230041  00100402300012
# 2231   GEN        4     25     2        1  o010040250021  00100402500006
# 2270   GEN        4     26     9        1  o010040260091  00100402600024
# 2281   GEN        5      1     4        1  o010050010041  00100500100008
# 2314   GEN        5      3     2        1  o010050030021  00100500300006
# 2336   GEN        5      4     3        1  o010050040031  00100500400008
# 2354   GEN        5      5     4        1  o010050050041  00100500500010
# 2412   GEN        5      9     2        1  o010050090021  00100500900006
# 2777   GEN        5     32    10        1  o010050320101  00100503200024
# 2980   GEN        6     10     6        1  o010060100061  00100601000014
# 3519   GEN        7     13     6        2  o010070130062  00100701300020
# 4687   GEN        9     18     7        1  o010090180071  00100901800020
# 4750   GEN        9     23     2        1  o010090230021  00100902300006
# 4813   GEN        9     26     5        1  o010090260051  00100902600012
# 4816   GEN        9     26     7        1  o010090260071  00100902600018
# 4828   GEN        9     27     6        1  o010090270061  00100902700018
# 4831   GEN        9     27     8        1  o010090270081  00100902700024
# 4865   GEN       10      1     5        1  o010100010051  00101000100012
# 4879   GEN       10      2     3        1  o010100020031  00101000200006
# 4883   GEN       10      2     5        2  o010100020052  00101000200014
# 4902   GEN       10      4     2        1  o010100040021  00101000400006
# 4933   GEN       10      6     4        2  o010100060042  00101000600012
# 4935   GEN       10      6     5        2  o010100060052  00101000600016
# 4991   GEN       10     10     4        1  o010100100041  00101001000010
# 4993   GEN       10     10     5        2  o010100100052  00101001000014
# 5042   GEN       10     13     8        1  o010100130081  00101001300022
# 5073   GEN       10     16     2        2  o010100160022  00101001600008
# 5081   GEN       10     16     6        2  o010100160062  00101001600024
# 5085   GEN       10     17     2        2  o010100170022  00101001700008
# 5089   GEN       10     17     4        2  o010100170042  00101001700016
# 5093   GEN       10     17     6        2  o010100170062  00101001700024
# 5097   GEN       10     18     2        2  o010100180022  00101001800008
# 5101   GEN       10     18     4        2  o010100180042  00101001800016
# 5111   GEN       10     18    10        2  o010100180102  00101001800036
# 5154   GEN       10     21     1        3  o010100210013  00101002100006
# 5167   GEN       10     22     2        1  o010100220021  00101002200004
# 5170   GEN       10     22     4        2  o010100220042  00101002200010
# 5193   GEN       10     24     5        2  o010100240052  00101002400014
# 5226   GEN       10     26     6        1  o010100260061  00101002600016
# 5229   GEN       10     26     8        1  o010100260081  00101002600022
# 5256   GEN       10     29     4        1  o010100290041  00101002900012
# 5279   GEN       10     31     3        1  o010100310031  00101003100006
# 5483   GEN       11      9     5        1  o010110090051  00101100900010
# 5505   GEN       11     10     3        1  o010110100031  00101101000006
# 5535   GEN       11     12     1        2  o010110120012  00101101200004
# 5624   GEN       11     18     2        1  o010110180021  00101101800006
# 5704   GEN       11     24     2        1  o010110240021  00101102400006
# 5939   GEN       12      4     9        1  o010120040091  00101200400024
# 5955   GEN       12      5     2        1  o010120050021  00101200500006
# 6348   GEN       13      3     3        2  o010130030032  00101300300012
# 6434   GEN       13      7    10        1  o010130070101  00101300700024
# 6440   GEN       13      7    12        3  o010130070123  00101300700036
# 6604   GEN       13     14    19        2  o010130140192  00101301400048
# 6705   GEN       14      1    14        1  o010140010141  00101400100034
# 6782   GEN       14      5    19        2  o010140050192  00101400500060
# 6859   GEN       14      9     7        1  o010140090071  00101400900016
# 6943   GEN       14     13     8        2  o010140130082  00101401300030
# 6946   GEN       14     13    10        2  o010140130102  00101401300036
# 7031   GEN       14     17     3        1  o010140170031  00101401700008
# 7339   GEN       15      8     3        1  o010150080031  00101500800008
# 7548   GEN       15     19     2        2  o010150190022  00101501900006
# 7552   GEN       15     19     4        2  o010150190042  00101501900014
# 7556   GEN       15     19     6        2  o010150190062  00101501900022
# 7560   GEN       15     20     2        2  o010150200022  00101502000008
# 7564   GEN       15     20     4        2  o010150200042  00101502000016
# 7580   GEN       15     21     6        2  o010150210062  00101502100024
# 7584   GEN       15     21     8        2  o010150210082  00101502100032
# 7597   GEN       16      1     9        1  o010160010091  00101600100022
# 7637   GEN       16      3     7        2  o010160030072  00101600300018
# 8225   GEN       17     15    11        1  o010170150111  00101701500024
# 10066  GEN       19     37     9        1  o010190370091  00101903700024
# 10098  GEN       20      1     5        2  o010200010052  00102000100016
# 10777  GEN       21     14    20        1  o010210140201  00102101400064
# 11122  GEN       21     31     6        1  o010210310061  00102103100018
# 11276  GEN       22      4     4        1  o010220040041  00102200400016
# 11645  GEN       22     19     9        1  o010220190091  00102201900024
# 11651  GEN       22     19    13        2  o010220190132  00102201900036
# 12055  GEN       23     16     2        1  o010230160021  00102301600006
# 12083  GEN       23     17     3        1  o010230170031  00102301700008
# 12968  GEN       24     36     2        1  o010240360021  00102403600006
# 13241  GEN       24     47    11        1  o010240470111  00102404700028
# 13568  GEN       24     62    10        2  o010240620102  00102406200028
# 13724  GEN       25      3    12        2  o010250030122  00102500300034
# 13901  GEN       25     13    10        2  o010250130102  00102501300028
# 13974  GEN       25     18    10        1  o010250180101  00102501800024
# 14008  GEN       25     20    12        2  o010250200122  00102502000032
# 14305  GEN       26      1    14        1  o010260010141  00102600100046
# 14753  GEN       26     22    11        1  o010260220111  00102602200032
# 14771  GEN       26     23     3        1  o010260230031  00102602300010
# 14837  GEN       26     26     5        2  o010260260052  00102602600016
# 14980  GEN       26     33     3        1  o010260330031  00102603300008
# 14986  GEN       26     33     8        1  o010260330081  00102603300020
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
# 16052  GEN       27     46     9        1  o010270460091  00102704600024
#
#       ot-nt          unicode            text   lemma normalized      english  \
# 1591     OT           אָדָ֣ם          אָדָ֣ם     121       None         adam
# 1682     OT           אָדָ֧ם          אָדָ֧ם     120       None         adam
# 1809     OT           קַ֕יִן          קַ֕יִן  7014 b       None         cain
# 1845     OT           הֶ֖בֶל          הֶ֖בֶל    1893       None         abel
# 1927     OT           הֶ֥בֶל          הֶ֥בֶל    1893       None         abel
# 2114     OT         חֲנוֹךְ֙        חֲנוֹךְ֙    2585       None        enoch
# 2198     OT           עָדָ֤ה          עָדָ֤ה    5711       None         adah
# 2231     OT           אָדָ֥ם          אָדָ֥ם     121       None         adam
# 2270     OT         אֱנ֑וֹשׁ        אֱנ֑וֹשׁ     583       None        enosh
# 2281     OT           אָדָ֑ם          אָדָ֑ם     121       None         adam
# 2314     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2336     OT           אָדָ֗ם          אָדָ֗ם     121       None         adam
# 2354     OT           אָדָם֙          אָדָם֙     121       None         adam
# 2412     OT         אֱנ֖וֹשׁ        אֱנ֖וֹשׁ     583       None        enosh
# 2777     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 2980     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 3519     OT            שֵׁם־            שֵׁם    8035       None         shem
# 4687     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4750     OT            שֵׁ֨ם           שֵׁ֨ם    8035       None         shem
# 4813     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4816     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4828     OT            שֵׁ֑ם           שֵׁ֑ם    8035       None         shem
# 4831     OT         כְנַ֖עַן        כְנַ֖עַן  3667 a       None       canaan
# 4865     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 4879     OT          גֹּ֣מֶר         גֹּ֣מֶר    1586       None        gomer
# 4883     OT           מָדַ֖י          מָדַ֖י    4074       None        madai
# 4902     OT           יָוָ֖ן          יָוָ֖ן    3120       None        javan
# 4933     OT       מִצְרַ֖יִם      מִצְרַ֖יִם    4714       None      mizraim
# 4935     OT            פ֥וּט           פ֥וּט    6316       None          put
# 4991     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 4993     OT          אֶ֖רֶךְ         אֶ֖רֶךְ     751       None        erech
# 5042     OT        לְהָבִ֖ים       לְהָבִ֖ים    3853       None      lehabim
# 5073     OT        יְבוּסִי֙       יְבוּסִי֙    2983       None    jebusites
# 5081     OT    גִּרְגָּשִֽׁי   גִּרְגָּשִֽׁי    1622       None  girgashites
# 5085     OT          חִוִּ֥י         חִוִּ֥י    2340       None      hivites
# 5089     OT         עַרְקִ֖י        עַרְקִ֖י    6208       None      arkites
# 5093     OT         סִּינִֽי        סִּינִֽי    5513       None      sinites
# 5097     OT       אַרְוָדִ֥י      אַרְוָדִ֥י     721       None    arvadites
# 5101     OT        צְּמָרִ֖י       צְּמָרִ֖י    6786       None    zemarites
# 5111     OT      כְּנַעֲנִֽי     כְּנַעֲנִֽי  3669 a       None    canaanite
# 5154     OT            שֵׁ֥ם           שֵׁ֥ם    8035       None         shem
# 5167     OT            שֵׁ֖ם           שֵׁ֖ם    8035       None         shem
# 5170     OT        אַשּׁ֑וּר       אַשּׁ֑וּר     804       None       asshur
# 5193     OT          שֶׁ֖לַח         שֶׁ֖לַח    7974       None       shelah
# 5226     OT          שָׁ֑לֶף         שָׁ֑לֶף    8026       None      sheleph
# 5229     OT     חֲצַרְמָ֖וֶת    חֲצַרְמָ֖וֶת    2700       None  hazarmaveth
# 5256     OT        חֲוִילָ֖ה       חֲוִילָ֖ה    2341       None      havilah
# 5279     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5483     OT          בָּבֶ֔ל         בָּבֶ֔ל     894       None        babel
# 5505     OT            שֵׁ֔ם           שֵׁ֔ם    8035       None         shem
# 5535     OT   אַרְפַּכְשַׁ֣ד  אַרְפַּכְשַׁ֣ד     775       None   arpachshad
# 5624     OT           פֶ֖לֶג          פֶ֖לֶג    6389       None        peleg
# 5704     OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 5939     OT            ל֑וֹט           ל֑וֹט    3876       None          lot
# 5955     OT         אַבְרָם֩        אַבְרָם֩      87       None        abram
# 6348     OT          נֶּ֖גֶב         נֶּ֖גֶב    5045       None        negev
# 6434     OT            ל֑וֹט           ל֑וֹט    3876       None        lot’s
# 6440     OT       פְּרִזִּ֔י      פְּרִזִּ֔י    6522       None   perizzites
# 6604     OT          נֶ֖גְבּ        נֶ֖גְבָּ    5045       None        south
# 6705     OT         גּוֹיִֽם        גּוֹיִֽם  1471 b       None        goiim
# 6782     OT          שָׁוֵ֖ה         שָׁוֵ֖ה    7740       None       shaveh
# 6859     OT         גּוֹיִ֔ם        גּוֹיִ֔ם  1471 b       None        goiim
# 6943     OT        אֵֽלֹנֵ֜י       אֵֽלֹנֵ֜י     436       None         oaks
# 6946     OT         אֱמֹרִ֗י        אֱמֹרִ֗י     567       None      amorite
# 7031     OT           סְדֹם֮          סְדֹם֮    5467       None        sodom
# 7339     OT          יֱהוִ֔ה         יֱהוִ֔ה    3069       None          god
# 7548     OT         קֵּינִי֙        קֵּינִי֙    7017       None      kenites
# 7552     OT       קְּנִזִּ֔י      קְּנִזִּ֔י    7074       None   kenizzites
# 7556     OT      קַּדְמֹנִֽי     קַּדְמֹנִֽי    6935       None   kadmonites
# 7560     OT          חִתִּ֥י         חִתִּ֥י    2850       None     hittites
# 7564     OT       פְּרִזִּ֖י      פְּרִזִּ֖י    6522       None   perizzites
# 7580     OT    גִּרְגָּשִׁ֖י   גִּרְגָּשִׁ֖י    1622       None  girgashites
# 7584     OT        יְבוּסִֽי       יְבוּסִֽי    2983       None    jebusites
# 7597     OT        מִצְרִ֖ית       מִצְרִ֖ית    4713       None     egyptian
# 7637     OT       מִּצְרִית֙      מִּצְרִית֙    4713       None     egyptian
# 8225     OT          שָׂרָ֑י         שָׂרָ֑י    8297       None        sarai
# 10066    OT          מוֹאָ֖ב         מוֹאָ֖ב    4124       None     moabites
# 10098    OT          נֶּ֔גֶב         נֶּ֔גֶב    5045       None        negev
# 10777    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 11122    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11276    OT       אַבְרָהָ֧ם      אַבְרָהָ֧ם      85       None      abraham
# 11645    OT  בְּאֵ֣ר שָׁ֑בַע         בְּאֵ֣ר    884+       None         None
# 11651    OT   בְאֵ֥ר שָֽׁבַע          בְאֵ֥ר    884+       None         None
# 12055    OT       אַבְרָהָם֮      אַבְרָהָם֮      85       None      abraham
# 12083    OT        עֶפְר֗וֹן       עֶפְר֗וֹן    6085       None     ephron’s
# 12968    OT          שָׂרָה֩         שָׂרָה֩    8283       None        sarah
# 13241    OT          נָח֔וֹר         נָח֔וֹר    5152       None        nahor
# 13568    OT          נֶּֽגֶב         נֶּֽגֶב    5045       None        negev
# 13724    OT       לְאֻמִּֽים      לְאֻמִּֽים    3817       None      leummim
# 13901    OT           קֵדָ֥ר          קֵדָ֥ר    6938       None        kedar
# 13974    OT        אַשּׁ֑וּר      אַשּׁ֑וּרָ     804       None       asshur
# 14008    OT  פַּדַּ֖נ אֲרָ֑ם        פַּדַּ֖ן   6307+       None         None
# 14305    OT    אֲבִימֶּ֥לֶךְ   אֲבִימֶּ֥לֶךְ      40       None    abimelech
# 14753    OT        רְחֹב֔וֹת       רְחֹב֔וֹת    7344       None     rehoboth
# 14771    OT  בְּאֵ֥ר שָֽׁבַע         בְּאֵ֥ר    884+       None         None
# 14837    OT        אֲחֻזַּת֙       אֲחֻזַּת֙     276       None     ahuzzath
# 14980    OT        שִׁבְעָ֑ה       שִׁבְעָ֑ה    7656       None       shibah
# 14986    OT  בְּאֵ֣ר שֶׁ֔בַע         בְּאֵ֣ר    884+       None         None
# 15003    OT       יְהוּדִ֔ית      יְהוּדִ֔ית    3067       None       judith
# 16052    OT             חֵ֑ת            חֵ֑ת    2845       None      hittite
#
#               greek         predicted
# 1591           αδαμ               man
# 1682           αδαμ                of
# 1809           καιν            tiller
# 1845           αβελ            vanity
# 1927           αβελ          futility
# 2114           ενωξ            hanoch
# 2198            αδα            zillah
# 2231           αδαμ               man
# 2270           ενως               man
# 2281       ἀνθρώπων               man
# 2314           αδαμ               man
# 2336           αδαμ               man
# 2354           αδαμ               man
# 2412           ενως            mortal
# 2777            σημ              name
# 2980            σημ              name
# 3519            σημ              name
# 4687            σημ              name
# 4750            σημ              name
# 4813            σημ              name
# 4816         ξανααν              shem
# 4828            σημ              name
# 4831         ξανααν              shem
# 4865            σημ              name
# 4879          γαμερ           japheth
# 4883          μαδαι             gomer
# 4902          ιωυαν            greece
# 4933        μεσραιμ             egypt
# 4935           φουδ           mizraim
# 4991        βαβυλὼν           babylon
# 4993           ορεξ              slow
# 5042           None              anam
# 5073     ιεβουσαῖον          jebusite
# 5081     γεργεσαῖον        girgashite
# 5085         ευαῖον            hivite
# 5089      αρουκαῖον            arkite
# 5093      ασενναῖον            sinite
# 5097        ἀράδιον          arvadite
# 5101      σαμαραῖον         hamathite
# 5111      ξαναναίων         tradesmen
# 5154            σημ              name
# 5167            σημ              name
# 5170         ασσουρ           assyria
# 5193           σαλα            became
# 5226           None           almodad
# 5229        ασαρμωθ           sheleph
# 5256          ευιλα             jobab
# 5279            σημ              name
# 5483       σύγξυσις           babylon
# 5505            σημ              name
# 5535         ἔζησεν        thirtyfive
# 5624          φαλεκ            thirty
# 5704          ναξωρ        twentynine
# 5939            λωτ             lot’s
# 5955          αβραμ             sarai
# 6348           None             south
# 6434            λωτ             lot’s
# 6440      φερεζαῖοι         perizzite
# 6604           None         southward
# 6705          ἐθνῶν           nations
# 6782           σαυη  shavehkiriathaim
# 6859          ἐθνῶν           nations
# 6943           δρυὶ             mamre
# 6946         αμορις          amorites
# 7031        σοδομων            defeat
# 7339           None               may
# 7548      καιναίους            kenite
# 7552     κενεζαίους         kenizzite
# 7556    κεδμωναίους         kadmonite
# 7560      ξετταίους           hittite
# 7564     φερεζαίους         perizzite
# 7580    γεργεσαίους        girgashite
# 7584    ιεβουσαίους          jebusite
# 7597       αἰγυπτία              maid
# 7637      αἰγυπτίαν           abram’s
# 8225           σαρα           princes
# 10066      μωαβιτῶν              moab
# 10098          λίβα             south
# 10777          None         beersheba
# 11122          None         beersheba
# 11276        αβρααμ            raised
# 11645          None         beersheba
# 11651          None         beersheba
# 12055        αβρααμ            ephron
# 12083         εφρων          ephron’s
# 12968         σαρρα          master’s
# 13241         ναξωρ        twentynine
# 13568          None             south
# 13724        λοωμιμ           peoples
# 13901         κηδαρ          nebaioth
# 13974          πρὸς           assyria
# 14008  μεσοποταμίας           aramean
# 14305      αβιμελεξ             gerar
# 14753     εὐρυξωρία           squares
# 14771          None         beersheba
# 14837        οξοζαθ           adviser
# 14980         ὅρκος             seven
# 14986          None         beersheba
# 15003        ιουδιν            judean
# 16052           ξετ              heth

# %%
hebrew_names = set(hebrew_names)
hebrew_matched_names = set(hebrew_matched_names)
list(hebrew_names - hebrew_matched_names)
# Out:
# ['מָכִֽי',
#  'יְה֗וּד',
#  'מִיכָיָ֜ה',
#  'זִ֥יעַ',
#  'נָב֗וֹת',
#  'נְבַלָּֽט',
#  'כִּנֶּ֔רֶת',
#  'נְבֽוּכַדְרֶאצַּ֥ר',
#  'זְבֻל֑וּן',
#  'רֶ֧גֶם',
#  'מּוֹאֲבִיָּ֜ה',
#  'הֶ֨בֶל֙',
#  'עֵ֠ילָם',
#  'מֵידָ֔ד',
#  'יִּשְׂרְאֵלִֽי',
#  'אֱלִישָׁ֖ה',
#  'הוֹמָ֑ם',
#  'בְאֵרָֽא',
#  'אַשְׁבֵּלִ֑י',
#  'אֲגַ֥ג',
#  'רֽאוּבֵנִ֗י',
#  'תַפֻּ֖חַ',
#  'אָצַל֒',
#  'כִּסְלֵיו֙',
#  'רְפָיָ֧ה',
#  'מִיכָיָ֧ה',
#  'בִּתִּ֞',
#  'שִׁמְעָתִ֖ים',
#  'תַּ֠תְּנַי',
#  'יִצְחָ֨ק',
#  'אֲשִׁימָֽא',
#  'יֵשׁ֛וּעַ',
#  'אֲחַזְיָ֤ה',
#  'אֲרִיאֵ֡ל',
#  'גִּבְעָ֨תָ',
#  'דָּ֣ן',
#  'שְׁבָ֔ט',
#  'בָּשָׁ֞ן',
#  'יִבְלְעָ֨ם',
#  'עִיּ֡וֹן',
#  'תֻּבַ֣ל',
#  'בִּנְיָמִ֣ין',
#  'צָפ֥וֹן',
#  'חֶלְקָֽי',
#  'שָׁמָע֙',
#  'מֹּ֣רַשְׁתִּ֔י',
#  'כְּנַעֲנִ֨י',
#  'אֲחִיה֖וּד',
#  'פַּלְטִ֔י',
#  'קְעִלָ֔ה',
#  'צוֹפִ֖ים',
#  'אַבְרָ֫הָ֥ם',
#  'שִׁרְטַ֖י',
#  'בַקְבֻּֽקְיָ֛ה',
#  'מֹּצָֽה',
#  'כְנָ֑נִי',
#  'יַּעֲקֹ֑ב',
#  'יְהוּדִי֙',
#  'נַעֲמָֽן',
#  'מָע֖וֹךְ',
#  'פְּרָ֔ת',
#  'שַׁלְמַ֖י',
#  'שִׁמְשַׁ֥י',
#  'חֲשֻׂפָ֖א',
#  'שִׁפְעִ֧י',
#  'אַמְנֹ֗ן',
#  'יַֽאֲזַנְיָ֨הוּ֙',
#  'בּוּנִּֽי',
#  'עֵיבָ֖ל',
#  'ירִימ֤וֹת',
#  'אֵ֔צֶר',
#  'אֲשַׂרְאֵ֖לָה',
#  'עֶקְרוֹן֮',
#  'מּוֹרָֽא',
#  'שִּׁטִּים֙',
#  'צְֽרֵרָ֔תָ',
#  'יְדוּת֑וּן',
#  'נֽוֹעַדְיָ֥ה',
#  'זְבֻ֣ל',
#  'דַּמֶּ֤שֶׂק',
#  'נֹ֑ף',
#  'גָדִ֜י',
#  'יִשָּׂשכָ֣ר',
#  'יִתְמָ֖ה',
#  'עָמְרִ֨י',
#  'שֵׁשַׁ֥י',
#  'בְּאֵ֣רֹתִ֔י',
#  'לֶ֗מֶךְ',
#  'שֵׁלָ֗ה',
#  'שָׁ֠אוּל',
#  'פַרְעֹ֖שׁ',
#  'מְשִׁלֵּמ֔וֹת',
#  'גִּלְעָדִֽי',
#  'אַבְנֵר֩',
#  'אֶסְתֵּֽר',
#  'אֲרִדַ֖י',
#  'אַרְבִּֽי',
#  'פַרְעֹה֒',
#  'עַבְדִּיאֵ֣ל',
#  'נָבָ֡ל',
#  'יְקַמְיָ֥ה',
#  'טֶ֣בַח',
#  'ס֧וּחַ',
#  'בֵּ֣לְטְשַׁאצַּ֗ר',
#  'נְתַנְיָ֥ה',
#  'יִֽזְרַחְיָ֖ה',
#  'עֵיטָם֒',
#  'קְוֵ֕א',
#  'מִכְמָ֔ס',
#  'נְבֽוּכַדְרֶאצַּר֒',
#  'יַעֲקֹב֮',
#  'יִגְאָל',
#  'גַעְתָּ֔ם',
#  'שִׁמְשׁ֥וֹן',
#  'בִּנְיָמִן֒',
#  'כַרְכַּ֔ס',
#  'חִלְקִיָּ֛הוּ',
#  'מֵּרֹ֣נֹתִ֔י',
#  'פִּרְעָתוֹנִ֑י',
#  'פַרְעֹה֮',
#  'גְדֵרֹתָ֑יִם',
#  'עֲשְׁתְּרָתִ֑י',
#  'מָֽרֵשָׁ֑ה',
#  'זַכַּ֖י',
#  'אַהֲרֹן֮',
#  'חֵ֨לֶף',
#  'נְבָ֗ט',
#  'אַרְנ֑וֹן',
#  'דָּוִ֡ד',
#  'ירִיחוֹ֮',
#  'אֶלְעָלֵ֔ה',
#  'נְּמ֣וּאֵלִ֔י',
#  'זָ֑רֶד',
#  'מֵישַׁךְ֙',
#  'שֵׁשַׁ֖ךְ',
#  'אֲדֹמִי֮',
#  'הוֹדַוְיָ֡הוּ',
#  'דּוּרָ֔א',
#  'אֹ֛רֶן',
#  'כּ֗וּשׁ',
#  'הָמָ֡ן',
#  'חָגָ֥ב',
#  'עֲתַלְיָ֑ה',
#  'אֱלִיאָ֣ב',
#  'אֲחִֽינָדָ֥ב',
#  'חָֽרֶת',
#  'יֽוֹצָדָ֔ק',
#  'זְרַֽחְיָ֑ה',
#  'אֲדוֹמִ֔ים',
#  'אֱלִיפַ֣ז',
#  'בְּנָיָֽה',
#  'צִיד֜וֹן',
#  'נְבֽוּכַדְנֶאצַּ֔ר',
#  'חֹרֵֽבָ',
#  'אַשּׁוּר֮',
#  'נָ֭הָר',
#  'חֲזָיָ֨ה',
#  'יְהוּכַ֣ל',
#  'בֵּבָ֑י',
#  'שָׂרָ֗ה',
#  'אֲבִיגַ֗יִל',
#  'נְתַנְיָ֔ה',
#  'יהוּדָ֧ה',
#  'אֲחַסְבַּ֖י',
#  'דָנִיֵּ֡אל',
#  'עֹג֙',
#  'בָלָ֜ק',
#  'שֹֽׁמְר֗וֹן',
#  'צְבֹעִ֖ים',
#  'נְבֻכַדְנֶאצַּ֨ר',
#  'מַלְכִּיָּ֔ה',
#  'עוּתַ֨י',
#  'שְׁבַנְיָ֡הוּ',
#  'הָמָ֥ן',
#  'הָגָ֑ר',
#  'אֲחוֹחִי֙',
#  'יְ֠הוֹחָנָן',
#  'אֲחַשְׁוֵר֜וֹשׁ',
#  'לֵּוִ֜י',
#  'דִינָה֙',
#  'בָשָׁן֙',
#  'אַבְרָם֮',
#  'יְהֽוֹעַדָּ֖ן',
#  'יוֹיָרִ֥יב',
#  'עַכְבּ֨וֹר',
#  'צֹּרִ֔ים',
#  'שְׂר֔וּג',
#  'שָׂרָ֔י',
#  'אַשְׁדּוֹדִ֔ית',
#  'זֶ֨רֶשׁ',
#  'כִּנְר֔וֹת',
#  'לוּדִ֕ים',
#  'עֶזְרָ֨א',
#  'פִּלְדָּ֖שׁ',
#  'שְׁכַנְיָ֖הוּ',
#  'כָּב֖וּל',
#  'קִדְר֜וֹן',
#  'טַבָּעֽוֹת',
#  'אִדּ֨וֹ',
#  'צְבוֹיִ֔ים',
#  'יְהוֹעַדָּ֖ן',
#  'סְכָכָֽה',
#  'מַֽעַזְיָ֖הוּ',
#  'פֻוָּ֖ה',
#  'מִֽיכָאֵ֗ל',
#  'בָלָ֗ק',
#  'בְּאֵֽרֹתִ֖י',
#  'נְעַרְיָה',
#  'אוּלָ֖ם',
#  'יִמְנָ֖ע',
#  'דָֽנִיֵּ֑אל',
#  'תַּרְשִׁישׁ֙',
#  'חָ֕ם',
#  'דְבִ֨רָ',
#  'מַלּוּךְ֙',
#  'חֲשַׁבְיָ֨ה',
#  'יְשַֽׁעְיָ֖ה',
#  'יִדְבָּ֑שׁ',
#  'גְּמַרְיָהוּ֩',
#  'אֶתְנִ֥י',
#  'גָד֩',
#  'אָסָף֩',
#  'דְלָיָ֨הוּ֙',
#  'אֶ֠לְקָנָה',
#  'יוֹזָבָ֔ד',
#  'שַׁלְתִּיאֵל֙',
#  'עָ֤ר',
#  'יֵ֥שֶׁר',
#  'כְּרֵתִ֛י',
#  'צַֽאֲנָ֔ן',
#  'פְּלִשְׁתִּים֒',
#  'שְׁמַעְיָ֔הוּ',
#  'נִמְשִׁ֖י',
#  'צָפֹ֛נָ',
#  'עָמְרִ֤י',
#  'גִבְע֨וֹן',
#  'שְׁמַעְיָ֧ה',
#  'יָ֣מָּ',
#  'לְּבָנ֞וֹן',
#  'מִּצְפָּה֒',
#  'קְצִיעָ֑ה',
#  'תְּקוֹעִ֑י',
#  'מִצְרַ֤יִם',
#  'נְ֠תַנְיָהוּ',
#  'קַבְצְאֵ֑ל',
#  'מַעֲכָה֙',
#  'עֲתַלְיָ֔ה',
#  'חֶצְר֗וֹן',
#  'דָּרְיָ֔וֶשׁ',
#  'רֶ֧שֶׁף',
#  'פּוּנִֽי',
#  'ירוּשְׁלֶ֛ם',
#  'חִלְקִיָּהוּ֩',
#  'בֵלְטְשַׁאצַּר֙',
#  'אֲמַצְיָ֣ה',
#  'ראוּבֵנִ֤י',
#  'זִיזָ֨א',
#  'עָלָ֑מֶת',
#  'לָכִ֛ישׁ',
#  'צִ֫יּ֥וֹן',
#  'אָ֣שֵׁרִ֔י',
#  'קַרְתָּ֖ן',
#  'נְ֠חֶמְיָה',
#  'נְּתִינִים֙',
#  'גִבְע֔וֹן',
#  'יְרִיח֥וֹ',
#  'זְאֵ֑ב',
#  'עַמִּיזָבָ֖ד',
#  'תְק֨וֹעַ֙',
#  'צִדְקִיָּ֤ה',
#  'שֵׁ֑ת',
#  'סַּרְדִּ֔י',
#  'צְּרֵדָ֗ה',
#  'פּוּעָֽה',
#  'יוֹיָכִֽין',
#  'פִרְעָתוֹן֙',
#  'מֵּרֹנֹתִֽי',
#  'גַ֨עַל',
#  'אַחְאָב֒',
#  'בְרִעָ֣ה',
#  'אַרְדִּ֔י',
#  'עַלְיָ֧ן',
#  'גִּרְגָּשִׁ֨י',
#  'מַקֵּדָ֔ה',
#  'אֶשְׁתָּאֹ֗ל',
#  'שְׁבָ֑א',
#  'עַמּ֧וֹן',
#  'קַּדְמֹנִֽי',
#  'יִבְנִיָּֽה',
#  'בֶּ֚לַע',
#  'גִּבְלִ֑ים',
#  'רְעוּאֵ֣ל',
#  'יְשַֽׁעְיָ֖הוּ',
#  'גִּבְעָ֜ה',
#  'יְשֻׁרוּן֙',
#  'אדֹנָ֔',
#  'אֶלְחָנָן֩',
#  'שִׁישַׁ֣ק',
#  'יְהוּדִ֔י',
#  'נָבָל֒',
#  'לֶּ֗חִי',
#  'חֵלֽוֹן',
#  'שּׁוּנַמִּ֖ית',
#  'חִזְקִיָּהוּ֒',
#  'מֶ֤שֶׁךְ',
#  'שִׁפְרָ֔ה',
#  'מִּצְפָּ֛ה',
#  'חָנֵ֥ס',
#  'גִיח֨וֹן',
#  'רוּמָ֖ה',
#  'נַחֲמָ֜נִי',
#  'יְהוּדָיֵ',
#  'וַיְזָֽתָא',
#  'גֹּ֖שֶׁן',
#  'יְהוֹאָחָ֤ז',
#  'בְּאֵרֹתִ֖ים',
#  'אֶלְתְּקֵ֥ה',
#  'בֵּלְטְשַׁאצַּ֗ר',
#  'יְהֻדִיָּ֗ה',
#  'חִירָ֜ם',
#  'זְכַרְיָ֡הוּ',
#  'אוּפָ֔ז',
#  'לְוִיִּ֨ם',
#  'יָרִ֖יב',
#  'רֵכָ֨ב',
#  'גֵֽי',
#  'שֶֽׁלֶמְיָ֥ה',
#  'בְנָיָ֖הוּ',
#  'מִּדְיָנִ֖ית',
#  'צְבֹאיִ֑ם',
#  'יִּזְרָ֑ח',
#  'שַׁלּ֣וּן',
#  'קֵדָ֛ר',
#  'תָּמָ֔ר',
#  'יוֹסֵ֨ף',
#  'זָנוֹחַ֒',
#  'יֹאושִׁיָּ֖הוּ',
#  'יְאֹר֒',
#  'דֶּ֛קֶר',
#  'רְפִידִ֔ם',
#  'גִּבְעוֹנִ֛י',
#  'יִּזְרְעֵאלִ֖י',
#  'יְאֹר֮',
#  'גַּרְמִ֑י',
#  'בֶרֶכְיָ֤ה',
#  'יְ֠רוּשָׁלִַם',
#  'חֲשַׁבְנְיָ֜ה',
#  'נָח֛וֹר',
#  'אֲחִֽיסָמָךְ֙',
#  'לוּבִ֥ים',
#  'סִ֛ין',
#  'אֲרָמִ֖ית',
#  'יָּ֑מָּ',
#  'ידִֽיעֲאֵל֙',
#  'בְּרִיעִֽי',
#  'מְלַטְיָ֣ה',
#  'גָ֑ד',
#  'בֶּ֣לַע',
#  'טוֹבִיָּ֑ה',
#  'לְבָנ֗וֹנָ',
#  'סֻכִּיִּ֖ים',
#  'גֵ֣י',
#  'תֶ֜רֶשׁ',
#  'עֶפְרוֹן֒',
#  'שָׁגֵ֖ה',
#  'תֵּימָ֔ן',
#  'יְה֣וֹנָדָ֔ב',
#  'בַּעַל',
#  'צֹ֔חַר',
#  'עִדּ֑וֹא',
#  'קָּרְחִ֑י',
#  'אַרְכִּ֔י',
#  'אֲחִימַ֗עַץ',
#  'יְהוָ֘ה',
#  'חֲמָ֛ת',
#  'אַחְיָ֣ן',
#  'יִרְמְיָ֨ה',
#  'אוּרִיָּה֙',
#  'אֲרָמִֽית',
#  'צְמָרַ֔יִם',
#  'שְׁכֶ֜ם',
#  'יַּרְדֵּן',
#  'אֱד֞וֹם',
#  'מַעֲשֵׂיָ֖ה',
#  'יְהוּדִ֜י',
#  'נֹּ֔א',
#  'אֶבְיָתָ֗ר',
#  'אֲמָ֥ם',
#  'יִּשְׂרָאֵ֛ל',
#  'מוֹאֲבִיּֽוֹת',
#  'פָּ֑עוּ',
#  'גִּבְע֑וֹן',
#  'חֲשַׁבְיָ֛ה',
#  'כְּלֽוּב',
#  'אֵימִ֔ים',
#  'יְרֵח֥וֹ',
#  'גָּ֑בַע',
#  'שְׁמוּאֵ֞ל',
#  'שִּׁילֹנִ֨י',
#  'חִוִּ֧י',
#  'אֱלִיעֶ֔זֶר',
#  'דַרְדַּ֖ע',
#  'נְתַנְיָ֑ה',
#  'הָרָא֙',
#  'יָבִ֔ין',
#  'יְע֛וּשׁ',
#  'רִצְיָֽא',
#  'בַרְזִלַּ֗י',
#  'אוּלָ֑י',
#  'אֶלְתְּקֵ֖א',
#  'לָֽשַׁע',
#  'צָּרְעָ֣ה',
#  'חֶפְצִי',
#  'אָשֵׁ֤ר',
#  'אֲבִינֹ֖עַם',
#  'צִֽקְלַ֖ג',
#  'בָבְלָיֵ',
#  'תָמָר֙',
#  'הֹרָם֙',
#  'יְהֹוָה֙',
#  'שַֽׁעֲלַבִּ֥ין',
#  'לְמוּאֵ֣ל',
#  'יהוֹשֻׁ֔עַ',
#  'חִילֵז֙',
#  'יְרֹחָ֧ם',
#  'ישַׁעְיָהוּ',
#  'קָֽיִן',
#  'יִּשְׂרָאֵל֒',
#  'פְּלִשְׁתִּ֤ים',
#  'חֲנֹ֔ךְ',
#  'אֵל֛וֹת',
#  'מַלְכִּיָּ֖ה',
#  'עֲדִינָ֨א',
#  'סְבָ֗א',
#  'אֲבִישׁ֗וּעַ',
#  'שִׁיאֹ֖ן',
#  'אִיזֶ֥בֶל',
#  'כַשְׂדָּֽי',
#  'אֲזַנְיָ֔ה',
#  'רַבָּה֒',
#  'יַעְכָּ֛ן',
#  'יְרוּשָׁלְַ֗מָ',
#  'אַשְׁפְּנַ֖ז',
#  'אָמוֹץ֙',
#  'אֲחִיָּ֣הוּ',
#  'צָפ֥וֹנָ',
#  'מֵּשָׁ֑א',
#  'מֹ֣ף',
#  'נֵ֜ר',
#  'זִפְרֹ֔נָ',
#  'יהוֹנָתָ֜ן',
#  'אֱלִיאָב֮',
#  'בִּזְּתָ֨א',
#  'זַמְזֻמִּֽים',
#  'דִֽימוֹנָ֖ה',
#  'יֽוֹשָׁפָ֡ט',
#  'שִׁמְשׁוֹן֮',
#  'אֶפְרַיִם֒',
#  'מִּצְרַיִם֒',
#  'פַשְׁחוּר֙',
#  'בְעֹֽן',
#  'פְּלַטְיָ֥הוּ',
#  'דָּוִיד֩',
#  'כְּבָ֔ר',
#  'שִׁיל֑וֹ',
#  'אֵלֹנִ֑י',
#  'יְהֹוָ֔ה',
#  'בִּדְקַר֙',
#  'יוֹשָׁ֖ה',
#  'יָרְקֳעָ֑ם',
#  'חֻבָּ֥ה',
#  'בָבֶ֛ל',
#  'יֹאשִׁיָּ֤הוּ',
#  'יְרִיח֑וֹ',
#  'תֵּימָ֤ן',
#  'גִדְע֥וֹן',
#  'גִּ֣זוֹנִ֔י',
#  'עֲמָלֵק֙',
#  'בַּעֲנָ֣ה',
#  'הַגְרִֽי',
#  'שְׁכֶ֧ם',
#  'אֲדוֹנָ֔',
#  'זְבַדְיָ֖ה',
#  'יִסְכָּֽה',
#  'דָ֠וִד',
#  'חֵ֤פֶר',
#  'בַּרְזִלַּ֤י',
#  'גֶּ֣בַע',
#  'צּוֹבָ֔ה',
#  'שֻּׁנַמִּית֙',
#  'שִּֽׁילוֹנִ֗י',
#  'גָּזֵֽז',
#  'מַעֲשֵׂיָ֧הוּ',
#  'יְהוֹשֻׁעַ֒',
#  'עֲרָבִ֔י',
#  'ל֑וֹט',
#  'נְח֣וּם',
#  'פְרִידָֽא',
#  'יַּחְלְאֵלִֽי',
#  'שֶׁבַע',
#  'נְבֽוּכַדְנֶצַּ֜ר',
#  'יֵ֠הוּא',
#  'פְּנוּאֵ֖ל',
#  'דְּבֹרָ֔ה',
#  'שִּׁל֤וֹ',
#  'דָוִ֜יד',
#  'אֲדֹ֣מִיֹּ֔ת',
#  'יְהֽוֹיָקִ֜ים',
#  'יִתְר֛וֹ',
#  'עַמֹּנִ֜ים',
#  'יְרֵחוֹ֒',
#  'חֲשַׁבְיָ֨הוּ',
#  'יֵהוּא֮',
#  'יָעֵל֙',
#  'אֱלִיעֶ֡זֶר',
#  'יְהֹוָ֧ה',
#  'לֵוָיֵ֜',
#  'אָמוֹן֩',
#  'גֹּעָֽתָ',
#  'חֲנַמְאֵ֨ל',
#  'מְּנַשֶּׁ֡ה',
#  'שַׁמְה֣וּת',
#  'פֶּ֧רֶץ',
#  'ישׁוֹחָיָה',
#  'יִתְר֖וֹ',
#  'שַׁלֻּם֙',
#  'מִרְיָ֛ם',
#  'אַבְשָׁלֹ֛ם',
#  'יַעְנַ֥י',
#  'מֵישַׁ֧ךְ',
#  'בַעֲנָ֔ה',
#  'יהֽוֹנָתָ֥ן',
#  'בָּבֶ֔לָ',
#  'יהוֹיָדָ֜ע',
#  'גָּ֞ד',
#  'אָזְנִ֕י',
#  'נֵיבָֽי',
#  'אֲבִישַׁ֨י',
#  'יָרָבְעָ֨ם',
#  'יהוֹיָקִ֨ים',
#  'אֶפְרַיִם֮',
#  'יהוֹשֻׁ֗עַ',
#  'דָּרְיָ֖וֶשׁ',
#  'קְּנִזִּי֙',
#  'בֶּֽרֶכְיָ֑הוּ',
#  'נַּחֲלִיאֵ֖ל',
#  'יְהוֹרָ֡ם',
#  'יַדּ֔וּעַ',
#  'גִּבְעָה֮',
#  'אוּרִיָּ֨ה',
#  'אֲחַזְיָ֛הוּ',
#  'תָֽמַח',
#  'נְצִ֖יחַ',
#  'עֲקָֽן',
#  'פוּאָ֛ה',
#  'בָלָ֧ק',
#  'סְפַרְוַ֔יִם',
#  'עֲנָקִים֙',
#  'אַבְשָׁל֧וֹם',
#  'אַרְדּֽוֹן',
#  'אֲבִימֶ֧לֶךְ',
#  'קַדְמִיאֵ֥ל',
#  'תַעְנַךְ֙',
#  'עַֽלְוָ֖ה',
#  'מַֽעֲכָת֙',
#  'יֽוֹצָדָ֜ק',
#  'בָּרָק֙',
#  'חַשּׁ֛וּב',
#  'אֶלְנָתָ֧ן',
#  'יִרְמְיָ֑ה',
#  'נְבוּכַדְרֶאצַּ֨ר',
#  'עֲשָׂהאֵ֛ל',
#  'כַלְכֹּ֥ל',
#  'פִּרְעָתוֹנִֽי',
#  'אֱמֹרִ֤י',
#  'מְהֵֽיטַבְאֵל֙',
#  'יוֹקִ֞ים',
#  'בַעְשָׁ֛א',
#  'הַגְרִֽים',
#  'יהוֹנָתָן',
#  'שָּׁא֖וּל',
#  'עֲנָ֔ב',
#  'חֲנַנְיָה',
#  'מִיכַל֒',
#  'יֶ֨רֶד',
#  'עַכּ֔וֹ',
#  'אֱלִיחֹ֧רֶף',
#  'דָויִ֔ד',
#  'כַשְׂדָּאָֽ',
#  'יְהֽוֹחָנָן֙',
#  'יִגְדַּלְיָ֖הוּ',
#  'גִּבְעָ֔תָ',
#  'ירֽוּשְׁלֶ֑ם',
#  'כְּנַעַן֒',
#  'שׁ֖וּרָ',
#  'דְּבִ֑יר',
#  'יְכָלְיָ֖הוּ',
#  'בַּעֲשֵׂיָ֖ה',
#  'עֲשָׂהאֵ֜ל',
#  'מִגְדּ֔וֹל',
#  'עֵינַ֔יִם',
#  'נָתָ֧ן',
#  'חֶלְקִֽי',
#  'בַּ֨עַל֙',
#  'צְרוּיָ֑ה',
#  'נְ֠תַנְיָה',
#  'יִתְנָֽן',
#  'עִירִ֜י',
#  'נְתַנְאֵ֡ל',
#  'עַקּֽוּב',
#  'חִירָ֛ה',
#  'פָדֽוֹן',
#  'נְתַנְיָ֤ה',
#  'ירֽוּשָׁלִַ֔ם',
#  'עֲרוֹעֵ֗ר',
#  'חֳרֵ֥ם',
#  'חֲנַנְיָה֙',
#  'גַזָּֽם',
#  'יהוּדָ֤ה',
#  'נ֟וּן',
#  'עֲרוֹעֵ֖ר',
#  'בָּשָׁן֒',
#  'צֵלַ֡ע',
#  'מְעוּנִ֖ים',
#  'אֲדֹנִיָּ֨הוּ֙',
#  'צְרֵדָֽתָ',
#  'דִּימ֖וֹן',
#  'גִּֽילֹנִ֜י',
#  'שַׁלֻּ֖ם',
#  'מִּצְפָּ֔תָ',
#  'תּוֹלָעִ֑י',
#  'נְבֽוּכַדְנֶצַּר֙',
#  'אֲמָנָ֗ה',
#  'לֶ֜שֶׁם',
#  'אֱלִיעֶ֧זֶר',
#  'אֲחִיָּ֗הוּ',
#  'מָכִ֤יר',
#  'טַבּ֣וּר',
#  'בַקְבּ֥וּק',
#  'יַֽעֲק֔וֹב',
#  'יֹ֣אשִׁיָּ֔הוּ',
#  'אֽוּרִיָּ֗ה',
#  'אַדְמָ֣תָא',
#  'חַרְחֽוּר',
#  'אַיָּל֜וֹן',
#  'רָפֽוּא',
#  'מַתַּנְיָה֙',
#  'חֲכִילָ֗ה',
#  'קֵֽלָיָה֙',
#  'בְּנְיָמִ֥ן',
#  'אֶלְיָשִׁ֜יב',
#  'אִֽיתִיאֵ֑ל',
#  'יהוֹשֻׁ֪עַ',
#  'פְנוּאֵ֔ל',
#  'מַֽשׁ',
#  'בָּ֠בֶל',
#  'אַדָּ֖ן',
#  'יְּהוּדִ֗י',
#  'שַׁבְּתַ֥י',
#  'חֶשְׁבּ֧וֹן',
#  'מָרָ֔תָ',
#  'עֲזַרְיָ֔הוּ',
#  'יִּשְׂרָאֵ֜ל',
#  'גָמ֖וּל',
#  'עֲזַרְיָ֨הוּ',
#  'אֲחִימֶ֜לֶךְ',
#  'פְּלִשְׁתִּים',
#  'רָ֣אמַת',
#  'גַ֖חַר',
#  'אֱלִ֨ישָׁמָ֜ע',
#  'צְרִ֡י',
#  'תִּרְשָׁ֜תָא',
#  'שְֽׁמַֽעְיָה֩',
#  'יְ֠הוֹיָקִים',
#  'אֲגַ֖ג',
#  'וָפְסִֽי',
#  'לוּד֙',
#  'גֶּ֥בֶר',
#  'אֲחִיָּ֜הוּ',
#  'זְאֵב֙',
#  'טָֽבְאֵל֙',
#  'ט֣וֹבִיָּ֔ה',
#  'דַבָּ֑שֶׁת',
#  'אֶבְיָתָ֨ר',
#  'נְבוּכַדְנֶצַּ֑ר',
#  'שִֽׁמְעִ֨י',
#  'צָּפ֛וֹן',
#  'גָּלִ֔ילָ',
#  'אַסְפָּֽתָא',
#  'עֶזְרָ֡א',
#  'צִפּ֔וֹר',
#  'ירוּשְׁלֶם֙',
#  'אֹ֖ן',
#  'שִּׁטִּ֗ים',
#  'בְרִיעָה֙',
#  'כְּלוּבָֽי',
#  'צְפַנְיָ֔ה',
#  'שֶּׂ֔כוּ',
#  'פֶּ֥קַח',
#  'ע֨וֹג',
#  'אַרְפַּכְשָׁ֔ד',
#  'רַעַמְסֵֽס',
#  'מַלְאָכִֽי',
#  'עֻזִּיאֵ֤ל',
#  'תּֽוֹגַרְמָ֔ה',
#  'צִיּ֞וֹן',
#  'עַזָּֽן',
#  'מִדְיָנִ֜ים',
#  'מַֽעַזְיָ֥ה',
#  'סְפָרַ֑ד',
#  'שַׂלְמָ֖א',
#  'נָ֣פַת',
#  'אַרְתַּחְשַׁ֖שְׂתְּ',
#  'פִּלְחָ֖א',
#  'יהֻ֥ד',
#  'דַנָּ֥ה',
#  'תִּרְשָׁ֡תָא',
#  'עֵלְמָיֵֽ',
#  'פּ֥וּל',
#  'דָּרְיָ֧וֶשׁ',
#  'קְלִיטָ֔א',
#  'יְהוִ֡ה',
#  'עֶקְרֹנִ֜ים',
#  'יָּ֧ם',
#  'פְּלֵתִ֖י',
#  'עֲנַמֶּ֖לֶךְ',
#  'יהוּדָה֒',
#  'נָב֨וֹת',
#  'וַשְׁתִּי֙',
#  'שִׁלוֹ֙',
#  'אֲרַ֥ב',
#  'כּוּשׁ֮',
#  'פְלִשְׁתִּיִּ֥ים',
#  'עֲנָ֖נִי',
#  'תְחַפְנְחֵס֙',
#  'יְר֣וּשְׁלֶ֔ם',
#  'שִּׁלֹ֗ה',
#  'שָּׁאוּלִֽי',
#  'אֲבִיגַ֣ל',
#  'נְבוּכַדנֶאצַּ֤ר',
#  'צִדְקִיָּ֡הוּ',
#  'רְחֻ֖ם',
#  'יְבוּסִ֥י',
#  'עַשְׁתָּרֹ֑ת',
#  'יְדוּתוּן֙',
#  'קִבְצַ֨יִם֙',
#  'יָ֥הּ',
#  'יֽוֹנָתָן֙',
#  'רְמַלְיָ֤הוּ',
#  'חֵ֤ת',
#  'יַבְנֵ֔ה',
#  'גַּדִּ֖י',
#  'ידַֽעְיָ֔ה',
#  'נְב֑וֹ',
#  'מֹּלֶךְ֒',
#  'אֲבִיגַ֡יִל',
#  'נְבוּכַדְנֶצַּר֒',
#  'מִּצְפָּה֮',
#  'תְּקוֹעִ֑ים',
#  'מִתְרְדָ֣ת',
#  'אֵלִיָּ֛הוּ',
#  'יְּהוּדִ֑ים',
#  'בִנּ֖וּי',
#  'לַ֥יִשׁ',
#  'אֽוּרִיאֵ֤ל',
#  'מָנ֜וֹחַ',
#  'יִשְׁמָעֵ֥אל',
#  'שָׁאוּל֒',
#  'אִבְצָ֖ן',
#  'יוֹזָבָד֙',
#  'אֲמַצְיָ֔ה',
#  'בִּלְהָ֔ה',
#  'תַחְפְּנֵ֔ס',
#  'יוֹרָ֤ם',
#  'כָּנְיָ֔הוּ',
#  'פְּתוּאֵֽל',
#  'שְׁכַנְיָ֔ה',
#  'שְׁלוֹמִ֖ית',
#  'גִלְעָ֛ד',
#  'מוֹאָ֧ב',
#  'הָרָרִ֑י',
#  'נִבְחַ֖ז',
#  'דָוִ֞יד',
#  'דַרְק֖וֹן',
#  'גִּדְעוֹנִֽי',
#  'דָּֽנִיֵּ֜אל',
#  'אֲחִיקָ֑ם',
#  'מַכְבֵּנָ֖ה',
#  'נְחֶמְיָ֧ה',
#  'אֲבִיה֛וּא',
#  'דִשׁ֥וֹן',
#  'צִלָּה֙',
#  'כַבּ֥וֹן',
#  'יְחִיאֵ֑ל',
#  'יָגְלִֽי',
#  'שֻּׁ֣תַלְחִ֔י',
#  'עֲמֹרָה֙',
#  'מִיכָ֣יְהוּ',
#  'יְרִיח֜וֹ',
#  'יִשָּׂשכָ֤ר',
#  'אַרְכְּוָיֵ֤',
#  'בְּנָיָ֣הוּ',
#  'שַׂלְמָֽה',
#  'עֻזִיָּ֖א',
#  'פ֔וּל',
#  'אַבְרָהָם֩',
#  'צִקְלַ֖ג',
#  'רֶ֔סֶן',
#  'מְרָרִי֒',
#  'עֻזִּיאֵל',
#  'צִידֹנִ֗ים',
#  'יְה֖וּד',
#  'עַיָּ֖ה',
#  'נַחֲלִיאֵ֑ל',
#  'יְבֻסִ֖י',
#  'בִּנְיָמִ֑ין',
#  'גַּ֣ת',
#  'שָׁ֑מֶד',
#  'אַמְצִ֣י',
#  'בָלָ֤ק',
#  'חוּקֹ֑קָ',
#  'מְּכֵ֣רָתִ֔י',
#  'עֲשִׂיאֵֽל',
#  'בִּנּ֖וּי',
#  'יְּהוּדִ֨ים',
#  'שְׁחַרְיָ֖ה',
#  'אֲחִיָּה֙',
#  'נְחֶמְיָ֗ה',
#  'אֲדֹנִיקָם֮',
#  'נְצִֽיב',
#  'אֱלִיָּ֔תָה',
#  'יְחִזְקִיָּ֡הוּ',
#  'נָּהָ֣ר',
#  'יְּהוּדִים֩',
#  'בְנָיָ֡הוּ',
#  'סַלּוּא֙',
#  'י֠וֹסֵף',
#  'אַשְׁקְל֗וֹן',
#  'זּוּזִ֖ים',
#  'כִּסְלֽוֹן',
#  'מָנ֤וֹחַ',
#  'זִ֗ו',
#  'צָפֹ֣נָ',
#  'מַּכְפֵּלָה֙',
#  'פִינְחָס',
#  'אָשֵׁ֜ר',
#  'תַּרְתָּ֑ק',
#  'צְלָפְחָד֮',
#  'יָבִ֗ין',
#  'יְהוִה֮',
#  'עָנִֽים',
#  'אֱלִיה֛וּא',
#  'תִּרְצָ֔ה',
#  'יְרֽוּשָׁלִַם֮',
#  'יָל֑וֹן',
#  'חֲתַֽת',
#  'שִּׁלֹנִֽי',
#  'זִיזָ֖ה',
#  'מְּדָנִ֔ים',
#  'פָֽרַס',
#  'מִֽיכָאֵ֜ל',
#  'שַׁלֻּ֔ם',
#  'שׁוּשָׁ֖ן',
#  'נְבֻכַדְנֶאצַּ֣ר',
#  'צִיעֹ֑ר',
#  'אֲחַזְיָ֜הוּ',
#  'מְהוּמָן',
#  'אֶלְיוֹעֵינַ֗י',
#  'מַכְנַדְבַ֥י',
#  'יְרַחְמְאֵ֑ל',
#  'יוֹרָם֩',
#  'מָכִיר֩',
#  'בָּלָ֥ק',
#  'תֵּמָ֑א',
#  'אַׄהֲׄרֹ֛ׄןׄ',
#  'מִֽיכָאֵ֑ל',
#  'אֲחִיט֜וּב',
#  'עַתְלָֽי',
#  'עֲזַרְיָהוּ֩',
#  'סְדֹ֜ם',
#  'שְׁמַעְיָה',
#  'הֵגַ֖י',
#  'בֵסַ֥י',
#  'סִֽיסְרָא֩',
#  'תֵּֽימָנִ֗י',
#  'צֹ֜ר',
#  'זְבוּב֮',
#  'חָצֹ֥ר',
#  'שָּׂטָן֙',
#  'יְדִידָ֥ה',
#  'לָכִ֨ישָׁ',
#  'נְבָ֨ט',
#  'הֵשִׁ֨יב',
#  'מְעוֹנֹתַ֖י',
#  'טְּלָאִ֔ים',
#  'עַ֗יִשׁ',
#  'אֲדֹ֨נִיָּ֧הוּ',
#  'שָׁוֵ֔ה',
#  'בִזְיוֹתְיָֽה',
#  'אֲחִיָּ֗ה',
#  'מִכָ֔יְהוּ',
#  'גָּדִ֖י',
#  'סֶ֣לֶד',
#  'גִּבְעֹנִ֞ים',
#  'צִידֹ֥ן',
#  'יְהוִ֤הּ',
#  'הוֹשָׁמָ֖ע',
#  'הָ֑ם',
#  'אַיָּ֑ה',
#  'עַמּוֹנִ֛ים',
#  'בִּנְיָמִין֒',
#  'קַּדְמוֹנִ֔י',
#  'כִּנֶּ֗רֶת',
#  'שְׁמוּאֵל֒',
#  'גֶ֨שֶׁם',
#  'אֲבִיהוּא֙',
#  'יוֹאָחָ֣ז',
#  'נְטָעִ֖ים',
#  'עֶקְרוֹן֒',
#  'פָּ֑עִי',
#  'בְּעֶשְׁתְּרָ֖ה',
#  'שָׁרָ֖ר',
#  'בְרִיעָ֑ה',
#  'עַשְׁתֹּרֶת֮',
#  'מְ֠נַחֵם',
#  'מַתִּתְיָ֜הוּ',
#  'יַעֲקוֹב֩',
#  'רֵ֠כָב',
#  'עֵרִֽי',
#  'יִ֠שְׁמָעֵאל',
#  'אָבִֽיב',
#  'יִשְׁפָּ֥ן',
#  'גָֽחַר',
#  'עֶפְרֹ֔ן',
#  'עֲמָשַׂ֞י',
#  'עַדְנָ֣ה',
#  'יִדְאֲלָ֖ה',
#  'גֵּבִ֖ים',
#  'סֶֽנֶּה',
#  'חֲנַמְאֵ֣ל',
#  'אֲחַשְׁוֵרֹ֔שׁ',
#  'קִישִׁ֔י',
#  'אֲחִימֶ֑לֶךְ',
#  'מַרְסְנָ֖א',
#  'שִׁמְרָ֖ת',
#  'חוּקֹק֙',
#  'אֶלְקָנָ֨ה',
#  'יֽוֹרָם',
#  'עֲנָת֑וֹת',
#  'בְנָיָהוּ֩',
#  'יְכָנְיָ֣הוּ',
#  'עַזּ֨וּר',
#  'לַעְדָּ֖ה',
#  'יַעֲק֗וֹב',
#  'צָּפוֹן֮',
#  'יְהוֹאָ֤שׁ',
#  'עֶפְרַ֖יִן',
#  'סַלּ֣וּ',
#  'חֹרֵב֙',
#  'דָנִיֵּ֤אל',
#  'יְהוּדָיֵ֔',
#  'סֶ֖לֶד',
#  'יִזִּיָּ֤ה',
#  'מוּשִׁ֗י',
#  'מְשֻׁלֶּ֥מֶת',
#  'כּוּשִׁ֑י',
#  'בֵּֽרֹתַ֖י',
#  'נַעֲמָ֣ן',
#  'יְהֹוִ֔ה',
#  'יֹֽ֠אשִׁיָּהוּ',
#  'יָבֵ֔שָׁ',
#  'זָבָ֣ד',
#  'זְבִינָ֔א',
#  'עַי֮',
#  'שָׂטָ֖ן',
#  'יְהוֹשׁ֔וּעַ',
#  'יְהוֹנָתָ֧ן',
#  'חַגִּ֑י',
#  'עֲטָר֣וֹת',
#  'נְטֹפָ֖ה',
#  'דְּלִילָה֩',
#  'יֽוֹאָחָז֙',
#  'גִלְעָ֑ד',
#  'חַלְח֥וּל',
#  'צ֕וֹר',
#  'עֻזִּיָּ֗הוּ',
#  'חִלְקִיָּ֖הוּ',
#  'יְהוֹצָדָק֙',
#  'גִלְעָדִ֑ים',
#  'בִּכְרִי֙',
#  'בְּעָלִ֑ים',
#  'אֱד֨וֹם',
#  'הַרְמ֖וֹנָ',
#  'פּ֣וּל',
#  'רִמּוֹן֩',
#  'עַמּוֹנִ֑י',
#  'עַזְרִיאֵ֗ל',
#  'בִנְיָמִ֧ן',
#  'יִּזְרְעֶ֗אל',
#  'יְרוּשְׁלֶֽם',
#  ...]

# %%
df[df['source'] == 'judith']
# Out:
#        Unnamed: 0  source    target  align_count  word score  verse score  \
# 48917       48917  judith  אִשָּׁה֙            1    0.333115     0.380322
# 48918       48918  judith  יִּקַּ֤ח            1    0.332959     0.380322
#
#       normalized_source normalized_target  jac_sim  match_counts  total_score
# 48917            judith               אשה     -1.0             0         -0.0
# 48918            judith               יקח     -1.0             0         -0.0

# %%
bible_df[bible_df['text'] == 'יְהוּדִ֔ית']
# Out:
#        book  chapter  verse  word  subword             id          marble  \
# 15003   GEN       26     34     9        1  o010260340091  00102603400022
# 231296  2KI       18     26    21        1  o120180260211  01201802600048
# 366489  ISA       36     11    19        1  o230360110191  02303601100044
#
#        ot-nt     unicode        text lemma normalized            english  \
# 15003     OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None             Judith
# 231296    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None          in Hebrew
# 366489    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3066       None  language of Judah
#
#             greek      hebrew mandarin domain_codes               domains  \
# 15003      ιουδιν  יְהוּדִ֔ית       犹滴  [003001007]     [Names of People]
# 231296  ιουδαϊστί  יְהוּדִ֔ית    用希伯来语  [003001009]  [Names of Languages]
# 366489  ιουδαϊστί  יְהוּדִ֔ית      犹大语  [003001009]  [Names of Languages]
#
#                sdbh_codes top_domains
# 15003   [002822001001000]    [003001]
# 231296  [002820001001000]    [003001]
# 366489  [002820001001000]    [003001]

# %%
df[df['normalized_target'] == 'יהודית']
# Out:
#        Unnamed: 0  source      target  align_count  word score  verse score  \
# 10354       10354   beeri  יְהוּדִ֔ית            1    0.195174     0.380322
# 48762       48762  judean  יְהוּדִ֑ית            2    0.570450     0.319680
# 48763       48763  judean  יְהוּדִ֔ית            2    0.523498     0.333000
#
#       normalized_source normalized_target   jac_sim  match_counts  total_score
# 10354             beeri            יהודית  0.125000             1     0.009279
# 48762            judean            יהודית  0.571429             4     0.416827
# 48763            judean            יהודית  0.571429             4     0.398457

# %%
bible_df[bible_df['english'] == 'Judith']
# Out:
#       book  chapter  verse  word  subword             id          marble  \
# 15003  GEN       26     34     9        1  o010260340091  00102603400022
#
#       ot-nt     unicode        text lemma normalized english   greek  \
# 15003    OT  יְהוּדִ֔ית  יְהוּדִ֔ית  3067       None  Judith  ιουδιν
#
#            hebrew mandarin domain_codes            domains         sdbh_codes  \
# 15003  יְהוּדִ֔ית       犹滴  [003001007]  [Names of People]  [002822001001000]
#
#       top_domains
# 15003    [003001]

# %%
normalize_word('יְהוּדִ֔ית')
# Out:
# 'יהודית'

# %%
old_matched_names = matched_names
