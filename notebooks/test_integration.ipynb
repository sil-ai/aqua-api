# %%
import requests
import sys, os
from dotenv import load_dotenv
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
from security_routes.utilities import hash_password
from pathlib import Path

# %% [markdown]
# ## Base URL
#
# You can run this notebook locally, on main runner, or development runner, please uncomment the one you are going to use, and comment the other base url's

# %%
# Main runner
# base_url = "https://tmv9bz5v4q.us-east-1.awsapprunner.com/"
# Development runner
# base_url = "https://cp3by92k8p.us-east-1.awsapprunner.com/"
# Local
base_url = "http://localhost:8000/"
prefix = "latest"

# %%
hash_password("password")
# Out:
# '$2b$12$3R1S0A5NPWbe5vm8Kb5hQ.AFxC92m42wYjOa60ZczCuFep08E0eFG'

# %%
load_dotenv("../.env", override=True)
# Out:
# True

# %%
# adminpassword = os.getenv("ADMIN_PASSWORD")
user = os.getenv("ADMIN_USER_TEST")
# user = os.getenv("TEST_USER")
# adminpassword = os.getenv("TEST_PASSWORD")
adminpassword = os.getenv("ADMIN_PASSWORD_TEST")
adminpassword is not None
# Out:
# True

# %%
response = requests.post(
    f"{base_url}{prefix}/token", data={"username": user, "password": adminpassword}
)
admin_token = response.json()["access_token"]

# %%
len(admin_token)
# Out:
# 145

# %% [markdown]
# #### get scripts

# %%
response = requests.get(
    base_url+f"{prefix}/language",
    headers={"Authorization": f"Bearer {admin_token}"},
)

response = response.json()
print(response)
# Out:
# [{'iso639': 'aaa', 'name': 'Ghotuo'}, {'iso639': 'aab', 'name': 'Alumu-Tesu'}, {'iso639': 'aac', 'name': 'Ari'}, {'iso639': 'aad', 'name': 'Amal'}, {'iso639': 'aae', 'name': 'Arbëreshë Albanian'}, {'iso639': 'aaf', 'name': 'Aranadan'}, {'iso639': 'aag', 'name': 'Ambrak'}, {'iso639': 'aah', 'name': "Abu' Arapesh"}, {'iso639': 'aai', 'name': 'Arifama-Miniafia'}, {'iso639': 'aak', 'name': 'Ankave'}, {'iso639': 'aal', 'name': 'Afade'}, {'iso639': 'aan', 'name': 'Anambé'}, {'iso639': 'aao', 'name': 'Algerian Saharan Arabic'}, {'iso639': 'aap', 'name': 'Pará Arára'}, {'iso639': 'aaq', 'name': 'Eastern Abnaki'}, {'iso639': 'aar', 'name': 'Afar'}, {'iso639': 'aas', 'name': 'Aasáx'}, {'iso639': 'aat', 'name': 'Arvanitika Albanian'}, {'iso639': 'aau', 'name': 'Abau'}, {'iso639': 'aaw', 'name': 'Solong'}, {'iso639': 'aax', 'name': 'Mandobo Atas'}, {'iso639': 'aaz', 'name': 'Amarasi'}, {'iso639': 'aba', 'name': 'Abé'}, {'iso639': 'abb', 'name': 'Bankon'}, {'iso639': 'abc', 'name': 'Ambala Ayta'}, {'iso639': 'abd', 'name': 'Manide'}, {'iso639': 'abe', 'name': 'Western Abnaki'}, {'iso639': 'abf', 'name': 'Abai Sungai'}, {'iso639': 'abg', 'name': 'Abaga'}, {'iso639': 'abh', 'name': 'Tajiki Arabic'}, {'iso639': 'abi', 'name': 'Abidji'}, {'iso639': 'abj', 'name': 'Aka-Bea'}, {'iso639': 'abk', 'name': 'Abkhazian'}, {'iso639': 'abl', 'name': 'Lampung Nyo'}, {
# %% [markdown]
# #### Post Revisions

# %%
new_version_data = {
    "name": "Cassie's Test Version Feb 24",
    "iso_language": "eng",
    "iso_script": "Latn",
    "abbreviation": "NV",
    "rights": "Some Rights",
    "machineTranslation": False,
    "is_reference": True,
}

response = requests.post(
    base_url+f"{prefix}/version",
    json=new_version_data,
    headers={"Authorization": f"Bearer {admin_token}"},
)
version_id =response.json()["id"]
response.json()
# Out:
# {'id': 2,
#  'name': "Cassie's Test Version Feb 24",
#  'iso_language': 'eng',
#  'iso_script': 'Latn',
#  'abbreviation': 'NV',
#  'rights': 'Some Rights',
#  'forward_translation_id': None,
#  'back_translation_id': None,
#  'machineTranslation': False,
#  'owner_id': 3,
#  'group_ids': [],
#  'is_reference': True}

# %%
test_revision = {
    "version_id": version_id,
    "name": "Test Revision Cassie Feb 24",
}
test_upload_file = Path("../fixtures/uploadtest.txt")

with open(test_upload_file, "rb") as file:
    files = {"file": file}
    response = requests.post(
    base_url + f"{prefix}/revision", params=test_revision, files=files, 
    headers={"Authorization": f"Bearer {admin_token}"}
    )
revision_id =response.json()["id"]
response.json()
# Out:
# {'id': 2,
#  'bible_version_id': 2,
#  'version_abbreviation': 'NV',
#  'date': '2025-02-25',
#  'name': 'Test Revision Cassie Feb 24',
#  'published': False,
#  'back_translation_id': None,
#  'machineTranslation': False,
#  'iso_language': 'eng',
#  'is_reference': False}

# %% [markdown]
# #### Pull revisions

# %%
response = requests.get(
    f"{base_url}{prefix}/revision",
    headers={"Authorization": f"Bearer {admin_token}"},
)

response.json()
# Out:
# [{'id': 1,
#   'bible_version_id': 1,
#   'version_abbreviation': 'BLTEST',
#   'date': '2025-02-25',
#   'name': None,
#   'published': False,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'iso_language': 'eng',
#   'is_reference': False},
#  {'id': 2,
#   'bible_version_id': 2,
#   'version_abbreviation': 'NV',
#   'date': '2025-02-25',
#   'name': 'Test Revision Cassie Feb 24',
#   'published': False,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'iso_language': 'eng',
#   'is_reference': False}]

# %% [markdown]
# #### Post assessment

# %%
response = requests.post(
    base_url+"latest/token", data={"username": user, "password": adminpassword}
)
admin_token = response.json()["access_token"]

rev_revision_id = 2626
ref_revision_id = 112

assessment_params = {
    "revision_id": rev_revision_id,
    "reference_id": ref_revision_id,
    "type": "semantic-similarity",
}

response = requests.post(
    f"{base_url}{prefix}/assessment",
    headers={"Authorization": f"Bearer {admin_token}"},
    params = assessment_params
)
response.json()
# Out:
# [{'id': 4274,
#   'revision_id': 2626,
#   'reference_id': 112,
#   'type': 'semantic-similarity',
#   'status': 'queued',
#   'requested_time': '2025-02-25T16:09:00.279628',
#   'start_time': None,
#   'end_time': None,
#   'owner_id': 115}]

# %% [markdown]
# #### Pull assessment results

# %%
response = requests.get(
    f"{base_url}{prefix}/assessment",
    headers={"Authorization": f"Bearer {admin_token}"},
)

response.json()
# Out:
# [{'id': 4274,
#   'revision_id': 2626,
#   'reference_id': 112,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02

#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-25T01:45:24.582882',
#   'start_time': '2025-02-25T01:45:29.919250',
#   'end_time': '2025-02-25T02:52:48.887369',
#   'owner_id': 213},
#  {'id': 4259,
#   'revision_id': 2665,
#   'reference_id': 1999,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T22:32:56.989108',
#   'start_time': '2025-02-24T22:33:00.950920',
#   'end_time': '2025-02-24T23:17:40.884287',
#   'owner_id': 467},
#  {'id': 4258,
#   'revision_id': 2619,
#   'reference_id': 1052,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:23:56.041840',
#   'start_time': '2025-02-24T21:23:57.983340',
#   'end_time': '2025-02-24T22:17:44.635853',
#   'owner_id': 213},
#  {'id': 4257,
#   'revision_id': 2619,
#   'reference_id': 1052,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:23:52.361945',
#   'start_time': '2025-02-24T21:23:57.762271',
#   'end_time': '2025-02-24T21:31:04.102475',
#   'owner_id': 213},
#  {'id': 4256,
#   'revision_id': 66,
#   'reference_id': 1052,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:19:16.301728',
#   'start_time': '2025-02-24T21:19:21.265007',
#   'end_time': '2025-02-24T21:24:12.201383',
#   'owner_id': 213},
#  {'id': 4255,
#   'revision_id': 101,
#   'reference_id': 1052,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:19:16.194250',
#   'start_time': '2025-02-24T21:19:20.483253',
#   'end_time': '2025-02-24T21:24:47.575242',
#   'owner_id': 213},
#  {'id': 4254,
#   'revision_id': 160,
#   'reference_id': 1052,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:19:13.892844',
#   'start_time': '2025-02-24T21:19:19.342061',
#   'end_time': '2025-02-24T21:37:50.543712',
#   'owner_id': 213},
#  {'id': 4253,
#   'revision_id': 16,
#   'reference_id': 1052,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:19:13.883607',
#   'start_time': '2025-02-24T21:19:18.971177',
#   'end_time': '2025-02-24T21:25:11.764191',
#   'owner_id': 213},
#  {'id': 4252,
#   'revision_id': 2664,
#   'reference_id': 160,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T21:16:53.819577',
#   'start_time': '2025-02-24T21:16:58.343695',
#   'end_time': '2025-02-24T23:12:54.202528',
#   'owner_id': 213},
#  {'id': 4251,
#   'revision_id': 2665,
#   'reference_id': 159,
#   'type': 'semantic-similarity',
#   'status': 'failed',
#   'requested_time': '2025-02-24T20:51:29.514240',
#   'start_time': '2025-02-24T20:51:32.496313',
#   'end_time': '2025-02-24T22:19:27.063716',
#   'owner_id': 213},
#  {'id': 4250,
#   'revision_id': 2665,
#   'reference_id': 159,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:51:26.650408',
#   'start_time': '2025-02-24T20:51:30.679548',
#   'end_time': '2025-02-24T21:09:28.875008',
#   'owner_id': 213},
#  {'id': 4249,
#   'revision_id': 2665,
#   'reference_id': 1999,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:40:18.514671',
#   'start_time': '2025-02-24T20:40:22.901077',
#   'end_time': '2025-02-24T20:44:04.973300',
#   'owner_id': 466},
#  {'id': 4248,
#   'revision_id': 2665,
#   'reference_id': 1999,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:40:18.368189',
#   'start_time': '2025-02-24T20:40:22.153434',
#   'end_time': '2025-02-24T20:44:12.282325',
#   'owner_id': 467},
#  {'id': 4247,
#   'revision_id': 2665,
#   'reference_id': 1999,
#   'type': 'semantic-similarity',
#   'status': 'failed',
#   'requested_time': '2025-02-24T20:40:17.475267',
#   'start_time': '2025-02-24T20:40:21.943957',
#   'end_time': '2025-02-24T22:22:39.123830',
#   'owner_id': 467},
#  {'id': 4246,
#   'revision_id': 2665,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:40:16.680832',
#   'start_time': '2025-02-24T20:40:21.420459',
#   'end_time': '2025-02-24T21:02:25.725954',
#   'owner_id': 467},
#  {'id': 4245,
#   'revision_id': 1998,
#   'reference_id': 1999,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:32.977899',
#   'start_time': '2025-02-24T20:34:36.224457',
#   'end_time': '2025-02-24T21:38:10.041454',
#   'owner_id': 466},
#  {'id': 4244,
#   'revision_id': 1999,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:32.726519',
#   'start_time': '2025-02-24T20:34:35.496227',
#   'end_time': '2025-02-24T20:49:01.335947',
#   'owner_id': 466},
#  {'id': 4243,
#   'revision_id': 1592,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:31.849798',
#   'start_time': '2025-02-24T20:34:34.049136',
#   'end_time': '2025-02-24T20:54:04.037375',
#   'owner_id': 466},
#  {'id': 4242,
#   'revision_id': 1591,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:31.031056',
#   'start_time': '2025-02-24T20:34:33.183482',
#   'end_time': '2025-02-24T20:54:03.040092',
#   'owner_id': 466},
#  {'id': 4241,
#   'revision_id': 221,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:29.821084',
#   'start_time': '2025-02-24T20:34:32.812870',
#   'end_time': '2025-02-24T20:49:38.118298',
#   'owner_id': 466},
#  {'id': 4240,
#   'revision_id': 128,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:28.865235',
#   'start_time': '2025-02-24T20:34:31.974555',
#   'end_time': '2025-02-24T20:54:03.342876',
#   'owner_id': 466},
#  {'id': 4239,
#   'revision_id': 225,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:28.011138',
#   'start_time': '2025-02-24T20:34:30.518592',
#   'end_time': '2025-02-24T20:48:56.329085',
#   'owner_id': 466},
#  {'id': 4238,
#   'revision_id': 306,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:27.094320',
#   'start_time': '2025-02-24T20:34:29.667323',
#   'end_time': '2025-02-24T20:40:18.792327',
#   'owner_id': 466},
#  {'id': 4237,
#   'revision_id': 1998,
#   'reference_id': 1999,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:34:23.352009',
#   'start_time': '2025-02-24T20:34:27.964650',
#   'end_time': '2025-02-24T20:41:27.040004',
#   'owner_id': 466},
#  {'id': 4236,
#   'revision_id': 141,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:29:00.688062',
#   'start_time': '2025-02-24T20:29:07.031815',
#   'end_time': '2025-02-24T20:35:49.350248',
#   'owner_id': 427},
#  {'id': 4235,
#   'revision_id': 2147,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:29:00.253092',
#   'start_time': '2025-02-24T20:29:05.748117',
#   'end_time': '2025-02-24T20:35:07.978638',
#   'owner_id': 427},
#  {'id': 4234,
#   'revision_id': 1558,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:29:00.103211',
#   'start_time': '2025-02-24T20:29:05.300928',
#   'end_time': '2025-02-24T20:35:06.633826',
#   'owner_id': 427},
#  {'id': 4233,
#   'revision_id': 229,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:28:59.870246',
#   'start_time': '2025-02-24T20:29:04.207466',
#   'end_time': '2025-02-24T20:35:06.588595',
#   'owner_id': 427},
#  {'id': 4232,
#   'revision_id': 20,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:28:57.922091',
#   'start_time': '2025-02-24T20:29:03.179992',
#   'end_time': '2025-02-24T20:36:13.952215',
#   'owner_id': 427},
#  {'id': 4231,
#   'revision_id': 227,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:28:57.916835',
#   'start_time': '2025-02-24T20:29:02.929033',
#   'end_time': '2025-02-24T20:31:23.089903',
#   'owner_id': 427},
#  {'id': 4230,
#   'revision_id': 306,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:28:57.735607',
#   'start_time': '2025-02-24T20:29:02.384286',
#   'end_time': '2025-02-24T20:34:27.519087',
#   'owner_id': 427},
#  {'id': 4229,
#   'revision_id': 2630,
#   'reference_id': 2658,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:28:57.430902',
#   'start_time': '2025-02-24T20:28:59.571596',
#   'end_time': '2025-02-24T20:35:09.803042',
#   'owner_id': 427},
#  {'id': 4228,
#   'revision_id': 1998,
#   'reference_id': 16,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:13.641770',
#   'start_time': '2025-02-24T20:23:16.652502',
#   'end_time': '2025-02-24T20:25:52.710211',
#   'owner_id': 467},
#  {'id': 4227,
#   'revision_id': 1998,
#   'reference_id': 16,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:12.579105',
#   'start_time': '2025-02-24T20:23:16.295031',
#   'end_time': '2025-02-24T21:24:13.176589',
#   'owner_id': 466},
#  {'id': 4226,
#   'revision_id': 1998,
#   'reference_id': 16,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:12.394609',
#   'start_time': '2025-02-24T20:23:16.225280',
#   'end_time': '2025-02-24T21:37:11.276128',
#   'owner_id': 467},
#  {'id': 4225,
#   'revision_id': 1999,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:11.077423',
#   'start_time': '2025-02-24T20:23:15.737447',
#   'end_time': '2025-02-24T20:27:52.900200',
#   'owner_id': 466},
#  {'id': 4224,
#   'revision_id': 225,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:10.942672',
#   'start_time': '2025-02-24T20:23:15.347079',
#   'end_time': '2025-02-24T20:25:00.820213',
#   'owner_id': 466},
#  {'id': 4223,
#   'revision_id': 1999,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:10.676076',
#   'start_time': '2025-02-24T20:23:15.146874',
#   'end_time': '2025-02-24T20:27:53.000213',
#   'owner_id': 467},
#  {'id': 4222,
#   'revision_id': 225,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:08.668276',
#   'start_time': '2025-02-24T20:23:14.568221',
#   'end_time': '2025-02-24T20:25:00.425605',
#   'owner_id': 467},
#  {'id': 4221,
#   'revision_id': 221,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:08.667348',
#   'start_time': '2025-02-24T20:23:14.562027',
#   'end_time': '2025-02-24T20:25:00.689273',
#   'owner_id': 467},
#  {'id': 4220,
#   'revision_id': 1591,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:08.623645',
#   'start_time': '2025-02-24T20:23:14.592854',
#   'end_time': '2025-02-24T20:28:47.753346',
#   'owner_id': 467},
#  {'id': 4219,
#   'revision_id': 1998,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T20:23:08.386802',
#   'start_time': '2025-02-24T20:23:13.915945',
#   'end_time': '2025-02-24T20:29:48.811896',
#   'owner_id': 467},
#  {'id': 4218,
#   'revision_id': 160,
#   'reference_id': 159,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:55:48.761914',
#   'start_time': '2025-02-24T19:55:56.183811',
#   'end_time': '2025-02-24T20:14:19.573167',
#   'owner_id': 213},
#  {'id': 4217,
#   'revision_id': 150,
#   'reference_id': 159,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:55:48.760335',
#   'start_time': '2025-02-24T19:55:54.880264',
#   'end_time': '2025-02-24T20:14:21.922239',
#   'owner_id': 213},
#  {'id': 4216,
#   'revision_id': 101,
#   'reference_id': 159,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:55:48.738288',
#   'start_time': '2025-02-24T19:55:53.491052',
#   'end_time': '2025-02-24T20:02:59.087946',
#   'owner_id': 213},
#  {'id': 4215,
#   'revision_id': 16,
#   'reference_id': 159,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:55:48.539843',
#   'start_time': '2025-02-24T19:55:53.460457',
#   'end_time': '2025-02-24T20:03:29.218469',
#   'owner_id': 213},
#  {'id': 4214,
#   'revision_id': 2664,
#   'reference_id': 221,
#   'type': 'semantic-similarity',
#   'status': 'failed',
#   'requested_time': '2025-02-24T19:03:51.955555',
#   'start_time': '2025-02-24T19:03:55.104550',
#   'end_time': '2025-02-24T20:24:02.775326',
#   'owner_id': 213},
#  {'id': 4213,
#   'revision_id': 2664,
#   'reference_id': 221,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:03:50.727655',
#   'start_time': '2025-02-24T19:03:54.050842',
#   'end_time': '2025-02-24T19:17:07.311204',
#   'owner_id': 213},
#  {'id': 4212,
#   'revision_id': 2664,
#   'reference_id': 160,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:02:55.624969',
#   'start_time': '2025-02-24T19:02:58.823246',
#   'end_time': '2025-02-24T19:10:34.853823',
#   'owner_id': 213},
#  {'id': 4211,
#   'revision_id': 2664,
#   'reference_id': 160,
#   'type': 'semantic-similarity',
#   'status': 'failed',
#   'requested_time': '2025-02-24T19:02:54.550129',
#   'start_time': '2025-02-24T19:30:45.018369',
#   'end_time': '2025-02-24T21:06:33.871380',
#   'owner_id': 213},
#  {'id': 4210,
#   'revision_id': 2664,
#   'reference_id': 160,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-24T19:02:53.425619',
#   'start_time': '2025-02-24T19:02:57.914599',
#   'end_time': '2025-02-24T19:24:06.227799',
#   'owner_id': 213},
#  {'id': 4209,
#   'revision_id': 147,
#   'reference_id': 141,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:52:17.093815',
#   'start_time': '2025-02-21T19:52:19.565404',
#   'end_time': '2025-02-21T19:57:57.281571',
#   'owner_id': 201},
#  {'id': 4208,
#   'revision_id': 146,
#   'reference_id': 141,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:52:16.234125',
#   'start_time': '2025-02-21T19:52:18.982714',
#   'end_time': '2025-02-21T20:09:48.436462',
#   'owner_id': 201},
#  {'id': 4207,
#   'revision_id': 144,
#   'reference_id': 141,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:52:16.065493',
#   'start_time': '2025-02-21T19:52:18.429780',
#   'end_time': '2025-02-21T19:58:03.143817',
#   'owner_id': 201},
#  {'id': 4206,
#   'revision_id': 228,
#   'reference_id': 141,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:52:12.444806',
#   'start_time': '2025-02-21T19:52:18.195825',
#   'end_time': '2025-02-21T20:12:10.191086',
#   'owner_id': 201},
#  {'id': 4205,
#   'revision_id': 145,
#   'reference_id': 141,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:52:12.433748',
#   'start_time': '2025-02-21T19:52:17.949144',
#   'end_time': '2025-02-21T19:58:40.309393',
#   'owner_id': 201},
#  {'id': 4204,
#   'revision_id': 1999,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:45.400461',
#   'start_time': '2025-02-21T19:12:49.720526',
#   'end_time': '2025-02-21T19:18:44.948223',
#   'owner_id': 387},
#  {'id': 4203,
#   'revision_id': 1998,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:45.245659',
#   'start_time': '2025-02-21T19:12:50.828236',
#   'end_time': '2025-02-21T19:19:30.856216',
#   'owner_id': 387},
#  {'id': 4202,
#   'revision_id': 126,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:42.603589',
#   'start_time': '2025-02-21T19:12:47.563392',
#   'end_time': '2025-02-21T19:18:18.809486',
#   'owner_id': 387},
#  {'id': 4201,
#   'revision_id': 128,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:42.601069',
#   'start_time': '2025-02-21T19:12:48.571627',
#   'end_time': '2025-02-21T19:19:09.988406',
#   'owner_id': 387},
#  {'id': 4200,
#   'revision_id': 129,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:42.575976',
#   'start_time': '2025-02-21T19:12:47.941417',
#   'end_time': '2025-02-21T19:17:34.890390',
#   'owner_id': 387},
#  {'id': 4199,
#   'revision_id': 2663,
#   'reference_id': 2662,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T19:12:42.420501',
#   'start_time': '2025-02-21T19:12:47.195565',
#   'end_time': '2025-02-21T19:18:10.169529',
#   'owner_id': 387},
#  {'id': 4198,
#   'revision_id': 2087,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:52.785624',
#   'start_time': '2025-02-21T18:06:58.660346',
#   'end_time': '2025-02-21T18:13:59.416806',
#   'owner_id': 207},
#  {'id': 4197,
#   'revision_id': 2067,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:52.477738',
#   'start_time': '2025-02-21T18:06:58.568998',
#   'end_time': '2025-02-21T18:16:37.376364',
#   'owner_id': 207},
#  {'id': 4196,
#   'revision_id': 2069,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:52.346444',
#   'start_time': '2025-02-21T18:06:57.536202',
#   'end_time': '2025-02-21T18:14:25.848070',
#   'owner_id': 207},
#  {'id': 4195,
#   'revision_id': 2065,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:52.243967',
#   'start_time': '2025-02-21T18:06:56.402360',
#   'end_time': '2025-02-21T18:14:16.337384',
#   'owner_id': 207},
#  {'id': 4194,
#   'revision_id': 2063,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:52.198871',
#   'start_time': '2025-02-21T18:06:55.888290',
#   'end_time': '2025-02-21T18:14:25.572304',
#   'owner_id': 207},
#  {'id': 4193,
#   'revision_id': 2059,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:49.925913',
#   'start_time': '2025-02-21T18:06:55.612175',
#   'end_time': '2025-02-21T18:14:26.020308',
#   'owner_id': 207},
#  {'id': 4192,
#   'revision_id': 2062,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:49.912070',
#   'start_time': '2025-02-21T18:06:55.566016',
#   'end_time': '2025-02-21T18:14:25.517931',
#   'owner_id': 207},
#  {'id': 4191,
#   'revision_id': 95,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:49.791805',
#   'start_time': '2025-02-21T18:06:55.099295',
#   'end_time': '2025-02-21T18:14:25.756679',
#   'owner_id': 207},
#  {'id': 4190,
#   'revision_id': 2084,
#   'reference_id': 1053,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T18:06:49.785901',
#   'start_time': '2025-02-21T18:06:54.432057',
#   'end_time': '2025-02-21T18:14:25.589659',
#   'owner_id': 207},
#  {'id': 4189,
#   'revision_id': 2084,
#   'reference_id': 1053,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2025-02

#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-21T00:08:07.755680',
#   'start_time': '2025-02-21T00:08:14.216898',
#   'end_time': '2025-02-21T00:13:02.653683',
#   'owner_id': 115},
#  {'id': 4173,
#   'revision_id': 2660,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:45:49.422291',
#   'start_time': '2025-02-20T21:45:52.122692',
#   'end_time': '2025-02-20T21:50:17.751300',
#   'owner_id': 197},
#  {'id': 4172,
#   'revision_id': 1998,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:17.882584',
#   'start_time': '2025-02-20T21:40:22.658941',
#   'end_time': '2025-02-20T21:45:37.667031',
#   'owner_id': 387},
#  {'id': 4171,
#   'revision_id': 1999,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:17.814282',
#   'start_time': '2025-02-20T21:40:22.041910',
#   'end_time': '2025-02-20T21:46:11.506090',
#   'owner_id': 387},
#  {'id': 4170,
#   'revision_id': 128,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:15.703648',
#   'start_time': '2025-02-20T21:40:21.553501',
#   'end_time': '2025-02-20T21:45:36.850653',
#   'owner_id': 387},
#  {'id': 4169,
#   'revision_id': 126,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:15.698695',
#   'start_time': '2025-02-20T21:40:21.493223',
#   'end_time': '2025-02-20T21:45:36.822926',
#   'owner_id': 387},
#  {'id': 4168,
#   'revision_id': 129,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:15.693926',
#   'start_time': '2025-02-20T21:40:21.160994',
#   'end_time': '2025-02-20T21:45:36.620897',
#   'owner_id': 387},
#  {'id': 4167,
#   'revision_id': 2662,
#   'reference_id': 2663,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:40:15.617251',
#   'start_time': '2025-02-20T21:40:20.645872',
#   'end_time': '2025-02-20T21:46:02.986141',
#   'owner_id': 387},
#  {'id': 4166,
#   'revision_id': 1999,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:05.984432',
#   'start_time': '2025-02-20T21:09:10.027177',
#   'end_time': '2025-02-20T21:33:52.270636',
#   'owner_id': 387},
#  {'id': 4165,
#   'revision_id': 1998,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:05.960160',
#   'start_time': '2025-02-20T21:09:09.891806',
#   'end_time': '2025-02-20T21:17:03.749119',
#   'owner_id': 387},
#  {'id': 4164,
#   'revision_id': 129,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:03.113929',
#   'start_time': '2025-02-20T21:09:09.497660',
#   'end_time': '2025-02-20T21:37:01.799065',
#   'owner_id': 387},
#  {'id': 4163,
#   'revision_id': 126,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:03.018398',
#   'start_time': '2025-02-20T21:09:07.698735',
#   'end_time': '2025-02-20T21:27:46.559692',
#   'owner_id': 387},
#  {'id': 4162,
#   'revision_id': 128,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:03.013584',
#   'start_time': '2025-02-20T21:09:08.111371',
#   'end_time': '2025-02-20T21:27:46.751861',
#   'owner_id': 387},
#  {'id': 4161,
#   'revision_id': 2662,
#   'reference_id': 2661,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T21:09:02.972407',
#   'start_time': '2025-02-20T21:09:08.548738',
#   'end_time': '2025-02-20T21:17:03.610906',
#   'owner_id': 387},
#  {'id': 4160,
#   'revision_id': 2624,
#   'reference_id': 1558,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20T07:55:13.445383',
#   'start_time': '2025-02-20T07:55:19.936602',
#   'end_time': '2025-02-20T08:12:21.820501',
#   'owner_id': 462},
#  {'id': 4159,
#   'revision_id': 102,
#   'reference_id': 1558,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-20

#   'reference_id': 2623,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-13T22:02:19.059939',
#   'start_time': '2025-02-13T22:02:25.049227',
#   'end_time': '2025-02-13T22:05:57.641016',
#   'owner_id': 201},
#  {'id': 4100,
#   'revision_id': 20,
#   'reference_id': 2623,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-13T22:02:19.040331',
#   'start_time': '2025-02-13T22:02:24.621948',
#   'end_time': '2025-02-13T22:06:08.733578',
#   'owner_id': 201},
#  {'id': 4099,
#   'revision_id': 19,
#   'reference_id': 2623,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2025-02-13T22:02:19.026253',
#   'start_time': '2025-02-13T22:02:24.181287',
#   'end_time': '2025-02-13T22:06:18.062964',
#   'owner_id': 201},
#  {'id': 4098,
# ...
#   'status': 'finished',
#   'requested_time': '2024-12-05T15:28:46.299323',
#   'start_time': '2024-12-05T15:28:52.478294',
#   'end_time': '2024-12-05T15:30:29.070247',
#   'owner_id': 341},
#  {'id': 3306,
#   'revision_id': 2243,
#   'reference_id': 2244,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T15:06:07.358675',
#   'start_time': '2024-12-05T15:06:12.992458',
#   'end_time': '2024-12-05T15:08:09.054812',
#   'owner_id': 341},
#  {'id': 3305,
#   'revision_id': 2237,
#   'reference_id': 2238,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T06:44:38.274229',
#   'start_time': '2024-12-05T06:44:42.667885',
#   'end_time': '2024-12-05T06:45:44.638444',
#   'owner_id': 341},
#  {'id': 3304,
#   'revision_id': 2230,
#   'reference_id': 2231,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T06:21:42.752937',
#   'start_time': '2024-12-05T06:21:47.761341',
#   'end_time': '2024-12-05T06:23:11.499490',
#   'owner_id': 341},
#  {'id': 3303,
#   'revision_id': 2223,
#   'reference_id': 2224,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T05:52:22.869590',
#   'start_time': '2024-12-05T05:52:27.728661',
#   'end_time': '2024-12-05T05:54:11.183674',
#   'owner_id': 341},
#  {'id': 3302,
#   'revision_id': 2216,
#   'reference_id': 2217,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T05:19:22.324394',
#   'start_time': '2024-12-05T05:19:26.304193',
#   'end_time': '2024-12-05T05:21:10.357972',
#   'owner_id': 341},
#  {'id': 3301,
#   'revision_id': 2209,
#   'reference_id': 2210,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T04:14:57.626743',
#   'start_time': '2024-12-05T04:15:01.921009',
#   'end_time': '2024-12-05T04:16:39.501144',
#   'owner_id': 341},
#  {'id': 3300,
#   'revision_id': 2202,
#   'reference_id': 2203,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T03:23:44.648526',
#   'start_time': '2024-12-05T03:23:50.473785',
#   'end_time': '2024-12-05T03:25:26.047339',
#   'owner_id': 341},
#  {'id': 3299,
#   'revision_id': 2195,
#   'reference_id': 2196,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T01:55:04.666385',
#   'start_time': '2024-12-05T01:55:10.008480',
#   'end_time': '2024-12-05T01:56:46.092123',
#   'owner_id': 341},
#  {'id': 3298,
#   'revision_id': 2191,
#   'reference_id': 2192,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-05T01:51:01.170839',
#   'start_time': '2024-12-05T01:51:07.541350',
#   'end_time': '2024-12-05T01:52:16.964861',
#   'owner_id': 341},
#  {'id': 3297,
#   'revision_id': 2187,
#   'reference_id': 2188,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-04T21:29:12.242205',
#   'start_time': '2024-12-04T21:29:17.182444',
#   'end_time': '2024-12-04T21:30:47.674341',
#   'owner_id': 341},
#  {'id': 3296,
#   'revision_id': 2181,
#   'reference_id': 2182,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-04T20:05:15.891225',
#   'start_time': '2024-12-04T20:05:21.358408',
#   'end_time': '2024-12-04T20:06:49.327007',
#   'owner_id': 341},
#  {'id': 3295,
#   'revision_id': 2176,
#   'reference_id': 2177,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-04T16:52:30.200956',
#   'start_time': '2024-12-04T16:52:34.785831',
#   'end_time': '2024-12-04T16:54:13.121701',
#   'owner_id': 341},
#  {'id': 3294,
#   'revision_id': 2172,
#   'reference_id': 2173,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-04T16:48:25.880842',
#   'start_time': '2024-12-04T16:48:31.413717',
#   'end_time': '2024-12-04T16:54:12.995440',
#   'owner_id': 341},
#  {'id': 3293,
#   'revision_id': 233,
#   'reference_id': 1592,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-12-03T14:10:58.939266',
#   'start_time': '2024-12-03T14:11:01.077860',
#   'end_time': '2024-12-03T15:00:42.804769',
#   'owner_id': 201},
#  {'id': 3292,
#   'revision_id': 233,
#   'reference_id': 1592,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-03T14:10:54.531299',
#   'start_time': '2024-12-03T14:10:59.638662',
#   'end_time': '2024-12-03T14:31:09.896803',
#   'owner_id': 201},
#  {'id': 3291,
#   'revision_id': 67,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-03T08:30:31.566163',
#   'start_time': '2024-12-03T08:30:37.406274',
#   'end_time': '2024-12-03T08:46:04.816967',
#   'owner_id': 204},
#  {'id': 3290,
#   'revision_id': 315,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:18.718522',
#   'start_time': '2024-12-02T11:23:24.732258',
#   'end_time': '2024-12-02T11:40:06.509777',
#   'owner_id': 204},
#  {'id': 3289,
#   'revision_id': 309,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:18.573475',
#   'start_time': '2024-12-02T11:23:23.653097',
#   'end_time': '2024-12-02T11:40:07.152728',
#   'owner_id': 204},
#  {'id': 3288,
#   'revision_id': 310,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:18.427919',
#   'start_time': '2024-12-02T11:23:23.262300',
#   'end_time': '2024-12-02T11:34:59.369393',
#   'owner_id': 204},
#  {'id': 3287,
#   'revision_id': 68,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:16.189050',
#   'start_time': '2024-12-02T11:23:22.504208',
#   'end_time': '2024-12-02T11:40:06.117445',
#   'owner_id': 204},
#  {'id': 3286,
#   'revision_id': 229,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:16.181813',
#   'start_time': '2024-12-02T11:23:21.977237',
#   'end_time': '2024-12-02T11:41:55.316431',
#   'owner_id': 204},
#  {'id': 3285,
#   'revision_id': 308,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:16.158140',
#   'start_time': '2024-12-02T11:23:21.806487',
#   'end_time': '2024-12-02T11:40:16.527322',
#   'owner_id': 204},
#  {'id': 3284,
#   'revision_id': 2170,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T11:23:15.971744',
#   'start_time': '2024-12-02T11:23:21.073693',
#   'end_time': '2024-12-02T11:39:18.118420',
#   'owner_id': 204},
#  {'id': 3283,
#   'revision_id': 315,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:57.080337',
#   'start_time': '2024-12-02T10:52:00.991695',
#   'end_time': '2024-12-02T11:11:54.029966',
#   'owner_id': 204},
#  {'id': 3282,
#   'revision_id': 310,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:56.922622',
#   'start_time': '2024-12-02T10:52:54.268511',
#   'end_time': '2024-12-02T11:04:50.308647',
#   'owner_id': 204},
#  {'id': 3281,
#   'revision_id': 2170,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:54.505045',
#   'start_time': '2024-12-02T10:51:59.288034',
#   'end_time': '2024-12-02T11:09:08.435674',
#   'owner_id': 204},
#  {'id': 3280,
#   'revision_id': 309,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:54.503072',
#   'start_time': '2024-12-02T10:52:00.378259',
#   'end_time': '2024-12-02T11:09:23.440589',
#   'owner_id': 204},
#  {'id': 3279,
#   'revision_id': 308,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:54.499972',
#   'start_time': '2024-12-02T10:52:00.348919',
#   'end_time': '2024-12-02T11:09:08.501506',
#   'owner_id': 204},
#  {'id': 3278,
#   'revision_id': 68,
#   'reference_id': 127,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-12-02T10:51:54.433016',
#   'start_time': '2024-12-02T10:51:58.173182',
#   'end_time': '2024-12-02T11:08:52.841500',
#   'owner_id': 204},
#  {'id': 3277,
#   'revision_id': 17,
#   'reference_id': 24,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-30T23:00:11.704206',
#   'start_time': '2024-11-30T23:00:18.771351',
#   'end_time': '2024-11-30T23:34:23.155405',
#   'owner_id': 300},
#  {'id': 3276,
#   'revision_id': 19,
#   'reference_id': 24,
#   'type': 'semantic-similarity',
#   'status': 'failed',
#   'requested_time': '2024-11-30T22:49:18.925221',
#   'start_time': '2024-11-30T22:49:24.656104',
#   'end_time': '2024-12-01T00:38:07.740775',
#   'owner_id': 300},
#  {'id': 3275,
#   'revision_id': 2166,
#   'reference_id': 150,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-30T00:18:44.463830',
#   'start_time': '2024-11-30T00:18:50.198132',
#   'end_time': '2024-11-30T01:41:10.526334',
#   'owner_id': 213},
#  {'id': 3274,
#   'revision_id': 16,
#   'reference_id': 150,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-30T00:18:43.084738',
#   'start_time': '2024-11-30T00:18:48.405497',
#   'end_time': '2024-11-30T00:23:46.535615',
#   'owner_id': 213},
#  {'id': 3273,
#   'revision_id': 2166,
#   'reference_id': 150,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-30T00:18:42.908033',
#   'start_time': '2024-11-30T00:18:47.488440',
#   'end_time': '2024-11-30T00:25:54.723306',
#   'owner_id': 213},
#  {'id': 3272,
#   'revision_id': 2168,
#   'reference_id': 21,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:49.335170',
#   'start_time': '2024-11-29T14:48:52.391893',
#   'end_time': '2024-11-29T14:49:07.270155',
#   'owner_id': 204},
#  {'id': 3271,
#   'revision_id': 2169,
#   'reference_id': 21,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:45.991607',
#   'start_time': '2024-11-29T14:48:49.908673',
#   'end_time': '2024-11-29T14:55:11.034555',
#   'owner_id': 204},
#  {'id': 3270,
#   'revision_id': 308,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:43.761821',
#   'start_time': '2024-11-29T14:48:49.526782',
#   'end_time': '2024-11-29T15:13:26.112744',
#   'owner_id': 204},
#  {'id': 3269,
#   'revision_id': 315,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:43.019610',
#   'start_time': '2024-11-29T14:48:49.100400',
#   'end_time': '2024-11-29T15:07:10.596671',
#   'owner_id': 204},
#  {'id': 3268,
#   'revision_id': 310,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:42.934523',
#   'start_time': '2024-11-29T14:48:48.110433',
#   'end_time': '2024-11-29T15:05:12.752489',
#   'owner_id': 204},
#  {'id': 3267,
#   'revision_id': 309,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:40.147911',
#   'start_time': '2024-11-29T14:48:47.494283',
#   'end_time': '2024-11-29T15:07:09.009093',
#   'owner_id': 204},
#  {'id': 3266,
#   'revision_id': 229,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:40.143379',
#   'start_time': '2024-11-29T14:48:48.023846',
#   'end_time': '2024-11-29T15:07:10.086227',
#   'owner_id': 204},
#  {'id': 3265,
#   'revision_id': 2168,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:40.138381',
#   'start_time': '2024-11-29T14:48:46.445248',
#   'end_time': '2024-11-29T14:53:48.684242',
#   'owner_id': 204},
#  {'id': 3264,
#   'revision_id': 68,
#   'reference_id': 21,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-29T14:48:40.069773',
#   'start_time': '2024-11-29T14:48:45.649075',
#   'end_time': '2024-11-29T15:12:06.356672',
#   'owner_id': 204},
#  {'id': 3263,
#   'revision_id': 2167,
#   'reference_id': 19,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-27T19:52:40.965982',
#   'start_time': '2024-11-27T19:52:47.004660',
#   'end_time': '2024-11-27T19:57:40.334522',
#   'owner_id': 437},
#  {'id': 3262,
#   'revision_id': 2166,
#   'reference_id': 160,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:34:07.010746',
#   'start_time': '2024-11-27T04:34:10.426705',
#   'end_time': '2024-11-27T06:08:49.808226',
#   'owner_id': 213},
#  {'id': 3261,
#   'revision_id': 101,
#   'reference_id': 160,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:34:05.951228',
#   'start_time': '2024-11-27T04:34:09.281614',
#   'end_time': '2024-11-27T04:39:57.362830',
#   'owner_id': 213},
#  {'id': 3260,
#   'revision_id': 16,
#   'reference_id': 160,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:34:04.499989',
#   'start_time': '2024-11-27T04:34:08.245523',
#   'end_time': '2024-11-27T04:38:27.555236',
#   'owner_id': 213},
#  {'id': 3259,
#   'revision_id': 2166,
#   'reference_id': 160,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:34:00.047195',
#   'start_time': '2024-11-27T04:34:03.936593',
#   'end_time': '2024-11-27T04:42:17.547682',
#   'owner_id': 213},
#  {'id': 3258,
#   'revision_id': 2166,
#   'reference_id': 16,
#   'type': 'sentence-length',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:27:18.819585',
#   'start_time': '2024-11-27T04:27:25.620005',
#   'end_time': '2024-11-27T04:27:40.767815',
#   'owner_id': 213},
#  {'id': 3257,
#   'revision_id': 2166,
#   'reference_id': 16,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:27:17.750014',
#   'start_time': '2024-11-27T05:48:33.304118',
#   'end_time': '2024-11-27T07:03:11.232652',
#   'owner_id': 213},
#  {'id': 3256,
#   'revision_id': 2166,
#   'reference_id': 16,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-27T04:27:16.426968',
#   'start_time': '2024-11-27T04:27:23.486586',
#   'end_time': '2024-11-27T04:33:14.902236',
#   'owner_id': 213},
#  {'id': 3255,
#   'revision_id': 306,
#   'reference_id': 1592,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-25T20:00:43.390323',
#   'start_time': '2024-11-25T20:00:46.255077',
#   'end_time': '2024-11-25T20:20:56.559843',
#   'owner_id': 115},
#  {'id': 3254,
#   'revision_id': 302,
#   'reference_id': 1592,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:59:30.578956',
#   'start_time': '2024-11-25T19:59:36.033947',
#   'end_time': '2024-11-25T20:33:28.136167',
#   'owner_id': 115},
#  {'id': 3253,
#   'revision_id': 106,
#   'reference_id': 2062,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:48:57.476120',
#   'start_time': '2024-11-25T19:49:00.531612',
#   'end_time': '2024-11-25T20:42:14.353693',
#   'owner_id': 201},
#  {'id': 3252,
#   'revision_id': 106,
#   'reference_id': 2062,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:48:51.968051',
#   'start_time': '2024-11-25T19:48:55.090247',
#   'end_time': '2024-11-25T19:55:02.178359',
#   'owner_id': 201},
#  {'id': 3251,
#   'revision_id': 2046,
#   'reference_id': 2062,
#   'type': 'semantic-similarity',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:44:21.004241',
#   'start_time': '2024-11-25T19:44:31.275559',
#   'end_time': '2024-11-25T20:34:56.097000',
#   'owner_id': 201},
#  {'id': 3250,
#   'revision_id': 233,
#   'reference_id': 2062,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:44:19.912320',
#   'start_time': '2024-11-25T19:44:29.652909',
#   'end_time': '2024-11-25T19:52:44.465550',
#   'owner_id': 201},
#  {'id': 3249,
#   'revision_id': 232,
#   'reference_id': 2062,
#   'type': 'word-alignment',
#   'status': 'finished',
#   'requested_time': '2024-11-25T19:44:19.840871',
#   'start_time': '2024-11-25T19:44:28.372880',
#   'end_time': '2024-11-25T19:52:31.859094',
#   'owner_id': 201},
#  ...]

# %% [markdown]
# ##################################################################

# %% [markdown]
# Create user and group

# %%
new_user_data = {
        "username": "new_user_2",
        "email": "new_user@example.com",
        "is_admin": False,
    }

new_auth_data = {
    "username": "new_user_2",
    "password": "password123",
}

response = requests.post(
        base_url + f"{prefix}/users",
        params=new_user_data,
        data=new_auth_data,
        headers={"Authorization": f"Bearer {admin_token}"},
    )

response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"detail":"Username already registered"}'

# %%
group_data = {
    "name": "new_group",
    "description": "A new group",
}
response = requests.post(
    base_url+f"{prefix}/groups",
    params=group_data,
    headers={"Authorization": f"Bearer {admin_token}"},
)
response
# Out:
# <Response [400]>

# %%
response.text
# Out:
# '{"detail":"Group already exists"}'

# %%
link_data = {
    "username": "new_user",
    "groupname": "new_group",
}
response = requests.post(
    base_url+f"{prefix}/link-user-group",
    params=link_data,
    headers={"Authorization": f"Bearer {admin_token}"},
)
response
# Out:
# <Response [400]>

# %%
response.text
# Out:
# '{"detail":"User is already linked to this group"}'

# %% [markdown]
# Create a revision

# %%
response = requests.post(
    base_url+"latest/token", data={"username": "new_user", "password": "password123"}
)
token = response.json()["access_token"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 4
#       1 response = requests.post(
#       2     base_url+"latest/token", data={"username": "new_user", "password": "password123"}
#       3 )
# ----> 4 token = response.json()["access_token"]
#
# KeyError: 'access_token'

# %%
len(token)
# Out:
# 151

# %%
new_version_data = {
    "name": "New Version",
    "iso_language": "eng",
    "iso_script": "Latn",
    "abbreviation": "NV",
    "rights": "Some Rights",
    "machineTranslation": False,
    "is_reference": True,
}

response = requests.post(
    base_url+f"{prefix}/version",
    json=new_version_data,
    headers={"Authorization": f"Bearer {token}"},
)
version_id =response.json()["id"]
response.json()
# Out:
# {'id': 1727,
#  'name': 'New Version',
#  'iso_language': 'eng',
#  'iso_script': 'Latn',
#  'abbreviation': 'NV',
#  'rights': 'Some Rights',
#  'forward_translation_id': None,
#  'back_translation_id': None,
#  'machineTranslation': False,
#  'owner_id': 382,
#  'group_ids': [],
#  'is_reference': True}

# %% [markdown]
# Update Name

# %%
# Modify name of the version
attr_update = {
    "id": version_id,
    "name": "New Version 2"
    }
response = requests.put(
    base_url+f"{prefix}/version",
    json=attr_update,
    headers={"Authorization": f"Bearer {token}"},
)
version_name = response.json()["name"]
version_name
# Out:
# 'New Version 2'

# %%
print(new_version_data)
# Out:
# {'name': 'New Version', 'iso_language': 'eng', 'iso_script': 'Latn', 'abbreviation': 'NV', 'rights': 'Some Rights', 'machineTranslation': False, 'is_reference': True}

# %%
response.text
# Out:
# '{"name":"New Version 2","iso_language":"eng","abbreviation":"NV","forward_translation_id":null,"machine_translation":false,"deleted":false,"owner_id":382,"id":1727,"iso_script":"Latn","rights":"Some Rights","back_translation_id":null,"is_reference":true,"deletedAt":null}'

# %%
headers = {"Authorization": f"Bearer {admin_token}"}

# %%
test_revision = {
    "version_id": version_id,
    "name": "Test Revision",
}
test_upload_file = Path("../fixtures/uploadtest.txt")

with open(test_upload_file, "rb") as file:
    files = {"file": file}
    response = requests.post(
    base_url + f"{prefix}/revision", params=test_revision, files=files, headers=headers
    )
revision_id =response.json()["id"]
response.json()
# Out:
# {'id': 2652,
#  'bible_version_id': 1727,
#  'version_abbreviation': 'NV',
#  'date': '2025-02-10',
#  'name': 'Test Revision',
#  'published': False,
#  'back_translation_id': None,
#  'machineTranslation': False,
#  'iso_language': 'eng',
#  'is_reference': False}

# %%
response.text
# Out:
# '{"id":2652,"bible_version_id":1727,"version_abbreviation":"NV","date":"2025-02-10","name":"Test Revision","published":false,"back_translation_id":null,"machineTranslation":false,"iso_language":"eng","is_reference":false}'

# %%
response = requests.get(
    base_url+f"{prefix}/revision",
    headers={"Authorization": f"Bearer {token}"},
)
response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 response = requests.get(
#       2     base_url+f"{prefix}/revision",
# ----> 3     headers={"Authorization": f"Bearer {token}"},
#       4 )
#       5 response.json()
#
# NameError: name 'token' is not defined

# %%
response = requests.get(
    base_url+f"{prefix}/version",
    headers={"Authorization": f"Bearer {token}"},
)
response.json()
# Out:
# [{'id': 1168,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1169,
#   'name': 'New Version',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1170,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1171,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1172,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1201,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1206,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1207,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1208,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1209,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1210,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1211,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1212,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1722,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True},
#  {'id': 1727,
#   'name': 'New Version 2',
#   'iso_language': 'eng',
#   'iso_script': 'Latn',
#   'abbreviation': 'NV',
#   'rights': 'Some Rights',
#   'forward_translation_id': None,
#   'back_translation_id': None,
#   'machineTranslation': False,
#   'owner_id': 382,
#   'group_ids': [473],
#   'is_reference': True}]

# %% [markdown]
# Create a new assesment

# %%
assessment_ids = []

assessment_data = ["semantic-similarity", "word-alignment", "sentence-length"]
for assessment in assessment_data:
    data = {"revision_id": revision_id, "reference_id": revision_id, "type": str(assessment)}
    response = requests.post(f"{base_url}v3/assessment", params=data, headers=headers)

    print(response.status_code)
    assessment_ids.append(response.json()[0]["id"])
    print(response.json())
    print(response.text)
# Out:
# 200
# [{'id': 4056, 'revision_id': 2652, 'reference_id': 2652, 'type': 'semantic-similarity', 'status': 'queued', 'requested_time': '2025-02-10T16:36:18.650733', 'start_time': None, 'end_time': None, 'owner_id': 115}]
# [{"id":4056,"revision_id":2652,"reference_id":2652,"type":"semantic-similarity","status":"queued","requested_time":"2025-02-10T16:36:18.650733","start_time":null,"end_time":null,"owner_id":115}]
# 200
# [{'id': 4057, 'revision_id': 2652, 'reference_id': 2652, 'type': 'word-alignment', 'status': 'queued', 'requested_time': '2025-02-10T16:36:20.747111', 'start_time': None, 'end_time': None, 'owner_id': 115}]
# [{"id":4057,"revision_id":2652,"reference_id":2652,"type":"word-alignment","status":"queued","requested_time":"2025-02-10T16:36:20.747111","start_time":null,"end_time":null,"owner_id":115}]
# 200
# [{'id': 4058, 'revision_id': 2652, 'reference_id': 2652, 'type': 'sentence-length', 'status': 'queued', 'requested_time': '2025-02-10T16:36:21.364032', 'start_time': None, 'end_time': None, 'owner_id': 115}]
# [{"id":4058,"revision_id":2652,"reference_id":2652,"type":"sentence-length","status":"queued","requested_time":"2025-02-10T16:36:21.364032","start_time":null,"end_time":null,"owner_id":115}]

# %%
# data = {"revision_id": revision_id, "reference_id": revision_id, "type": "translation-similarity"}
# response = requests.post(f"{base_url}v3/assessment", params=data, headers=headers)

# print(response.status_code)
# print(response.json())
# print(response.text)

# Not working

# %%
for assessment in assessment_ids:
    assessment_id =  assessment
    response_get = requests.get(
        base_url+f"{prefix}/result",
        headers={"Authorization": f"Bearer {admin_token}"},
        params={"assessment_id": assessment_id},
    )
    print(response_get.json())
# Out:
# {'results': [{'id': 61606752, 'assessment_id': 4056, 'vref': 'GEN 1:1', 'source': None, 'target': None, 'score': 0.9999999403953552, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606753, 'assessment_id': 4056, 'vref': 'GEN 1:2', 'source': None, 'target': None, 'score': 1.0, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606754, 'assessment_id': 4056, 'vref': 'GEN 1:3', 'source': None, 'target': None, 'score': 1.0, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}], 'total_count': 3}
# {'results': [{'id': 61606749, 'assessment_id': 4057, 'vref': 'GEN 1:1', 'source': None, 'target': None, 'score': 0.7131190708705357, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606750, 'assessment_id': 4057, 'vref': 'GEN 1:2', 'source': None, 'target': None, 'score': 0.8043554687500001, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606751, 'assessment_id': 4057, 'vref': 'GEN 1:3', 'source': None, 'target': None, 'score': 0.8403878348214285, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}], 'total_count': 3}
# {'results': [{'id': 61606746, 'assessment_id': 4058, 'vref': 'GEN 1:1', 'source': None, 'target': None, 'score': 29.088235294117645, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606747, 'assessment_id': 4058, 'vref': 'GEN 1:2', 'source': None, 'target': None, 'score': 29.088235294117645, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}, {'id': 61606748, 'assessment_id': 4058, 'vref': 'GEN 1:3', 'source': None, 'target': None, 'score': 29.088235294117645, 'flag': False, 'note': None, 'revision_text': None, 'reference_text': None, 'hide': False}], 'total_count': 3}

# %%
data = {"revision_id": revision_id, "reference_id": revision_id, "type":"ngrams"}
response = requests.post(f"{base_url}v3/assessment", params=data, headers=headers)

# %%
print(response.status_code)
print(response.json())
print(response.text)
id = response.json()[0]["id"]
assessment_ids.append(id)
# Out:
# 200
# [{'id': 4059, 'revision_id': 2652, 'reference_id': 2652, 'type': 'ngrams', 'status': 'queued', 'requested_time': '2025-02-10T16:42:15.763301', 'start_time': None, 'end_time': None, 'owner_id': 115}]
# [{"id":4059,"revision_id":2652,"reference_id":2652,"type":"ngrams","status":"queued","requested_time":"2025-02-10T16:42:15.763301","start_time":null,"end_time":null,"owner_id":115}]

# %%
assessment_id =  id
response_get = requests.get(
    base_url+f"{prefix}/result",
    headers={"Authorization": f"Bearer {admin_token}"},
    params={"assessment_id": assessment_id},
)
print(response_get.json())
# Out:
# {'results': [], 'total_count': 0}

# %%
for assessment in assessment_ids:
    assessment_id =  assessment
    response_delete = requests.delete(
        f"{base_url}v3/assessment",
        headers={"Authorization": f"Bearer {admin_token}"},
        params={"assessment_id": assessment_id},
    )
    print(response_delete.json())
# Out:
# {'detail': 'Assessment 4056 deleted successfully'}
# {'detail': 'Assessment 4057 deleted successfully'}
# {'detail': 'Assessment 4058 deleted successfully'}
# {'detail': 'Assessment 4059 deleted successfully'}

# %% [markdown]
# Delete version and revision

# %%
response = requests.delete(
    base_url+f"{prefix}/revision",
    params={"id": revision_id},
    headers={"Authorization": f"Bearer {admin_token}"},
)
response.json()
# Out:
# {'detail': 'Revision 2652 deleted successfully.'}

# %%
response = requests.delete(
    base_url+f"{prefix}/version",
    params={"id": version_id},
    headers={"Authorization": f"Bearer {admin_token}"},
)
response.json()
# Out:
# {'detail': 'Version New Version 2 successfully deleted.'}

# %% [markdown]
# Delete user and group

# %%
# response = requests.delete(
#     base_url+f"{prefix}/users",
#     params={"username": "new_user"},
#     headers={"Authorization": f"Bearer {admin_token}"},
# )
# response
# Out:
# <Response [500]>

# %%
# response.text
# Out:
# 'Internal Server Error'

# %%
# response = requests.delete(
#     base_url+f"{prefix}/groups",
#     params={"groupname": "new_group"},
#     headers={"Authorization": f"Bearer {admin_token}"},
# )
# response
# Out:
# <Response [400]>

# %%
# response.text
# Out:
# '{"detail":"Group is linked to users and cannot be deleted"}'

# %%
# headers = {"Authorization": f"Bearer {admin_token}"}
# response = requests.get(f"{base_url}v3/language", headers=headers)
# assert response.status_code == 200
# assert {"iso639": "eng", "name": "english"} in response.json()
# print(response.json())
